# %% [markdown]
# ## ENVIRONMENT VARIABLES

# %%
EN_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/"

# %%
NAH_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish"

# %%
tokenizer_path = "/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/"

# %%
# %env TOKENIZER_PATH = /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en
# Out:
# env: TOKENIZER_PATH=/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en

# %%
tokenized_path_es_en = "/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en/"
tokenized_path_nah_es = "/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es/"

# %%
# %env TOKENIZED_PATH_ES_EN = /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en
# %env TOKENIZED_PATH_NAH_ES = /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es
# Out:
# env: TOKENIZED_PATH_ES_EN=/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en
# env: TOKENIZED_PATH_NAH_ES=/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es

# %%
# %env BIN_DIR = /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin
# Out:
# env: BIN_DIR=/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin

# %%
! mkdir -p $TOKENIZED_PATH_ES_EN
! mkdir -p $TOKENIZED_PATH_NAH_ES
! mkdir -p $BIN_DIR

# %%
# %env MODEL_DIR = /storage/master-thesis/models/resdrop__nah-es_es-en
# Out:
# env: MODEL_DIR=/storage/master-thesis/models/resdrop__nah-es_es-en

# %%
# %env CODE_STORAGE = /storage/code/
# Out:
# env: CODE_STORAGE=/storage/code/

# %%
! locale
# Out:
# LANG=
# LANGUAGE=
# LC_CTYPE="POSIX"
# LC_NUMERIC="POSIX"
# LC_TIME="POSIX"
# LC_COLLATE="POSIX"
# LC_MONETARY="POSIX"
# LC_MESSAGES="POSIX"
# LC_PAPER="POSIX"
# LC_NAME="POSIX"
# LC_ADDRESS="POSIX"
# LC_TELEPHONE="POSIX"
# LC_MEASUREMENT="POSIX"
# LC_IDENTIFICATION="POSIX"
# LC_ALL=

# %%
! update-locale LANG=en_US.UTF-8 LANGUAGE=en.UTF-8

# %env LANG=en_US.UTF-8
# %env LC_CTYPE=en_US.UTF-8
# %env LC_ALL=en_US.UTF-8
# Out:
# /bin/sh: 1: update-locale: not found
# env: LANG=en_US.UTF-8
# env: LC_CTYPE=en_US.UTF-8
# env: LC_ALL=en_US.UTF-8

# %%
! cat /etc/rc.conf
# Out:
# cat: /etc/rc.conf: No such file or directory

# %% [markdown]
# ## Libraries

# %%
pip install tokenizers==0.10.3
# Out:
# Requirement already satisfied: tokenizers==0.10.3 in /usr/local/lib/python3.6/dist-packages (0.10.3)
# WARNING: You are using pip version 20.2.4; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall torch torchvision torchaudio -y

# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113

# %%
pip uninstall fairseq -y

# %%
pip install fairseq
# Out:
# Requirement already satisfied: fairseq in /usr/local/lib/python3.6/dist-packages (0.10.2)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.3)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.8)
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.6.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.24)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.51.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2020.11.13)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.4.4)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (2.3.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.8.9)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (0.18.2)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from hydra-core->fairseq) (5.2.2)
# Requirement already satisfied: omegaconf==2.1.* in /usr/local/lib/python3.6/dist-packages (from hydra-core->fairseq) (2.1.1)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.6/dist-packages (from hydra-core->fairseq) (4.8)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core->fairseq) (3.4.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.6/dist-packages (from omegaconf==2.1.*->hydra-core->fairseq) (5.4.1)
# WARNING: You are using pip version 20.2.4; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip uninstall apex -y

# %%
rm -r apex

# %%
#! git clone https://github.com/NVIDIA/apex

! pip install -v --disable-pip-version-check --no-cache-dir apex

# %%
pip install tensorboardX

# %% [markdown]
# ## Converting tatoeba format to standard format

# %%
import csv

with open(EN_ES_CORPUS_DIR + "original/valid.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "dev.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "dev.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
    en.close()
    es.close()
    
with open(EN_ES_CORPUS_DIR + "original/dev.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "train.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "train.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        if "\n" in line[2] or "\n" in line[3]:
            continue
        if len(line) != 4:
            continue
            
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
        
    en.close()
    es.close()

# %% [markdown]
# ### Tokenizing data

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece

en_es_nah_tokenizer = Tokenizer(WordPiece(unk_token="[UNK]"))

# %%
from tokenizers.trainers import WordPieceTrainer

en_es_nah_trainer = WordPieceTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"], show_progress=True)

# %%
from tokenizers.pre_tokenizers import Whitespace

en_es_nah_tokenizer.pre_tokenizer = Whitespace()

en_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/{split}.en" for split in ["dev", "train"]]
es_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/{split}.es" for split in ["dev", "train"]]
nah_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/{split}.nah" for split in ["dev", "train"]]
es2_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/{split}.es" for split in ["dev", "train"]]

files = en_files + es_files + es2_files + nah_files
#print(files)
en_es_nah_tokenizer.train(files= files, trainer=en_es_nah_trainer)

# %%
from pathlib import Path



def tokenize_files(tokenizer, files, extension, output_path):
    for file in files:
        print(f"Reading file {file}")
        with open(file, encoding='utf8') as f:
          lines = f.readlines()
          tokenized_lines = tokenizer.encode_batch(lines)
          tokenized_name = Path(file).stem
          tokenized_name = output_path + tokenized_name + "." + extension
          print(tokenized_name)
          with open(tokenized_name, 'w', encoding='utf8') as wf:

            wf.writelines([" ".join(t.tokens) + "\n" for t in tokenized_lines])

# %%
en_es_nah_tokenizer.save(tokenizer_path + "nah-es-en-tokenizer.json")

# %%
print(en_es_nah_tokenizer)
# Out:
# <tokenizers.Tokenizer object at 0x7fea4000f6c0>

# %%
tok = en_es_nah_tokenizer.encode("we hold this truth to be self evidently that everyone is created equal?")
print(tok.tokens)
# Out:
# ['we', 'hold', 'this', 'truth', 'to', 'be', 'self', 'evident', '##ly', 'that', 'everyone', 'is', 'created', 'equal', '?']

# %%
tokenize_files(en_es_nah_tokenizer, en_files, "en", tokenized_path_es_en)
tokenize_files(en_es_nah_tokenizer, es_files, "es", tokenized_path_es_en)

tokenize_files(en_es_nah_tokenizer, nah_files, "nah", tokenized_path_nah_es)
tokenize_files(en_es_nah_tokenizer, es2_files, "es", tokenized_path_nah_es)
# Out:
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.en
# /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en/dev.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/train.en
# /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en/train.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.es
# /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en/dev.es
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/train.es
# /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/dev.nah
# /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es/dev.nah
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/train.nah
# /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es/train.nah
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/dev.es
# /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/train.es
# /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es/train.es

# %% [markdown]
# ## Binarizing data

# %%
### Removing previous dict files
! rm $BIN_DIR/dict.nah.txt
! rm $BIN_DIR/dict.es.txt
! rm $BIN_DIR/dict.en.txt
# Out:
# rm: cannot remove '/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/dict.nah.txt': No such file or directory
# rm: cannot remove '/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/dict.es.txt': No such file or directory
# rm: cannot remove '/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/dict.en.txt': No such file or directory

# %%
## Concatenating all training data
! cat $TOKENIZED_PATH_NAH_ES/train.nah $TOKENIZED_PATH_NAH_ES/train.es $TOKENIZED_PATH_ES_EN/train.es $TOKENIZED_PATH_ES_EN/train.en > $BIN_DIR/train.all

# %%
! fairseq-preprocess --source-lang all \
    --trainpref $BIN_DIR/train \
    --destdir $BIN_DIR \
    --workers 20 \
    --only-source
# Out:
# 2022-09-20 10:08:26 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=True, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='all', srcdict=None, suppress_crashes=False, target_lang=None, task='translation', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/train', use_plasma_view=False, user_dir=None, validpref=None, wandb_project=None, workers=20)
# 2022-09-20 10:08:30 | INFO | fairseq_cli.preprocess | [all] Dictionary: 28912 types
# 2022-09-20 10:08:39 | INFO | fairseq_cli.preprocess | [all] /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/train.all: 426884 sents, 4903897 tokens, 0.0% replaced (by <unk>)
# 2022-09-20 10:08:39 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin

# %%
! fairseq-preprocess --source-lang nah --target-lang es \
    --trainpref $TOKENIZED_PATH_NAH_ES/train --validpref $TOKENIZED_PATH_NAH_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --workers 20
# Out:
# 2022-09-20 10:08:42 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='nah', srcdict='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es/dev', wandb_project=None, workers=20)
# 2022-09-20 10:08:42 | INFO | fairseq_cli.preprocess | [nah] Dictionary: 28912 types
# 2022-09-20 10:08:43 | INFO | fairseq_cli.preprocess | [nah] /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es/train.nah: 16145 sents, 529292 tokens, 0.0% replaced (by <unk>)
# 2022-09-20 10:08:43 | INFO | fairseq_cli.preprocess | [nah] Dictionary: 28912 types
# 2022-09-20 10:08:44 | INFO | fairseq_cli.preprocess | [nah] /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es/dev.nah: 671 sents, 9094 tokens, 0.44% replaced (by <unk>)
# 2022-09-20 10:08:44 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28912 types
# 2022-09-20 10:08:45 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es/train.es: 16145 sents, 544057 tokens, 0.0% replaced (by <unk>)
# 2022-09-20 10:08:45 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28912 types
# 2022-09-20 10:08:45 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/nah-es/dev.es: 671 sents, 8705 tokens, 0.172% replaced (by <unk>)
# 2022-09-20 10:08:45 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin

# %% [markdown]
# ### Reusing es dict from quy-es preprocessing

# %%
! fairseq-preprocess --source-lang es --target-lang en \
    --trainpref $TOKENIZED_PATH_ES_EN/train --validpref $TOKENIZED_PATH_ES_EN/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --workers 20
# Out:
# 2022-09-20 10:08:48 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='es', srcdict='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/dict.all.txt', suppress_crashes=False, target_lang='en', task='translation', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en/dev', wandb_project=None, workers=20)
# 2022-09-20 10:08:49 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28912 types
# 2022-09-20 10:08:57 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en/train.es: 197297 sents, 1874500 tokens, 0.0% replaced (by <unk>)
# 2022-09-20 10:08:57 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28912 types
# 2022-09-20 10:08:58 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en/dev.es: 4643 sents, 51254 tokens, 0.041% replaced (by <unk>)
# 2022-09-20 10:08:58 | INFO | fairseq_cli.preprocess | [en] Dictionary: 28912 types
# 2022-09-20 10:09:01 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en/train.en: 197297 sents, 1956048 tokens, 0.0% replaced (by <unk>)
# 2022-09-20 10:09:01 | INFO | fairseq_cli.preprocess | [en] Dictionary: 28912 types
# 2022-09-20 10:09:02 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/es-en/dev.en: 4643 sents, 53168 tokens, 0.0414% replaced (by <unk>)
# 2022-09-20 10:09:02 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin

# %% [markdown]
# ## Training model

# %%
! cd $CODE_STORAGE

# %%
! git clone https://github.com/dannigt/fairseq.git
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 25231, done.
# remote: Total 25231 (delta 0), reused 0 (delta 0), pack-reused 25231
# Receiving objects: 100% (25231/25231), 19.74 MiB | 16.78 MiB/s, done.
# Resolving deltas: 100% (18304/18304), done.
# Checking out files: 100% (771/771), done.

# %%
cd ..
# Out:
# /

# %%
! fairseq-train $BIN_DIR \
    --user-dir $CODE_STORAGE/fairseq/examples/residual_drop/residual_drop_src/ \
    --arch=residual_drop_transformer --share-all-embeddings \
    --task translation_multi_simple_epoch --lang-pairs nah-es,es-en \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 5e-4 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --dropout 0.3 --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --max-tokens 4096 \
    --restore-file $MODEL_DIR/checkpoint_last.pt \
    --save-dir $MODEL_DIR/ \
    --keep-last-epochs 2 \
    --reset-optimizer \
    --encoder-langtok "src" \
    --decoder-langtok \
    --fp16 \
    --max-epoch 200 \
    --patience 10 \
    --encoder-drop-residual 2
# Out:
# 2022-09-20 11:25:10 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': '/storage/code//fairseq/examples/residual_drop/residual_drop_src/', 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 4096, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 4096, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 200, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.0005], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '/storage/master-thesis/models/resdrop__nah-es_es-en/', 'restore_file': '/storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': True, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': 2, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpo ...
# 2022-09-20 11:25:10 | WARNING | fairseq.data.multilingual.multilingual_data_manager | External language dictionary is not provided; use lang-pairs to infer the set of supported languages. The language ordering is not stable which might cause misalignment in pretraining and finetuning.
# 2022-09-20 11:25:10 | INFO | fairseq.data.multilingual.multilingual_data_manager | inferred language list: ['en', 'es', 'nah']
# 2022-09-20 11:25:10 | INFO | fairseq.data.multilingual.multilingual_data_manager | [nah] dictionary: 28915 types
# 2022-09-20 11:25:11 | INFO | fairseq.data.multilingual.multilingual_data_manager | [es] dictionary: 28915 types
# **************************** False
# **************************** False
# **************************** True
# **************************** False
# **************************** False
# **************************** False
# 2022-09-20 11:25:11 | INFO | fairseq_cli.train | ResidualDropTransformerModel(
#   (encoder): ResidualDropTransformerEncoder(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(28915, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): ResidualDropTransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): ResidualDropTransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): ResidualDropTransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): ResidualDropTransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): ResidualDropTransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): ResidualDropTransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(28915, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=512, out_features=28915, bias=False)
#   )
# )
# 2022-09-20 11:25:11 | INFO | fairseq_cli.train | task: TranslationMultiSimpleEpochTask
# 2022-09-20 11:25:11 | INFO | fairseq_cli.train | model: ResidualDropTransformerModel
# 2022-09-20 11:25:11 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-09-20 11:25:11 | INFO | fairseq_cli.train | num. shared model params: 77,844,992 (num. trained: 77,844,992)
# 2022-09-20 11:25:12 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-09-20 11:25:12 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for valid epoch=1/None
# 2022-09-20 11:25:12 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:25:12 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-20 11:25:12 | INFO | fairseq.data.multilingual.multilingual_data_manager | [valid] num of shards: {'main:nah-es': 1, 'main:es-en': 1}
# 2022-09-20 11:25:12 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:nah-es src_langtok: 28914; tgt_langtok: 28913
# 2022-09-20 11:25:12 | INFO | fairseq.data.data_utils | loaded 671 examples from: /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/valid.nah-es.nah
# 2022-09-20 11:25:12 | INFO | fairseq.data.data_utils | loaded 671 examples from: /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/valid.nah-es.es
# 2022-09-20 11:25:12 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin valid nah-es 671 examples
# 2022-09-20 11:25:12 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:es-en src_langtok: 28913; tgt_langtok: 28912
# 2022-09-20 11:25:12 | INFO | fairseq.data.data_utils | loaded 4,643 examples from: /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/valid.es-en.es
# 2022-09-20 11:25:12 | INFO | fairseq.data.data_utils | loaded 4,643 examples from: /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/valid.es-en.en
# 2022-09-20 11:25:12 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin valid es-en 4643 examples
# 2022-09-20 11:25:17 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.embed_tokens.weight
# 2022-09-20 11:25:17 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.output_projection.weight
# 2022-09-20 11:25:17 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-20 11:25:17 | INFO | fairseq.utils | rank   0: capabilities =  7.5  ; total memory = 15.747 GB ; name = Quadro RTX 5000
# 2022-09-20 11:25:17 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-20 11:25:17 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-09-20 11:25:17 | INFO | fairseq_cli.train | max tokens per device = 4096 and max sentences per device = None
# 2022-09-20 11:25:17 | INFO | fairseq.trainer | Preparing to load checkpoint /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint_last.pt
# 2022-09-20 11:25:18 | INFO | fairseq.trainer | Loaded checkpoint /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint_last.pt (epoch 37 @ 0 updates)
# 2022-09-20 11:25:18 | INFO | fairseq.trainer | loading train data for epoch 37
# 2022-09-20 11:25:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for train epoch=37/None
# 2022-09-20 11:25:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.multilingual_data_manager | [train] num of shards: {'main:nah-es': 1, 'main:es-en': 1}
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:nah-es src_langtok: 28914; tgt_langtok: 28913
# 2022-09-20 11:25:18 | INFO | fairseq.data.data_utils | loaded 16,145 examples from: /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/train.nah-es.nah
# 2022-09-20 11:25:18 | INFO | fairseq.data.data_utils | loaded 16,145 examples from: /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/train.nah-es.es
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin train nah-es 16145 examples
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:es-en src_langtok: 28913; tgt_langtok: 28912
# 2022-09-20 11:25:18 | INFO | fairseq.data.data_utils | loaded 197,297 examples from: /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/train.es-en.es
# 2022-09-20 11:25:18 | INFO | fairseq.data.data_utils | loaded 197,297 examples from: /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin/train.es-en.en
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/resdrop__nah-es_es-en/tokenizers/nah-es-en/bin train es-en 197297 examples
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.multilingual_data_manager | estimated total data sizes of all shards used in sampling ratios: [('main:nah-es', 16145), ('main:es-en', 197297)]. Note that if the data a shard has not been loaded yet, use the max known data size to approximate
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.sampling_method | selected sampler: concat
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Raw sizes: {'main:nah-es': 16145, 'main:es-en': 197297}; raw total size: 213442
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Resampled sizes: {'main:nah-es': 16145, 'main:es-en': 197297}; resampled total size: 213442
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] A concat dataset
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] virtual dataset established time: 0:00:00.021410
# 2022-09-20 11:25:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 11:25:18 | INFO | fairseq.data.multilingual.sampled_multi_dataset | sizes() calling time: 0:00:00.002913
# 2022-09-20 11:25:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.052386
# 2022-09-20 11:25:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:25:18 | WARNING | fairseq.tasks.fairseq_task | 16 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[3456, 779, 2750, 3774, 9221, 879, 5531, 6082, 9703, 4441]
# 2022-09-20 11:25:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.004085
# 2022-09-20 11:25:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:25:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.008216
# 2022-09-20 11:25:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.065515
# 2022-09-20 11:25:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:25:18 | INFO | fairseq.data.iterators | grouped total_num_itrs = 779
# epoch 037:   0%|                                        | 0/779 [00:00<?, ?it/s]2022-09-20 11:25:18 | INFO | fairseq.trainer | begin training epoch 37
# 2022-09-20 11:25:18 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 037:   0%|                                | 1/779 [00:00<02:50,  4.55it/s]2022-09-20 11:25:19 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 037: 100%|9| 778/779 [01:26<00:00,  8.95it/s, loss=2.913, nll_loss=1.106, 2022-09-20 11:26:45 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 11:26:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 11:26:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001782
# 2022-09-20 11:26:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:26:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.048520
# 2022-09-20 11:26:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:26:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.038869
# 2022-09-20 11:26:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.089865
# 2022-09-20 11:26:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 037 | valid on 'valid' subset:   0%|               | 0/26 [00:00<?, ?it/s]
# epoch 037 | valid on 'valid' subset:   8%|5      | 2/26 [00:00<00:01, 19.02it/s]
# epoch 037 | valid on 'valid' subset:  23%|#6     | 6/26 [00:00<00:00, 21.49it/s]
# epoch 037 | valid on 'valid' subset:  38%|##3   | 10/26 [00:00<00:00, 23.49it/s]
# epoch 037 | valid on 'valid' subset:  54%|###2  | 14/26 [00:00<00:00, 25.60it/s]
# epoch 037 | valid on 'valid' subset:  69%|####1 | 18/26 [00:00<00:00, 27.19it/s]
# epoch 037 | valid on 'valid' subset:  85%|##### | 22/26 [00:00<00:00, 28.31it/s]
# epoch 037 | valid on 'valid' subset: 100%|######| 26/26 [00:00<00:00, 30.76it/s]
#                                                                                 2022-09-20 11:26:46 | INFO | valid | epoch 037 | valid on 'valid' subset | loss 4.852 | nll_loss 3.164 | ppl 8.96 | wps 82230.8 | wpb 2584.1 | bsz 204.4 | num_updates 778
# 2022-09-20 11:26:46 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 37 @ 778 updates
# 2022-09-20 11:26:46 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint37.pt
# 2022-09-20 11:26:49 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint37.pt
# 2022-09-20 11:26:53 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint37.pt (epoch 37 @ 778 updates, score 4.852) (writing took 7.389653711812571 seconds)
# 2022-09-20 11:26:54 | INFO | fairseq_cli.train | end of epoch 37 (average epoch stats below)
# 2022-09-20 11:26:54 | INFO | train | epoch 037 | loss 2.907 | nll_loss 1.098 | ppl 2.14 | wps 28066.1 | ups 8.18 | wpb 3433.9 | bsz 274.2 | num_updates 778 | lr 9.725e-05 | gnorm 0.96 | loss_scale 64 | train_wall 85 | gb_free 12.2 | wall 97
# 2022-09-20 11:26:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 11:26:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.054171
# 2022-09-20 11:26:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:26:54 | WARNING | fairseq.tasks.fairseq_task | 16 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[3456, 779, 2750, 3774, 9221, 879, 5531, 6082, 9703, 4441]
# 2022-09-20 11:26:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.004684
# 2022-09-20 11:26:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:26:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.008009
# 2022-09-20 11:26:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.067755
# 2022-09-20 11:26:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:26:54 | INFO | fairseq.data.iterators | grouped total_num_itrs = 779
# epoch 038:   0%|                                        | 0/779 [00:00<?, ?it/s]2022-09-20 11:26:54 | INFO | fairseq.trainer | begin training epoch 38
# 2022-09-20 11:26:54 | INFO | fairseq_cli.train | Start iterating over samples
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f07818ad828>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 038:  13%|1| 104/779 [00:11<01:15,  8.96it/s, loss=2.913, nll_loss=1.106, Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f078b693c88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 038: 100%|9| 778/779 [01:26<00:00,  8.66it/s, loss=3.105, nll_loss=1.321, 2022-09-20 11:28:20 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 11:28:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 11:28:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001669
# 2022-09-20 11:28:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:28:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.047980
# 2022-09-20 11:28:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:28:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.038631
# 2022-09-20 11:28:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.088954
# 2022-09-20 11:28:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 038 | valid on 'valid' subset:   0%|               | 0/26 [00:00<?, ?it/s]
# epoch 038 | valid on 'valid' subset:   8%|5      | 2/26 [00:00<00:01, 16.99it/s]
# epoch 038 | valid on 'valid' subset:  23%|#6     | 6/26 [00:00<00:01, 19.62it/s]
# epoch 038 | valid on 'valid' subset:  38%|##3   | 10/26 [00:00<00:00, 22.04it/s]
# epoch 038 | valid on 'valid' subset:  54%|###2  | 14/26 [00:00<00:00, 24.38it/s]
# epoch 038 | valid on 'valid' subset:  69%|####1 | 18/26 [00:00<00:00, 26.25it/s]
# epoch 038 | valid on 'valid' subset:  85%|##### | 22/26 [00:00<00:00, 27.64it/s]
# epoch 038 | valid on 'valid' subset: 100%|######| 26/26 [00:00<00:00, 30.10it/s]
#                                                                                 2022-09-20 11:28:21 | INFO | valid | epoch 038 | valid on 'valid' subset | loss 4.886 | nll_loss 3.194 | ppl 9.15 | wps 82626 | wpb 2584.1 | bsz 204.4 | num_updates 1557 | best_loss 4.852
# 2022-09-20 11:28:21 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 38 @ 1557 updates
# 2022-09-20 11:28:21 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint38.pt
# 2022-09-20 11:28:25 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint38.pt
# 2022-09-20 11:28:27 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint38.pt (epoch 38 @ 1557 updates, score 4.886) (writing took 5.245841684984043 seconds)
# 2022-09-20 11:28:27 | INFO | fairseq_cli.train | end of epoch 38 (average epoch stats below)
# 2022-09-20 11:28:27 | INFO | train | epoch 038 | loss 2.946 | nll_loss 1.143 | ppl 2.21 | wps 28669.8 | ups 8.35 | wpb 3433.9 | bsz 274 | num_updates 1557 | lr 0.000194625 | gnorm 1.048 | loss_scale 64 | train_wall 85 | gb_free 12.1 | wall 190
# 2022-09-20 11:28:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 11:28:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.054685
# 2022-09-20 11:28:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:28:27 | WARNING | fairseq.tasks.fairseq_task | 16 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[3456, 779, 2750, 3774, 9221, 879, 5531, 6082, 9703, 4441]
# 2022-09-20 11:28:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.004510
# 2022-09-20 11:28:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:28:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.008570
# 2022-09-20 11:28:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.068680
# 2022-09-20 11:28:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:28:27 | INFO | fairseq.data.iterators | grouped total_num_itrs = 779
# epoch 039:   0%|                                        | 0/779 [00:00<?, ?it/s]2022-09-20 11:28:27 | INFO | fairseq.trainer | begin training epoch 39
# 2022-09-20 11:28:27 | INFO | fairseq_cli.train | Start iterating over samples
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781cd69e8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 039:  12%|1| 93/779 [00:10<01:17,  8.81it/s, loss=2.919, nll_loss=1.112, pException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f078b693c88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781d2fb38>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 039:  41%|4| 323/779 [00:35<00:52,  8.71it/s, loss=2.935, nll_loss=1.131, 2022-09-20 11:29:03 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 039: 100%|9| 778/779 [01:26<00:00,  9.06it/s, loss=3.236, nll_loss=1.47, p2022-09-20 11:29:54 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 11:29:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 11:29:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.003201
# 2022-09-20 11:29:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:29:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.054379
# 2022-09-20 11:29:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:29:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.049191
# 2022-09-20 11:29:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.107477
# 2022-09-20 11:29:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 039 | valid on 'valid' subset:   0%|               | 0/26 [00:00<?, ?it/s]
# epoch 039 | valid on 'valid' subset:   8%|5      | 2/26 [00:00<00:01, 16.49it/s]
# epoch 039 | valid on 'valid' subset:  23%|#6     | 6/26 [00:00<00:01, 19.06it/s]
# epoch 039 | valid on 'valid' subset:  35%|##4    | 9/26 [00:00<00:00, 21.40it/s]
# epoch 039 | valid on 'valid' subset:  50%|###   | 13/26 [00:00<00:00, 23.72it/s]
# epoch 039 | valid on 'valid' subset:  65%|###9  | 17/26 [00:00<00:00, 25.73it/s]
# epoch 039 | valid on 'valid' subset:  77%|####6 | 20/26 [00:00<00:00, 26.58it/s]
# epoch 039 | valid on 'valid' subset:  88%|#####3| 23/26 [00:00<00:00, 27.42it/s]
#                                                                                 2022-09-20 11:29:55 | INFO | valid | epoch 039 | valid on 'valid' subset | loss 4.938 | nll_loss 3.248 | ppl 9.5 | wps 79778.9 | wpb 2584.1 | bsz 204.4 | num_updates 2335 | best_loss 4.852
# 2022-09-20 11:29:55 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 39 @ 2335 updates
# 2022-09-20 11:29:55 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint39.pt
# 2022-09-20 11:29:58 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint39.pt
# 2022-09-20 11:30:00 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint39.pt (epoch 39 @ 2335 updates, score 4.938) (writing took 5.0855717330705374 seconds)
# 2022-09-20 11:30:04 | INFO | fairseq_cli.train | end of epoch 39 (average epoch stats below)
# 2022-09-20 11:30:04 | INFO | train | epoch 039 | loss 3.041 | nll_loss 1.248 | ppl 2.38 | wps 27441.9 | ups 7.99 | wpb 3434.7 | bsz 274.3 | num_updates 2335 | lr 0.000291875 | gnorm 1.184 | loss_scale 32 | train_wall 85 | gb_free 12.1 | wall 287
# 2022-09-20 11:30:04 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 11:30:04 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.056146
# 2022-09-20 11:30:04 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:30:04 | WARNING | fairseq.tasks.fairseq_task | 16 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[3456, 779, 2750, 3774, 9221, 879, 5531, 6082, 9703, 4441]
# 2022-09-20 11:30:04 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.004118
# 2022-09-20 11:30:04 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:30:04 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.007779
# 2022-09-20 11:30:04 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.068873
# 2022-09-20 11:30:04 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:30:04 | INFO | fairseq.data.iterators | grouped total_num_itrs = 779
# epoch 040:   0%|                                        | 0/779 [00:00<?, ?it/s]2022-09-20 11:30:04 | INFO | fairseq.trainer | begin training epoch 40
# 2022-09-20 11:30:04 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 040:   9%| | 73/779 [00:08<01:18,  8.96it/s, loss=3.132, nll_loss=1.345, pException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f078b693c88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781d2fb38>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781da4208>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781d9a898>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 040:  46%|4| 357/779 [00:40<00:47,  8.94it/s, loss=3.265, nll_loss=1.493, 2022-09-20 11:30:45 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 16.0
# epoch 040: 100%|9| 778/779 [01:26<00:00,  8.71it/s, loss=3.197, nll_loss=1.425, 2022-09-20 11:31:31 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 11:31:31 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 11:31:31 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001744
# 2022-09-20 11:31:31 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:31:31 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.054564
# 2022-09-20 11:31:31 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:31:31 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.050084
# 2022-09-20 11:31:31 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.107048
# 2022-09-20 11:31:31 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 040 | valid on 'valid' subset:   0%|               | 0/26 [00:00<?, ?it/s]
# epoch 040 | valid on 'valid' subset:   8%|5      | 2/26 [00:00<00:01, 17.98it/s]
# epoch 040 | valid on 'valid' subset:  19%|#3     | 5/26 [00:00<00:01, 20.37it/s]
# epoch 040 | valid on 'valid' subset:  35%|##4    | 9/26 [00:00<00:00, 22.57it/s]
# epoch 040 | valid on 'valid' subset:  50%|###   | 13/26 [00:00<00:00, 24.45it/s]
# ...
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781e8a5f8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781e627b8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781d2f438>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781c389b0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 057: 100%|9| 778/779 [01:26<00:00,  9.15it/s, loss=2.962, nll_loss=1.157, 2022-09-20 11:58:57 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 11:58:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 11:58:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001690
# 2022-09-20 11:58:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:58:58 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.048092
# 2022-09-20 11:58:58 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 11:58:58 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.039018
# 2022-09-20 11:58:58 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.089591
# 2022-09-20 11:58:58 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 057 | valid on 'valid' subset:   0%|               | 0/26 [00:00<?, ?it/s]
# epoch 057 | valid on 'valid' subset:   4%|2      | 1/26 [00:00<00:02,  9.73it/s]
# epoch 057 | valid on 'valid' subset:  15%|#      | 4/26 [00:00<00:01, 12.00it/s]
# epoch 057 | valid on 'valid' subset:  27%|#8     | 7/26 [00:00<00:01, 14.57it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0780171dd8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f085897ab00>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781ed9390>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781e18240>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f07818ade80>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781e4b240>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781ca3240>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781d160b8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781bac978>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781efccf8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781ca3630>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781e8a5f8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781e627b8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781d2f438>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0781c389b0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#
# epoch 057 | valid on 'valid' subset:  35%|##4    | 9/26 [00:00<00:01, 12.57it/s]
# epoch 057 | valid on 'valid' subset:  46%|##7   | 12/26 [00:00<00:00, 15.13it/s]
# epoch 057 | valid on 'valid' subset:  62%|###6  | 16/26 [00:00<00:00, 17.92it/s]
# epoch 057 | valid on 'valid' subset:  77%|####6 | 20/26 [00:00<00:00, 20.51it/s]
# epoch 057 | valid on 'valid' subset:  92%|#####5| 24/26 [00:01<00:00, 22.79it/s]
#                                                                                 2022-09-20 11:58:59 | INFO | valid | epoch 057 | valid on 'valid' subset | loss 4.934 | nll_loss 3.267 | ppl 9.62 | wps 66601.5 | wpb 2584.1 | bsz 204.4 | num_updates 16356 | best_loss 4.817
# 2022-09-20 11:58:59 | INFO | fairseq_cli.train | early stop since valid performance hasn't improved for last 10 runs
# 2022-09-20 11:58:59 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 57 @ 16356 updates
# 2022-09-20 11:58:59 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint57.pt
# 2022-09-20 11:59:02 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint57.pt
# 2022-09-20 11:59:04 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/resdrop__nah-es_es-en/checkpoint57.pt (epoch 57 @ 16356 updates, score 4.934) (writing took 5.143869417952374 seconds)
# 2022-09-20 11:59:04 | INFO | fairseq_cli.train | end of epoch 57 (average epoch stats below)
# 2022-09-20 11:59:04 | INFO | train | epoch 057 | loss 2.869 | nll_loss 1.054 | ppl 2.08 | wps 28607.2 | ups 8.33 | wpb 3433.9 | bsz 274 | num_updates 16356 | lr 0.000247264 | gnorm 1.152 | loss_scale 16 | train_wall 85 | gb_free 12.5 | wall 2027
# 2022-09-20 11:59:04 | INFO | fairseq_cli.train | done training in 2025.8 seconds

# %%
! echo $MODEL_DIR
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
cd /storage/master-thesis/models/quy-es+es-en
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
! rm checkpoint108.pt
! rm checkpoint109.pt
! rm checkpoint_best.pt
! rm checkpoint_last.pt

# %%
! rm dict.en.txt
! rm dict.es.txt
! rm dict.quy.txt

# %%
! du -shc /notebooks/*
# Out:
# 2.5K	/notebooks/CITATION.cff
# 5.5K	/notebooks/CODE_OF_CONDUCT.md
# 15K	/notebooks/CONTRIBUTING.md
# 19K	/notebooks/ISSUES.md
# 12K	/notebooks/LICENSE
# 512	/notebooks/MANIFEST.in
# 3.5K	/notebooks/Makefile
# 41K	/notebooks/README.md
# 41K	/notebooks/README_zh-hans.md
# 42K	/notebooks/README_zh-hant.md
# 12K	/notebooks/docker
# 4.6M	/notebooks/docs
# 5.0M	/notebooks/examples
# 8.5K	/notebooks/hubconf.py
# 7.8G	/notebooks/master-thesis
# 1.5K	/notebooks/model_cards
# 9.5K	/notebooks/notebooks
# 512	/notebooks/pyproject.toml
# 64K	/notebooks/scripts
# 1.0K	/notebooks/setup.cfg
# 13K	/notebooks/setup.py
# 13M	/notebooks/src
# 731K	/notebooks/templates
# 4.5K	/notebooks/test quy-es -> es-en model.ipynb
# 6.8M	/notebooks/tests
# 147K	/notebooks/train es-en model.ipynb
# 158K	/notebooks/train quy-es + es-en model.ipynb
# 160K	/notebooks/utils
# 3.5K	/notebooks/valohai.yaml
# 7.9G	total

# %%
! du -shc /notebooks/master-thesis/*
# Out:
# 512	/notebooks/master-thesis/Untitled.ipynb
# 362M	/notebooks/master-thesis/corpora
# 7.5G	/notebooks/master-thesis/models
# 7.8G	total

# %%
! du -shc /notebooks/master-thesis/models/*
# Out:
# 1.6G	/notebooks/master-thesis/models/es-en
# 802M	/notebooks/master-thesis/models/quy-es
# 5.2G	/notebooks/master-thesis/models/quy-es+es-en
# 7.5G	total

# %%
! du -shc /*
# Out:
# 19M	/apex
# 5.0M	/bin
# 4.0K	/boot
# 24K	/content
# ^C

# %%
ls
# Out:
#  CITATION.cff         docker/          setup.py
#  CODE_OF_CONDUCT.md   docs/            src/
#  CONTRIBUTING.md      examples/        templates/
#  ISSUES.md            hubconf.py      'test quy-es -> es-en model.ipynb'
#  LICENSE              master-thesis/   tests/
#  MANIFEST.in          model_cards/    'train es-en model.ipynb'
#  Makefile             notebooks/      'train quy-es + es-en model.ipynb'
#  README.md            pyproject.toml   utils/
#  README_zh-hans.md    scripts/         valohai.yaml
#  README_zh-hant.md    setup.cfg

# %%
# Out:
# /storage/master-thesis
