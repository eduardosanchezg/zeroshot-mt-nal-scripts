# %% [markdown]
# ## ENVIRONMENT VARIABLES

# %%
EN_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/"

# %%
tokenizer_path = "/storage/master-thesis/models/es-en/tokenizers/es-en/"

# %%
# %env TOKENIZER_PATH = /storage/master-thesis/models/es-en/tokenizers/es-en
# Out:
# env: TOKENIZER_PATH=/storage/master-thesis/models/es-en/tokenizers/es-en

# %%
tokenized_path_es_en = "/storage/master-thesis/models/es-en/tokenizers/es-en/es-en/"

# %%
# %env TOKENIZED_PATH_ES_EN = /storage/master-thesis/models/es-en/tokenizers/es-en/es-en
# Out:
# env: TOKENIZED_PATH_ES_EN=/storage/master-thesis/models/es-en/tokenizers/es-en/es-en

# %%
# %env BIN_DIR = /storage/master-thesis/models/es-en/tokenizers/es-en/bin
# Out:
# env: BIN_DIR=/storage/master-thesis/models/es-en/tokenizers/es-en/bin

# %%
# %env MODEL_DIR = /storage/master-thesis/models/es-en
# Out:
# env: MODEL_DIR=/storage/master-thesis/models/es-en

# %%
! mkdir -p $TOKENIZED_PATH_ES_EN
! mkdir -p $BIN_DIR

# %%
! locale
# Out:
# locale: Cannot set LC_CTYPE to default locale: No such file or directory
# locale: Cannot set LC_MESSAGES to default locale: No such file or directory
# locale: Cannot set LC_ALL to default locale: No such file or directory
# LANG=en_US.UTF-8
# LANGUAGE=
# LC_CTYPE="en_US.UTF-8"
# LC_NUMERIC="en_US.UTF-8"
# LC_TIME="en_US.UTF-8"
# LC_COLLATE="en_US.UTF-8"
# LC_MONETARY="en_US.UTF-8"
# LC_MESSAGES="en_US.UTF-8"
# LC_PAPER="en_US.UTF-8"
# LC_NAME="en_US.UTF-8"
# LC_ADDRESS="en_US.UTF-8"
# LC_TELEPHONE="en_US.UTF-8"
# LC_MEASUREMENT="en_US.UTF-8"
# LC_IDENTIFICATION="en_US.UTF-8"
# LC_ALL=en_US.UTF-8

# %%
! update-locale LANG=en_US.UTF-8 LANGUAGE=en.UTF-8

# %env LANG=en_US.UTF-8
# %env LC_CTYPE=en_US.UTF-8
# %env LC_ALL=en_US.UTF-8
# Out:
# /bin/sh: 1: update-locale: not found
# env: LANG=en_US.UTF-8
# env: LC_CTYPE=en_US.UTF-8
# env: LC_ALL=en_US.UTF-8

# %% [markdown]
# ## Libraries

# %%
pip install tokenizers==0.10.3
# Out:
# Requirement already satisfied: tokenizers==0.10.3 in /usr/local/lib/python3.6/dist-packages (0.10.3)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 1.9.1
# Uninstalling torch-1.9.1:
#   Successfully uninstalled torch-1.9.1
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (1821.5 MB)
#      |################################| 1821.5 MB 7.6 kB/s  eta 0:00:01K     |#######                         | 449.6 MB 46.7 MB/s eta 0:00:30     |############                    | 723.3 MB 51.0 MB/s eta 0:00:22     |##############                  | 842.8 MB 17.4 MB/s eta 0:00:57     |##########################      | 1482.4 MB 44.6 MB/s eta 0:00:08 MB 48.0 MB/s eta 0:00:06     |############################### | 1817.8 MB 79.9 MB/s eta 0:00:01
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.11.3%2Bcu113-cp36-cp36m-linux_x86_64.whl (24.6 MB)
#      |################################| 24.6 MB 40.2 MB/s eta 0:00:01
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (2.9 MB)
#      |################################| 2.9 MB 54.9 MB/s eta 0:00:01
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from torchvision) (8.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.18.5)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.10.2+cu113 torchaudio-0.10.2+cu113 torchvision-0.11.3+cu113
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall fairseq -y
# Out:
# Found existing installation: fairseq 0.10.2
# Uninstalling fairseq-0.10.2:
#   Successfully uninstalled fairseq-0.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fairseq # --no-deps
# Out:
# Collecting fairseq
#   Downloading fairseq-0.12.2-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.0 MB)
#      |################################| 11.0 MB 7.1 MB/s eta 0:00:01
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.10.2+cu113)
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.10.2+cu113)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.8)
# Requirement already satisfied: numpy<1.20.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Collecting bitarray
#   Downloading bitarray-2.6.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (235 kB)
#      |################################| 235 kB 110.1 MB/s eta 0:00:01
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.24)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.51.0)
# Collecting omegaconf<2.1
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2020.11.13)
# Collecting hydra-core<1.1,>=1.0.7
#   Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#      |################################| 123 kB 104.9 MB/s eta 0:00:01
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (3.10.0.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (2.3.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.4.4)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.8.9)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.6/dist-packages (from omegaconf<2.1->fairseq) (5.4.1)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (4.8)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (5.2.2)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core<1.1,>=1.0.7->fairseq) (3.4.0)
# Installing collected packages: bitarray, omegaconf, hydra-core, fairseq
#   Attempting uninstall: omegaconf
#     Found existing installation: omegaconf 2.1.1
#     Uninstalling omegaconf-2.1.1:
#       Successfully uninstalled omegaconf-2.1.1
#   Attempting uninstall: hydra-core
#     Found existing installation: hydra-core 1.1.1
#     Uninstalling hydra-core-1.1.1:
#       Successfully uninstalled hydra-core-1.1.1
# Successfully installed bitarray-2.6.0 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip uninstall apex -y
# Out:
# Found existing installation: apex 0.1
# Uninstalling apex-0.1:
#   Successfully uninstalled apex-0.1

# %%
rm -r apex
# Out:
# rm: cannot remove 'apex': No such file or directory

# %%
#! git clone https://github.com/NVIDIA/apex

! pip install -v --disable-pip-version-check --no-cache-dir apex

# %%
pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |################################| 125 kB 31.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.5)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.13.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (50.3.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5.1
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Converting tatoeba format to standard format

# %%
import csv

with open(EN_ES_CORPUS_DIR + "original/valid.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "dev.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "dev.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
    en.close()
    es.close()
    
with open(EN_ES_CORPUS_DIR + "original/dev.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "train.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "train.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        if "\n" in line[2] or "\n" in line[3]:
            continue
        if len(line) != 4:
            continue
            
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
        
    en.close()
    es.close()

# %% [markdown]
# ### Tokenizing data

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece

en_es_tokenizer = Tokenizer(WordPiece(unk_token="[UNK]"))

# %%
from tokenizers.trainers import WordPieceTrainer

en_es_trainer = WordPieceTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"], show_progress=True)

# %%
from tokenizers.pre_tokenizers import Whitespace

en_es_tokenizer.pre_tokenizer = Whitespace()

en_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/{split}.en" for split in ["dev", "train"]]
es_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/{split}.es" for split in ["dev", "train"]]

files = en_files + es_files
#print(files)
en_es_tokenizer.train(files= files, trainer=en_es_trainer)

# %%
# ! cat /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.en

# %%
from pathlib import Path



def tokenize_files(tokenizer, files, extension, output_path):
    for file in files:
        print(f"Reading file {file}")
        with open(file, encoding='utf8') as f:
          lines = f.readlines()
          tokenized_lines = tokenizer.encode_batch(lines)
          tokenized_name = Path(file).stem
          tokenized_name = output_path + tokenized_name + "." + extension
          print(tokenized_name)
          with open(tokenized_name, 'w', encoding='utf8') as wf:

            wf.writelines([" ".join(t.tokens) + "\n" for t in tokenized_lines])

# %%
en_es_tokenizer.save(tokenizer_path + "aym-es-en-tokenizer.json")

# %%
print(en_es_tokenizer)
# Out:
# <tokenizers.Tokenizer object at 0x7fd540109f90>

# %%
tok = en_es_tokenizer.encode("we hold this truth to be self evidentely that everyones is created equal?")
print(tok.tokens)
# Out:
# ['we', 'hold', 'this', 'truth', 'to', 'be', 'self', 'evidente', '##ly', 'that', 'everyone', '##s', 'is', 'created', 'equal', '?']

# %%
tokenize_files(en_es_tokenizer, en_files, "en", tokenized_path_es_en)
tokenize_files(en_es_tokenizer, es_files, "es", tokenized_path_es_en)
# Out:
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.en
# /storage/master-thesis/models/es-en/tokenizers/es-en/es-en/dev.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/train.en
# /storage/master-thesis/models/es-en/tokenizers/es-en/es-en/train.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.es
# /storage/master-thesis/models/es-en/tokenizers/es-en/es-en/dev.es
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/train.es
# /storage/master-thesis/models/es-en/tokenizers/es-en/es-en/train.es

# %% [markdown]
# ## Binarizing data

# %%
### Removing previous dict files
! rm $BIN_DIR/dict.es.txt
! rm $BIN_DIR/dict.en.txt
# Out:
# rm: cannot remove '/storage/master-thesis/models/es-en/tokenizers/es-en/bin/dict.es.txt': No such file or directory
# rm: cannot remove '/storage/master-thesis/models/es-en/tokenizers/es-en/bin/dict.en.txt': No such file or directory

# %%
## Concatenating all training data
#! cat $TOKENIZED_PATH_AYM_ES/train.aym $TOKENIZED_PATH_AYM_ES/train.es $TOKENIZED_PATH_ES_EN/train.es $TOKENIZED_PATH_ES_EN/train.en > $BIN_DIR/train.all

# %%
ls

# %%
! echo $BIN_DIR

# %% [markdown]
# ### Reusing es dict from aym-es preprocessing

# %%
! fairseq-preprocess --source-lang es --target-lang en \
    --trainpref $TOKENIZED_PATH_ES_EN/train --validpref $TOKENIZED_PATH_ES_EN/dev \
    --destdir $BIN_DIR \
    --workers 20
# Out:
# 2022-09-20 20:42:02 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/es-en/tokenizers/es-en/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='es', srcdict=None, suppress_crashes=False, target_lang='en', task='translation', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/es-en/tokenizers/es-en/es-en/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/es-en/tokenizers/es-en/es-en/dev', wandb_project=None, workers=20)
# 2022-09-20 20:42:05 | INFO | fairseq_cli.preprocess | [es] Dictionary: 20112 types
# 2022-09-20 20:42:08 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/es-en/tokenizers/es-en/es-en/train.es: 197297 sents, 1840181 tokens, 0.0% replaced (by <unk>)
# 2022-09-20 20:42:08 | INFO | fairseq_cli.preprocess | [es] Dictionary: 20112 types
# 2022-09-20 20:42:08 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/es-en/tokenizers/es-en/es-en/dev.es: 4643 sents, 50017 tokens, 0.384% replaced (by <unk>)
# 2022-09-20 20:42:08 | INFO | fairseq_cli.preprocess | [en] Dictionary: 14800 types
# 2022-09-20 20:42:11 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/es-en/tokenizers/es-en/es-en/train.en: 197297 sents, 1928820 tokens, 0.0% replaced (by <unk>)
# 2022-09-20 20:42:11 | INFO | fairseq_cli.preprocess | [en] Dictionary: 14800 types
# 2022-09-20 20:42:12 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/es-en/tokenizers/es-en/es-en/dev.en: 4643 sents, 52151 tokens, 0.288% replaced (by <unk>)
# 2022-09-20 20:42:12 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/es-en/tokenizers/es-en/bin

# %% [markdown]
# ## Training model

# %%
! fairseq-train $BIN_DIR \
    --arch=transformer \
    --task translation_multi_simple_epoch --lang-pairs es-en \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 5e-4 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --dropout 0.3 --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --max-tokens 4096 \
    --restore-file $MODEL_DIR/checkpoint_last.pt \
    --save-dir $MODEL_DIR/ \
    --keep-last-epochs 2 \
    --reset-optimizer \
    --encoder-langtok "src" \
    --decoder-langtok \
    --fp16 \
    --max-epoch 200 \
    --patience 10
# Out:
# 2022-09-20 20:43:27 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 4096, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 4096, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 200, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.0005], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '/storage/master-thesis/models/es-en/', 'restore_file': '/storage/master-thesis/models/es-en/checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': True, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': 2, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': 10, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'loa ...
# 2022-09-20 20:43:27 | WARNING | fairseq.data.multilingual.multilingual_data_manager | External language dictionary is not provided; use lang-pairs to infer the set of supported languages. The language ordering is not stable which might cause misalignment in pretraining and finetuning.
# 2022-09-20 20:43:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | inferred language list: ['en', 'es']
# 2022-09-20 20:43:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | [es] dictionary: 20114 types
# 2022-09-20 20:43:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | [en] dictionary: 14802 types
# 2022-09-20 20:43:28 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(20114, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(14802, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=512, out_features=14802, bias=False)
#   )
# )
# 2022-09-20 20:43:28 | INFO | fairseq_cli.train | task: TranslationMultiSimpleEpochTask
# 2022-09-20 20:43:28 | INFO | fairseq_cli.train | model: TransformerModel
# 2022-09-20 20:43:28 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-09-20 20:43:28 | INFO | fairseq_cli.train | num. shared model params: 88,496,128 (num. trained: 88,496,128)
# 2022-09-20 20:43:28 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-09-20 20:43:28 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for valid epoch=1/None
# 2022-09-20 20:43:28 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:43:28 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-20 20:43:28 | INFO | fairseq.data.multilingual.multilingual_data_manager | [valid] num of shards: {'main:es-en': 1}
# 2022-09-20 20:43:28 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:es-en src_langtok: 20113; tgt_langtok: 14800
# 2022-09-20 20:43:28 | INFO | fairseq.data.data_utils | loaded 4,643 examples from: /storage/master-thesis/models/es-en/tokenizers/es-en/bin/valid.es-en.es
# 2022-09-20 20:43:28 | INFO | fairseq.data.data_utils | loaded 4,643 examples from: /storage/master-thesis/models/es-en/tokenizers/es-en/bin/valid.es-en.en
# 2022-09-20 20:43:28 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/es-en/tokenizers/es-en/bin valid es-en 4643 examples
# 2022-09-20 20:43:33 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-20 20:43:33 | INFO | fairseq.utils | rank   0: capabilities =  8.6  ; total memory = 15.740 GB ; name = RTX A4000
# 2022-09-20 20:43:33 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-20 20:43:33 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-09-20 20:43:33 | INFO | fairseq_cli.train | max tokens per device = 4096 and max sentences per device = None
# 2022-09-20 20:43:33 | INFO | fairseq.trainer | Preparing to load checkpoint /storage/master-thesis/models/es-en/checkpoint_last.pt
# 2022-09-20 20:43:33 | INFO | fairseq.trainer | No existing checkpoint found /storage/master-thesis/models/es-en/checkpoint_last.pt
# 2022-09-20 20:43:33 | INFO | fairseq.trainer | loading train data for epoch 1
# 2022-09-20 20:43:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for train epoch=1/None
# 2022-09-20 20:43:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:43:33 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-20 20:43:33 | INFO | fairseq.data.multilingual.multilingual_data_manager | [train] num of shards: {'main:es-en': 1}
# 2022-09-20 20:43:33 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:es-en src_langtok: 20113; tgt_langtok: 14800
# 2022-09-20 20:43:33 | INFO | fairseq.data.data_utils | loaded 197,297 examples from: /storage/master-thesis/models/es-en/tokenizers/es-en/bin/train.es-en.es
# 2022-09-20 20:43:33 | INFO | fairseq.data.data_utils | loaded 197,297 examples from: /storage/master-thesis/models/es-en/tokenizers/es-en/bin/train.es-en.en
# 2022-09-20 20:43:33 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/es-en/tokenizers/es-en/bin train es-en 197297 examples
# 2022-09-20 20:43:33 | INFO | fairseq.data.multilingual.multilingual_data_manager | estimated total data sizes of all shards used in sampling ratios: [('main:es-en', 197297)]. Note that if the data a shard has not been loaded yet, use the max known data size to approximate
# 2022-09-20 20:43:33 | INFO | fairseq.data.multilingual.sampling_method | selected sampler: concat
# 2022-09-20 20:43:33 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Raw sizes: {'main:es-en': 197297}; raw total size: 197297
# 2022-09-20 20:43:33 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Resampled sizes: {'main:es-en': 197297}; resampled total size: 197297
# 2022-09-20 20:43:33 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] A concat dataset
# 2022-09-20 20:43:33 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] virtual dataset established time: 0:00:00.013821
# 2022-09-20 20:43:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 20:43:33 | INFO | fairseq.data.multilingual.sampled_multi_dataset | sizes() calling time: 0:00:00.002251
# 2022-09-20 20:43:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.040850
# 2022-09-20 20:43:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:43:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.001561
# 2022-09-20 20:43:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:43:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.004670
# 2022-09-20 20:43:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.047864
# 2022-09-20 20:43:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:43:34 | INFO | fairseq.data.iterators | grouped total_num_itrs = 566
# epoch 001:   0%|                                        | 0/566 [00:00<?, ?it/s]2022-09-20 20:43:34 | INFO | fairseq.trainer | begin training epoch 1
# 2022-09-20 20:43:34 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 001:   0%|                                | 1/566 [00:00<01:32,  6.10it/s]2022-09-20 20:43:34 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 001:   4%|#2                             | 22/566 [00:02<00:53, 10.13it/s]2022-09-20 20:43:36 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 001: 100%|9| 564/566 [00:54<00:00,  9.93it/s, loss=7.69, nll_loss=6.743, p2022-09-20 20:44:29 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 20:44:29 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 20:44:29 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001238
# 2022-09-20 20:44:29 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:44:29 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.032595
# 2022-09-20 20:44:29 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:44:29 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.026526
# 2022-09-20 20:44:29 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.061087
# 2022-09-20 20:44:29 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 001 | valid on 'valid' subset:   0%|               | 0/21 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:  14%|#      | 3/21 [00:00<00:00, 23.77it/s]
# epoch 001 | valid on 'valid' subset:  33%|##3    | 7/21 [00:00<00:00, 26.78it/s]
# epoch 001 | valid on 'valid' subset:  52%|###1  | 11/21 [00:00<00:00, 29.71it/s]
# epoch 001 | valid on 'valid' subset:  71%|####2 | 15/21 [00:00<00:00, 31.86it/s]
# epoch 001 | valid on 'valid' subset:  90%|#####4| 19/21 [00:00<00:00, 33.66it/s]
#                                                                                 2022-09-20 20:44:30 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 7.608 | nll_loss 6.575 | ppl 95.33 | wps 104398 | wpb 2704.5 | bsz 221.1 | num_updates 564
# 2022-09-20 20:44:30 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 564 updates
# 2022-09-20 20:44:30 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en/checkpoint1.pt
# 2022-09-20 20:44:32 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en/checkpoint1.pt
# 2022-09-20 20:44:37 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en/checkpoint1.pt (epoch 1 @ 564 updates, score 7.608) (writing took 7.308953151921742 seconds)
# 2022-09-20 20:44:37 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2022-09-20 20:44:37 | INFO | train | epoch 001 | loss 9.013 | nll_loss 8.283 | ppl 311.54 | wps 33538 | ups 8.93 | wpb 3755.3 | bsz 348 | num_updates 564 | lr 7.05e-05 | gnorm 3.111 | loss_scale 32 | train_wall 54 | gb_free 12.7 | wall 63
# 2022-09-20 20:44:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 20:44:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.044242
# 2022-09-20 20:44:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:44:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.002193
# 2022-09-20 20:44:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:44:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.005353
# 2022-09-20 20:44:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.052780
# 2022-09-20 20:44:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:44:37 | INFO | fairseq.data.iterators | grouped total_num_itrs = 566
# epoch 002:   0%|                                        | 0/566 [00:00<?, ?it/s]2022-09-20 20:44:37 | INFO | fairseq.trainer | begin training epoch 2
# 2022-09-20 20:44:37 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 002:  13%|1| 73/566 [00:07<00:49, 10.03it/s, loss=7.191, nll_loss=6.168, pException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1bb8f74c88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1c86101a20>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 002: 100%|9| 564/566 [00:55<00:00, 10.20it/s, loss=6.283, nll_loss=5.123, 2022-09-20 20:45:33 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 20:45:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 20:45:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.003755
# 2022-09-20 20:45:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:45:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.031338
# 2022-09-20 20:45:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:45:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.025410
# 2022-09-20 20:45:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.061017
# 2022-09-20 20:45:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 002 | valid on 'valid' subset:   0%|               | 0/21 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:  14%|#      | 3/21 [00:00<00:00, 24.55it/s]
# epoch 002 | valid on 'valid' subset:  33%|##3    | 7/21 [00:00<00:00, 27.55it/s]
# epoch 002 | valid on 'valid' subset:  52%|###1  | 11/21 [00:00<00:00, 30.38it/s]
# epoch 002 | valid on 'valid' subset:  71%|####2 | 15/21 [00:00<00:00, 32.46it/s]
# epoch 002 | valid on 'valid' subset:  90%|#####4| 19/21 [00:00<00:00, 34.34it/s]
#                                                                                 2022-09-20 20:45:34 | INFO | valid | epoch 002 | valid on 'valid' subset | loss 6.612 | nll_loss 5.406 | ppl 42.41 | wps 106206 | wpb 2704.5 | bsz 221.1 | num_updates 1130 | best_loss 6.612
# 2022-09-20 20:45:34 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 2 @ 1130 updates
# 2022-09-20 20:45:34 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en/checkpoint2.pt
# 2022-09-20 20:45:37 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en/checkpoint2.pt
# 2022-09-20 20:45:39 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en/checkpoint2.pt (epoch 2 @ 1130 updates, score 6.612) (writing took 5.550670273019932 seconds)
# 2022-09-20 20:45:39 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2022-09-20 20:45:39 | INFO | train | epoch 002 | loss 6.561 | nll_loss 5.441 | ppl 43.46 | wps 33945.2 | ups 9.04 | wpb 3756.4 | bsz 348.6 | num_updates 1130 | lr 0.00014125 | gnorm 1.987 | loss_scale 32 | train_wall 55 | gb_free 12.6 | wall 126
# 2022-09-20 20:45:39 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 20:45:40 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.039950
# 2022-09-20 20:45:40 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:45:40 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.001710
# 2022-09-20 20:45:40 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:45:40 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.004515
# 2022-09-20 20:45:40 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.046882
# 2022-09-20 20:45:40 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:45:40 | INFO | fairseq.data.iterators | grouped total_num_itrs = 566
# epoch 003:   0%|                                        | 0/566 [00:00<?, ?it/s]2022-09-20 20:45:40 | INFO | fairseq.trainer | begin training epoch 3
# 2022-09-20 20:45:40 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 003:  12%|###6                           | 66/566 [00:06<00:50,  9.96it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1bb8f74c88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1c86101a20>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f627208>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f274160>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 003: 100%|9| 565/566 [00:56<00:00,  9.55it/s, loss=5.48, nll_loss=4.202, p2022-09-20 20:46:36 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 20:46:36 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 20:46:36 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.002772
# 2022-09-20 20:46:36 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:46:36 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.030869
# 2022-09-20 20:46:36 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:46:36 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.025514
# 2022-09-20 20:46:36 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.059731
# 2022-09-20 20:46:36 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 003 | valid on 'valid' subset:   0%|               | 0/21 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:   5%|3      | 1/21 [00:00<00:02,  9.90it/s]
# epoch 003 | valid on 'valid' subset:  24%|#6     | 5/21 [00:00<00:01, 12.71it/s]
# epoch 003 | valid on 'valid' subset:  43%|###    | 9/21 [00:00<00:00, 15.90it/s]
# epoch 003 | valid on 'valid' subset:  67%|####  | 14/21 [00:00<00:00, 19.48it/s]
# epoch 003 | valid on 'valid' subset:  86%|#####1| 18/21 [00:00<00:00, 22.90it/s]
#                                                                                 2022-09-20 20:46:37 | INFO | valid | epoch 003 | valid on 'valid' subset | loss 6.02 | nll_loss 4.715 | ppl 26.27 | wps 107008 | wpb 2704.5 | bsz 221.1 | num_updates 1696 | best_loss 6.02
# 2022-09-20 20:46:37 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 3 @ 1696 updates
# 2022-09-20 20:46:37 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en/checkpoint3.pt
# 2022-09-20 20:46:45 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en/checkpoint3.pt
# 2022-09-20 20:46:47 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en/checkpoint3.pt (epoch 3 @ 1696 updates, score 6.02) (writing took 10.393008787068538 seconds)
# 2022-09-20 20:46:47 | INFO | fairseq_cli.train | end of epoch 3 (average epoch stats below)
# 2022-09-20 20:46:47 | INFO | train | epoch 003 | loss 5.716 | nll_loss 4.473 | ppl 22.21 | wps 31262.7 | ups 8.32 | wpb 3756.4 | bsz 348.6 | num_updates 1696 | lr 0.000212 | gnorm 1.577 | loss_scale 32 | train_wall 55 | gb_free 12.7 | wall 194
# 2022-09-20 20:46:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 20:46:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.041375
# 2022-09-20 20:46:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:46:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.001767
# 2022-09-20 20:46:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:46:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.004668
# 2022-09-20 20:46:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.048634
# 2022-09-20 20:46:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:46:48 | INFO | fairseq.data.iterators | grouped total_num_itrs = 566
# epoch 004:   0%|                                        | 0/566 [00:00<?, ?it/s]2022-09-20 20:46:48 | INFO | fairseq.trainer | begin training epoch 4
# 2022-09-20 20:46:48 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 004:   6%| | 35/566 [00:03<00:53,  9.89it/s, loss=5.486, nll_loss=4.209, pException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1bb8f74c88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1c86101a20>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f627208>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f274160>>
# Traceback (most recent call last):
# epoch 004:   6%| | 36/566 [00:03<00:53,  9.84it/s, loss=5.486, nll_loss=4.209, p  File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f5a64a8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 004: 100%|9| 565/566 [00:56<00:00,  9.83it/s, loss=4.848, nll_loss=3.474, 2022-09-20 20:47:44 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 20:47:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 20:47:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.002813
# 2022-09-20 20:47:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:47:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.030648
# 2022-09-20 20:47:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:47:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.025462
# 2022-09-20 20:47:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.059598
# 2022-09-20 20:47:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 004 | valid on 'valid' subset:   0%|               | 0/21 [00:00<?, ?it/s]
# epoch 004 | valid on 'valid' subset:  14%|#      | 3/21 [00:00<00:00, 27.25it/s]
# epoch 004 | valid on 'valid' subset:  33%|##3    | 7/21 [00:00<00:00, 29.84it/s]
# epoch 004 | valid on 'valid' subset:  52%|###1  | 11/21 [00:00<00:00, 32.27it/s]
# epoch 004 | valid on 'valid' subset:  71%|####2 | 15/21 [00:00<00:00, 34.00it/s]
# epoch 004 | valid on 'valid' subset:  90%|#####4| 19/21 [00:00<00:00, 35.41it/s]
#                                                                                 2022-09-20 20:47:45 | INFO | valid | epoch 004 | valid on 'valid' subset | loss 5.434 | nll_loss 4.036 | ppl 16.4 | wps 106061 | wpb 2704.5 | bsz 221.1 | num_updates 2262 | best_loss 5.434
# 2022-09-20 20:47:45 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 4 @ 2262 updates
# 2022-09-20 20:47:45 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en/checkpoint4.pt
# 2022-09-20 20:47:52 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en/checkpoint4.pt
# 2022-09-20 20:47:55 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en/checkpoint4.pt (epoch 4 @ 2262 updates, score 5.434) (writing took 10.378494371077977 seconds)
# 2022-09-20 20:47:55 | INFO | fairseq_cli.train | end of epoch 4 (average epoch stats below)
# 2022-09-20 20:47:55 | INFO | train | epoch 004 | loss 5.029 | nll_loss 3.683 | ppl 12.85 | wps 31414 | ups 8.36 | wpb 3756.4 | bsz 348.6 | num_updates 2262 | lr 0.00028275 | gnorm 1.336 | loss_scale 32 | train_wall 55 | gb_free 12.7 | wall 262
# 2022-09-20 20:47:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 20:47:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.042940
# 2022-09-20 20:47:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:47:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.001681
# 2022-09-20 20:47:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:47:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.004717
# 2022-09-20 20:47:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.050141
# 2022-09-20 20:47:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 20:47:55 | INFO | fairseq.data.iterators | grouped total_num_itrs = 566
# epoch 005:   0%|                                        | 0/566 [00:00<?, ?it/s]2022-09-20 20:47:55 | INFO | fairseq.trainer | begin training epoch 5
# 2022-09-20 20:47:55 | INFO | fairseq_cli.train | Start iterating over samples
# ...
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f7c87f0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 031: 100%|9| 565/566 [00:56<00:00,  9.40it/s, loss=2.266, nll_loss=0.542, 2022-09-20 21:17:41 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 21:17:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:17:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001269
# 2022-09-20 21:17:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:17:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.030640
# 2022-09-20 21:17:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:17:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.025586
# 2022-09-20 21:17:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.057954
# 2022-09-20 21:17:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 031 | valid on 'valid' subset:   0%|               | 0/21 [00:00<?, ?it/s]
# epoch 031 | valid on 'valid' subset:  14%|#      | 3/21 [00:00<00:00, 27.90it/s]
# epoch 031 | valid on 'valid' subset:  33%|##3    | 7/21 [00:00<00:00, 30.54it/s]
# epoch 031 | valid on 'valid' subset:  52%|###1  | 11/21 [00:00<00:00, 32.74it/s]
# epoch 031 | valid on 'valid' subset:  71%|####2 | 15/21 [00:00<00:00, 34.36it/s]
# epoch 031 | valid on 'valid' subset:  90%|#####4| 19/21 [00:00<00:00, 35.75it/s]
#                                                                                 2022-09-20 21:17:41 | INFO | valid | epoch 031 | valid on 'valid' subset | loss 3.788 | nll_loss 2.174 | ppl 4.51 | wps 106732 | wpb 2704.5 | bsz 221.1 | num_updates 17544 | best_loss 3.749
# 2022-09-20 21:17:41 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 31 @ 17544 updates
# 2022-09-20 21:17:41 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en/checkpoint31.pt
# 2022-09-20 21:17:45 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en/checkpoint31.pt
# 2022-09-20 21:17:46 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en/checkpoint31.pt (epoch 31 @ 17544 updates, score 3.788) (writing took 4.5774615770205855 seconds)
# 2022-09-20 21:17:47 | INFO | fairseq_cli.train | end of epoch 31 (average epoch stats below)
# 2022-09-20 21:17:47 | INFO | train | epoch 031 | loss 2.259 | nll_loss 0.534 | ppl 1.45 | wps 31412.1 | ups 8.36 | wpb 3756.4 | bsz 348.6 | num_updates 17544 | lr 0.000238746 | gnorm 0.679 | loss_scale 64 | train_wall 55 | gb_free 12.9 | wall 2053
# 2022-09-20 21:17:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:17:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.044223
# 2022-09-20 21:17:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:17:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.002469
# 2022-09-20 21:17:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:17:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.005234
# 2022-09-20 21:17:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.052804
# 2022-09-20 21:17:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:17:47 | INFO | fairseq.data.iterators | grouped total_num_itrs = 566
# epoch 032:   0%|                                        | 0/566 [00:00<?, ?it/s]2022-09-20 21:17:47 | INFO | fairseq.trainer | begin training epoch 32
# 2022-09-20 21:17:47 | INFO | fairseq_cli.train | Start iterating over samples
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f41c160>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 032:  17%|1| 97/566 [00:09<00:45, 10.28it/s, loss=2.247, nll_loss=0.52, ppException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f5e7048>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f6bd4a8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f406828>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f67ecf8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f7ab780>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f783a20>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f720748>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f5e7710>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f6ef0b8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f7c87f0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1b9f7c8cc0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 032: 100%|9| 564/566 [00:56<00:00,  9.60it/s, loss=2.238, nll_loss=0.515, 2022-09-20 21:18:44 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 21:18:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:18:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001370
# 2022-09-20 21:18:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:18:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.037113
# 2022-09-20 21:18:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:18:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.029654
# 2022-09-20 21:18:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.068874
# 2022-09-20 21:18:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 032 | valid on 'valid' subset:   0%|               | 0/21 [00:00<?, ?it/s]
# epoch 032 | valid on 'valid' subset:  14%|#      | 3/21 [00:00<00:00, 26.60it/s]
# epoch 032 | valid on 'valid' subset:  33%|##3    | 7/21 [00:00<00:00, 29.31it/s]
# epoch 032 | valid on 'valid' subset:  52%|###1  | 11/21 [00:00<00:00, 31.76it/s]
# epoch 032 | valid on 'valid' subset:  71%|####2 | 15/21 [00:00<00:00, 33.47it/s]
# epoch 032 | valid on 'valid' subset:  90%|#####4| 19/21 [00:00<00:00, 34.91it/s]
#                                                                                 2022-09-20 21:18:44 | INFO | valid | epoch 032 | valid on 'valid' subset | loss 3.817 | nll_loss 2.197 | ppl 4.58 | wps 104957 | wpb 2704.5 | bsz 221.1 | num_updates 18110 | best_loss 3.749
# 2022-09-20 21:18:44 | INFO | fairseq_cli.train | early stop since valid performance hasn't improved for last 10 runs
# 2022-09-20 21:18:44 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 32 @ 18110 updates
# 2022-09-20 21:18:44 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en/checkpoint32.pt
# 2022-09-20 21:18:47 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en/checkpoint32.pt
# 2022-09-20 21:18:49 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en/checkpoint32.pt (epoch 32 @ 18110 updates, score 3.817) (writing took 4.491662755957805 seconds)
# 2022-09-20 21:18:53 | INFO | fairseq_cli.train | end of epoch 32 (average epoch stats below)
# 2022-09-20 21:18:53 | INFO | train | epoch 032 | loss 2.246 | nll_loss 0.52 | ppl 1.43 | wps 32352.2 | ups 8.61 | wpb 3756.4 | bsz 348.6 | num_updates 18110 | lr 0.000234985 | gnorm 0.676 | loss_scale 64 | train_wall 55 | gb_free 12.7 | wall 2119
# 2022-09-20 21:18:53 | INFO | fairseq_cli.train | done training in 2119.0 seconds

# %%
! echo $MODEL_DIR
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
cd /storage/master-thesis/models/aym-es+es-en
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
! rm dict.en.txt
! rm dict.es.txt
! rm dict.aym.txt

# %%
! du -shc /notebooks/*
# Out:
# 2.5K	/notebooks/CITATION.cff
# 5.5K	/notebooks/CODE_OF_CONDUCT.md
# 15K	/notebooks/CONTRIBUTING.md
# 19K	/notebooks/ISSUES.md
# 12K	/notebooks/LICENSE
# 512	/notebooks/MANIFEST.in
# 3.5K	/notebooks/Makefile
# 41K	/notebooks/README.md
# 41K	/notebooks/README_zh-hans.md
# 42K	/notebooks/README_zh-hant.md
# 12K	/notebooks/docker
# 4.6M	/notebooks/docs
# 5.0M	/notebooks/examples
# 8.5K	/notebooks/hubconf.py
# 7.8G	/notebooks/master-thesis
# 1.5K	/notebooks/model_cards
# 9.5K	/notebooks/notebooks
# 512	/notebooks/pyproject.toml
# 64K	/notebooks/scripts
# 1.0K	/notebooks/setup.cfg
# 13K	/notebooks/setup.py
# 13M	/notebooks/src
# 731K	/notebooks/templates
# 4.5K	/notebooks/test quy-es -> es-en model.ipynb
# 6.8M	/notebooks/tests
# 147K	/notebooks/train es-en model.ipynb
# 158K	/notebooks/train quy-es + es-en model.ipynb
# 160K	/notebooks/utils
# 3.5K	/notebooks/valohai.yaml
# 7.9G	total

# %%
! du -shc /notebooks/master-thesis/*
# Out:
# 512	/notebooks/master-thesis/Untitled.ipynb
# 362M	/notebooks/master-thesis/corpora
# 7.5G	/notebooks/master-thesis/models
# 7.8G	total

# %%
! du -shc /notebooks/master-thesis/models/*
# Out:
# 1.6G	/notebooks/master-thesis/models/es-en
# 802M	/notebooks/master-thesis/models/quy-es
# 5.2G	/notebooks/master-thesis/models/quy-es+es-en
# 7.5G	total

# %%
! du -shc /*
# Out:
# 19M	/apex
# 5.0M	/bin
# 4.0K	/boot
# 24K	/content
# ^C

# %%
ls
# Out:
#  CITATION.cff         docker/          setup.py
#  CODE_OF_CONDUCT.md   docs/            src/
#  CONTRIBUTING.md      examples/        templates/
#  ISSUES.md            hubconf.py      'test quy-es -> es-en model.ipynb'
#  LICENSE              master-thesis/   tests/
#  MANIFEST.in          model_cards/    'train es-en model.ipynb'
#  Makefile             notebooks/      'train quy-es + es-en model.ipynb'
#  README.md            pyproject.toml   utils/
#  README_zh-hans.md    scripts/         valohai.yaml
#  README_zh-hant.md    setup.cfg

# %%
# Out:
# /storage/master-thesis
