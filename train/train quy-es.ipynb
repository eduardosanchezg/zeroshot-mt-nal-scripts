# %% [markdown]
# ## ENVIRONMENT VARIABLES

# %%
QUY_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish"

# %%
tokenizer_path = "/storage/master-thesis/models/quy-es/tokenizers/quy-es/"

# %%
# %env TOKENIZER_PATH = /storage/master-thesis/models/quy-es/tokenizers/quy-es
# Out:
# env: TOKENIZER_PATH=/storage/master-thesis/models/quy-es/tokenizers/quy-es

# %%
tokenized_path_quy_es = "/storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es/"

# %%
# %env TOKENIZED_PATH_QUY_ES = /storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es
# Out:
# env: TOKENIZED_PATH_QUY_ES=/storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es

# %%
# %env BIN_DIR = /storage/master-thesis/models/quy-es/tokenizers/quy-es/bin
# Out:
# env: BIN_DIR=/storage/master-thesis/models/quy-es/tokenizers/quy-es/bin

# %%
# %env MODEL_DIR = /storage/master-thesis/models/quy-es
# Out:
# env: MODEL_DIR=/storage/master-thesis/models/quy-es

# %%
! mkdir -p $TOKENIZED_PATH_QUY_ES
! mkdir -p $BIN_DIR

# %%
! locale
# Out:
# LANG=
# LANGUAGE=
# LC_CTYPE="POSIX"
# LC_NUMERIC="POSIX"
# LC_TIME="POSIX"
# LC_COLLATE="POSIX"
# LC_MONETARY="POSIX"
# LC_MESSAGES="POSIX"
# LC_PAPER="POSIX"
# LC_NAME="POSIX"
# LC_ADDRESS="POSIX"
# LC_TELEPHONE="POSIX"
# LC_MEASUREMENT="POSIX"
# LC_IDENTIFICATION="POSIX"
# LC_ALL=

# %%
! update-locale LANG=en_US.UTF-8 LANGUAGE=en.UTF-8

# %env LANG=en_US.UTF-8
# %env LC_CTYPE=en_US.UTF-8
# %env LC_ALL=en_US.UTF-8
# Out:
# /bin/sh: 1: update-locale: not found
# env: LANG=en_US.UTF-8
# env: LC_CTYPE=en_US.UTF-8
# env: LC_ALL=en_US.UTF-8

# %% [markdown]
# ## Libraries

# %%
pip install tokenizers==0.10.3
# Out:
# Requirement already satisfied: tokenizers==0.10.3 in /usr/local/lib/python3.6/dist-packages (0.10.3)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 1.10.2+cu113
# Uninstalling torch-1.10.2+cu113:
#   Successfully uninstalled torch-1.10.2+cu113
# Found existing installation: torchvision 0.11.3+cu113
# Uninstalling torchvision-0.11.3+cu113:
#   Successfully uninstalled torchvision-0.11.3+cu113
# Found existing installation: torchaudio 0.10.2+cu113
# Uninstalling torchaudio-0.10.2+cu113:
#   Successfully uninstalled torchaudio-0.10.2+cu113
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cu113/torch-1.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (1821.5 MB)
# Collecting torchvision
#   Using cached https://download.pytorch.org/whl/cu113/torchvision-0.11.3%2Bcu113-cp36-cp36m-linux_x86_64.whl (24.6 MB)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/cu113/torchaudio-0.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (2.9 MB)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.18.5)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from torchvision) (8.3.2)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.10.2+cu113 torchaudio-0.10.2+cu113 torchvision-0.11.3+cu113
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall fairseq -y
# Out:
# Found existing installation: fairseq 0.12.2
# Uninstalling fairseq-0.12.2:
#   Successfully uninstalled fairseq-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fairseq # --no-deps
# Out:
# Collecting fairseq
#   Using cached fairseq-0.12.2-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.0 MB)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.10.2+cu113)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.8)
# Requirement already satisfied: bitarray in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.6.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2020.11.13)
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.51.0)
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.10.2+cu113)
# Requirement already satisfied: numpy<1.20.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Requirement already satisfied: omegaconf<2.1 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.6)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.24)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.3)
# Requirement already satisfied: hydra-core<1.1,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.0.7)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (3.10.0.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.4.4)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (2.3.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.8.9)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.6/dist-packages (from omegaconf<2.1->fairseq) (5.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (4.8)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (5.2.2)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core<1.1,>=1.0.7->fairseq) (3.4.0)
# Installing collected packages: fairseq
# Successfully installed fairseq-0.12.2
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip uninstall apex -y
# Out:
# Found existing installation: apex 0.9.10.dev0
# Uninstalling apex-0.9.10.dev0:
#   Successfully uninstalled apex-0.9.10.dev0

# %%
rm -r apex
# Out:
# rm: cannot remove 'apex': No such file or directory

# %%
#! git clone https://github.com/NVIDIA/apex

! pip install -v --disable-pip-version-check --no-cache-dir apex

# %%
pip install tensorboardX
# Out:
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.6/dist-packages (2.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.5)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.13.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (50.3.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Converting tatoeba format to standard format

# %%
import csv

with open(EN_ES_CORPUS_DIR + "original/valid.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "dev.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "dev.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
    en.close()
    es.close()
    
with open(EN_ES_CORPUS_DIR + "original/dev.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "train.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "train.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        if "\n" in line[2] or "\n" in line[3]:
            continue
        if len(line) != 4:
            continue
            
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
        
    en.close()
    es.close()

# %% [markdown]
# ### Tokenizing data

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece

es_quy_tokenizer = Tokenizer(WordPiece(unk_token="[UNK]"))

# %%
from tokenizers.trainers import WordPieceTrainer

es_quy_trainer = WordPieceTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"], show_progress=True)

# %%
from tokenizers.pre_tokenizers import Whitespace

es_quy_tokenizer.pre_tokenizer = Whitespace()

quy_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/{split}.quy" for split in ["dev", "train"]]
es2_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/{split}.es" for split in ["dev", "train"]]


files = es2_files + quy_files
#print(files)
es_quy_tokenizer.train(files= files, trainer=es_quy_trainer)

# %%
# ! cat /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.en

# %%
from pathlib import Path



def tokenize_files(tokenizer, files, extension, output_path):
    for file in files:
        print(f"Reading file {file}")
        with open(file, encoding='utf8') as f:
          lines = f.readlines()
          tokenized_lines = tokenizer.encode_batch(lines)
          tokenized_name = Path(file).stem
          tokenized_name = output_path + tokenized_name + "." + extension
          print(tokenized_name)
          with open(tokenized_name, 'w', encoding='utf8') as wf:

            wf.writelines([" ".join(t.tokens) + "\n" for t in tokenized_lines])

# %%
es_quy_tokenizer.save(tokenizer_path + "es-quy-tokenizer.json")

# %%
print(es_quy_tokenizer)
# Out:
# <tokenizers.Tokenizer object at 0x287a2e0>

# %%
tok = es_quy_tokenizer.encode("we hold this truth to be self evidently that everyone is created equal?")
print(tok.tokens)
# Out:
# ['w', '##e', 'hol', '##d', 't', '##hi', '##s', 'tr', '##uth', 'to', 'be', 'sel', '##f', 'evid', '##en', '##t', '##ly', 't', '##ha', '##t', 'ev', '##er', '##y', '##one', 'is', 'crea', '##ted', 'e', '##qu', '##al', '?']

# %%
tokenize_files(es_quy_tokenizer, quy_files, "quy", tokenized_path_quy_es)
tokenize_files(es_quy_tokenizer, es2_files, "es", tokenized_path_quy_es)
# Out:
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/dev.quy
# /storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es/dev.quy
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/train.quy
# /storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es/train.quy
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/dev.es
# /storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/train.es
# /storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es/train.es

# %% [markdown]
# ## Binarizing data

# %%
### Removing previous dict files
! rm $BIN_DIR/dict.quy.txt
! rm $BIN_DIR/dict.es.txt
# Out:
# rm: cannot remove '/storage/master-thesis/models/quy-es/tokenizers/quy-es/bin/dict.quy.txt': No such file or directory
# rm: cannot remove '/storage/master-thesis/models/quy-es/tokenizers/quy-es/bin/dict.es.txt': No such file or directory

# %%
## Concatenating all training data
#! cat $TOKENIZED_PATH_QUY_ES/train.quy $TOKENIZED_PATH_QUY_ES/train.es $TOKENIZED_PATH_AYM_ES/train.aym $TOKENIZED_PATH_AYM_ES/train.es > $BIN_DIR/train.all

# %%
ls
# Out:
#  Untitled.ipynb
#  bar.txt
#  checkpoints/
#  den.pt
#  docker/
#  docs/
#  examples/
#  master-thesis/
#  model_cards/
#  norm.pt
#  notebooks/
#  num.pt
# 'old scripts'/
#  pos.pt
#  s.pt
#  scripts/
#  sj.pt
#  src/
#  templates/
# 'test 10nal-es + es-en model.ipynb'
# 'test capsulenet quy-es + es-en model.ipynb'
# 'test it-nl-ro-en model.ipynb'
# 'test nl-it-en + de-en model.ipynb'
# 'test quy-es + aym-es,en + es-en model.ipynb'
# 'test quy-es + es-en model.ipynb'
# 'test quy-es -> es-en model.ipynb'
# 'test residual drop quy-es + es-en model.ipynb'
#  tests/
# 'train 10nal-es + es-en model.ipynb'
# 'train aym-es,es-en.ipynb'
# 'train capsulenet nl-it-en + de-en model.ipynb'
# 'train capsulenet quy-es + es-en model.ipynb'
# 'train es-en model.ipynb'
# 'train it-nl-ro-en model.ipynb'
# 'train nah-es,es-en.ipynb'
# 'train nl-en,it-en,ro-en,en-de.ipynb'
# 'train quy-es + aym-es,en + es-en model.ipynb'
# 'train quy-es,aym-es,es-en.ipynb'
# 'train quy-es,es-en.ipynb'
# 'train residual drop quy-es + es-en model.ipynb'
#  utils/
#  vj.pt

# %%
#! fairseq-preprocess --source-lang all \
#    --trainpref $BIN_DIR/train \
#    --destdir $BIN_DIR \
#    --workers 20 \
#    --only-source
# Out:
# 2022-09-19 21:50:17 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/quy-es++aym-es/tokenizers/quy-aym-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=True, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='all', srcdict=None, suppress_crashes=False, target_lang=None, task='translation', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/quy-es++aym-es/tokenizers/quy-aym-es/bin/train', use_plasma_view=False, user_dir=None, validpref=None, wandb_project=None, workers=20)
# 2022-09-19 21:50:21 | INFO | fairseq_cli.preprocess | [all] Dictionary: 28024 types
# 2022-09-19 21:50:28 | INFO | fairseq_cli.preprocess | [all] /storage/master-thesis/models/quy-es++aym-es/tokenizers/quy-aym-es/bin/train.all: 263078 sents, 6754000 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 21:50:28 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/quy-es++aym-es/tokenizers/quy-aym-es/bin

# %%
! echo $BIN_DIR
# Out:
# /storage/master-thesis/models/quy-es++aym-es/tokenizers/quy-aym-es/bin

# %%
! fairseq-preprocess --source-lang quy --target-lang es \
    --trainpref $TOKENIZED_PATH_QUY_ES/train --validpref $TOKENIZED_PATH_QUY_ES/dev \
    --destdir $BIN_DIR \
    --workers 20
# Out:
# 2022-09-20 21:23:49 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/quy-es/tokenizers/quy-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='quy', srcdict=None, suppress_crashes=False, target_lang='es', task='translation', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es/dev', wandb_project=None, workers=20)
# 2022-09-20 21:23:52 | INFO | fairseq_cli.preprocess | [quy] Dictionary: 18824 types
# 2022-09-20 21:24:09 | INFO | fairseq_cli.preprocess | [quy] /storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es/train.quy: 125008 sents, 1829816 tokens, 0.0% replaced (by <unk>)
# 2022-09-20 21:24:09 | INFO | fairseq_cli.preprocess | [quy] Dictionary: 18824 types
# 2022-09-20 21:24:09 | INFO | fairseq_cli.preprocess | [quy] /storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es/dev.quy: 996 sents, 14038 tokens, 3.85% replaced (by <unk>)
# 2022-09-20 21:24:09 | INFO | fairseq_cli.preprocess | [es] Dictionary: 15848 types
# 2022-09-20 21:24:12 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es/train.es: 125008 sents, 2428035 tokens, 0.0% replaced (by <unk>)
# 2022-09-20 21:24:12 | INFO | fairseq_cli.preprocess | [es] Dictionary: 15848 types
# 2022-09-20 21:24:12 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/quy-es/tokenizers/quy-es/quy-es/dev.es: 996 sents, 15551 tokens, 0.932% replaced (by <unk>)
# 2022-09-20 21:24:12 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/quy-es/tokenizers/quy-es/bin

# %% [markdown]
# ## Training model

# %%
! fairseq-train $BIN_DIR \
    --arch=transformer \
    --task translation_multi_simple_epoch --lang-pairs quy-es \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 5e-4 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --dropout 0.3 --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --max-tokens 4096 \
    --restore-file $MODEL_DIR/checkpoint_last.pt \
    --save-dir $MODEL_DIR/ \
    --keep-last-epochs 2 \
    --reset-optimizer \
    --encoder-langtok "src" \
    --decoder-langtok \
    --fp16 \
    --max-epoch 200 \
    --patience 10
# Out:
# 2022-09-20 21:24:16 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 4096, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 4096, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 200, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.0005], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '/storage/master-thesis/models/quy-es/', 'restore_file': '/storage/master-thesis/models/quy-es/checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': True, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': 2, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': 10, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'l ...
# 2022-09-20 21:24:16 | WARNING | fairseq.data.multilingual.multilingual_data_manager | External language dictionary is not provided; use lang-pairs to infer the set of supported languages. The language ordering is not stable which might cause misalignment in pretraining and finetuning.
# 2022-09-20 21:24:16 | INFO | fairseq.data.multilingual.multilingual_data_manager | inferred language list: ['es', 'quy']
# 2022-09-20 21:24:16 | INFO | fairseq.data.multilingual.multilingual_data_manager | [quy] dictionary: 18826 types
# 2022-09-20 21:24:16 | INFO | fairseq.data.multilingual.multilingual_data_manager | [es] dictionary: 15850 types
# 2022-09-20 21:24:17 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(18826, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(15850, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=512, out_features=15850, bias=False)
#   )
# )
# 2022-09-20 21:24:17 | INFO | fairseq_cli.train | task: TranslationMultiSimpleEpochTask
# 2022-09-20 21:24:17 | INFO | fairseq_cli.train | model: TransformerModel
# 2022-09-20 21:24:17 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-09-20 21:24:17 | INFO | fairseq_cli.train | num. shared model params: 88,909,824 (num. trained: 88,909,824)
# 2022-09-20 21:24:17 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-09-20 21:24:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for valid epoch=1/None
# 2022-09-20 21:24:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:24:17 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-20 21:24:17 | INFO | fairseq.data.multilingual.multilingual_data_manager | [valid] num of shards: {'main:quy-es': 1}
# 2022-09-20 21:24:17 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:quy-es src_langtok: 18825; tgt_langtok: 15848
# 2022-09-20 21:24:17 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/quy-es/tokenizers/quy-es/bin/valid.quy-es.quy
# 2022-09-20 21:24:17 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/quy-es/tokenizers/quy-es/bin/valid.quy-es.es
# 2022-09-20 21:24:17 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/quy-es/tokenizers/quy-es/bin valid quy-es 996 examples
# 2022-09-20 21:24:22 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-20 21:24:22 | INFO | fairseq.utils | rank   0: capabilities =  8.6  ; total memory = 15.740 GB ; name = RTX A4000
# 2022-09-20 21:24:22 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-20 21:24:22 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-09-20 21:24:22 | INFO | fairseq_cli.train | max tokens per device = 4096 and max sentences per device = None
# 2022-09-20 21:24:22 | INFO | fairseq.trainer | Preparing to load checkpoint /storage/master-thesis/models/quy-es/checkpoint_last.pt
# 2022-09-20 21:24:22 | INFO | fairseq.trainer | No existing checkpoint found /storage/master-thesis/models/quy-es/checkpoint_last.pt
# 2022-09-20 21:24:22 | INFO | fairseq.trainer | loading train data for epoch 1
# 2022-09-20 21:24:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for train epoch=1/None
# 2022-09-20 21:24:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:24:22 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-20 21:24:22 | INFO | fairseq.data.multilingual.multilingual_data_manager | [train] num of shards: {'main:quy-es': 1}
# 2022-09-20 21:24:22 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:quy-es src_langtok: 18825; tgt_langtok: 15848
# 2022-09-20 21:24:22 | INFO | fairseq.data.data_utils | loaded 125,008 examples from: /storage/master-thesis/models/quy-es/tokenizers/quy-es/bin/train.quy-es.quy
# 2022-09-20 21:24:22 | INFO | fairseq.data.data_utils | loaded 125,008 examples from: /storage/master-thesis/models/quy-es/tokenizers/quy-es/bin/train.quy-es.es
# 2022-09-20 21:24:22 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/quy-es/tokenizers/quy-es/bin train quy-es 125008 examples
# 2022-09-20 21:24:22 | INFO | fairseq.data.multilingual.multilingual_data_manager | estimated total data sizes of all shards used in sampling ratios: [('main:quy-es', 125008)]. Note that if the data a shard has not been loaded yet, use the max known data size to approximate
# 2022-09-20 21:24:22 | INFO | fairseq.data.multilingual.sampling_method | selected sampler: concat
# 2022-09-20 21:24:22 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Raw sizes: {'main:quy-es': 125008}; raw total size: 125008
# 2022-09-20 21:24:22 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Resampled sizes: {'main:quy-es': 125008}; resampled total size: 125008
# 2022-09-20 21:24:22 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] A concat dataset
# 2022-09-20 21:24:22 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] virtual dataset established time: 0:00:00.009659
# 2022-09-20 21:24:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:24:22 | INFO | fairseq.data.multilingual.sampled_multi_dataset | sizes() calling time: 0:00:00.001271
# 2022-09-20 21:24:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.024872
# 2022-09-20 21:24:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:24:22 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-20 21:24:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.001494
# 2022-09-20 21:24:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:24:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.003619
# 2022-09-20 21:24:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.030566
# 2022-09-20 21:24:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:24:22 | INFO | fairseq.data.iterators | grouped total_num_itrs = 712
# epoch 001:   0%|                                        | 0/712 [00:00<?, ?it/s]2022-09-20 21:24:22 | INFO | fairseq.trainer | begin training epoch 1
# 2022-09-20 21:24:22 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 001:   1%|2                               | 5/712 [00:00<01:29,  7.93it/s]2022-09-20 21:24:23 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 001:   3%|8                              | 19/712 [00:01<01:07, 10.20it/s]2022-09-20 21:24:24 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 001: 100%|9| 711/712 [01:04<00:00, 11.02it/s, loss=8.958, nll_loss=8.167, 2022-09-20 21:25:27 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 21:25:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:25:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.000828
# 2022-09-20 21:25:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:25:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.007008
# 2022-09-20 21:25:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:25:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.005820
# 2022-09-20 21:25:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.014229
# 2022-09-20 21:25:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 001 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:  50%|####    | 4/8 [00:00<00:00, 32.70it/s]
#                                                                                 2022-09-20 21:25:27 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 9.64 | nll_loss 8.882 | ppl 471.75 | wps 83018.7 | wpb 2068.4 | bsz 124.5 | num_updates 710
# 2022-09-20 21:25:27 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 710 updates
# 2022-09-20 21:25:27 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint1.pt
# 2022-09-20 21:25:35 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint1.pt
# 2022-09-20 21:25:41 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es/checkpoint1.pt (epoch 1 @ 710 updates, score 9.64) (writing took 13.370895509957336 seconds)
# 2022-09-20 21:25:41 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2022-09-20 21:25:41 | INFO | train | epoch 001 | loss 10.217 | nll_loss 9.631 | ppl 793.03 | wps 32436 | ups 9.05 | wpb 3584.3 | bsz 174.3 | num_updates 710 | lr 8.875e-05 | gnorm 2.199 | loss_scale 32 | train_wall 63 | gb_free 12.7 | wall 79
# 2022-09-20 21:25:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:25:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.026028
# 2022-09-20 21:25:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:25:41 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-20 21:25:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.003569
# 2022-09-20 21:25:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:25:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.004440
# 2022-09-20 21:25:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.034746
# 2022-09-20 21:25:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:25:41 | INFO | fairseq.data.iterators | grouped total_num_itrs = 712
# epoch 002:   0%|                                        | 0/712 [00:00<?, ?it/s]2022-09-20 21:25:41 | INFO | fairseq.trainer | begin training epoch 2
# 2022-09-20 21:25:41 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 002:  38%|3| 274/712 [00:25<00:40, 10.92it/s, loss=8.527, nll_loss=7.672, Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7cc61cc88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 002: 100%|9| 710/712 [01:06<00:00, 10.61it/s, loss=7.959, nll_loss=7.01, p2022-09-20 21:26:47 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 21:26:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:26:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.000765
# 2022-09-20 21:26:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:26:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.006820
# 2022-09-20 21:26:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:26:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.005580
# 2022-09-20 21:26:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.013606
# 2022-09-20 21:26:47 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 002 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:  38%|###     | 3/8 [00:00<00:00, 28.28it/s]
# epoch 002 | valid on 'valid' subset: 100%|########| 8/8 [00:00<00:00, 31.96it/s]
#                                                                                 2022-09-20 21:26:47 | INFO | valid | epoch 002 | valid on 'valid' subset | loss 9.016 | nll_loss 8.167 | ppl 287.5 | wps 84117.7 | wpb 2068.4 | bsz 124.5 | num_updates 1422 | best_loss 9.016
# 2022-09-20 21:26:47 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 2 @ 1422 updates
# 2022-09-20 21:26:47 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint2.pt
# 2022-09-20 21:26:50 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint2.pt
# 2022-09-20 21:26:53 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es/checkpoint2.pt (epoch 2 @ 1422 updates, score 9.016) (writing took 5.439654240035452 seconds)
# 2022-09-20 21:26:53 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2022-09-20 21:26:53 | INFO | train | epoch 002 | loss 8.3 | nll_loss 7.407 | ppl 169.72 | wps 35387.2 | ups 9.87 | wpb 3584.3 | bsz 175.6 | num_updates 1422 | lr 0.00017775 | gnorm 1.648 | loss_scale 32 | train_wall 65 | gb_free 12.7 | wall 151
# 2022-09-20 21:26:53 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:26:53 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.031994
# 2022-09-20 21:26:53 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:26:53 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-20 21:26:53 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.004692
# 2022-09-20 21:26:53 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:26:53 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.007263
# 2022-09-20 21:26:53 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.045059
# 2022-09-20 21:26:53 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:26:53 | INFO | fairseq.data.iterators | grouped total_num_itrs = 712
# epoch 003:   0%|                                        | 0/712 [00:00<?, ?it/s]2022-09-20 21:26:53 | INFO | fairseq.trainer | begin training epoch 3
# 2022-09-20 21:26:53 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 003:   0%|1                               | 3/712 [00:00<01:13,  9.66it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2ce9c88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 003:  31%|3| 222/712 [00:20<00:44, 10.96it/s, loss=7.825, nll_loss=6.852, Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7cc61cc88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2e8e278>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 003: 100%|9| 710/712 [01:06<00:00, 10.42it/s, loss=7.45, nll_loss=6.417, p2022-09-20 21:27:59 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 21:27:59 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:27:59 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.000834
# 2022-09-20 21:27:59 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:27:59 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.006858
# 2022-09-20 21:27:59 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:27:59 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.005787
# 2022-09-20 21:27:59 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.014033
# 2022-09-20 21:27:59 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 003 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:  38%|###     | 3/8 [00:00<00:00, 28.41it/s]
# epoch 003 | valid on 'valid' subset: 100%|########| 8/8 [00:00<00:00, 31.81it/s]
#                                                                                 2022-09-20 21:28:00 | INFO | valid | epoch 003 | valid on 'valid' subset | loss 8.723 | nll_loss 7.798 | ppl 222.62 | wps 82054.2 | wpb 2068.4 | bsz 124.5 | num_updates 2134 | best_loss 8.723
# 2022-09-20 21:28:00 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 3 @ 2134 updates
# 2022-09-20 21:28:00 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint3.pt
# 2022-09-20 21:28:02 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint3.pt
# 2022-09-20 21:28:05 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es/checkpoint3.pt (epoch 3 @ 2134 updates, score 8.723) (writing took 5.671745237079449 seconds)
# 2022-09-20 21:28:08 | INFO | fairseq_cli.train | end of epoch 3 (average epoch stats below)
# 2022-09-20 21:28:08 | INFO | train | epoch 003 | loss 7.61 | nll_loss 6.603 | ppl 97.24 | wps 34063.9 | ups 9.5 | wpb 3584.3 | bsz 175.6 | num_updates 2134 | lr 0.00026675 | gnorm 1.408 | loss_scale 32 | train_wall 65 | gb_free 12.7 | wall 226
# 2022-09-20 21:28:08 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:28:08 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.025805
# 2022-09-20 21:28:08 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:28:08 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-20 21:28:08 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.003357
# 2022-09-20 21:28:08 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:28:08 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.003954
# 2022-09-20 21:28:08 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.033791
# 2022-09-20 21:28:08 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:28:13 | INFO | fairseq.data.iterators | grouped total_num_itrs = 712
# epoch 004:   0%|                                        | 0/712 [00:00<?, ?it/s]2022-09-20 21:28:13 | INFO | fairseq.trainer | begin training epoch 4
# 2022-09-20 21:28:13 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 004:  20%|1| 141/712 [00:12<00:53, 10.76it/s, loss=7.321, nll_loss=6.27, pException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7cc61cc88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2e8e278>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c27474e0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 004: 100%|9| 711/712 [01:06<00:00, 10.76it/s, loss=6.994, nll_loss=5.889, 2022-09-20 21:29:19 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 21:29:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:29:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.000823
# 2022-09-20 21:29:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:29:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.007356
# 2022-09-20 21:29:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:29:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.005939
# 2022-09-20 21:29:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.014556
# 2022-09-20 21:29:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 004 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 004 | valid on 'valid' subset:  38%|###     | 3/8 [00:00<00:00, 25.36it/s]
# epoch 004 | valid on 'valid' subset: 100%|########| 8/8 [00:00<00:00, 29.34it/s]
#                                                                                 2022-09-20 21:29:19 | INFO | valid | epoch 004 | valid on 'valid' subset | loss 8.434 | nll_loss 7.475 | ppl 177.96 | wps 84888.5 | wpb 2068.4 | bsz 124.5 | num_updates 2846 | best_loss 8.434
# 2022-09-20 21:29:19 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 4 @ 2846 updates
# 2022-09-20 21:29:19 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint4.pt
# 2022-09-20 21:29:22 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint4.pt
# 2022-09-20 21:29:25 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es/checkpoint4.pt (epoch 4 @ 2846 updates, score 8.434) (writing took 5.351806439924985 seconds)
# 2022-09-20 21:29:25 | INFO | fairseq_cli.train | end of epoch 4 (average epoch stats below)
# 2022-09-20 21:29:25 | INFO | train | epoch 004 | loss 7.129 | nll_loss 6.044 | ppl 66 | wps 33143.9 | ups 9.25 | wpb 3584.3 | bsz 175.6 | num_updates 2846 | lr 0.00035575 | gnorm 1.249 | loss_scale 32 | train_wall 65 | gb_free 12.7 | wall 303
# 2022-09-20 21:29:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:29:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.025890
# 2022-09-20 21:29:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:29:25 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-20 21:29:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.003071
# 2022-09-20 21:29:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:29:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.004387
# 2022-09-20 21:29:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.034336
# 2022-09-20 21:29:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:29:25 | INFO | fairseq.data.iterators | grouped total_num_itrs = 712
# epoch 005:   0%|                                        | 0/712 [00:00<?, ?it/s]2022-09-20 21:29:25 | INFO | fairseq.trainer | begin training epoch 5
# 2022-09-20 21:29:25 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 005:   1%|2                               | 5/712 [00:00<01:28,  8.01it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2ce94a8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 005:  19%|1| 134/712 [00:12<00:55, 10.50it/s, loss=6.862, nll_loss=5.737, Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7cc61cc88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2e8e278>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c27474e0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# ...
# 2022-09-20 21:46:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:46:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.000772
# 2022-09-20 21:46:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:46:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.006970
# 2022-09-20 21:46:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:46:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.006231
# 2022-09-20 21:46:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.014446
# 2022-09-20 21:46:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 018 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 018 | valid on 'valid' subset:  38%|###     | 3/8 [00:00<00:00, 27.57it/s]
# epoch 018 | valid on 'valid' subset: 100%|########| 8/8 [00:00<00:00, 31.18it/s]
#                                                                                 2022-09-20 21:46:34 | INFO | valid | epoch 018 | valid on 'valid' subset | loss 8.315 | nll_loss 7.194 | ppl 146.43 | wps 81927.3 | wpb 2068.4 | bsz 124.5 | num_updates 12813 | best_loss 7.958
# 2022-09-20 21:46:34 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 18 @ 12813 updates
# 2022-09-20 21:46:34 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint18.pt
# 2022-09-20 21:46:36 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint18.pt
# 2022-09-20 21:46:38 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es/checkpoint18.pt (epoch 18 @ 12813 updates, score 8.315) (writing took 4.098519550054334 seconds)
# 2022-09-20 21:46:42 | INFO | fairseq_cli.train | end of epoch 18 (average epoch stats below)
# 2022-09-20 21:46:42 | INFO | train | epoch 018 | loss 4.79 | nll_loss 3.331 | ppl 10.06 | wps 33873.5 | ups 9.45 | wpb 3584.3 | bsz 175.6 | num_updates 12813 | lr 0.000279367 | gnorm 1.044 | loss_scale 16 | train_wall 65 | gb_free 12.7 | wall 1340
# 2022-09-20 21:46:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:46:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.024722
# 2022-09-20 21:46:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:46:42 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-20 21:46:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.003164
# 2022-09-20 21:46:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:46:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.004259
# 2022-09-20 21:46:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.032789
# 2022-09-20 21:46:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:46:42 | INFO | fairseq.data.iterators | grouped total_num_itrs = 712
# epoch 019:   0%|                                        | 0/712 [00:00<?, ?it/s]2022-09-20 21:46:42 | INFO | fairseq.trainer | begin training epoch 19
# 2022-09-20 21:46:42 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 019:   0%|1                               | 3/712 [00:00<01:24,  8.40it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2ab4978>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 019:  27%|2| 193/712 [00:17<00:46, 11.26it/s, loss=4.636, nll_loss=3.154, Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c189b0f0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff8aed26b00>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2c0d198>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2ab4390>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2deb668>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2ae2240>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2ebd470>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2a2c390>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2ba9400>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2ebd4a8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2ebd5f8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2e368d0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7ff7c2e5cf28>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 019: 100%|9| 711/712 [01:06<00:00, 10.30it/s, loss=4.801, nll_loss=3.34, p2022-09-20 21:47:49 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-20 21:47:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-20 21:47:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.000783
# 2022-09-20 21:47:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:47:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.006805
# 2022-09-20 21:47:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-20 21:47:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.006136
# 2022-09-20 21:47:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.014202
# 2022-09-20 21:47:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 019 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 019 | valid on 'valid' subset:  38%|###     | 3/8 [00:00<00:00, 29.61it/s]
# epoch 019 | valid on 'valid' subset: 100%|########| 8/8 [00:00<00:00, 33.29it/s]
#                                                                                 2022-09-20 21:47:49 | INFO | valid | epoch 019 | valid on 'valid' subset | loss 8.26 | nll_loss 7.144 | ppl 141.4 | wps 84427.8 | wpb 2068.4 | bsz 124.5 | num_updates 13525 | best_loss 7.958
# 2022-09-20 21:47:49 | INFO | fairseq_cli.train | early stop since valid performance hasn't improved for last 10 runs
# 2022-09-20 21:47:49 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 19 @ 13525 updates
# 2022-09-20 21:47:49 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint19.pt
# 2022-09-20 21:47:52 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es/checkpoint19.pt
# 2022-09-20 21:47:53 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es/checkpoint19.pt (epoch 19 @ 13525 updates, score 8.26) (writing took 4.222510213963687 seconds)
# 2022-09-20 21:47:53 | INFO | fairseq_cli.train | end of epoch 19 (average epoch stats below)
# 2022-09-20 21:47:53 | INFO | train | epoch 019 | loss 4.725 | nll_loss 3.255 | ppl 9.54 | wps 35890.3 | ups 10.01 | wpb 3584.3 | bsz 175.6 | num_updates 13525 | lr 0.000271914 | gnorm 1.049 | loss_scale 16 | train_wall 65 | gb_free 12.9 | wall 1411
# 2022-09-20 21:47:53 | INFO | fairseq_cli.train | done training in 1411.1 seconds

# %%
! echo $MODEL_DIR
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
cd /storage/master-thesis/models/aym-es+es-en
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
! rm dict.en.txt
! rm dict.es.txt
! rm dict.aym.txt

# %%
! du -shc /notebooks/*
# Out:
# 2.5K	/notebooks/CITATION.cff
# 5.5K	/notebooks/CODE_OF_CONDUCT.md
# 15K	/notebooks/CONTRIBUTING.md
# 19K	/notebooks/ISSUES.md
# 12K	/notebooks/LICENSE
# 512	/notebooks/MANIFEST.in
# 3.5K	/notebooks/Makefile
# 41K	/notebooks/README.md
# 41K	/notebooks/README_zh-hans.md
# 42K	/notebooks/README_zh-hant.md
# 12K	/notebooks/docker
# 4.6M	/notebooks/docs
# 5.0M	/notebooks/examples
# 8.5K	/notebooks/hubconf.py
# 7.8G	/notebooks/master-thesis
# 1.5K	/notebooks/model_cards
# 9.5K	/notebooks/notebooks
# 512	/notebooks/pyproject.toml
# 64K	/notebooks/scripts
# 1.0K	/notebooks/setup.cfg
# 13K	/notebooks/setup.py
# 13M	/notebooks/src
# 731K	/notebooks/templates
# 4.5K	/notebooks/test quy-es -> es-en model.ipynb
# 6.8M	/notebooks/tests
# 147K	/notebooks/train es-en model.ipynb
# 158K	/notebooks/train quy-es + es-en model.ipynb
# 160K	/notebooks/utils
# 3.5K	/notebooks/valohai.yaml
# 7.9G	total

# %%
! du -shc /notebooks/master-thesis/*
# Out:
# 512	/notebooks/master-thesis/Untitled.ipynb
# 362M	/notebooks/master-thesis/corpora
# 7.5G	/notebooks/master-thesis/models
# 7.8G	total

# %%
! du -shc /notebooks/master-thesis/models/*
# Out:
# 1.6G	/notebooks/master-thesis/models/es-en
# 802M	/notebooks/master-thesis/models/quy-es
# 5.2G	/notebooks/master-thesis/models/quy-es+es-en
# 7.5G	total

# %%
! du -shc /*
# Out:
# 19M	/apex
# 5.0M	/bin
# 4.0K	/boot
# 24K	/content
# ^C

# %%
ls
# Out:
#  CITATION.cff         docker/          setup.py
#  CODE_OF_CONDUCT.md   docs/            src/
#  CONTRIBUTING.md      examples/        templates/
#  ISSUES.md            hubconf.py      'test quy-es -> es-en model.ipynb'
#  LICENSE              master-thesis/   tests/
#  MANIFEST.in          model_cards/    'train es-en model.ipynb'
#  Makefile             notebooks/      'train quy-es + es-en model.ipynb'
#  README.md            pyproject.toml   utils/
#  README_zh-hans.md    scripts/         valohai.yaml
#  README_zh-hant.md    setup.cfg

# %%
# Out:
# /storage/master-thesis
