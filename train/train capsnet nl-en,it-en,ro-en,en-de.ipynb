# %% [markdown]
# ## ENVIRONMENT VARIABLES

# %%
EN_IT_CORPUS_DIR = "/notebooks/master-thesis/corpora/iwslt17/en-it/"

# %%
EN_NL_CORPUS_DIR = "/notebooks/master-thesis/corpora/iwslt17/en-nl/"

# %%
EN_RO_CORPUS_DIR = "/notebooks/master-thesis/corpora/iwslt17/en-ro/"

# %%
DE_EN_CORPUS_DIR = "/notebooks/master-thesis/corpora/iwslt17/de-en/"

# %%
tokenizer_path = "/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/"

# %%
# %env TOKENIZER_PATH = /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de
# Out:
# env: TOKENIZER_PATH=/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de

# %%
tokenized_path_en_it = "/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/"
tokenized_path_en_nl = "/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/"
tokenized_path_en_ro = "/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/"
tokenized_path_de_en = "/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/"

# %%
# %env TOKENIZED_PATH_EN_IT = /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it
# %env TOKENIZED_PATH_EN_NL = /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl
# %env TOKENIZED_PATH_EN_RO = /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro
# %env TOKENIZED_PATH_DE_EN = /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en
# Out:
# env: TOKENIZED_PATH_EN_IT=/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it
# env: TOKENIZED_PATH_EN_NL=/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl
# env: TOKENIZED_PATH_EN_RO=/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro
# env: TOKENIZED_PATH_DE_EN=/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en

# %%
# %env BIN_DIR = /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin
# Out:
# env: BIN_DIR=/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
# %env MODEL_DIR = /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de
# Out:
# env: MODEL_DIR=/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de

# %%
! mkdir -p $TOKENIZED_PATH_EN_IT
! mkdir -p $TOKENIZED_PATH_EN_NL
! mkdir -p $TOKENIZED_PATH_EN_RO
! mkdir -p $TOKENIZED_PATH_DE_EN
! mkdir -p $BIN_DIR

# %%
# %env CODE_STORAGE = /storage/code/
# Out:
# env: CODE_STORAGE=/storage/code/

# %%
pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |################################| 125 kB 22.4 MB/s eta 0:00:01
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (50.3.2)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5.1
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 1.9.1
# Uninstalling torch-1.9.1:
#   Successfully uninstalled torch-1.9.1
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (1821.5 MB)
#      |################################| 1821.5 MB 5.4 kB/s eta 0:00:0101B 106.9 MB/s eta 0:00:11[K     |##################              | 1050.1 MB 2.0 MB/s eta 0:06:29[K     |#####################           | 1210.0 MB 1.7 MB/s eta 0:06:09.2 MB 106.6 MB/s eta 0:00:03################# | 1776.9 MB 102.7 MB/s eta 0:00:01
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.11.3%2Bcu113-cp36-cp36m-linux_x86_64.whl (24.6 MB)
#      |################################| 24.6 MB 7.2 MB/s eta 0:00:01
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (2.9 MB)
#      |################################| 2.9 MB 7.4 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from torchvision) (8.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.18.5)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.10.2+cu113 torchaudio-0.10.2+cu113 torchvision-0.11.3+cu113
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall fairseq -y
# Out:
# Found existing installation: fairseq 0.10.2
# Uninstalling fairseq-0.10.2:
#   Successfully uninstalled fairseq-0.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fairseq
# Out:
# Collecting fairseq
#   Downloading fairseq-0.12.2-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.0 MB)
#      |################################| 11.0 MB 24.9 MB/s eta 0:00:01
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2020.11.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.51.0)
# Requirement already satisfied: numpy<1.20.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.10.2+cu113)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.8)
# Collecting hydra-core<1.1,>=1.0.7
#   Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#      |################################| 123 kB 92.5 MB/s eta 0:00:01
# Collecting bitarray
#   Downloading bitarray-2.6.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (235 kB)
#      |################################| 235 kB 81.5 MB/s eta 0:00:01
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.24)
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.10.2+cu113)
# Collecting omegaconf<2.1
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (3.10.0.2)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (5.2.2)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (4.8)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (2.3.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.8.9)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.4.4)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.6/dist-packages (from omegaconf<2.1->fairseq) (5.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core<1.1,>=1.0.7->fairseq) (3.4.0)
# Installing collected packages: omegaconf, hydra-core, bitarray, fairseq
#   Attempting uninstall: omegaconf
#     Found existing installation: omegaconf 2.1.1
#     Uninstalling omegaconf-2.1.1:
#       Successfully uninstalled omegaconf-2.1.1
#   Attempting uninstall: hydra-core
#     Found existing installation: hydra-core 1.1.1
#     Uninstalling hydra-core-1.1.1:
#       Successfully uninstalled hydra-core-1.1.1
# Successfully installed bitarray-2.6.0 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip uninstall apex -y
# Out:
# Found existing installation: apex 0.1
# Uninstalling apex-0.1:
#   Successfully uninstalled apex-0.1

# %%
! pip install -v --disable-pip-version-check --no-cache-dir apex

# %% [markdown]
# ### Tokenizing data

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece

it_nl_ro_en_de_tokenizer = Tokenizer(WordPiece(unk_token="[UNK]"))

# %%
from tokenizers.trainers import WordPieceTrainer

it_nl_ro_en_de_trainer = WordPieceTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"], show_progress=True)

# %%
from tokenizers.pre_tokenizers import Whitespace

it_nl_ro_en_de_tokenizer.pre_tokenizer = Whitespace()

en_it_files = [EN_IT_CORPUS_DIR + f"{split}.en" for split in ["valid","train"]]
it_en_files = [EN_IT_CORPUS_DIR + f"{split}.it" for split in ["valid","train"]]

en_nl_files = [EN_NL_CORPUS_DIR + f"{split}.en" for split in ["valid","train"]]
nl_en_files = [EN_NL_CORPUS_DIR + f"{split}.nl" for split in ["valid","train"]]

en_ro_files = [EN_RO_CORPUS_DIR + f"{split}.en" for split in ["valid","train"]]
ro_en_files = [EN_RO_CORPUS_DIR + f"{split}.ro" for split in ["valid","train"]]

de_en_files = [DE_EN_CORPUS_DIR + f"{split}.de" for split in ["valid", "train"]]
en_de_files = [DE_EN_CORPUS_DIR + f"{split}.en" for split in ["valid", "train"]]


files = en_it_files + it_en_files + en_nl_files + nl_en_files + en_ro_files + ro_en_files + de_en_files + en_de_files
it_nl_ro_en_de_tokenizer.train(files= files, trainer=it_nl_ro_en_de_trainer)

# %%
from pathlib import Path



def tokenize_files(tokenizer, files, extension, output_path):
    for file in files:
        print(f"Reading file {file}")
        with open(file, encoding='utf8') as f:
          lines = f.readlines()
          tokenized_lines = tokenizer.encode_batch(lines)
          tokenized_name = Path(file).stem
          tokenized_name = output_path + tokenized_name + "." + extension
          print(tokenized_name)
          with open(tokenized_name, 'w', encoding='utf8') as wf:

            wf.writelines([" ".join(t.tokens) + "\n" for t in tokenized_lines])

# %%
it_nl_ro_en_de_tokenizer.save(tokenizer_path + "it_nl_ro_en_de_tokenizer.json")

# %%
tok = it_nl_ro_en_de_tokenizer.encode("we hold this truthfbjh to be self evidently that everyone is created equal?")
print(tok.tokens)
# Out:
# ['we', 'hold', 'this', 'truth', '##f', '##b', '##j', '##h', 'to', 'be', 'self', 'evident', '##ly', 'that', 'everyone', 'is', 'created', 'equal', '?']

# %%
tokenize_files(it_nl_ro_en_de_tokenizer, en_it_files, "en", tokenized_path_en_it)
tokenize_files(it_nl_ro_en_de_tokenizer, it_en_files, "it", tokenized_path_en_it)

tokenize_files(it_nl_ro_en_de_tokenizer, en_nl_files, "en", tokenized_path_en_nl)
tokenize_files(it_nl_ro_en_de_tokenizer, nl_en_files, "nl", tokenized_path_en_nl)

tokenize_files(it_nl_ro_en_de_tokenizer, en_ro_files, "en", tokenized_path_en_ro)
tokenize_files(it_nl_ro_en_de_tokenizer, ro_en_files, "ro", tokenized_path_en_ro)

tokenize_files(it_nl_ro_en_de_tokenizer, de_en_files, "de", tokenized_path_de_en)
tokenize_files(it_nl_ro_en_de_tokenizer, en_de_files, "en", tokenized_path_de_en)
# Out:
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-it/valid.en
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/valid.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-it/train.en
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/train.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-it/valid.it
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/valid.it
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-it/train.it
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/train.it
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-nl/valid.en
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/valid.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-nl/train.en
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/train.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-nl/valid.nl
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/valid.nl
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-nl/train.nl
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/train.nl
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-ro/valid.en
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/valid.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-ro/train.en
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/train.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-ro/valid.ro
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/valid.ro
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-ro/train.ro
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/train.ro
# Reading file /notebooks/master-thesis/corpora/iwslt17/de-en/valid.de
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/valid.de
# Reading file /notebooks/master-thesis/corpora/iwslt17/de-en/train.de
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/train.de
# Reading file /notebooks/master-thesis/corpora/iwslt17/de-en/valid.en
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/valid.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/de-en/train.en
# /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/train.en

# %% [markdown]
# ## Binarizing data

# %%
## Concatenating all training data
! cat $TOKENIZED_PATH_EN_IT/train.en $TOKENIZED_PATH_EN_IT/train.it \
    $TOKENIZED_PATH_EN_NL/train.en $TOKENIZED_PATH_EN_NL/train.nl \
    $TOKENIZED_PATH_EN_RO/train.en $TOKENIZED_PATH_EN_RO/train.ro \
    $TOKENIZED_PATH_DE_EN/train.de $TOKENIZED_PATH_DE_EN/train.en \
    > $BIN_DIR/train.all

# %%
! fairseq-preprocess --source-lang all \
    --trainpref $BIN_DIR/train \
    --destdir $BIN_DIR \
    --workers 20 \
    --task translation_multi_simple_epoch \
    --only-source
# Out:
# 2022-10-30 01:12:52 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=True, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='all', srcdict=None, suppress_crashes=False, target_lang=None, task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train', use_plasma_view=False, user_dir=None, validpref=None, wandb_project=None, workers=20)
# 2022-10-30 01:13:00 | INFO | fairseq_cli.preprocess | [all] Dictionary: 29312 types
# 2022-10-30 01:13:19 | INFO | fairseq_cli.preprocess | [all] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.all: 899650 sents, 20643737 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 01:13:19 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
! fairseq-preprocess --source-lang it --target-lang en \
    --trainpref $TOKENIZED_PATH_EN_IT/train --validpref $TOKENIZED_PATH_EN_IT/valid \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-10-30 01:13:21 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='it', srcdict='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', suppress_crashes=False, target_lang='en', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/valid', wandb_project=None, workers=20)
# 2022-10-30 01:13:22 | INFO | fairseq_cli.preprocess | [it] Dictionary: 29312 types
# 2022-10-30 01:13:25 | INFO | fairseq_cli.preprocess | [it] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/train.it: 145105 sents, 3375399 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 01:13:25 | INFO | fairseq_cli.preprocess | [it] Dictionary: 29312 types
# 2022-10-30 01:13:25 | INFO | fairseq_cli.preprocess | [it] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/valid.it: 929 sents, 23680 tokens, 0.0591% replaced (by <unk>)
# 2022-10-30 01:13:25 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-10-30 01:13:29 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/train.en: 145105 sents, 3332751 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 01:13:29 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-10-30 01:13:29 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/valid.en: 929 sents, 24225 tokens, 0.066% replaced (by <unk>)
# 2022-10-30 01:13:29 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
! fairseq-preprocess --source-lang nl --target-lang en \
    --trainpref $TOKENIZED_PATH_EN_NL/train --validpref $TOKENIZED_PATH_EN_NL/valid \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-10-30 01:13:31 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='nl', srcdict='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', suppress_crashes=False, target_lang='en', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/valid', wandb_project=None, workers=20)
# 2022-10-30 01:13:31 | INFO | fairseq_cli.preprocess | [nl] Dictionary: 29312 types
# 2022-10-30 01:13:34 | INFO | fairseq_cli.preprocess | [nl] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/train.nl: 145105 sents, 3191574 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 01:13:34 | INFO | fairseq_cli.preprocess | [nl] Dictionary: 29312 types
# 2022-10-30 01:13:34 | INFO | fairseq_cli.preprocess | [nl] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/valid.nl: 1003 sents, 22731 tokens, 0.0616% replaced (by <unk>)
# 2022-10-30 01:13:34 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-10-30 01:13:38 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/train.en: 145105 sents, 3332751 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 01:13:38 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-10-30 01:13:38 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/valid.en: 1003 sents, 24300 tokens, 0.0658% replaced (by <unk>)
# 2022-10-30 01:13:38 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
! fairseq-preprocess --source-lang ro --target-lang en \
    --trainpref $TOKENIZED_PATH_EN_RO/train --validpref $TOKENIZED_PATH_EN_RO/valid \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-10-30 01:13:40 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='ro', srcdict='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', suppress_crashes=False, target_lang='en', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/valid', wandb_project=None, workers=20)
# 2022-10-30 01:13:40 | INFO | fairseq_cli.preprocess | [ro] Dictionary: 29312 types
# 2022-10-30 01:13:44 | INFO | fairseq_cli.preprocess | [ro] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/train.ro: 145105 sents, 3342971 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 01:13:44 | INFO | fairseq_cli.preprocess | [ro] Dictionary: 29312 types
# 2022-10-30 01:13:44 | INFO | fairseq_cli.preprocess | [ro] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/valid.ro: 914 sents, 25026 tokens, 0.0559% replaced (by <unk>)
# 2022-10-30 01:13:44 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-10-30 01:13:47 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/train.en: 145105 sents, 3332751 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 01:13:47 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-10-30 01:13:48 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/valid.en: 914 sents, 24223 tokens, 0.0661% replaced (by <unk>)
# 2022-10-30 01:13:48 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
! fairseq-preprocess --source-lang en --target-lang de \
    --trainpref $TOKENIZED_PATH_DE_EN/train --validpref $TOKENIZED_PATH_DE_EN/valid \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-10-30 01:13:50 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='en', srcdict='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', suppress_crashes=False, target_lang='de', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/valid', wandb_project=None, workers=20)
# 2022-10-30 01:13:50 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-10-30 01:13:50 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/train.en: 14510 sents, 332275 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 01:13:50 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-10-30 01:13:51 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/valid.en: 1138 sents, 24977 tokens, 2.53% replaced (by <unk>)
# 2022-10-30 01:13:51 | INFO | fairseq_cli.preprocess | [de] Dictionary: 29312 types
# 2022-10-30 01:13:51 | INFO | fairseq_cli.preprocess | [de] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/train.de: 14510 sents, 403265 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 01:13:51 | INFO | fairseq_cli.preprocess | [de] Dictionary: 29312 types
# 2022-10-30 01:13:52 | INFO | fairseq_cli.preprocess | [de] /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/valid.de: 1138 sents, 31232 tokens, 0.756% replaced (by <unk>)
# 2022-10-30 01:13:52 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
ls $MODEL_DIR
# Out:
# checkpoint64.pt  checkpoint_best.pt  tokenizers/
# checkpoint65.pt  checkpoint_last.pt

# %% [markdown]
# ## Training model

# %%
cd /storage/code
# Out:
# /storage/code

# %%
! rm -r fairseq-dynamic-routing-plugin

# %%
! git clone https://github.com/eduardosanchezg/fairseq-dynamic-routing-plugin.git
# Out:
# Cloning into 'fairseq-dynamic-routing-plugin'...
# remote: Enumerating objects: 32879, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 32879 (delta 9), reused 0 (delta 0), pack-reused 32858
# Receiving objects: 100% (32879/32879), 13.90 MiB | 40.89 MiB/s, done.
# Resolving deltas: 100% (24198/24198), done.

# %%
cd /notebooks
# Out:
# /notebooks

# %%
! fairseq-train $BIN_DIR \
    --user-dir /storage/code/fairseq-dynamic-routing-plugin/examples/dynamic_routing/dynamic_routing_src/ \
    --arch=capsnet_transformer --share-all-embeddings \
    --task translation_multi_simple_epoch --lang-pairs it-en,nl-en,ro-en,en-de \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 5e-4 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --dropout 0.3 --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --max-tokens 4096 \
    --restore-file $MODEL_DIR/checkpoint_last.pt \
    --save-dir $MODEL_DIR/ \
    --keep-last-epochs 2 \
    --reset-optimizer \
    --encoder-langtok "src" \
    --decoder-langtok \
    --fp16 \
    --max-epoch 200 \
    --patience 10
# Out:
# 2022-10-30 01:15:54 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': '/storage/code/fairseq-dynamic-routing-plugin/examples/dynamic_routing/dynamic_routing_src/', 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 4096, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 4096, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 200, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.0005], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/', 'restore_file': '/storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': True, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': 2, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_ch ...
# 2022-10-30 01:15:54 | WARNING | fairseq.data.multilingual.multilingual_data_manager | External language dictionary is not provided; use lang-pairs to infer the set of supported languages. The language ordering is not stable which might cause misalignment in pretraining and finetuning.
# 2022-10-30 01:15:54 | INFO | fairseq.data.multilingual.multilingual_data_manager | inferred language list: ['de', 'en', 'it', 'nl', 'ro']
# 2022-10-30 01:15:54 | INFO | fairseq.data.multilingual.multilingual_data_manager | [ro] dictionary: 29317 types
# 2022-10-30 01:15:54 | INFO | fairseq.data.multilingual.multilingual_data_manager | [en] dictionary: 29317 types
# INITIALIZED!!!!!!
# 2022-10-30 01:15:55 | INFO | fairseq_cli.train | CapsNetTransformerModel(
#   (encoder): CapsNetTransformerEncoder(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(29317, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): CapsNetTransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (self_attn_layer): ModifiedMultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(29317, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=512, out_features=29317, bias=False)
#   )
# )
# 2022-10-30 01:15:55 | INFO | fairseq_cli.train | task: TranslationMultiSimpleEpochTask
# 2022-10-30 01:15:55 | INFO | fairseq_cli.train | model: CapsNetTransformerModel
# 2022-10-30 01:15:55 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-10-30 01:15:55 | INFO | fairseq_cli.train | num. shared model params: 79,363,584 (num. trained: 79,363,584)
# 2022-10-30 01:15:55 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-10-30 01:15:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for valid epoch=1/None
# 2022-10-30 01:15:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:15:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-10-30 01:15:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | [valid] num of shards: {'main:it-en': 1, 'main:nl-en': 1, 'main:ro-en': 1, 'main:en-de': 1}
# 2022-10-30 01:15:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:it-en src_langtok: 29314; tgt_langtok: 29313
# 2022-10-30 01:15:55 | INFO | fairseq.data.data_utils | loaded 929 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.it-en.it
# 2022-10-30 01:15:55 | INFO | fairseq.data.data_utils | loaded 929 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.it-en.en
# 2022-10-30 01:15:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin valid it-en 929 examples
# 2022-10-30 01:15:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:nl-en src_langtok: 29315; tgt_langtok: 29313
# 2022-10-30 01:15:55 | INFO | fairseq.data.data_utils | loaded 1,003 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.nl-en.nl
# 2022-10-30 01:15:55 | INFO | fairseq.data.data_utils | loaded 1,003 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.nl-en.en
# 2022-10-30 01:15:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin valid nl-en 1003 examples
# 2022-10-30 01:15:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:ro-en src_langtok: 29316; tgt_langtok: 29313
# 2022-10-30 01:15:55 | INFO | fairseq.data.data_utils | loaded 914 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.ro-en.ro
# 2022-10-30 01:15:55 | INFO | fairseq.data.data_utils | loaded 914 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.ro-en.en
# 2022-10-30 01:15:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin valid ro-en 914 examples
# 2022-10-30 01:15:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:en-de src_langtok: 29313; tgt_langtok: 29312
# 2022-10-30 01:15:55 | INFO | fairseq.data.data_utils | loaded 1,138 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.en-de.en
# 2022-10-30 01:15:55 | INFO | fairseq.data.data_utils | loaded 1,138 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.en-de.de
# 2022-10-30 01:15:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin valid en-de 1138 examples
# 2022-10-30 01:16:00 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.embed_tokens.weight
# 2022-10-30 01:16:00 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.output_projection.weight
# 2022-10-30 01:16:00 | INFO | fairseq.trainer | detected shared parameter: encoder.layers.0.dynamic_routing_weights <- encoder.layers.0.self_attn_layer.dynamic_routing_weights
# 2022-10-30 01:16:00 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-10-30 01:16:00 | INFO | fairseq.utils | rank   0: capabilities =  8.6  ; total memory = 15.740 GB ; name = NVIDIA RTX A4000
# 2022-10-30 01:16:00 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-10-30 01:16:00 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-10-30 01:16:00 | INFO | fairseq_cli.train | max tokens per device = 4096 and max sentences per device = None
# 2022-10-30 01:16:00 | INFO | fairseq.trainer | Preparing to load checkpoint /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint_last.pt
# 2022-10-30 01:16:00 | INFO | fairseq.trainer | No existing checkpoint found /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint_last.pt
# 2022-10-30 01:16:00 | INFO | fairseq.trainer | loading train data for epoch 1
# 2022-10-30 01:16:00 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for train epoch=1/None
# 2022-10-30 01:16:00 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.multilingual_data_manager | [train] num of shards: {'main:it-en': 1, 'main:nl-en': 1, 'main:ro-en': 1, 'main:en-de': 1}
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:it-en src_langtok: 29314; tgt_langtok: 29313
# 2022-10-30 01:16:00 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.it-en.it
# 2022-10-30 01:16:00 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.it-en.en
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin train it-en 145105 examples
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:nl-en src_langtok: 29315; tgt_langtok: 29313
# 2022-10-30 01:16:00 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.nl-en.nl
# 2022-10-30 01:16:00 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.nl-en.en
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin train nl-en 145105 examples
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:ro-en src_langtok: 29316; tgt_langtok: 29313
# 2022-10-30 01:16:00 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.ro-en.ro
# 2022-10-30 01:16:00 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.ro-en.en
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin train ro-en 145105 examples
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:en-de src_langtok: 29313; tgt_langtok: 29312
# 2022-10-30 01:16:00 | INFO | fairseq.data.data_utils | loaded 14,510 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.en-de.en
# 2022-10-30 01:16:00 | INFO | fairseq.data.data_utils | loaded 14,510 examples from: /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.en-de.de
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin train en-de 14510 examples
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.multilingual_data_manager | estimated total data sizes of all shards used in sampling ratios: [('main:it-en', 145105), ('main:nl-en', 145105), ('main:ro-en', 145105), ('main:en-de', 14510)]. Note that if the data a shard has not been loaded yet, use the max known data size to approximate
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.sampling_method | selected sampler: concat
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Raw sizes: {'main:it-en': 145105, 'main:nl-en': 145105, 'main:ro-en': 145105, 'main:en-de': 14510}; raw total size: 449825
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Resampled sizes: {'main:it-en': 145105, 'main:nl-en': 145105, 'main:ro-en': 145105, 'main:en-de': 14510}; resampled total size: 449825
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] A concat dataset
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] virtual dataset established time: 0:00:00.030210
# 2022-10-30 01:16:00 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 01:16:00 | INFO | fairseq.data.multilingual.sampled_multi_dataset | sizes() calling time: 0:00:00.004477
# 2022-10-30 01:16:00 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.107277
# 2022-10-30 01:16:00 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:16:00 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.004462
# 2022-10-30 01:16:00 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:16:00 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.016347
# 2022-10-30 01:16:00 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.129032
# 2022-10-30 01:16:00 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:16:00 | INFO | fairseq.data.iterators | grouped total_num_itrs = 2996
# epoch 001:   0%|                                       | 0/2996 [00:00<?, ?it/s]2022-10-30 01:16:00 | INFO | fairseq.trainer | begin training epoch 1
# 2022-10-30 01:16:00 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 001:   0%|                               | 1/2996 [00:00<22:33,  2.21it/s]2022-10-30 01:16:00 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 001:   0%|1                             | 10/2996 [00:01<09:08,  5.44it/s]2022-10-30 01:16:02 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 001: 100%|9| 2995/2996 [08:41<00:00,  5.61it/s, loss=6.913, nll_loss=5.6992022-10-30 01:24:41 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 01:24:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 01:24:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001047
# 2022-10-30 01:24:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:24:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.032980
# 2022-10-30 01:24:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:24:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.022755
# 2022-10-30 01:24:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.057359
# 2022-10-30 01:24:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 001 | valid on 'valid' subset:   0%|               | 0/47 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:   2%|1      | 1/47 [00:00<00:05,  8.87it/s]
# epoch 001 | valid on 'valid' subset:   6%|4      | 3/47 [00:00<00:04,  9.94it/s]
# epoch 001 | valid on 'valid' subset:  11%|7      | 5/47 [00:00<00:03, 10.94it/s]
# epoch 001 | valid on 'valid' subset:  15%|#      | 7/47 [00:00<00:03, 11.74it/s]
# epoch 001 | valid on 'valid' subset:  19%|#3     | 9/47 [00:00<00:03, 12.64it/s]
# epoch 001 | valid on 'valid' subset:  23%|#4    | 11/47 [00:00<00:02, 13.15it/s]
# epoch 001 | valid on 'valid' subset:  28%|#6    | 13/47 [00:00<00:02, 13.60it/s]
# epoch 001 | valid on 'valid' subset:  32%|#9    | 15/47 [00:01<00:02, 13.88it/s]
# epoch 001 | valid on 'valid' subset:  36%|##1   | 17/47 [00:01<00:02, 13.93it/s]
# epoch 001 | valid on 'valid' subset:  40%|##4   | 19/47 [00:01<00:01, 14.01it/s]
# epoch 001 | valid on 'valid' subset:  45%|##6   | 21/47 [00:01<00:01, 14.05it/s]
# epoch 001 | valid on 'valid' subset:  49%|##9   | 23/47 [00:01<00:01, 14.13it/s]
# epoch 001 | valid on 'valid' subset:  53%|###1  | 25/47 [00:01<00:01, 14.31it/s]
# epoch 001 | valid on 'valid' subset:  57%|###4  | 27/47 [00:01<00:01, 14.44it/s]
# epoch 001 | valid on 'valid' subset:  62%|###7  | 29/47 [00:02<00:01, 14.44it/s]
# epoch 001 | valid on 'valid' subset:  66%|###9  | 31/47 [00:02<00:01, 14.42it/s]
# epoch 001 | valid on 'valid' subset:  70%|####2 | 33/47 [00:02<00:00, 14.57it/s]
# epoch 001 | valid on 'valid' subset:  74%|####4 | 35/47 [00:02<00:00, 14.51it/s]
# epoch 001 | valid on 'valid' subset:  79%|####7 | 37/47 [00:02<00:00, 14.40it/s]
# epoch 001 | valid on 'valid' subset:  83%|####9 | 39/47 [00:02<00:00, 14.33it/s]
# epoch 001 | valid on 'valid' subset:  87%|#####2| 41/47 [00:02<00:00, 14.62it/s]
# epoch 001 | valid on 'valid' subset:  91%|#####4| 43/47 [00:03<00:00, 14.50it/s]
# epoch 001 | valid on 'valid' subset:  96%|#####7| 45/47 [00:03<00:00, 14.52it/s]
# epoch 001 | valid on 'valid' subset: 100%|######| 47/47 [00:03<00:00, 15.18it/s]
#                                                                                 2022-10-30 01:24:45 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 8.204 | nll_loss 7.1 | ppl 137.21 | wps 33521.7 | wpb 2297.1 | bsz 84.8 | num_updates 2994
# 2022-10-30 01:24:45 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 2994 updates
# 2022-10-30 01:24:45 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint1.pt
# 2022-10-30 01:24:47 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint1.pt
# 2022-10-30 01:24:48 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint1.pt (epoch 1 @ 2994 updates, score 8.204) (writing took 3.8252559332177043 seconds)
# 2022-10-30 01:24:48 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2022-10-30 01:24:48 | INFO | train | epoch 001 | loss 8.151 | nll_loss 7.118 | ppl 138.94 | wps 20527.2 | ups 5.67 | wpb 3622 | bsz 150.1 | num_updates 2994 | lr 0.00037425 | gnorm 1.699 | loss_scale 32 | train_wall 514 | gb_free 12.1 | wall 529
# 2022-10-30 01:24:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 01:24:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.104262
# 2022-10-30 01:24:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:24:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.004730
# 2022-10-30 01:24:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:24:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.017243
# 2022-10-30 01:24:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.127797
# 2022-10-30 01:24:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:24:49 | INFO | fairseq.data.iterators | grouped total_num_itrs = 2996
# epoch 002:   0%|                                       | 0/2996 [00:00<?, ?it/s]2022-10-30 01:24:49 | INFO | fairseq.trainer | begin training epoch 2
# 2022-10-30 01:24:49 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 002:  46%|4| 1385/2996 [04:01<04:39,  5.76it/s, loss=6.363, nll_loss=5.071Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1212b02908>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f12050d2320>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 002: 100%|9| 2995/2996 [08:41<00:00,  5.77it/s, loss=5.605, nll_loss=4.2062022-10-30 01:33:30 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 01:33:30 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 01:33:30 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001215
# 2022-10-30 01:33:30 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:33:30 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.029777
# 2022-10-30 01:33:30 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:33:30 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.021990
# 2022-10-30 01:33:30 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.053465
# 2022-10-30 01:33:30 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 002 | valid on 'valid' subset:   0%|               | 0/47 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:   4%|2      | 2/47 [00:00<00:03, 12.26it/s]
# epoch 002 | valid on 'valid' subset:   9%|5      | 4/47 [00:00<00:03, 12.97it/s]
# epoch 002 | valid on 'valid' subset:  13%|8      | 6/47 [00:00<00:03, 13.54it/s]
# epoch 002 | valid on 'valid' subset:  17%|#1     | 8/47 [00:00<00:02, 13.86it/s]
# epoch 002 | valid on 'valid' subset:  21%|#2    | 10/47 [00:00<00:02, 14.53it/s]
# epoch 002 | valid on 'valid' subset:  26%|#5    | 12/47 [00:00<00:02, 14.70it/s]
# epoch 002 | valid on 'valid' subset:  30%|#7    | 14/47 [00:00<00:02, 14.82it/s]
# epoch 002 | valid on 'valid' subset:  34%|##    | 16/47 [00:01<00:02, 14.92it/s]
# epoch 002 | valid on 'valid' subset:  38%|##2   | 18/47 [00:01<00:01, 14.91it/s]
# epoch 002 | valid on 'valid' subset:  43%|##5   | 20/47 [00:01<00:01, 14.90it/s]
# epoch 002 | valid on 'valid' subset:  47%|##8   | 22/47 [00:01<00:01, 14.91it/s]
# epoch 002 | valid on 'valid' subset:  51%|###   | 24/47 [00:01<00:01, 14.87it/s]
# epoch 002 | valid on 'valid' subset:  55%|###3  | 26/47 [00:01<00:01, 14.90it/s]
# epoch 002 | valid on 'valid' subset:  60%|###5  | 28/47 [00:01<00:01, 14.79it/s]
# epoch 002 | valid on 'valid' subset:  64%|###8  | 30/47 [00:02<00:01, 14.58it/s]
# epoch 002 | valid on 'valid' subset:  68%|####  | 32/47 [00:02<00:01, 14.40it/s]
# epoch 002 | valid on 'valid' subset:  72%|####3 | 34/47 [00:02<00:00, 14.32it/s]
# epoch 002 | valid on 'valid' subset:  77%|####5 | 36/47 [00:02<00:00, 14.15it/s]
# epoch 002 | valid on 'valid' subset:  81%|####8 | 38/47 [00:02<00:00, 13.88it/s]
# epoch 002 | valid on 'valid' subset:  85%|#####1| 40/47 [00:02<00:00, 14.18it/s]
# epoch 002 | valid on 'valid' subset:  89%|#####3| 42/47 [00:02<00:00, 14.12it/s]
# epoch 002 | valid on 'valid' subset:  94%|#####6| 44/47 [00:03<00:00, 14.10it/s]
# epoch 002 | valid on 'valid' subset:  98%|#####8| 46/47 [00:03<00:00, 14.49it/s]
#                                                                                 2022-10-30 01:33:33 | INFO | valid | epoch 002 | valid on 'valid' subset | loss 6.97 | nll_loss 5.646 | ppl 50.09 | wps 33888.6 | wpb 2297.1 | bsz 84.8 | num_updates 5990 | best_loss 6.97
# 2022-10-30 01:33:33 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 2 @ 5990 updates
# 2022-10-30 01:33:33 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint2.pt
# 2022-10-30 01:33:35 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint2.pt
# 2022-10-30 01:33:37 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint2.pt (epoch 2 @ 5990 updates, score 6.97) (writing took 4.029974263161421 seconds)
# 2022-10-30 01:33:37 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2022-10-30 01:33:37 | INFO | train | epoch 002 | loss 6.273 | nll_loss 4.968 | ppl 31.29 | wps 20509.9 | ups 5.66 | wpb 3621.9 | bsz 150.1 | num_updates 5990 | lr 0.000408589 | gnorm 1.025 | loss_scale 32 | train_wall 514 | gb_free 12 | wall 1058
# 2022-10-30 01:33:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 01:33:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.128101
# 2022-10-30 01:33:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:33:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.004877
# 2022-10-30 01:33:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:33:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.025901
# 2022-10-30 01:33:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.160131
# 2022-10-30 01:33:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:33:38 | INFO | fairseq.data.iterators | grouped total_num_itrs = 2996
# epoch 003:   0%|                                       | 0/2996 [00:00<?, ?it/s]2022-10-30 01:33:38 | INFO | fairseq.trainer | begin training epoch 3
# 2022-10-30 01:33:38 | INFO | fairseq_cli.train | Start iterating over samples
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f12051c0b70>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 003:  33%|3| 987/2996 [02:51<06:01,  5.55it/s, loss=5.344, nll_loss=3.901,Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1212b02908>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f12050d2320>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f120534ed30>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 003: 100%|9| 2995/2996 [08:41<00:00,  5.58it/s, loss=4.834, nll_loss=3.3152022-10-30 01:42:20 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 01:42:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 01:42:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001371
# 2022-10-30 01:42:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:42:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.030247
# 2022-10-30 01:42:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 01:42:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.021826
# 2022-10-30 01:42:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.053980
# 2022-10-30 01:42:20 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 003 | valid on 'valid' subset:   0%|               | 0/47 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:   4%|2      | 2/47 [00:00<00:03, 12.84it/s]
# epoch 003 | valid on 'valid' subset:   9%|5      | 4/47 [00:00<00:03, 13.47it/s]
# epoch 003 | valid on 'valid' subset:  13%|8      | 6/47 [00:00<00:02, 13.86it/s]
# epoch 003 | valid on 'valid' subset:  17%|#1     | 8/47 [00:00<00:02, 14.08it/s]
# epoch 003 | valid on 'valid' subset:  21%|#2    | 10/47 [00:00<00:02, 14.66it/s]
# epoch 003 | valid on 'valid' subset:  26%|#5    | 12/47 [00:00<00:02, 14.72it/s]
# epoch 003 | valid on 'valid' subset:  30%|#7    | 14/47 [00:00<00:02, 14.77it/s]
# epoch 003 | valid on 'valid' subset:  34%|##    | 16/47 [00:01<00:02, 14.72it/s]
# epoch 003 | valid on 'valid' subset:  38%|##2   | 18/47 [00:01<00:01, 14.62it/s]
# epoch 003 | valid on 'valid' subset:  43%|##5   | 20/47 [00:01<00:01, 14.62it/s]
# epoch 003 | valid on 'valid' subset:  47%|##8   | 22/47 [00:01<00:01, 14.58it/s]
# epoch 003 | valid on 'valid' subset:  51%|###   | 24/47 [00:01<00:01, 14.67it/s]
# epoch 003 | valid on 'valid' subset:  55%|###3  | 26/47 [00:01<00:01, 14.71it/s]
# epoch 003 | valid on 'valid' subset:  60%|###5  | 28/47 [00:01<00:01, 14.73it/s]
# epoch 003 | valid on 'valid' subset:  64%|###8  | 30/47 [00:02<00:01, 14.59it/s]
# epoch 003 | valid on 'valid' subset:  68%|####  | 32/47 [00:02<00:01, 14.63it/s]
# ...
# epoch 028 | valid on 'valid' subset:  87%|#####2| 41/47 [00:02<00:00, 14.04it/s]
# epoch 028 | valid on 'valid' subset:  91%|#####4| 43/47 [00:03<00:00, 13.93it/s]
# epoch 028 | valid on 'valid' subset:  96%|#####7| 45/47 [00:03<00:00, 14.06it/s]
# epoch 028 | valid on 'valid' subset: 100%|######| 47/47 [00:03<00:00, 14.82it/s]
#                                                                                 2022-10-30 05:23:10 | INFO | valid | epoch 028 | valid on 'valid' subset | loss 5.14 | nll_loss 3.551 | ppl 11.72 | wps 33145.8 | wpb 2297.1 | bsz 84.8 | num_updates 83883 | best_loss 5.12
# 2022-10-30 05:23:10 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 28 @ 83883 updates
# 2022-10-30 05:23:10 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint28.pt
# 2022-10-30 05:23:12 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint28.pt
# 2022-10-30 05:23:13 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint28.pt (epoch 28 @ 83883 updates, score 5.14) (writing took 3.0630272645503283 seconds)
# 2022-10-30 05:23:13 | INFO | fairseq_cli.train | end of epoch 28 (average epoch stats below)
# 2022-10-30 05:23:13 | INFO | train | epoch 028 | loss 3.173 | nll_loss 1.43 | ppl 2.69 | wps 20464.5 | ups 5.65 | wpb 3621.9 | bsz 150.1 | num_updates 83883 | lr 0.000109185 | gnorm 1.082 | loss_scale 64 | train_wall 516 | gb_free 12.6 | wall 14833
# 2022-10-30 05:23:13 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 05:23:13 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.105937
# 2022-10-30 05:23:13 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 05:23:13 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.004797
# 2022-10-30 05:23:13 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 05:23:13 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.015872
# 2022-10-30 05:23:13 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.127572
# 2022-10-30 05:23:13 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 05:23:13 | INFO | fairseq.data.iterators | grouped total_num_itrs = 2996
# epoch 029:   0%|                                       | 0/2996 [00:00<?, ?it/s]2022-10-30 05:23:13 | INFO | fairseq.trainer | begin training epoch 29
# 2022-10-30 05:23:13 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 029:   1%| | 23/2996 [00:04<08:31,  5.81it/s, loss=3.207, nll_loss=1.466, Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1205348d68>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 029:  25%|2| 738/2996 [02:08<06:18,  5.96it/s, loss=3.136, nll_loss=1.387,2022-10-30 05:25:22 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 029:  48%|4| 1428/2996 [04:08<04:21,  6.00it/s, loss=3.164, nll_loss=1.421Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1204f0a080>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 029: 100%|9| 2995/2996 [08:41<00:00,  5.86it/s, loss=3.169, nll_loss=1.4272022-10-30 05:31:55 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 05:31:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 05:31:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001229
# 2022-10-30 05:31:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 05:31:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.029968
# 2022-10-30 05:31:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 05:31:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.022223
# 2022-10-30 05:31:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.053942
# 2022-10-30 05:31:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 029 | valid on 'valid' subset:   0%|               | 0/47 [00:00<?, ?it/s]
# epoch 029 | valid on 'valid' subset:   4%|2      | 2/47 [00:00<00:03, 12.60it/s]
# epoch 029 | valid on 'valid' subset:   9%|5      | 4/47 [00:00<00:03, 13.32it/s]
# epoch 029 | valid on 'valid' subset:  13%|8      | 6/47 [00:00<00:02, 13.73it/s]
# epoch 029 | valid on 'valid' subset:  17%|#1     | 8/47 [00:00<00:02, 13.97it/s]
# epoch 029 | valid on 'valid' subset:  21%|#2    | 10/47 [00:00<00:02, 14.45it/s]
# epoch 029 | valid on 'valid' subset:  26%|#5    | 12/47 [00:00<00:02, 14.34it/s]
# epoch 029 | valid on 'valid' subset:  30%|#7    | 14/47 [00:00<00:02, 14.51it/s]
# epoch 029 | valid on 'valid' subset:  34%|##    | 16/47 [00:01<00:02, 14.60it/s]
# epoch 029 | valid on 'valid' subset:  38%|##2   | 18/47 [00:01<00:01, 14.62it/s]
# epoch 029 | valid on 'valid' subset:  43%|##5   | 20/47 [00:01<00:01, 14.62it/s]
# epoch 029 | valid on 'valid' subset:  47%|##8   | 22/47 [00:01<00:01, 14.53it/s]
# epoch 029 | valid on 'valid' subset:  51%|###   | 24/47 [00:01<00:01, 14.58it/s]
# epoch 029 | valid on 'valid' subset:  55%|###3  | 26/47 [00:01<00:01, 14.46it/s]
# epoch 029 | valid on 'valid' subset:  60%|###5  | 28/47 [00:01<00:01, 14.24it/s]
# epoch 029 | valid on 'valid' subset:  64%|###8  | 30/47 [00:02<00:01, 14.03it/s]
# epoch 029 | valid on 'valid' subset:  68%|####  | 32/47 [00:02<00:01, 14.15it/s]
# epoch 029 | valid on 'valid' subset:  72%|####3 | 34/47 [00:02<00:00, 14.31it/s]
# epoch 029 | valid on 'valid' subset:  77%|####5 | 36/47 [00:02<00:00, 14.36it/s]
# epoch 029 | valid on 'valid' subset:  81%|####8 | 38/47 [00:02<00:00, 14.42it/s]
# epoch 029 | valid on 'valid' subset:  85%|#####1| 40/47 [00:02<00:00, 14.38it/s]
# epoch 029 | valid on 'valid' subset:  89%|#####3| 42/47 [00:02<00:00, 14.40it/s]
# epoch 029 | valid on 'valid' subset:  94%|#####6| 44/47 [00:03<00:00, 14.20it/s]
# epoch 029 | valid on 'valid' subset:  98%|#####8| 46/47 [00:03<00:00, 14.47it/s]
#                                                                                 2022-10-30 05:31:59 | INFO | valid | epoch 029 | valid on 'valid' subset | loss 5.156 | nll_loss 3.565 | ppl 11.84 | wps 33479.1 | wpb 2297.1 | bsz 84.8 | num_updates 86878 | best_loss 5.12
# 2022-10-30 05:31:59 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 29 @ 86878 updates
# 2022-10-30 05:31:59 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint29.pt
# 2022-10-30 05:32:06 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint29.pt
# 2022-10-30 05:32:07 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint29.pt (epoch 29 @ 86878 updates, score 5.156) (writing took 8.050887716002762 seconds)
# 2022-10-30 05:32:07 | INFO | fairseq_cli.train | end of epoch 29 (average epoch stats below)
# 2022-10-30 05:32:07 | INFO | train | epoch 029 | loss 3.159 | nll_loss 1.414 | ppl 2.66 | wps 20328.2 | ups 5.61 | wpb 3621.9 | bsz 150 | num_updates 86878 | lr 0.000107287 | gnorm 1.094 | loss_scale 32 | train_wall 514 | gb_free 12.3 | wall 15367
# 2022-10-30 05:32:07 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 05:32:07 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.111275
# 2022-10-30 05:32:07 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 05:32:07 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.004363
# 2022-10-30 05:32:07 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 05:32:07 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.015860
# 2022-10-30 05:32:07 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.132443
# 2022-10-30 05:32:07 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 05:32:07 | INFO | fairseq.data.iterators | grouped total_num_itrs = 2996
# epoch 030:   0%|                                       | 0/2996 [00:00<?, ?it/s]2022-10-30 05:32:07 | INFO | fairseq.trainer | begin training epoch 30
# 2022-10-30 05:32:07 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 030:  38%|3| 1139/2996 [03:19<04:58,  6.21it/s, loss=3.164, nll_loss=1.419Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1204f0a080>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f1205367c18>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 030: 100%|9| 2995/2996 [08:42<00:00,  5.76it/s, loss=3.158, nll_loss=1.4122022-10-30 05:40:49 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 05:40:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 05:40:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001241
# 2022-10-30 05:40:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 05:40:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.029593
# 2022-10-30 05:40:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 05:40:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.022254
# 2022-10-30 05:40:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.053616
# 2022-10-30 05:40:49 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 030 | valid on 'valid' subset:   0%|               | 0/47 [00:00<?, ?it/s]
# epoch 030 | valid on 'valid' subset:   4%|2      | 2/47 [00:00<00:03, 12.08it/s]
# epoch 030 | valid on 'valid' subset:   9%|5      | 4/47 [00:00<00:03, 12.84it/s]
# epoch 030 | valid on 'valid' subset:  13%|8      | 6/47 [00:00<00:03, 13.44it/s]
# epoch 030 | valid on 'valid' subset:  17%|#1     | 8/47 [00:00<00:02, 13.88it/s]
# epoch 030 | valid on 'valid' subset:  21%|#2    | 10/47 [00:00<00:02, 13.96it/s]
# epoch 030 | valid on 'valid' subset:  26%|#5    | 12/47 [00:00<00:02, 14.18it/s]
# epoch 030 | valid on 'valid' subset:  30%|#7    | 14/47 [00:00<00:02, 14.43it/s]
# epoch 030 | valid on 'valid' subset:  34%|##    | 16/47 [00:01<00:02, 14.54it/s]
# epoch 030 | valid on 'valid' subset:  38%|##2   | 18/47 [00:01<00:01, 14.55it/s]
# epoch 030 | valid on 'valid' subset:  43%|##5   | 20/47 [00:01<00:01, 14.48it/s]
# epoch 030 | valid on 'valid' subset:  47%|##8   | 22/47 [00:01<00:01, 14.46it/s]
# epoch 030 | valid on 'valid' subset:  51%|###   | 24/47 [00:01<00:01, 14.54it/s]
# epoch 030 | valid on 'valid' subset:  55%|###3  | 26/47 [00:01<00:01, 14.45it/s]
# epoch 030 | valid on 'valid' subset:  60%|###5  | 28/47 [00:01<00:01, 14.41it/s]
# epoch 030 | valid on 'valid' subset:  64%|###8  | 30/47 [00:02<00:01, 14.10it/s]
# epoch 030 | valid on 'valid' subset:  68%|####  | 32/47 [00:02<00:01, 14.00it/s]
# epoch 030 | valid on 'valid' subset:  72%|####3 | 34/47 [00:02<00:00, 14.20it/s]
# epoch 030 | valid on 'valid' subset:  77%|####5 | 36/47 [00:02<00:00, 14.23it/s]
# epoch 030 | valid on 'valid' subset:  81%|####8 | 38/47 [00:02<00:00, 14.14it/s]
# epoch 030 | valid on 'valid' subset:  85%|#####1| 40/47 [00:02<00:00, 14.34it/s]
# epoch 030 | valid on 'valid' subset:  89%|#####3| 42/47 [00:02<00:00, 14.33it/s]
# epoch 030 | valid on 'valid' subset:  94%|#####6| 44/47 [00:03<00:00, 14.11it/s]
# epoch 030 | valid on 'valid' subset:  98%|#####8| 46/47 [00:03<00:00, 14.48it/s]
#                                                                                 2022-10-30 05:40:53 | INFO | valid | epoch 030 | valid on 'valid' subset | loss 5.143 | nll_loss 3.555 | ppl 11.75 | wps 33345.7 | wpb 2297.1 | bsz 84.8 | num_updates 89874 | best_loss 5.12
# 2022-10-30 05:40:53 | INFO | fairseq_cli.train | early stop since valid performance hasn't improved for last 10 runs
# 2022-10-30 05:40:53 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 30 @ 89874 updates
# 2022-10-30 05:40:53 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint30.pt
# 2022-10-30 05:40:55 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint30.pt
# 2022-10-30 05:40:56 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/capsnet__nl-en_it-en_ro-en_en-de/checkpoint30.pt (epoch 30 @ 89874 updates, score 5.143) (writing took 3.066710735671222 seconds)
# 2022-10-30 05:40:56 | INFO | fairseq_cli.train | end of epoch 30 (average epoch stats below)
# 2022-10-30 05:40:56 | INFO | train | epoch 030 | loss 3.148 | nll_loss 1.401 | ppl 2.64 | wps 20508.2 | ups 5.66 | wpb 3621.9 | bsz 150.1 | num_updates 89874 | lr 0.000105483 | gnorm 1.107 | loss_scale 32 | train_wall 515 | gb_free 12 | wall 15896
# 2022-10-30 05:40:56 | INFO | fairseq_cli.train | done training in 15896.0 seconds

# %%
! echo $MODEL_DIR
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
cd /storage/master-thesis/models/quy-es+es-en
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
! rm checkpoint108.pt
! rm checkpoint109.pt
! rm checkpoint_best.pt
! rm checkpoint_last.pt

# %%
! rm dict.en.txt
! rm dict.es.txt
! rm dict.quy.txt

# %%
! du -shc /notebooks/*
# Out:
# 2.5K	/notebooks/CITATION.cff
# 5.5K	/notebooks/CODE_OF_CONDUCT.md
# 15K	/notebooks/CONTRIBUTING.md
# 19K	/notebooks/ISSUES.md
# 12K	/notebooks/LICENSE
# 512	/notebooks/MANIFEST.in
# 3.5K	/notebooks/Makefile
# 41K	/notebooks/README.md
# 41K	/notebooks/README_zh-hans.md
# 42K	/notebooks/README_zh-hant.md
# 12K	/notebooks/docker
# 4.6M	/notebooks/docs
# 5.0M	/notebooks/examples
# 8.5K	/notebooks/hubconf.py
# 7.8G	/notebooks/master-thesis
# 1.5K	/notebooks/model_cards
# 9.5K	/notebooks/notebooks
# 512	/notebooks/pyproject.toml
# 64K	/notebooks/scripts
# 1.0K	/notebooks/setup.cfg
# 13K	/notebooks/setup.py
# 13M	/notebooks/src
# 731K	/notebooks/templates
# 4.5K	/notebooks/test quy-es -> es-en model.ipynb
# 6.8M	/notebooks/tests
# 147K	/notebooks/train es-en model.ipynb
# 158K	/notebooks/train quy-es + es-en model.ipynb
# 160K	/notebooks/utils
# 3.5K	/notebooks/valohai.yaml
# 7.9G	total

# %%
! du -shc /notebooks/master-thesis/*
# Out:
# 512	/notebooks/master-thesis/Untitled.ipynb
# 362M	/notebooks/master-thesis/corpora
# 7.5G	/notebooks/master-thesis/models
# 7.8G	total

# %%
! du -shc /notebooks/master-thesis/models/*
# Out:
# 1.6G	/notebooks/master-thesis/models/es-en
# 802M	/notebooks/master-thesis/models/quy-es
# 5.2G	/notebooks/master-thesis/models/quy-es+es-en
# 7.5G	total

# %%
! du -shc /*
# Out:
# 19M	/apex
# 5.0M	/bin
# 4.0K	/boot
# 24K	/content
# ^C

# %%
ls
# Out:
#  CITATION.cff         docker/          setup.py
#  CODE_OF_CONDUCT.md   docs/            src/
#  CONTRIBUTING.md      examples/        templates/
#  ISSUES.md            hubconf.py      'test quy-es -> es-en model.ipynb'
#  LICENSE              master-thesis/   tests/
#  MANIFEST.in          model_cards/    'train es-en model.ipynb'
#  Makefile             notebooks/      'train quy-es + es-en model.ipynb'
#  README.md            pyproject.toml   utils/
#  README_zh-hans.md    scripts/         valohai.yaml
#  README_zh-hant.md    setup.cfg

# %%
# Out:
# /storage/master-thesis
