# %% [markdown]
# ## ENVIRONMENT VARIABLES

# %%
EN_IT_CORPUS_DIR = "/notebooks/master-thesis/corpora/iwslt17/en-it/"

# %%
EN_NL_CORPUS_DIR = "/notebooks/master-thesis/corpora/iwslt17/en-nl/"

# %%
EN_RO_CORPUS_DIR = "/notebooks/master-thesis/corpora/iwslt17/en-ro/"

# %%
DE_EN_CORPUS_DIR = "/notebooks/master-thesis/corpora/iwslt17/de-en/"

# %%
tokenizer_path = "/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/"

# %%
# %env TOKENIZER_PATH = /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de
# Out:
# env: TOKENIZER_PATH=/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de

# %%
tokenized_path_en_it = "/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/"
tokenized_path_en_nl = "/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/"
tokenized_path_en_ro = "/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/"
tokenized_path_de_en = "/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/"

# %%
# %env TOKENIZED_PATH_EN_IT = /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it
# %env TOKENIZED_PATH_EN_NL = /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl
# %env TOKENIZED_PATH_EN_RO = /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro
# %env TOKENIZED_PATH_DE_EN = /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en
# Out:
# env: TOKENIZED_PATH_EN_IT=/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it
# env: TOKENIZED_PATH_EN_NL=/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl
# env: TOKENIZED_PATH_EN_RO=/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro
# env: TOKENIZED_PATH_DE_EN=/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en

# %%
# %env BIN_DIR = /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin
# Out:
# env: BIN_DIR=/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
# %env MODEL_DIR = /storage/master-thesis/models/nl-en_it-en_ro-en_en-de
# Out:
# env: MODEL_DIR=/storage/master-thesis/models/nl-en_it-en_ro-en_en-de

# %%
! mkdir -p $TOKENIZED_PATH_EN_IT
! mkdir -p $TOKENIZED_PATH_EN_NL
! mkdir -p $TOKENIZED_PATH_EN_RO
! mkdir -p $TOKENIZED_PATH_DE_EN
! mkdir -p $BIN_DIR

# %%
pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |################################| 125 kB 22.4 MB/s eta 0:00:01
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (50.3.2)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5.1
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 1.9.1
# Uninstalling torch-1.9.1:
#   Successfully uninstalled torch-1.9.1
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (1821.5 MB)
#      |################################| 1821.5 MB 5.4 kB/s eta 0:00:0101B 106.9 MB/s eta 0:00:11[K     |##################              | 1050.1 MB 2.0 MB/s eta 0:06:29[K     |#####################           | 1210.0 MB 1.7 MB/s eta 0:06:09.2 MB 106.6 MB/s eta 0:00:03################# | 1776.9 MB 102.7 MB/s eta 0:00:01
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.11.3%2Bcu113-cp36-cp36m-linux_x86_64.whl (24.6 MB)
#      |################################| 24.6 MB 7.2 MB/s eta 0:00:01
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (2.9 MB)
#      |################################| 2.9 MB 7.4 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from torchvision) (8.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.18.5)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.10.2+cu113 torchaudio-0.10.2+cu113 torchvision-0.11.3+cu113
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall fairseq -y
# Out:
# Found existing installation: fairseq 0.10.2
# Uninstalling fairseq-0.10.2:
#   Successfully uninstalled fairseq-0.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fairseq
# Out:
# Collecting fairseq
#   Downloading fairseq-0.12.2-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.0 MB)
#      |################################| 11.0 MB 24.9 MB/s eta 0:00:01
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2020.11.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.51.0)
# Requirement already satisfied: numpy<1.20.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.10.2+cu113)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.8)
# Collecting hydra-core<1.1,>=1.0.7
#   Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#      |################################| 123 kB 92.5 MB/s eta 0:00:01
# Collecting bitarray
#   Downloading bitarray-2.6.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (235 kB)
#      |################################| 235 kB 81.5 MB/s eta 0:00:01
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.24)
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.10.2+cu113)
# Collecting omegaconf<2.1
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (3.10.0.2)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (5.2.2)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (4.8)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (2.3.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.8.9)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.4.4)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.6/dist-packages (from omegaconf<2.1->fairseq) (5.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core<1.1,>=1.0.7->fairseq) (3.4.0)
# Installing collected packages: omegaconf, hydra-core, bitarray, fairseq
#   Attempting uninstall: omegaconf
#     Found existing installation: omegaconf 2.1.1
#     Uninstalling omegaconf-2.1.1:
#       Successfully uninstalled omegaconf-2.1.1
#   Attempting uninstall: hydra-core
#     Found existing installation: hydra-core 1.1.1
#     Uninstalling hydra-core-1.1.1:
#       Successfully uninstalled hydra-core-1.1.1
# Successfully installed bitarray-2.6.0 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip uninstall apex -y
# Out:
# Found existing installation: apex 0.1
# Uninstalling apex-0.1:
#   Successfully uninstalled apex-0.1

# %%
! pip install -v --disable-pip-version-check --no-cache-dir apex

# %% [markdown]
# ### Tokenizing data

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece

it_nl_ro_en_de_tokenizer = Tokenizer(WordPiece(unk_token="[UNK]"))

# %%
from tokenizers.trainers import WordPieceTrainer

it_nl_ro_en_de_trainer = WordPieceTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"], show_progress=True)

# %%
from tokenizers.pre_tokenizers import Whitespace

it_nl_ro_en_de_tokenizer.pre_tokenizer = Whitespace()

en_it_files = [EN_IT_CORPUS_DIR + f"{split}.en" for split in ["valid","train"]]
it_en_files = [EN_IT_CORPUS_DIR + f"{split}.it" for split in ["valid","train"]]

en_nl_files = [EN_NL_CORPUS_DIR + f"{split}.en" for split in ["valid","train"]]
nl_en_files = [EN_NL_CORPUS_DIR + f"{split}.nl" for split in ["valid","train"]]

en_ro_files = [EN_RO_CORPUS_DIR + f"{split}.en" for split in ["valid","train"]]
ro_en_files = [EN_RO_CORPUS_DIR + f"{split}.ro" for split in ["valid","train"]]

de_en_files = [DE_EN_CORPUS_DIR + f"{split}.de" for split in ["valid", "train"]]
en_de_files = [DE_EN_CORPUS_DIR + f"{split}.en" for split in ["valid", "train"]]


files = en_it_files + it_en_files + en_nl_files + nl_en_files + en_ro_files + ro_en_files + de_en_files + en_de_files
it_nl_ro_en_de_tokenizer.train(files= files, trainer=it_nl_ro_en_de_trainer)

# %%
from pathlib import Path



def tokenize_files(tokenizer, files, extension, output_path):
    for file in files:
        print(f"Reading file {file}")
        with open(file, encoding='utf8') as f:
          lines = f.readlines()
          tokenized_lines = tokenizer.encode_batch(lines)
          tokenized_name = Path(file).stem
          tokenized_name = output_path + tokenized_name + "." + extension
          print(tokenized_name)
          with open(tokenized_name, 'w', encoding='utf8') as wf:

            wf.writelines([" ".join(t.tokens) + "\n" for t in tokenized_lines])

# %%
it_nl_ro_en_de_tokenizer.save(tokenizer_path + "it_nl_ro_en_de_tokenizer.json")

# %%
tok = it_nl_ro_en_de_tokenizer.encode("we hold this truthfbjh to be self evidently that everyone is created equal?")
print(tok.tokens)
# Out:
# ['we', 'hold', 'this', 'truth', '##f', '##b', '##j', '##h', 'to', 'be', 'self', 'evident', '##ly', 'that', 'everyone', 'is', 'created', 'equal', '?']

# %%
tokenize_files(it_nl_ro_en_de_tokenizer, en_it_files, "en", tokenized_path_en_it)
tokenize_files(it_nl_ro_en_de_tokenizer, it_en_files, "it", tokenized_path_en_it)

tokenize_files(it_nl_ro_en_de_tokenizer, en_nl_files, "en", tokenized_path_en_nl)
tokenize_files(it_nl_ro_en_de_tokenizer, nl_en_files, "nl", tokenized_path_en_nl)

tokenize_files(it_nl_ro_en_de_tokenizer, en_ro_files, "en", tokenized_path_en_ro)
tokenize_files(it_nl_ro_en_de_tokenizer, ro_en_files, "ro", tokenized_path_en_ro)

tokenize_files(it_nl_ro_en_de_tokenizer, de_en_files, "de", tokenized_path_de_en)
tokenize_files(it_nl_ro_en_de_tokenizer, en_de_files, "en", tokenized_path_de_en)
# Out:
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-it/valid.en
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/valid.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-it/train.en
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/train.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-it/valid.it
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/valid.it
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-it/train.it
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/train.it
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-nl/valid.en
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/valid.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-nl/train.en
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/train.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-nl/valid.nl
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/valid.nl
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-nl/train.nl
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/train.nl
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-ro/valid.en
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/valid.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-ro/train.en
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/train.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-ro/valid.ro
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/valid.ro
# Reading file /notebooks/master-thesis/corpora/iwslt17/en-ro/train.ro
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/train.ro
# Reading file /notebooks/master-thesis/corpora/iwslt17/de-en/valid.de
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/valid.de
# Reading file /notebooks/master-thesis/corpora/iwslt17/de-en/train.de
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/train.de
# Reading file /notebooks/master-thesis/corpora/iwslt17/de-en/valid.en
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/valid.en
# Reading file /notebooks/master-thesis/corpora/iwslt17/de-en/train.en
# /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/train.en

# %% [markdown]
# ## Binarizing data

# %%
## Concatenating all training data
! cat $TOKENIZED_PATH_EN_IT/train.en $TOKENIZED_PATH_EN_IT/train.it \
    $TOKENIZED_PATH_EN_NL/train.en $TOKENIZED_PATH_EN_NL/train.nl \
    $TOKENIZED_PATH_EN_RO/train.en $TOKENIZED_PATH_EN_RO/train.ro \
    $TOKENIZED_PATH_DE_EN/train.de $TOKENIZED_PATH_DE_EN/train.en \
    > $BIN_DIR/train.all

# %%
! fairseq-preprocess --source-lang all \
    --trainpref $BIN_DIR/train \
    --destdir $BIN_DIR \
    --workers 20 \
    --task translation_multi_simple_epoch \
    --only-source
# Out:
# 2022-09-15 08:45:12 | INFO | fairseq_cli.preprocess | Namespace(align_suffix=None, alignfile=None, all_gather_list_size=16384, bf16=False, bpe=None, checkpoint_shard_count=1, checkpoint_suffix='', cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=True, optimizer=None, padding_factor=8, profile=False, quantization_config_path=None, scoring='bleu', seed=1, source_lang='all', srcdict=None, target_lang=None, task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train', user_dir=None, validpref=None, workers=20)
# 2022-09-15 08:45:22 | INFO | fairseq_cli.preprocess | [all] Dictionary: 29312 types
# 2022-09-15 08:45:45 | INFO | fairseq_cli.preprocess | [all] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.all: 899650 sents, 20643737 tokens, 0.0% replaced by <unk>
# 2022-09-15 08:45:45 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
! fairseq-preprocess --source-lang it --target-lang en \
    --trainpref $TOKENIZED_PATH_EN_IT/train --validpref $TOKENIZED_PATH_EN_IT/valid \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-15 08:47:17 | INFO | fairseq_cli.preprocess | Namespace(align_suffix=None, alignfile=None, all_gather_list_size=16384, bf16=False, bpe=None, checkpoint_shard_count=1, checkpoint_suffix='', cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer=None, padding_factor=8, profile=False, quantization_config_path=None, scoring='bleu', seed=1, source_lang='it', srcdict='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', target_lang='en', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/train', user_dir=None, validpref='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/valid', workers=20)
# 2022-09-15 08:47:18 | INFO | fairseq_cli.preprocess | [it] Dictionary: 29312 types
# 2022-09-15 08:47:22 | INFO | fairseq_cli.preprocess | [it] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/train.it: 145105 sents, 3375399 tokens, 0.0% replaced by <unk>
# 2022-09-15 08:47:22 | INFO | fairseq_cli.preprocess | [it] Dictionary: 29312 types
# 2022-09-15 08:47:23 | INFO | fairseq_cli.preprocess | [it] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/valid.it: 929 sents, 23680 tokens, 0.0591% replaced by <unk>
# 2022-09-15 08:47:23 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-09-15 08:47:29 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/train.en: 145105 sents, 3332751 tokens, 0.0% replaced by <unk>
# 2022-09-15 08:47:29 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-09-15 08:47:30 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-it/valid.en: 929 sents, 24225 tokens, 0.066% replaced by <unk>
# 2022-09-15 08:47:30 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
! fairseq-preprocess --source-lang nl --target-lang en \
    --trainpref $TOKENIZED_PATH_EN_NL/train --validpref $TOKENIZED_PATH_EN_NL/valid \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-15 08:48:41 | INFO | fairseq_cli.preprocess | Namespace(align_suffix=None, alignfile=None, all_gather_list_size=16384, bf16=False, bpe=None, checkpoint_shard_count=1, checkpoint_suffix='', cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer=None, padding_factor=8, profile=False, quantization_config_path=None, scoring='bleu', seed=1, source_lang='nl', srcdict='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', target_lang='en', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/train', user_dir=None, validpref='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/valid', workers=20)
# 2022-09-15 08:48:42 | INFO | fairseq_cli.preprocess | [nl] Dictionary: 29312 types
# 2022-09-15 08:48:46 | INFO | fairseq_cli.preprocess | [nl] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/train.nl: 145105 sents, 3191574 tokens, 0.0% replaced by <unk>
# 2022-09-15 08:48:46 | INFO | fairseq_cli.preprocess | [nl] Dictionary: 29312 types
# 2022-09-15 08:48:46 | INFO | fairseq_cli.preprocess | [nl] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/valid.nl: 1003 sents, 22731 tokens, 0.0616% replaced by <unk>
# 2022-09-15 08:48:46 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-09-15 08:48:50 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/train.en: 145105 sents, 3332751 tokens, 0.0% replaced by <unk>
# 2022-09-15 08:48:50 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-09-15 08:48:55 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-nl/valid.en: 1003 sents, 24300 tokens, 0.0658% replaced by <unk>
# 2022-09-15 08:48:55 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
! fairseq-preprocess --source-lang ro --target-lang en \
    --trainpref $TOKENIZED_PATH_EN_RO/train --validpref $TOKENIZED_PATH_EN_RO/valid \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-15 08:49:00 | INFO | fairseq_cli.preprocess | Namespace(align_suffix=None, alignfile=None, all_gather_list_size=16384, bf16=False, bpe=None, checkpoint_shard_count=1, checkpoint_suffix='', cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer=None, padding_factor=8, profile=False, quantization_config_path=None, scoring='bleu', seed=1, source_lang='ro', srcdict='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', target_lang='en', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/train', user_dir=None, validpref='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/valid', workers=20)
# 2022-09-15 08:49:00 | INFO | fairseq_cli.preprocess | [ro] Dictionary: 29312 types
# 2022-09-15 08:49:05 | INFO | fairseq_cli.preprocess | [ro] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/train.ro: 145105 sents, 3342971 tokens, 0.0% replaced by <unk>
# 2022-09-15 08:49:05 | INFO | fairseq_cli.preprocess | [ro] Dictionary: 29312 types
# 2022-09-15 08:49:05 | INFO | fairseq_cli.preprocess | [ro] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/valid.ro: 914 sents, 25026 tokens, 0.0559% replaced by <unk>
# 2022-09-15 08:49:05 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-09-15 08:49:14 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/train.en: 145105 sents, 3332751 tokens, 0.0% replaced by <unk>
# 2022-09-15 08:49:14 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-09-15 08:49:15 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/en-ro/valid.en: 914 sents, 24223 tokens, 0.0661% replaced by <unk>
# 2022-09-15 08:49:15 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
! fairseq-preprocess --source-lang en --target-lang de \
    --trainpref $TOKENIZED_PATH_DE_EN/train --validpref $TOKENIZED_PATH_DE_EN/valid \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-15 08:49:17 | INFO | fairseq_cli.preprocess | Namespace(align_suffix=None, alignfile=None, all_gather_list_size=16384, bf16=False, bpe=None, checkpoint_shard_count=1, checkpoint_suffix='', cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer=None, padding_factor=8, profile=False, quantization_config_path=None, scoring='bleu', seed=1, source_lang='en', srcdict='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', target_lang='de', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/train', user_dir=None, validpref='/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/valid', workers=20)
# 2022-09-15 08:49:17 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-09-15 08:49:18 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/train.en: 14510 sents, 332275 tokens, 0.0% replaced by <unk>
# 2022-09-15 08:49:18 | INFO | fairseq_cli.preprocess | [en] Dictionary: 29312 types
# 2022-09-15 08:49:18 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/valid.en: 1138 sents, 24977 tokens, 2.53% replaced by <unk>
# 2022-09-15 08:49:18 | INFO | fairseq_cli.preprocess | [de] Dictionary: 29312 types
# 2022-09-15 08:49:19 | INFO | fairseq_cli.preprocess | [de] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/train.de: 14510 sents, 403265 tokens, 0.0% replaced by <unk>
# 2022-09-15 08:49:19 | INFO | fairseq_cli.preprocess | [de] Dictionary: 29312 types
# 2022-09-15 08:49:20 | INFO | fairseq_cli.preprocess | [de] /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/de-en/valid.de: 1138 sents, 31232 tokens, 0.756% replaced by <unk>
# 2022-09-15 08:49:20 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin

# %%
ls $MODEL_DIR
# Out:
# checkpoint64.pt  checkpoint_best.pt  tokenizers/
# checkpoint65.pt  checkpoint_last.pt

# %% [markdown]
# ## Training model

# %%
! fairseq-train $BIN_DIR \
    --arch=transformer --share-all-embeddings \
    --task translation_multi_simple_epoch --lang-pairs it-en,nl-en,ro-en,en-de \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 5e-5 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --dropout 0.3 --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --max-tokens 4096 \
    --restore-file $MODEL_DIR/checkpoint_last.pt \
    --save-dir $MODEL_DIR/ \
    --keep-last-epochs 2 \
    --reset-optimizer \
    --encoder-langtok "src" \
    --decoder-langtok \
    --fp16 \
    --max-epoch 200 \
    --patience 10
    #--update-freq 2
    #original lr: 5e-4
# Out:
# 2022-09-19 08:18:37 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 4096, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 4096, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 200, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [5e-05], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/', 'restore_file': '/storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': True, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': 2, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': 10, 'checkpoint_suffix': '' ...
# 2022-09-19 08:18:37 | WARNING | fairseq.data.multilingual.multilingual_data_manager | External language dictionary is not provided; use lang-pairs to infer the set of supported languages. The language ordering is not stable which might cause misalignment in pretraining and finetuning.
# 2022-09-19 08:18:37 | INFO | fairseq.data.multilingual.multilingual_data_manager | inferred language list: ['de', 'en', 'it', 'nl', 'ro']
# 2022-09-19 08:18:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | [ro] dictionary: 29317 types
# 2022-09-19 08:18:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | [en] dictionary: 29317 types
# 2022-09-19 08:18:39 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(29317, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(29317, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=512, out_features=29317, bias=False)
#   )
# )
# 2022-09-19 08:18:39 | INFO | fairseq_cli.train | task: TranslationMultiSimpleEpochTask
# 2022-09-19 08:18:39 | INFO | fairseq_cli.train | model: TransformerModel
# 2022-09-19 08:18:39 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-09-19 08:18:39 | INFO | fairseq_cli.train | num. shared model params: 78,050,816 (num. trained: 78,050,816)
# 2022-09-19 08:18:39 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-09-19 08:18:39 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for valid epoch=1/None
# 2022-09-19 08:18:39 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:18:39 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-19 08:18:39 | INFO | fairseq.data.multilingual.multilingual_data_manager | [valid] num of shards: {'main:it-en': 1, 'main:nl-en': 1, 'main:ro-en': 1, 'main:en-de': 1}
# 2022-09-19 08:18:39 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:it-en src_langtok: 29314; tgt_langtok: 29313
# 2022-09-19 08:18:39 | INFO | fairseq.data.data_utils | loaded 929 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.it-en.it
# 2022-09-19 08:18:39 | INFO | fairseq.data.data_utils | loaded 929 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.it-en.en
# 2022-09-19 08:18:39 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin valid it-en 929 examples
# 2022-09-19 08:18:39 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:nl-en src_langtok: 29315; tgt_langtok: 29313
# 2022-09-19 08:18:39 | INFO | fairseq.data.data_utils | loaded 1,003 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.nl-en.nl
# 2022-09-19 08:18:39 | INFO | fairseq.data.data_utils | loaded 1,003 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.nl-en.en
# 2022-09-19 08:18:39 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin valid nl-en 1003 examples
# 2022-09-19 08:18:39 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:ro-en src_langtok: 29316; tgt_langtok: 29313
# 2022-09-19 08:18:39 | INFO | fairseq.data.data_utils | loaded 914 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.ro-en.ro
# 2022-09-19 08:18:39 | INFO | fairseq.data.data_utils | loaded 914 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.ro-en.en
# 2022-09-19 08:18:39 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin valid ro-en 914 examples
# 2022-09-19 08:18:39 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:en-de src_langtok: 29313; tgt_langtok: 29312
# 2022-09-19 08:18:39 | INFO | fairseq.data.data_utils | loaded 1,138 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.en-de.en
# 2022-09-19 08:18:39 | INFO | fairseq.data.data_utils | loaded 1,138 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/valid.en-de.de
# 2022-09-19 08:18:39 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin valid en-de 1138 examples
# 2022-09-19 08:18:44 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.embed_tokens.weight
# 2022-09-19 08:18:44 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.output_projection.weight
# 2022-09-19 08:18:44 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-19 08:18:44 | INFO | fairseq.utils | rank   0: capabilities =  7.5  ; total memory = 15.747 GB ; name = Quadro RTX 5000
# 2022-09-19 08:18:44 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-19 08:18:44 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-09-19 08:18:44 | INFO | fairseq_cli.train | max tokens per device = 4096 and max sentences per device = None
# 2022-09-19 08:18:44 | INFO | fairseq.trainer | Preparing to load checkpoint /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint_last.pt
# 2022-09-19 08:18:48 | INFO | fairseq.trainer | Loaded checkpoint /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint_last.pt (epoch 173 @ 0 updates)
# 2022-09-19 08:18:48 | INFO | fairseq.trainer | loading train data for epoch 173
# 2022-09-19 08:18:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for train epoch=173/None
# 2022-09-19 08:18:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.multilingual_data_manager | [train] num of shards: {'main:it-en': 1, 'main:nl-en': 1, 'main:ro-en': 1, 'main:en-de': 1}
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:it-en src_langtok: 29314; tgt_langtok: 29313
# 2022-09-19 08:18:48 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.it-en.it
# 2022-09-19 08:18:48 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.it-en.en
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin train it-en 145105 examples
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:nl-en src_langtok: 29315; tgt_langtok: 29313
# 2022-09-19 08:18:48 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.nl-en.nl
# 2022-09-19 08:18:48 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.nl-en.en
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin train nl-en 145105 examples
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:ro-en src_langtok: 29316; tgt_langtok: 29313
# 2022-09-19 08:18:48 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.ro-en.ro
# 2022-09-19 08:18:48 | INFO | fairseq.data.data_utils | loaded 145,105 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.ro-en.en
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin train ro-en 145105 examples
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:en-de src_langtok: 29313; tgt_langtok: 29312
# 2022-09-19 08:18:48 | INFO | fairseq.data.data_utils | loaded 14,510 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.en-de.en
# 2022-09-19 08:18:48 | INFO | fairseq.data.data_utils | loaded 14,510 examples from: /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin/train.en-de.de
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/tokenizers/it-nl-ro-en-de/bin train en-de 14510 examples
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.multilingual_data_manager | estimated total data sizes of all shards used in sampling ratios: [('main:it-en', 145105), ('main:nl-en', 145105), ('main:ro-en', 145105), ('main:en-de', 14510)]. Note that if the data a shard has not been loaded yet, use the max known data size to approximate
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.sampling_method | selected sampler: concat
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Raw sizes: {'main:it-en': 145105, 'main:nl-en': 145105, 'main:ro-en': 145105, 'main:en-de': 14510}; raw total size: 449825
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Resampled sizes: {'main:it-en': 145105, 'main:nl-en': 145105, 'main:ro-en': 145105, 'main:en-de': 14510}; resampled total size: 449825
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] A concat dataset
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] virtual dataset established time: 0:00:00.049164
# 2022-09-19 08:18:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 08:18:48 | INFO | fairseq.data.multilingual.sampled_multi_dataset | sizes() calling time: 0:00:00.007161
# 2022-09-19 08:18:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.141846
# 2022-09-19 08:18:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:18:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.007467
# 2022-09-19 08:18:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:18:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.026495
# 2022-09-19 08:18:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.177403
# 2022-09-19 08:18:48 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:18:48 | INFO | fairseq.data.iterators | grouped total_num_itrs = 2996
# epoch 173:   0%|                                       | 0/2996 [00:00<?, ?it/s]2022-09-19 08:18:48 | INFO | fairseq.trainer | begin training epoch 173
# 2022-09-19 08:18:48 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 173:   0%|1                             | 14/2996 [00:01<05:27,  9.10it/s]2022-09-19 08:18:50 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 173:  92%|9| 2758/2996 [05:12<00:28,  8.45it/s, loss=3.226, nll_loss=1.4852022-09-19 08:24:01 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 173: 100%|9| 2995/2996 [05:39<00:00,  8.76it/s, loss=3.241, nll_loss=1.5012022-09-19 08:24:27 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 08:24:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 08:24:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001479
# 2022-09-19 08:24:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:24:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.038373
# 2022-09-19 08:24:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:24:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.029218
# 2022-09-19 08:24:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.069820
# 2022-09-19 08:24:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 173 | valid on 'valid' subset:   0%|               | 0/47 [00:00<?, ?it/s]
# epoch 173 | valid on 'valid' subset:   6%|4      | 3/47 [00:00<00:01, 24.11it/s]
# epoch 173 | valid on 'valid' subset:  15%|#      | 7/47 [00:00<00:01, 26.11it/s]
# epoch 173 | valid on 'valid' subset:  23%|#4    | 11/47 [00:00<00:01, 27.60it/s]
# epoch 173 | valid on 'valid' subset:  32%|#9    | 15/47 [00:00<00:01, 28.68it/s]
# epoch 173 | valid on 'valid' subset:  40%|##4   | 19/47 [00:00<00:00, 29.48it/s]
# epoch 173 | valid on 'valid' subset:  49%|##9   | 23/47 [00:00<00:00, 30.05it/s]
# epoch 173 | valid on 'valid' subset:  57%|###4  | 27/47 [00:00<00:00, 30.67it/s]
# epoch 173 | valid on 'valid' subset:  64%|###8  | 30/47 [00:00<00:00, 30.16it/s]
# epoch 173 | valid on 'valid' subset:  72%|####3 | 34/47 [00:01<00:00, 30.40it/s]
# epoch 173 | valid on 'valid' subset:  79%|####7 | 37/47 [00:01<00:00, 29.88it/s]
# epoch 173 | valid on 'valid' subset:  87%|#####2| 41/47 [00:01<00:00, 30.16it/s]
# epoch 173 | valid on 'valid' subset:  94%|#####6| 44/47 [00:01<00:00, 29.84it/s]
#                                                                                 2022-09-19 08:24:29 | INFO | valid | epoch 173 | valid on 'valid' subset | loss 5.239 | nll_loss 3.644 | ppl 12.5 | wps 71648.9 | wpb 2297.1 | bsz 84.8 | num_updates 2994
# 2022-09-19 08:24:29 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 173 @ 2994 updates
# 2022-09-19 08:24:29 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint173.pt
# 2022-09-19 08:24:33 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint173.pt
# 2022-09-19 08:24:36 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint173.pt (epoch 173 @ 2994 updates, score 5.239) (writing took 7.385755572468042 seconds)
# 2022-09-19 08:24:37 | INFO | fairseq_cli.train | end of epoch 173 (average epoch stats below)
# 2022-09-19 08:24:37 | INFO | train | epoch 173 | loss 3.194 | nll_loss 1.45 | ppl 2.73 | wps 31149.2 | ups 8.6 | wpb 3621.8 | bsz 150.1 | num_updates 2994 | lr 3.7425e-05 | gnorm 1.766 | loss_scale 32 | train_wall 330 | gb_free 12 | wall 352
# 2022-09-19 08:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 08:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.137375
# 2022-09-19 08:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.008038
# 2022-09-19 08:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.028079
# 2022-09-19 08:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.174700
# 2022-09-19 08:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:24:37 | INFO | fairseq.data.iterators | grouped total_num_itrs = 2996
# epoch 174:   0%|                                       | 0/2996 [00:00<?, ?it/s]2022-09-19 08:24:37 | INFO | fairseq.trainer | begin training epoch 174
# 2022-09-19 08:24:37 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 174:   0%|                               | 3/2996 [00:00<06:23,  7.80it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f4760f122b0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 174:  12%|1| 372/2996 [00:42<04:55,  8.88it/s, loss=3.217, nll_loss=1.475,Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f476a77dcc0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 174: 100%|9| 2995/2996 [05:39<00:00,  8.81it/s, loss=3.315, nll_loss=1.5852022-09-19 08:30:16 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 08:30:16 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 08:30:16 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001580
# 2022-09-19 08:30:16 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:30:16 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.038816
# 2022-09-19 08:30:16 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:30:16 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.028659
# 2022-09-19 08:30:16 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.069812
# 2022-09-19 08:30:16 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 174 | valid on 'valid' subset:   0%|               | 0/47 [00:00<?, ?it/s]
# epoch 174 | valid on 'valid' subset:   4%|2      | 2/47 [00:00<00:02, 17.52it/s]
# epoch 174 | valid on 'valid' subset:  13%|8      | 6/47 [00:00<00:02, 20.09it/s]
# epoch 174 | valid on 'valid' subset:  21%|#2    | 10/47 [00:00<00:01, 22.48it/s]
# epoch 174 | valid on 'valid' subset:  28%|#6    | 13/47 [00:00<00:01, 23.95it/s]
# epoch 174 | valid on 'valid' subset:  36%|##1   | 17/47 [00:00<00:01, 25.71it/s]
# epoch 174 | valid on 'valid' subset:  45%|##6   | 21/47 [00:00<00:00, 26.98it/s]
# epoch 174 | valid on 'valid' subset:  53%|###1  | 25/47 [00:00<00:00, 28.34it/s]
# epoch 174 | valid on 'valid' subset:  62%|###7  | 29/47 [00:00<00:00, 28.97it/s]
# epoch 174 | valid on 'valid' subset:  70%|####2 | 33/47 [00:01<00:00, 29.81it/s]
# epoch 174 | valid on 'valid' subset:  77%|####5 | 36/47 [00:01<00:00, 29.61it/s]
# epoch 174 | valid on 'valid' subset:  85%|#####1| 40/47 [00:01<00:00, 30.05it/s]
# epoch 174 | valid on 'valid' subset:  94%|#####6| 44/47 [00:01<00:00, 29.91it/s]
#                                                                                 2022-09-19 08:30:18 | INFO | valid | epoch 174 | valid on 'valid' subset | loss 5.252 | nll_loss 3.661 | ppl 12.65 | wps 70790.3 | wpb 2297.1 | bsz 84.8 | num_updates 5990 | best_loss 5.239
# 2022-09-19 08:30:18 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 174 @ 5990 updates
# 2022-09-19 08:30:18 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint174.pt
# 2022-09-19 08:30:21 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint174.pt
# 2022-09-19 08:30:23 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint174.pt (epoch 174 @ 5990 updates, score 5.252) (writing took 5.107786083593965 seconds)
# 2022-09-19 08:30:23 | INFO | fairseq_cli.train | end of epoch 174 (average epoch stats below)
# 2022-09-19 08:30:23 | INFO | train | epoch 174 | loss 3.262 | nll_loss 1.527 | ppl 2.88 | wps 31337.1 | ups 8.65 | wpb 3621.9 | bsz 150.1 | num_updates 5990 | lr 4.08589e-05 | gnorm 1.862 | loss_scale 32 | train_wall 330 | gb_free 12.2 | wall 698
# 2022-09-19 08:30:23 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 08:30:23 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.129472
# 2022-09-19 08:30:23 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:30:23 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.007197
# 2022-09-19 08:30:23 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:30:23 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.028217
# 2022-09-19 08:30:23 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.166099
# 2022-09-19 08:30:23 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:30:23 | INFO | fairseq.data.iterators | grouped total_num_itrs = 2996
# epoch 175:   0%|                                       | 0/2996 [00:00<?, ?it/s]2022-09-19 08:30:23 | INFO | fairseq.trainer | begin training epoch 175
# 2022-09-19 08:30:23 | INFO | fairseq_cli.train | Start iterating over samples
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f4760b16278>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 175:   6%| | 166/2996 [00:19<05:20,  8.84it/s, loss=3.249, nll_loss=1.51, Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f476a77dcc0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f474f8a6f28>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 175: 100%|9| 2995/2996 [05:39<00:00,  8.88it/s, loss=3.268, nll_loss=1.5352022-09-19 08:36:03 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 08:36:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 08:36:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001407
# 2022-09-19 08:36:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:36:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.041091
# 2022-09-19 08:36:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:36:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.029238
# 2022-09-19 08:36:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.072700
# 2022-09-19 08:36:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 175 | valid on 'valid' subset:   0%|               | 0/47 [00:00<?, ?it/s]
# epoch 175 | valid on 'valid' subset:   4%|2      | 2/47 [00:00<00:02, 18.27it/s]
# epoch 175 | valid on 'valid' subset:  11%|7      | 5/47 [00:00<00:02, 20.50it/s]
# epoch 175 | valid on 'valid' subset:  17%|#1     | 8/47 [00:00<00:01, 22.62it/s]
# epoch 175 | valid on 'valid' subset:  26%|#5    | 12/47 [00:00<00:01, 24.77it/s]
# epoch 175 | valid on 'valid' subset:  32%|#9    | 15/47 [00:00<00:01, 25.49it/s]
# epoch 175 | valid on 'valid' subset:  40%|##4   | 19/47 [00:00<00:01, 26.86it/s]
# epoch 175 | valid on 'valid' subset:  49%|##9   | 23/47 [00:00<00:00, 27.90it/s]
# epoch 175 | valid on 'valid' subset:  57%|###4  | 27/47 [00:00<00:00, 28.79it/s]
# epoch 175 | valid on 'valid' subset:  66%|###9  | 31/47 [00:01<00:00, 29.13it/s]
# epoch 175 | valid on 'valid' subset:  74%|####4 | 35/47 [00:01<00:00, 29.21it/s]
# epoch 175 | valid on 'valid' subset:  81%|####8 | 38/47 [00:01<00:00, 28.04it/s]
# epoch 175 | valid on 'valid' subset:  89%|#####3| 42/47 [00:01<00:00, 28.54it/s]
# epoch 175 | valid on 'valid' subset:  96%|#####7| 45/47 [00:01<00:00, 28.19it/s]
#                                                                                 2022-09-19 08:36:05 | INFO | valid | epoch 175 | valid on 'valid' subset | loss 5.233 | nll_loss 3.637 | ppl 12.44 | wps 68375.9 | wpb 2297.1 | bsz 84.8 | num_updates 8986 | best_loss 5.233
# 2022-09-19 08:36:05 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 175 @ 8986 updates
# 2022-09-19 08:36:05 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint175.pt
# 2022-09-19 08:36:08 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint175.pt
# 2022-09-19 08:36:12 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint175.pt (epoch 175 @ 8986 updates, score 5.233) (writing took 7.629277588799596 seconds)
# 2022-09-19 08:36:12 | INFO | fairseq_cli.train | end of epoch 175 (average epoch stats below)
# 2022-09-19 08:36:12 | INFO | train | epoch 175 | loss 3.243 | nll_loss 1.505 | ppl 2.84 | wps 31049.5 | ups 8.57 | wpb 3621.9 | bsz 150.1 | num_updates 8986 | lr 3.33593e-05 | gnorm 1.804 | loss_scale 32 | train_wall 330 | gb_free 12.2 | wall 1048
# 2022-09-19 08:36:12 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 08:36:12 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.139693
# 2022-09-19 08:36:12 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:36:12 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.009576
# 2022-09-19 08:36:12 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:36:12 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.041034
# 2022-09-19 08:36:12 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.192315
# 2022-09-19 08:36:12 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 08:36:13 | INFO | fairseq.data.iterators | grouped total_num_itrs = 2996
# epoch 176:   0%|                                       | 0/2996 [00:00<?, ?it/s]2022-09-19 08:36:13 | INFO | fairseq.trainer | begin training epoch 176
# 2022-09-19 08:36:13 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 176:  43%|4| 1296/2996 [02:27<03:10,  8.91it/s, loss=3.243, nll_loss=1.503Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f4760a210f0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f4760f1edd8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
# ...
# 2022-09-19 09:57:33 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 189 | valid on 'valid' subset:   0%|               | 0/47 [00:00<?, ?it/s]
# epoch 189 | valid on 'valid' subset:   6%|4      | 3/47 [00:00<00:01, 23.10it/s]
# epoch 189 | valid on 'valid' subset:  15%|#      | 7/47 [00:00<00:01, 24.78it/s]
# epoch 189 | valid on 'valid' subset:  23%|#4    | 11/47 [00:00<00:01, 26.29it/s]
# epoch 189 | valid on 'valid' subset:  30%|#7    | 14/47 [00:00<00:01, 27.13it/s]
# epoch 189 | valid on 'valid' subset:  36%|##1   | 17/47 [00:00<00:01, 27.67it/s]
# epoch 189 | valid on 'valid' subset:  43%|##5   | 20/47 [00:00<00:00, 27.80it/s]
# epoch 189 | valid on 'valid' subset:  49%|##9   | 23/47 [00:00<00:00, 28.02it/s]
# epoch 189 | valid on 'valid' subset:  55%|###3  | 26/47 [00:00<00:00, 28.18it/s]
# epoch 189 | valid on 'valid' subset:  62%|###7  | 29/47 [00:01<00:00, 28.50it/s]
# epoch 189 | valid on 'valid' subset:  70%|####2 | 33/47 [00:01<00:00, 29.15it/s]
# epoch 189 | valid on 'valid' subset:  77%|####5 | 36/47 [00:01<00:00, 29.21it/s]
# epoch 189 | valid on 'valid' subset:  83%|####9 | 39/47 [00:01<00:00, 29.00it/s]
# epoch 189 | valid on 'valid' subset:  89%|#####3| 42/47 [00:01<00:00, 29.09it/s]
# epoch 189 | valid on 'valid' subset:  96%|#####7| 45/47 [00:01<00:00, 28.69it/s]
#                                                                                 2022-09-19 09:57:35 | INFO | valid | epoch 189 | valid on 'valid' subset | loss 5.239 | nll_loss 3.649 | ppl 12.55 | wps 67563.2 | wpb 2297.1 | bsz 84.8 | num_updates 50929 | best_loss 5.23
# 2022-09-19 09:57:35 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 189 @ 50929 updates
# 2022-09-19 09:57:35 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint189.pt
# 2022-09-19 09:57:43 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint189.pt
# 2022-09-19 09:57:45 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint189.pt (epoch 189 @ 50929 updates, score 5.239) (writing took 10.317479997873306 seconds)
# 2022-09-19 09:57:45 | INFO | fairseq_cli.train | end of epoch 189 (average epoch stats below)
# 2022-09-19 09:57:45 | INFO | train | epoch 189 | loss 3.117 | nll_loss 1.362 | ppl 2.57 | wps 30250.2 | ups 8.35 | wpb 3621.9 | bsz 150.1 | num_updates 50929 | lr 1.40126e-05 | gnorm 1.783 | loss_scale 64 | train_wall 331 | gb_free 12.4 | wall 5941
# 2022-09-19 09:57:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 09:57:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.135863
# 2022-09-19 09:57:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 09:57:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.008078
# 2022-09-19 09:57:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 09:57:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.026652
# 2022-09-19 09:57:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.171832
# 2022-09-19 09:57:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 09:57:45 | INFO | fairseq.data.iterators | grouped total_num_itrs = 2996
# epoch 190:   0%|                                       | 0/2996 [00:00<?, ?it/s]2022-09-19 09:57:45 | INFO | fairseq.trainer | begin training epoch 190
# 2022-09-19 09:57:45 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 190:  30%|3| 902/2996 [01:42<03:58,  8.78it/s, loss=3.11, nll_loss=1.353, Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f476107a278>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f474fb52fd0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 190:  38%|3| 1133/2996 [02:08<03:25,  9.08it/s, loss=3.111, nll_loss=1.3552022-09-19 09:59:54 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 190: 100%|9| 2995/2996 [05:41<00:00,  8.87it/s, loss=3.115, nll_loss=1.3582022-09-19 10:03:27 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 10:03:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 10:03:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001554
# 2022-09-19 10:03:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 10:03:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.038551
# 2022-09-19 10:03:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 10:03:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.029897
# 2022-09-19 10:03:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.070800
# 2022-09-19 10:03:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 190 | valid on 'valid' subset:   0%|               | 0/47 [00:00<?, ?it/s]
# epoch 190 | valid on 'valid' subset:   6%|4      | 3/47 [00:00<00:01, 22.96it/s]
# epoch 190 | valid on 'valid' subset:  15%|#      | 7/47 [00:00<00:01, 24.89it/s]
# epoch 190 | valid on 'valid' subset:  23%|#4    | 11/47 [00:00<00:01, 26.58it/s]
# epoch 190 | valid on 'valid' subset:  32%|#9    | 15/47 [00:00<00:01, 27.62it/s]
# epoch 190 | valid on 'valid' subset:  40%|##4   | 19/47 [00:00<00:00, 28.42it/s]
# epoch 190 | valid on 'valid' subset:  47%|##8   | 22/47 [00:00<00:00, 28.38it/s]
# epoch 190 | valid on 'valid' subset:  53%|###1  | 25/47 [00:00<00:00, 28.15it/s]
# epoch 190 | valid on 'valid' subset:  60%|###5  | 28/47 [00:00<00:00, 28.00it/s]
# epoch 190 | valid on 'valid' subset:  66%|###9  | 31/47 [00:01<00:00, 27.69it/s]
# epoch 190 | valid on 'valid' subset:  72%|####3 | 34/47 [00:01<00:00, 27.76it/s]
# epoch 190 | valid on 'valid' subset:  79%|####7 | 37/47 [00:01<00:00, 27.29it/s]
# epoch 190 | valid on 'valid' subset:  85%|#####1| 40/47 [00:01<00:00, 27.52it/s]
# epoch 190 | valid on 'valid' subset:  91%|#####4| 43/47 [00:01<00:00, 27.90it/s]
# epoch 190 | valid on 'valid' subset: 100%|######| 47/47 [00:01<00:00, 28.99it/s]
#                                                                                 2022-09-19 10:03:29 | INFO | valid | epoch 190 | valid on 'valid' subset | loss 5.252 | nll_loss 3.658 | ppl 12.62 | wps 66500.3 | wpb 2297.1 | bsz 84.8 | num_updates 53924 | best_loss 5.23
# 2022-09-19 10:03:29 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 190 @ 53924 updates
# 2022-09-19 10:03:29 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint190.pt
# 2022-09-19 10:03:37 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint190.pt
# 2022-09-19 10:03:39 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint190.pt (epoch 190 @ 53924 updates, score 5.252) (writing took 10.162911595776677 seconds)
# 2022-09-19 10:03:39 | INFO | fairseq_cli.train | end of epoch 190 (average epoch stats below)
# 2022-09-19 10:03:39 | INFO | train | epoch 190 | loss 3.114 | nll_loss 1.358 | ppl 2.56 | wps 30675 | ups 8.47 | wpb 3621.9 | bsz 150.1 | num_updates 53924 | lr 1.36179e-05 | gnorm 1.786 | loss_scale 64 | train_wall 332 | gb_free 12.2 | wall 6294
# 2022-09-19 10:03:39 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 10:03:39 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.141838
# 2022-09-19 10:03:39 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 10:03:39 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.008030
# 2022-09-19 10:03:39 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 10:03:39 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.025676
# 2022-09-19 10:03:39 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.176700
# 2022-09-19 10:03:39 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 10:03:39 | INFO | fairseq.data.iterators | grouped total_num_itrs = 2996
# epoch 191:   0%|                                       | 0/2996 [00:00<?, ?it/s]2022-09-19 10:03:39 | INFO | fairseq.trainer | begin training epoch 191
# 2022-09-19 10:03:39 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 191:  21%|2| 631/2996 [01:11<04:25,  8.89it/s, loss=3.131, nll_loss=1.378,Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f476107a278>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f474fb52fd0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f4760f1e668>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 191: 100%|9| 2994/2996 [05:38<00:00,  9.18it/s, loss=3.17, nll_loss=1.421,2022-09-19 10:09:18 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 10:09:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 10:09:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001503
# 2022-09-19 10:09:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 10:09:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.037202
# 2022-09-19 10:09:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 10:09:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.027991
# 2022-09-19 10:09:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.067315
# 2022-09-19 10:09:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 191 | valid on 'valid' subset:   0%|               | 0/47 [00:00<?, ?it/s]
# epoch 191 | valid on 'valid' subset:   6%|4      | 3/47 [00:00<00:01, 24.02it/s]
# epoch 191 | valid on 'valid' subset:  13%|8      | 6/47 [00:00<00:01, 25.51it/s]
# epoch 191 | valid on 'valid' subset:  21%|#2    | 10/47 [00:00<00:01, 26.78it/s]
# epoch 191 | valid on 'valid' subset:  28%|#6    | 13/47 [00:00<00:01, 27.47it/s]
# epoch 191 | valid on 'valid' subset:  36%|##1   | 17/47 [00:00<00:01, 28.41it/s]
# epoch 191 | valid on 'valid' subset:  45%|##6   | 21/47 [00:00<00:00, 29.00it/s]
# epoch 191 | valid on 'valid' subset:  53%|###1  | 25/47 [00:00<00:00, 29.75it/s]
# epoch 191 | valid on 'valid' subset:  62%|###7  | 29/47 [00:00<00:00, 30.20it/s]
# epoch 191 | valid on 'valid' subset:  70%|####2 | 33/47 [00:01<00:00, 30.66it/s]
# epoch 191 | valid on 'valid' subset:  77%|####5 | 36/47 [00:01<00:00, 30.45it/s]
# epoch 191 | valid on 'valid' subset:  83%|####9 | 39/47 [00:01<00:00, 30.12it/s]
# epoch 191 | valid on 'valid' subset:  91%|#####4| 43/47 [00:01<00:00, 30.47it/s]
# epoch 191 | valid on 'valid' subset: 100%|######| 47/47 [00:01<00:00, 31.70it/s]
#                                                                                 2022-09-19 10:09:20 | INFO | valid | epoch 191 | valid on 'valid' subset | loss 5.255 | nll_loss 3.661 | ppl 12.65 | wps 70826.2 | wpb 2297.1 | bsz 84.8 | num_updates 56920 | best_loss 5.23
# 2022-09-19 10:09:20 | INFO | fairseq_cli.train | early stop since valid performance hasn't improved for last 10 runs
# 2022-09-19 10:09:20 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 191 @ 56920 updates
# 2022-09-19 10:09:20 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint191.pt
# 2022-09-19 10:09:28 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint191.pt
# 2022-09-19 10:09:30 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/nl-en_it-en_ro-en_en-de/checkpoint191.pt (epoch 191 @ 56920 updates, score 5.255) (writing took 10.208095835521817 seconds)
# 2022-09-19 10:09:32 | INFO | fairseq_cli.train | end of epoch 191 (average epoch stats below)
# 2022-09-19 10:09:32 | INFO | train | epoch 191 | loss 3.109 | nll_loss 1.353 | ppl 2.55 | wps 30717.9 | ups 8.48 | wpb 3621.9 | bsz 150.1 | num_updates 56920 | lr 1.32546e-05 | gnorm 1.791 | loss_scale 64 | train_wall 330 | gb_free 12 | wall 6648
# 2022-09-19 10:09:32 | INFO | fairseq_cli.train | done training in 6643.9 seconds

# %%
! echo $MODEL_DIR
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
cd /storage/master-thesis/models/quy-es+es-en
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
! rm checkpoint108.pt
! rm checkpoint109.pt
! rm checkpoint_best.pt
! rm checkpoint_last.pt

# %%
! rm dict.en.txt
! rm dict.es.txt
! rm dict.quy.txt

# %%
! du -shc /notebooks/*
# Out:
# 2.5K	/notebooks/CITATION.cff
# 5.5K	/notebooks/CODE_OF_CONDUCT.md
# 15K	/notebooks/CONTRIBUTING.md
# 19K	/notebooks/ISSUES.md
# 12K	/notebooks/LICENSE
# 512	/notebooks/MANIFEST.in
# 3.5K	/notebooks/Makefile
# 41K	/notebooks/README.md
# 41K	/notebooks/README_zh-hans.md
# 42K	/notebooks/README_zh-hant.md
# 12K	/notebooks/docker
# 4.6M	/notebooks/docs
# 5.0M	/notebooks/examples
# 8.5K	/notebooks/hubconf.py
# 7.8G	/notebooks/master-thesis
# 1.5K	/notebooks/model_cards
# 9.5K	/notebooks/notebooks
# 512	/notebooks/pyproject.toml
# 64K	/notebooks/scripts
# 1.0K	/notebooks/setup.cfg
# 13K	/notebooks/setup.py
# 13M	/notebooks/src
# 731K	/notebooks/templates
# 4.5K	/notebooks/test quy-es -> es-en model.ipynb
# 6.8M	/notebooks/tests
# 147K	/notebooks/train es-en model.ipynb
# 158K	/notebooks/train quy-es + es-en model.ipynb
# 160K	/notebooks/utils
# 3.5K	/notebooks/valohai.yaml
# 7.9G	total

# %%
! du -shc /notebooks/master-thesis/*
# Out:
# 512	/notebooks/master-thesis/Untitled.ipynb
# 362M	/notebooks/master-thesis/corpora
# 7.5G	/notebooks/master-thesis/models
# 7.8G	total

# %%
! du -shc /notebooks/master-thesis/models/*
# Out:
# 1.6G	/notebooks/master-thesis/models/es-en
# 802M	/notebooks/master-thesis/models/quy-es
# 5.2G	/notebooks/master-thesis/models/quy-es+es-en
# 7.5G	total

# %%
! du -shc /*
# Out:
# 19M	/apex
# 5.0M	/bin
# 4.0K	/boot
# 24K	/content
# ^C

# %%
ls
# Out:
#  CITATION.cff         docker/          setup.py
#  CODE_OF_CONDUCT.md   docs/            src/
#  CONTRIBUTING.md      examples/        templates/
#  ISSUES.md            hubconf.py      'test quy-es -> es-en model.ipynb'
#  LICENSE              master-thesis/   tests/
#  MANIFEST.in          model_cards/    'train es-en model.ipynb'
#  Makefile             notebooks/      'train quy-es + es-en model.ipynb'
#  README.md            pyproject.toml   utils/
#  README_zh-hans.md    scripts/         valohai.yaml
#  README_zh-hant.md    setup.cfg

# %%
# Out:
# /storage/master-thesis
