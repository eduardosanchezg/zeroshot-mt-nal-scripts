# %% [markdown]
# ## ENVIRONMENT VARIABLES

# %%
EN_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/"

# %%
AYM_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish"

# %%
QUY_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish"

# %%
tokenizer_path = "/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/"

# %%
# %env TOKENIZER_PATH = /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en
# Out:
# env: TOKENIZER_PATH=/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en

# %%
tokenized_path_es_en = "/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en/"
tokenized_path_quy_es = "/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es/"
tokenized_path_aym_es = "/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es/"

# %%
# %env TOKENIZED_PATH_ES_EN = /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en
# %env TOKENIZED_PATH_QUY_ES = /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es
# %env TOKENIZED_PATH_AYM_ES = /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es
# Out:
# env: TOKENIZED_PATH_ES_EN=/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en
# env: TOKENIZED_PATH_QUY_ES=/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es
# env: TOKENIZED_PATH_AYM_ES=/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es

# %%
# %env BIN_DIR = /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin
# Out:
# env: BIN_DIR=/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin

# %%
# %env MODEL_DIR = /storage/master-thesis/models/quy-es++aym-es++es-en
# Out:
# env: MODEL_DIR=/storage/master-thesis/models/quy-es++aym-es++es-en

# %%
! mkdir -p $TOKENIZED_PATH_ES_EN
! mkdir -p $TOKENIZED_PATH_QUY_ES
! mkdir -p $TOKENIZED_PATH_AYM_ES
! mkdir -p $BIN_DIR

# %%
! locale
# Out:
# LANG=
# LANGUAGE=
# LC_CTYPE="POSIX"
# LC_NUMERIC="POSIX"
# LC_TIME="POSIX"
# LC_COLLATE="POSIX"
# LC_MONETARY="POSIX"
# LC_MESSAGES="POSIX"
# LC_PAPER="POSIX"
# LC_NAME="POSIX"
# LC_ADDRESS="POSIX"
# LC_TELEPHONE="POSIX"
# LC_MEASUREMENT="POSIX"
# LC_IDENTIFICATION="POSIX"
# LC_ALL=

# %%
! update-locale LANG=en_US.UTF-8 LANGUAGE=en.UTF-8

# %env LANG=en_US.UTF-8
# %env LC_CTYPE=en_US.UTF-8
# %env LC_ALL=en_US.UTF-8
# Out:
# /bin/sh: 1: update-locale: not found
# env: LANG=en_US.UTF-8
# env: LC_CTYPE=en_US.UTF-8
# env: LC_ALL=en_US.UTF-8

# %% [markdown]
# ## Libraries

# %%
pip install tokenizers==0.10.3
# Out:
# Requirement already satisfied: tokenizers==0.10.3 in /usr/local/lib/python3.6/dist-packages (0.10.3)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 1.10.2+cu113
# Uninstalling torch-1.10.2+cu113:
#   Successfully uninstalled torch-1.10.2+cu113
# Found existing installation: torchvision 0.11.3+cu113
# Uninstalling torchvision-0.11.3+cu113:
#   Successfully uninstalled torchvision-0.11.3+cu113
# Found existing installation: torchaudio 0.10.2+cu113
# Uninstalling torchaudio-0.10.2+cu113:
#   Successfully uninstalled torchaudio-0.10.2+cu113
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cu113/torch-1.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (1821.5 MB)
# Collecting torchvision
#   Using cached https://download.pytorch.org/whl/cu113/torchvision-0.11.3%2Bcu113-cp36-cp36m-linux_x86_64.whl (24.6 MB)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/cu113/torchaudio-0.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (2.9 MB)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.18.5)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from torchvision) (8.3.2)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.10.2+cu113 torchaudio-0.10.2+cu113 torchvision-0.11.3+cu113
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall fairseq -y
# Out:
# Found existing installation: fairseq 0.12.2
# Uninstalling fairseq-0.12.2:
#   Successfully uninstalled fairseq-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fairseq # --no-deps
# Out:
# Collecting fairseq
#   Using cached fairseq-0.12.2-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.0 MB)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.10.2+cu113)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.8)
# Requirement already satisfied: bitarray in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.6.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2020.11.13)
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.51.0)
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.10.2+cu113)
# Requirement already satisfied: numpy<1.20.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Requirement already satisfied: omegaconf<2.1 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.6)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.24)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.3)
# Requirement already satisfied: hydra-core<1.1,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.0.7)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (3.10.0.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.4.4)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (2.3.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.8.9)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.6/dist-packages (from omegaconf<2.1->fairseq) (5.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (4.8)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (5.2.2)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core<1.1,>=1.0.7->fairseq) (3.4.0)
# Installing collected packages: fairseq
# Successfully installed fairseq-0.12.2
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip uninstall apex -y
# Out:
# Found existing installation: apex 0.9.10.dev0
# Uninstalling apex-0.9.10.dev0:
#   Successfully uninstalled apex-0.9.10.dev0

# %%
rm -r apex
# Out:
# rm: cannot remove 'apex': No such file or directory

# %%
#! git clone https://github.com/NVIDIA/apex

! pip install -v --disable-pip-version-check --no-cache-dir apex
# Out:
# Using pip 20.2.4 from /usr/local/lib/python3.6/dist-packages/pip (python 3.6)
# Non-user install because site-packages writeable
# Created temporary directory: /tmp/pip-ephem-wheel-cache-93xyggrm
# Created temporary directory: /tmp/pip-req-tracker-hypa8ikn
# Initialized build tracking at /tmp/pip-req-tracker-hypa8ikn
# Created build tracker: /tmp/pip-req-tracker-hypa8ikn
# Entered build tracker: /tmp/pip-req-tracker-hypa8ikn
# Created temporary directory: /tmp/pip-install-kubqtf0z
# 1 location(s) to search for versions of apex:
# * https://pypi.org/simple/apex/
# Fetching project page and analyzing links: https://pypi.org/simple/apex/
# Getting page https://pypi.org/simple/apex/
# Found index url https://pypi.org/simple
# Starting new HTTPS connection (1): pypi.org:443
# https://pypi.org:443 "GET /simple/apex/ HTTP/1.1" 200 709
#   Found link https://files.pythonhosted.org/packages/24/ce/5cb0a89aaaa08a6ad5919d4c7c39eabec148f545d7b1e1a23e6af131c73c/apex-0.9.8dev.linux-i686.tar.gz#sha256=c592d7152caae257613b4dcd9f3dbd181e9163be3f5cf3cbdd71daf9c89f79bd (from https://pypi.org/simple/apex/), version: 0.9.8dev.linux-i686
#   Found link https://files.pythonhosted.org/packages/01/22/ef3e010781b221c2cb06c8687070c3926a24702d76e980636fc13671986d/apex-0.9.8dev.tar.gz#sha256=399be6a17510944d64988ae694ac9e27a1880df4d891313909f2d49e53e35464 (from https://pypi.org/simple/apex/), version: 0.9.8dev
#   Found link https://files.pythonhosted.org/packages/f0/28/ec2fcc1ec0e2fa0b07812b8799e10b042dae71d43790b59053d6b27018fb/apex-0.9.8adev.tar.gz#sha256=da4c1858c3a0a00db5da605d81589d376268bd6cc4b06896d1298dd882b9b2dc (from https://pypi.org/simple/apex/), version: 0.9.8adev
#   Found link https://files.pythonhosted.org/packages/57/c0/085e75b7ff40f2e33082ac88bc3c4cbec6aa106a8901572910b49577bd65/apex-0.9.9dev.tar.gz#sha256=f1e82d56944d093ca073044e246e67279c28bcb40cc8a4e62d2ee799576a40d8 (from https://pypi.org/simple/apex/), version: 0.9.9dev
#   Found link https://files.pythonhosted.org/packages/31/b6/923de12ffcc2686157d7f74b96396b87c854eaaeec9d441d120facc2a0e0/apex-0.9.10dev.tar.gz#sha256=48aa6d9e805e661e609161bd52e0d02d89a9a32f32dc29cde6c950df58129119 (from https://pypi.org/simple/apex/), version: 0.9.10dev
# Given no hashes to check 4 links for project 'apex': discarding no candidates
# Using version 0.9.10.dev0 (newest of versions: 0.9.8.dev0, 0.9.8a0.dev0, 0.9.9.dev0, 0.9.10.dev0)
# Collecting apex
#   Created temporary directory: /tmp/pip-unpack-6_a3__jl
#   Starting new HTTPS connection (1): files.pythonhosted.org:443
#   https://files.pythonhosted.org:443 "GET /packages/31/b6/923de12ffcc2686157d7f74b96396b87c854eaaeec9d441d120facc2a0e0/apex-0.9.10dev.tar.gz HTTP/1.1" 200 36085
#   Downloading apex-0.9.10dev.tar.gz (36 kB)
#   Added apex from https://files.pythonhosted.org/packages/31/b6/923de12ffcc2686157d7f74b96396b87c854eaaeec9d441d120facc2a0e0/apex-0.9.10dev.tar.gz#sha256=48aa6d9e805e661e609161bd52e0d02d89a9a32f32dc29cde6c950df58129119 to build tracker '/tmp/pip-req-tracker-hypa8ikn'
#     Running setup.py (path:/tmp/pip-install-kubqtf0z/apex/setup.py) egg_info for package apex
#     Created temporary directory: /tmp/pip-pip-egg-info-1pvcuph6
#     Running command python setup.py egg_info
#     running egg_info
#     creating /tmp/pip-pip-egg-info-1pvcuph6/apex.egg-info
#     writing /tmp/pip-pip-egg-info-1pvcuph6/apex.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-1pvcuph6/apex.egg-info/dependency_links.txt
#     writing entry points to /tmp/pip-pip-egg-info-1pvcuph6/apex.egg-info/entry_points.txt
#     writing requirements to /tmp/pip-pip-egg-info-1pvcuph6/apex.egg-info/requires.txt
#     writing top-level names to /tmp/pip-pip-egg-info-1pvcuph6/apex.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-1pvcuph6/apex.egg-info/SOURCES.txt'
#     reading manifest file '/tmp/pip-pip-egg-info-1pvcuph6/apex.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     writing manifest file '/tmp/pip-pip-egg-info-1pvcuph6/apex.egg-info/SOURCES.txt'
#   Source in /tmp/pip-install-kubqtf0z/apex has version 0.9.10.dev0, which satisfies requirement apex from https://files.pythonhosted.org/packages/31/b6/923de12ffcc2686157d7f74b96396b87c854eaaeec9d441d120facc2a0e0/apex-0.9.10dev.tar.gz#sha256=48aa6d9e805e661e609161bd52e0d02d89a9a32f32dc29cde6c950df58129119
#   Removed apex from https://files.pythonhosted.org/packages/31/b6/923de12ffcc2686157d7f74b96396b87c854eaaeec9d441d120facc2a0e0/apex-0.9.10dev.tar.gz#sha256=48aa6d9e805e661e609161bd52e0d02d89a9a32f32dc29cde6c950df58129119 from build tracker '/tmp/pip-req-tracker-hypa8ikn'
# Requirement already satisfied: cryptacular in /usr/local/lib/python3.6/dist-packages (from apex) (1.6.2)
# Requirement already satisfied: zope.sqlalchemy in /usr/local/lib/python3.6/dist-packages (from apex) (1.6)
# Requirement already satisfied: velruse>=1.0.3 in /usr/local/lib/python3.6/dist-packages (from apex) (1.1.1)
# Requirement already satisfied: pyramid>1.1.2 in /usr/local/lib/python3.6/dist-packages (from apex) (2.0)
# Requirement already satisfied: pyramid_mailer in /usr/local/lib/python3.6/dist-packages (from apex) (0.15.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from apex) (2.25.0)
# Requirement already satisfied: wtforms in /usr/local/lib/python3.6/dist-packages (from apex) (3.0.0)
# Requirement already satisfied: wtforms-recaptcha in /usr/local/lib/python3.6/dist-packages (from apex) (0.3.2)
# Requirement already satisfied: pbkdf2 in /usr/local/lib/python3.6/dist-packages (from cryptacular->apex) (1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from cryptacular->apex) (50.3.2)
# Requirement already satisfied: SQLAlchemy!=1.4.0,!=1.4.1,!=1.4.2,!=1.4.3,!=1.4.4,!=1.4.5,!=1.4.6,>=0.9 in /usr/local/lib/python3.6/dist-packages (from zope.sqlalchemy->apex) (1.4.41)
# Requirement already satisfied: transaction>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from zope.sqlalchemy->apex) (3.0.1)
# Requirement already satisfied: zope.interface>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from zope.sqlalchemy->apex) (5.4.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.6/dist-packages (from velruse>=1.0.3->apex) (1.3.0)
# Requirement already satisfied: anykeystore in /usr/local/lib/python3.6/dist-packages (from velruse>=1.0.3->apex) (0.2)
# Requirement already satisfied: python3-openid in /usr/local/lib/python3.6/dist-packages (from velruse>=1.0.3->apex) (3.2.0)
# Requirement already satisfied: zope.deprecation>=3.5.0 in /usr/local/lib/python3.6/dist-packages (from pyramid>1.1.2->apex) (4.4.0)
# Requirement already satisfied: venusian>=1.0 in /usr/local/lib/python3.6/dist-packages (from pyramid>1.1.2->apex) (3.0.0)
# Requirement already satisfied: hupper>=1.5 in /usr/local/lib/python3.6/dist-packages (from pyramid>1.1.2->apex) (1.10.3)
# Requirement already satisfied: plaster in /usr/local/lib/python3.6/dist-packages (from pyramid>1.1.2->apex) (1.0)
# Requirement already satisfied: plaster-pastedeploy in /usr/local/lib/python3.6/dist-packages (from pyramid>1.1.2->apex) (0.7)
# Requirement already satisfied: translationstring>=0.4 in /usr/local/lib/python3.6/dist-packages (from pyramid>1.1.2->apex) (1.4)
# Requirement already satisfied: webob>=1.8.3 in /usr/local/lib/python3.6/dist-packages (from pyramid>1.1.2->apex) (1.8.7)
# Requirement already satisfied: repoze.sendmail>=4.1 in /usr/local/lib/python3.6/dist-packages (from pyramid_mailer->apex) (4.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->apex) (1.26.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->apex) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests->apex) (2.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->apex) (3.0.4)
# Requirement already satisfied: MarkupSafe in /usr/local/lib/python3.6/dist-packages (from wtforms->apex) (1.1.1)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /usr/local/lib/python3.6/dist-packages (from SQLAlchemy!=1.4.0,!=1.4.1,!=1.4.2,!=1.4.3,!=1.4.4,!=1.4.5,!=1.4.6,>=0.9->zope.sqlalchemy->apex) (1.1.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from SQLAlchemy!=1.4.0,!=1.4.1,!=1.4.2,!=1.4.3,!=1.4.4,!=1.4.5,!=1.4.6,>=0.9->zope.sqlalchemy->apex) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib->velruse>=1.0.3->apex) (3.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from python3-openid->velruse>=1.0.3->apex) (0.6.0)
# Requirement already satisfied: PasteDeploy>=2.0 in /usr/local/lib/python3.6/dist-packages (from plaster-pastedeploy->pyramid>1.1.2->apex) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->SQLAlchemy!=1.4.0,!=1.4.1,!=1.4.2,!=1.4.3,!=1.4.4,!=1.4.5,!=1.4.6,>=0.9->zope.sqlalchemy->apex) (3.4.0)
# Building wheels for collected packages: apex
#   Created temporary directory: /tmp/pip-wheel-zsqleyba
#   Building wheel for apex (setup.py) ...   Destination directory: /tmp/pip-wheel-zsqleyba
#   Running command /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-kubqtf0z/apex/setup.py'"'"'; __file__='"'"'/tmp/pip-install-kubqtf0z/apex/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-zsqleyba
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   creating build/lib/apex
#   copying apex/exceptions.py -> build/lib/apex
#   copying apex/forms.py -> build/lib/apex
#   copying apex/interfaces.py -> build/lib/apex
#   copying apex/decorators.py -> build/lib/apex
#   copying apex/models.py -> build/lib/apex
#   copying apex/views.py -> build/lib/apex
#   copying apex/i18n.py -> build/lib/apex
#   copying apex/__init__.py -> build/lib/apex
#   creating build/lib/apex/tests
#   copying apex/tests/test_views.py -> build/lib/apex/tests
#   copying apex/tests/test_lib_libapex.py -> build/lib/apex/tests
#   copying apex/tests/__init__.py -> build/lib/apex/tests
#   creating build/lib/apex/ext
#   copying apex/ext/deform.py -> build/lib/apex/ext
#   copying apex/ext/__init__.py -> build/lib/apex/ext
#   creating build/lib/apex/lib
#   copying apex/lib/fallbacks.py -> build/lib/apex/lib
#   copying apex/lib/libapex.py -> build/lib/apex/lib
#   copying apex/lib/flash.py -> build/lib/apex/lib
#   copying apex/lib/db.py -> build/lib/apex/lib
#   copying apex/lib/form.py -> build/lib/apex/lib
#   copying apex/lib/i18n.py -> build/lib/apex/lib
#   copying apex/lib/subscribers.py -> build/lib/apex/lib
#   copying apex/lib/__init__.py -> build/lib/apex/lib
#   creating build/lib/apex/scaffolds
#   copying apex/scaffolds/__init__.py -> build/lib/apex/scaffolds
#   running egg_info
#   writing apex.egg-info/PKG-INFO
#   writing dependency_links to apex.egg-info/dependency_links.txt
#   writing entry points to apex.egg-info/entry_points.txt
#   writing requirements to apex.egg-info/requires.txt
#   writing top-level names to apex.egg-info/top_level.txt
#   reading manifest file 'apex.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   writing manifest file 'apex.egg-info/SOURCES.txt'
#   creating build/lib/apex/locale
#   copying apex/locale/apex.pot -> build/lib/apex/locale
#   creating build/lib/apex/locale/fr
#   creating build/lib/apex/locale/fr/LC_MESSAGES
#   copying apex/locale/fr/LC_MESSAGES/Apex.mo -> build/lib/apex/locale/fr/LC_MESSAGES
#   copying apex/locale/fr/LC_MESSAGES/Apex.po -> build/lib/apex/locale/fr/LC_MESSAGES
#   creating build/lib/apex/static
#   creating build/lib/apex/static/css
#   copying apex/static/css/apex_flash.css -> build/lib/apex/static/css
#   copying apex/static/css/apex_forms.css -> build/lib/apex/static/css
#   creating build/lib/apex/static/images
#   copying apex/static/images/fb-connect.png -> build/lib/apex/static/images
#   copying apex/static/images/google-connect.png -> build/lib/apex/static/images
#   copying apex/static/images/twitter-connect.png -> build/lib/apex/static/images
#   creating build/lib/apex/templates
#   copying apex/templates/apex_callback.mako -> build/lib/apex/templates
#   copying apex/templates/apex_template.mako -> build/lib/apex/templates
#   copying apex/templates/apex_template.pt -> build/lib/apex/templates
#   copying apex/templates/flash_template.jinja2 -> build/lib/apex/templates
#   copying apex/templates/flash_template.mako -> build/lib/apex/templates
#   copying apex/templates/flash_template.pt -> build/lib/apex/templates
#   copying apex/templates/login_template.mako -> build/lib/apex/templates
#   creating build/lib/apex/templates/forms
#   copying apex/templates/forms/fieldsetform.mako -> build/lib/apex/templates/forms
#   copying apex/templates/forms/tableform.mako -> build/lib/apex/templates/forms
#   copying apex/templates/forms/tableform.pt -> build/lib/apex/templates/forms
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/apex
#   creating build/bdist.linux-x86_64/wheel/apex/static
#   creating build/bdist.linux-x86_64/wheel/apex/static/images
#   copying build/lib/apex/static/images/fb-connect.png -> build/bdist.linux-x86_64/wheel/apex/static/images
#   copying build/lib/apex/static/images/google-connect.png -> build/bdist.linux-x86_64/wheel/apex/static/images
#   copying build/lib/apex/static/images/twitter-connect.png -> build/bdist.linux-x86_64/wheel/apex/static/images
#   creating build/bdist.linux-x86_64/wheel/apex/static/css
#   copying build/lib/apex/static/css/apex_forms.css -> build/bdist.linux-x86_64/wheel/apex/static/css
#   copying build/lib/apex/static/css/apex_flash.css -> build/bdist.linux-x86_64/wheel/apex/static/css
#   copying build/lib/apex/exceptions.py -> build/bdist.linux-x86_64/wheel/apex
#   copying build/lib/apex/forms.py -> build/bdist.linux-x86_64/wheel/apex
#   creating build/bdist.linux-x86_64/wheel/apex/templates
#   copying build/lib/apex/templates/flash_template.pt -> build/bdist.linux-x86_64/wheel/apex/templates
#   copying build/lib/apex/templates/flash_template.jinja2 -> build/bdist.linux-x86_64/wheel/apex/templates
#   creating build/bdist.linux-x86_64/wheel/apex/templates/forms
#   copying build/lib/apex/templates/forms/tableform.mako -> build/bdist.linux-x86_64/wheel/apex/templates/forms
#   copying build/lib/apex/templates/forms/fieldsetform.mako -> build/bdist.linux-x86_64/wheel/apex/templates/forms
#   copying build/lib/apex/templates/forms/tableform.pt -> build/bdist.linux-x86_64/wheel/apex/templates/forms
#   copying build/lib/apex/templates/apex_template.mako -> build/bdist.linux-x86_64/wheel/apex/templates
#   copying build/lib/apex/templates/apex_callback.mako -> build/bdist.linux-x86_64/wheel/apex/templates
#   copying build/lib/apex/templates/login_template.mako -> build/bdist.linux-x86_64/wheel/apex/templates
#   copying build/lib/apex/templates/apex_template.pt -> build/bdist.linux-x86_64/wheel/apex/templates
#   copying build/lib/apex/templates/flash_template.mako -> build/bdist.linux-x86_64/wheel/apex/templates
#   creating build/bdist.linux-x86_64/wheel/apex/tests
#   copying build/lib/apex/tests/test_views.py -> build/bdist.linux-x86_64/wheel/apex/tests
#   copying build/lib/apex/tests/test_lib_libapex.py -> build/bdist.linux-x86_64/wheel/apex/tests
#   copying build/lib/apex/tests/__init__.py -> build/bdist.linux-x86_64/wheel/apex/tests
#   creating build/bdist.linux-x86_64/wheel/apex/ext
#   copying build/lib/apex/ext/deform.py -> build/bdist.linux-x86_64/wheel/apex/ext
#   copying build/lib/apex/ext/__init__.py -> build/bdist.linux-x86_64/wheel/apex/ext
#   creating build/bdist.linux-x86_64/wheel/apex/lib
#   copying build/lib/apex/lib/fallbacks.py -> build/bdist.linux-x86_64/wheel/apex/lib
#   copying build/lib/apex/lib/libapex.py -> build/bdist.linux-x86_64/wheel/apex/lib
#   copying build/lib/apex/lib/flash.py -> build/bdist.linux-x86_64/wheel/apex/lib
#   copying build/lib/apex/lib/db.py -> build/bdist.linux-x86_64/wheel/apex/lib
#   copying build/lib/apex/lib/form.py -> build/bdist.linux-x86_64/wheel/apex/lib
#   copying build/lib/apex/lib/i18n.py -> build/bdist.linux-x86_64/wheel/apex/lib
#   copying build/lib/apex/lib/subscribers.py -> build/bdist.linux-x86_64/wheel/apex/lib
#   copying build/lib/apex/lib/__init__.py -> build/bdist.linux-x86_64/wheel/apex/lib
#   copying build/lib/apex/interfaces.py -> build/bdist.linux-x86_64/wheel/apex
#   copying build/lib/apex/decorators.py -> build/bdist.linux-x86_64/wheel/apex
#   creating build/bdist.linux-x86_64/wheel/apex/locale
#   creating build/bdist.linux-x86_64/wheel/apex/locale/fr
#   creating build/bdist.linux-x86_64/wheel/apex/locale/fr/LC_MESSAGES
#   copying build/lib/apex/locale/fr/LC_MESSAGES/Apex.po -> build/bdist.linux-x86_64/wheel/apex/locale/fr/LC_MESSAGES
#   copying build/lib/apex/locale/fr/LC_MESSAGES/Apex.mo -> build/bdist.linux-x86_64/wheel/apex/locale/fr/LC_MESSAGES
#   copying build/lib/apex/locale/apex.pot -> build/bdist.linux-x86_64/wheel/apex/locale
#   copying build/lib/apex/models.py -> build/bdist.linux-x86_64/wheel/apex
#   creating build/bdist.linux-x86_64/wheel/apex/scaffolds
#   copying build/lib/apex/scaffolds/__init__.py -> build/bdist.linux-x86_64/wheel/apex/scaffolds
#   copying build/lib/apex/views.py -> build/bdist.linux-x86_64/wheel/apex
#   copying build/lib/apex/i18n.py -> build/bdist.linux-x86_64/wheel/apex
#   copying build/lib/apex/__init__.py -> build/bdist.linux-x86_64/wheel/apex
#   running install_egg_info
#   Copying apex.egg-info to build/bdist.linux-x86_64/wheel/apex-0.9.10.dev0-py3.6.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/apex-0.9.10.dev0.dist-info/WHEEL
#   creating '/tmp/pip-wheel-zsqleyba/apex-0.9.10.dev0-py3-none-any.whl' and adding '.' to it
#   adding 'apex/__init__.py'
#   adding 'apex/decorators.py'
#   adding 'apex/exceptions.py'
#   adding 'apex/forms.py'
#   adding 'apex/i18n.py'
#   adding 'apex/interfaces.py'
#   adding 'apex/models.py'
#   adding 'apex/views.py'
#   adding 'apex/ext/__init__.py'
#   adding 'apex/ext/deform.py'
#   adding 'apex/lib/__init__.py'
#   adding 'apex/lib/db.py'
#   adding 'apex/lib/fallbacks.py'
#   adding 'apex/lib/flash.py'
#   adding 'apex/lib/form.py'
#   adding 'apex/lib/i18n.py'
#   adding 'apex/lib/libapex.py'
#   adding 'apex/lib/subscribers.py'
#   adding 'apex/locale/apex.pot'
#   adding 'apex/locale/fr/LC_MESSAGES/Apex.mo'
#   adding 'apex/locale/fr/LC_MESSAGES/Apex.po'
#   adding 'apex/scaffolds/__init__.py'
#   adding 'apex/static/css/apex_flash.css'
#   adding 'apex/static/css/apex_forms.css'
#   adding 'apex/static/images/fb-connect.png'
#   adding 'apex/static/images/google-connect.png'
#   adding 'apex/static/images/twitter-connect.png'
#   adding 'apex/templates/apex_callback.mako'
#   adding 'apex/templates/apex_template.mako'
#   adding 'apex/templates/apex_template.pt'
#   adding 'apex/templates/flash_template.jinja2'
#   adding 'apex/templates/flash_template.mako'
#   adding 'apex/templates/flash_template.pt'
#   adding 'apex/templates/login_template.mako'
#   adding 'apex/templates/forms/fieldsetform.mako'
#   adding 'apex/templates/forms/tableform.mako'
#   adding 'apex/templates/forms/tableform.pt'
#   adding 'apex/tests/__init__.py'
#   adding 'apex/tests/test_lib_libapex.py'
#   adding 'apex/tests/test_views.py'
#   adding 'apex-0.9.10.dev0.dist-info/DESCRIPTION.rst'
#   adding 'apex-0.9.10.dev0.dist-info/entry_points.txt'
#   adding 'apex-0.9.10.dev0.dist-info/metadata.json'
#   adding 'apex-0.9.10.dev0.dist-info/top_level.txt'
#   adding 'apex-0.9.10.dev0.dist-info/zip-safe'
#   adding 'apex-0.9.10.dev0.dist-info/WHEEL'
#   adding 'apex-0.9.10.dev0.dist-info/METADATA'
#   adding 'apex-0.9.10.dev0.dist-info/RECORD'
# done
#   Created wheel for apex: filename=apex-0.9.10.dev0-py3-none-any.whl size=47478 sha256=6427306992b23a58943248223836599d54da1cd5967bd22c30403e56e63d4184
#   Stored in directory: /tmp/pip-ephem-wheel-cache-93xyggrm/wheels/b9/61/0b/24e8149602cfffd8d422f27e8364a8a24086c59e6794854ee7
# Successfully built apex
# Installing collected packages: apex
#
# Successfully installed apex-0.9.10.dev0
# Removed build tracker: '/tmp/pip-req-tracker-hypa8ikn'

# %%
pip install tensorboardX
# Out:
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.6/dist-packages (2.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.5)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.13.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (50.3.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Converting tatoeba format to standard format

# %%
import csv

with open(EN_ES_CORPUS_DIR + "original/valid.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "dev.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "dev.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
    en.close()
    es.close()
    
with open(EN_ES_CORPUS_DIR + "original/dev.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "train.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "train.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        if "\n" in line[2] or "\n" in line[3]:
            continue
        if len(line) != 4:
            continue
            
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
        
    en.close()
    es.close()

# %% [markdown]
# ### Tokenizing data

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece

en_es_quy_aym_tokenizer = Tokenizer(WordPiece(unk_token="[UNK]"))

# %%
from tokenizers.trainers import WordPieceTrainer

en_es_quy_aym_trainer = WordPieceTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"], show_progress=True)

# %%
from tokenizers.pre_tokenizers import Whitespace

en_es_quy_aym_tokenizer.pre_tokenizer = Whitespace()

en_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/{split}.en" for split in ["dev", "train"]]
es_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/{split}.es" for split in ["dev", "train"]]
quy_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/{split}.quy" for split in ["dev", "train"]]
es2_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/{split}.es" for split in ["dev", "train"]]
aym_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/{split}.aym" for split in ["dev", "train"]]
es3_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/{split}.es" for split in ["dev", "train"]]


files = en_files + es_files + es2_files + aym_files + aym_files + es3_files
#print(files)
en_es_quy_aym_tokenizer.train(files= files, trainer=en_es_quy_aym_trainer)

# %%
# ! cat /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.en

# %%
from pathlib import Path



def tokenize_files(tokenizer, files, extension, output_path):
    for file in files:
        print(f"Reading file {file}")
        with open(file, encoding='utf8') as f:
          lines = f.readlines()
          tokenized_lines = tokenizer.encode_batch(lines)
          tokenized_name = Path(file).stem
          tokenized_name = output_path + tokenized_name + "." + extension
          print(tokenized_name)
          with open(tokenized_name, 'w', encoding='utf8') as wf:

            wf.writelines([" ".join(t.tokens) + "\n" for t in tokenized_lines])

# %%
en_es_quy_aym_tokenizer.save(tokenizer_path + "en-es-quy-aym-tokenizer.json")

# %%
print(en_es_quy_aym_tokenizer)
# Out:
# <tokenizers.Tokenizer object at 0x1f8eba0>

# %%
tok = en_es_quy_aym_tokenizer.encode("we hold this truth to be self evidently that everyone is created equal?")
print(tok.tokens)
# Out:
# ['we', 'hold', 'this', 'truth', 'to', 'be', 'self', 'evident', '##ly', 'that', 'everyone', 'is', 'created', 'equal', '?']

# %%
tokenize_files(en_es_quy_aym_tokenizer, en_files, "en", tokenized_path_es_en)
tokenize_files(en_es_quy_aym_tokenizer, es_files, "es", tokenized_path_es_en)

tokenize_files(en_es_quy_aym_tokenizer, quy_files, "quy", tokenized_path_quy_es)
tokenize_files(en_es_quy_aym_tokenizer, es2_files, "es", tokenized_path_quy_es)

tokenize_files(en_es_quy_aym_tokenizer, aym_files, "aym", tokenized_path_aym_es)
tokenize_files(en_es_quy_aym_tokenizer, es3_files, "es", tokenized_path_aym_es)
# Out:
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.en
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en/dev.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/train.en
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en/train.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.es
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en/dev.es
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/train.es
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/dev.quy
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es/dev.quy
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/train.quy
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es/train.quy
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/dev.es
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/train.es
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/dev.aym
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es/dev.aym
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/train.aym
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es/train.aym
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/dev.es
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/train.es
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es/train.es

# %% [markdown]
# ## Binarizing data

# %%
### Removing previous dict files
! rm $BIN_DIR/dict.quy.txt
! rm $BIN_DIR/dict.aym.txt
! rm $BIN_DIR/dict.es.txt
! rm $BIN_DIR/dict.en.txt
# Out:
# rm: cannot remove '/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/dict.quy.txt': No such file or directory
# rm: cannot remove '/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/dict.aym.txt': No such file or directory
# rm: cannot remove '/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/dict.es.txt': No such file or directory
# rm: cannot remove '/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/dict.en.txt': No such file or directory

# %%
## Concatenating all training data
! cat $TOKENIZED_PATH_QUY_ES/train.quy $TOKENIZED_PATH_QUY_ES/train.es $TOKENIZED_PATH_AYM_ES/train.aym $TOKENIZED_PATH_AYM_ES/train.es $TOKENIZED_PATH_ES_EN/train.es $TOKENIZED_PATH_ES_EN/train.en > $BIN_DIR/train.all

# %%
ls
# Out:
#  Untitled.ipynb
#  bar.txt
#  checkpoints/
#  den.pt
#  docker/
#  docs/
#  examples/
#  master-thesis/
#  model_cards/
#  norm.pt
#  notebooks/
#  num.pt
# 'old scripts'/
#  pos.pt
#  s.pt
#  scripts/
#  sj.pt
#  src/
#  templates/
# 'test 10nal-es + es-en model.ipynb'
# 'test capsulenet quy-es + es-en model.ipynb'
# 'test it-nl-ro-en model.ipynb'
# 'test nl-it-en + de-en model.ipynb'
# 'test quy-es + aym-es,en + es-en model.ipynb'
# 'test quy-es + es-en model.ipynb'
# 'test quy-es -> es-en model.ipynb'
# 'test residual drop quy-es + es-en model.ipynb'
#  tests/
# 'train 10nal-es + es-en model.ipynb'
# 'train aym-es,es-en.ipynb'
# 'train capsulenet nl-it-en + de-en model.ipynb'
# 'train capsulenet quy-es + es-en model.ipynb'
# 'train es-en model.ipynb'
# 'train it-nl-ro-en model.ipynb'
# 'train nah-es,es-en.ipynb'
# 'train nl-en,it-en,ro-en,en-de.ipynb'
# 'train quy-es + aym-es,en + es-en model.ipynb'
# 'train quy-es,aym-es,es-en.ipynb'
# 'train quy-es,es-en.ipynb'
# 'train residual drop quy-es + es-en model.ipynb'
#  utils/
#  vj.pt

# %%
! fairseq-preprocess --source-lang all \
    --trainpref $BIN_DIR/train \
    --destdir $BIN_DIR \
    --workers 20 \
    --only-source
# Out:
# 2022-09-19 19:59:37 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=True, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='all', srcdict=None, suppress_crashes=False, target_lang=None, task='translation', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/train', use_plasma_view=False, user_dir=None, validpref=None, wandb_project=None, workers=20)
# 2022-09-19 19:59:43 | INFO | fairseq_cli.preprocess | [all] Dictionary: 28800 types
# 2022-09-19 19:59:56 | INFO | fairseq_cli.preprocess | [all] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/train.all: 657672 sents, 10802610 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 19:59:56 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin

# %%
! echo $BIN_DIR
# Out:
# /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin

# %%
! fairseq-preprocess --source-lang quy --target-lang es \
    --trainpref $TOKENIZED_PATH_QUY_ES/train --validpref $TOKENIZED_PATH_QUY_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --workers 20
# Out:
# 2022-09-19 20:00:04 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='quy', srcdict='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es/dev', wandb_project=None, workers=20)
# 2022-09-19 20:00:04 | INFO | fairseq_cli.preprocess | [quy] Dictionary: 28800 types
# 2022-09-19 20:00:09 | INFO | fairseq_cli.preprocess | [quy] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es/train.quy: 125008 sents, 4196664 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 20:00:09 | INFO | fairseq_cli.preprocess | [quy] Dictionary: 28800 types
# 2022-09-19 20:00:09 | INFO | fairseq_cli.preprocess | [quy] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es/dev.quy: 996 sents, 24912 tokens, 0.293% replaced (by <unk>)
# 2022-09-19 20:00:09 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28800 types
# 2022-09-19 20:00:13 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es/train.es: 125008 sents, 2415057 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 20:00:13 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28800 types
# 2022-09-19 20:00:13 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/quy-es/dev.es: 996 sents, 14662 tokens, 0.518% replaced (by <unk>)
# 2022-09-19 20:00:13 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin

# %%
! fairseq-preprocess --source-lang aym --target-lang es \
    --trainpref $TOKENIZED_PATH_AYM_ES/train --validpref $TOKENIZED_PATH_AYM_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --workers 20
# Out:
# 2022-09-19 20:00:19 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='aym', srcdict='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es/dev', wandb_project=None, workers=20)
# 2022-09-19 20:00:19 | INFO | fairseq_cli.preprocess | [aym] Dictionary: 28800 types
# 2022-09-19 20:00:27 | INFO | fairseq_cli.preprocess | [aym] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es/train.aym: 6531 sents, 182218 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 20:00:27 | INFO | fairseq_cli.preprocess | [aym] Dictionary: 28800 types
# 2022-09-19 20:00:28 | INFO | fairseq_cli.preprocess | [aym] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es/dev.aym: 996 sents, 16674 tokens, 0.606% replaced (by <unk>)
# 2022-09-19 20:00:28 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28800 types
# 2022-09-19 20:00:29 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es/train.es: 6531 sents, 179087 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 20:00:29 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28800 types
# 2022-09-19 20:00:29 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/aym-es/dev.es: 996 sents, 14662 tokens, 0.518% replaced (by <unk>)
# 2022-09-19 20:00:29 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin

# %% [markdown]
# ### Reusing es dict from aym-es preprocessing

# %%
! fairseq-preprocess --source-lang es --target-lang en \
    --trainpref $TOKENIZED_PATH_ES_EN/train --validpref $TOKENIZED_PATH_ES_EN/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --workers 20
# Out:
# 2022-09-19 20:00:35 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='es', srcdict='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/dict.all.txt', suppress_crashes=False, target_lang='en', task='translation', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en/dev', wandb_project=None, workers=20)
# 2022-09-19 20:00:35 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28800 types
# 2022-09-19 20:00:39 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en/train.es: 197297 sents, 1863763 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 20:00:39 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28800 types
# 2022-09-19 20:00:47 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en/dev.es: 4643 sents, 50739 tokens, 0.0512% replaced (by <unk>)
# 2022-09-19 20:00:47 | INFO | fairseq_cli.preprocess | [en] Dictionary: 28800 types
# 2022-09-19 20:00:50 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en/train.en: 197297 sents, 1965821 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 20:00:50 | INFO | fairseq_cli.preprocess | [en] Dictionary: 28800 types
# 2022-09-19 20:00:51 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/es-en/dev.en: 4643 sents, 53430 tokens, 0.0468% replaced (by <unk>)
# 2022-09-19 20:00:51 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin

# %% [markdown]
# ## Training model

# %%
! fairseq-train $BIN_DIR \
    --arch=transformer --share-all-embeddings \
    --task translation_multi_simple_epoch --lang-pairs quy-es,aym-es,es-en \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 5e-4 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --dropout 0.3 --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --max-tokens 4096 \
    --restore-file $MODEL_DIR/checkpoint_last.pt \
    --save-dir $MODEL_DIR/ \
    --keep-last-epochs 2 \
    --reset-optimizer \
    --encoder-langtok "src" \
    --decoder-langtok \
    --fp16 \
    --max-epoch 200 \
    --patience 10
# Out:
# 2022-09-19 20:00:54 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 4096, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 4096, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 200, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.0005], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '/storage/master-thesis/models/quy-es++aym-es++es-en/', 'restore_file': '/storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': True, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': 2, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': 10, 'checkpoint_suffix': '', ' ...
# 2022-09-19 20:00:54 | WARNING | fairseq.data.multilingual.multilingual_data_manager | External language dictionary is not provided; use lang-pairs to infer the set of supported languages. The language ordering is not stable which might cause misalignment in pretraining and finetuning.
# 2022-09-19 20:00:54 | INFO | fairseq.data.multilingual.multilingual_data_manager | inferred language list: ['aym', 'en', 'es', 'quy']
# 2022-09-19 20:00:54 | INFO | fairseq.data.multilingual.multilingual_data_manager | [quy] dictionary: 28804 types
# 2022-09-19 20:00:54 | INFO | fairseq.data.multilingual.multilingual_data_manager | [es] dictionary: 28804 types
# 2022-09-19 20:00:55 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(28804, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(28804, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=512, out_features=28804, bias=False)
#   )
# )
# 2022-09-19 20:00:55 | INFO | fairseq_cli.train | task: TranslationMultiSimpleEpochTask
# 2022-09-19 20:00:55 | INFO | fairseq_cli.train | model: TransformerModel
# 2022-09-19 20:00:55 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-09-19 20:00:55 | INFO | fairseq_cli.train | num. shared model params: 77,788,160 (num. trained: 77,788,160)
# 2022-09-19 20:00:55 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-09-19 20:00:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for valid epoch=1/None
# 2022-09-19 20:00:55 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:00:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-19 20:00:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | [valid] num of shards: {'main:quy-es': 1, 'main:aym-es': 1, 'main:es-en': 1}
# 2022-09-19 20:00:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:quy-es src_langtok: 28803; tgt_langtok: 28802
# 2022-09-19 20:00:55 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/valid.quy-es.quy
# 2022-09-19 20:00:55 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/valid.quy-es.es
# 2022-09-19 20:00:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin valid quy-es 996 examples
# 2022-09-19 20:00:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:aym-es src_langtok: 28800; tgt_langtok: 28802
# 2022-09-19 20:00:55 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/valid.aym-es.aym
# 2022-09-19 20:00:55 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/valid.aym-es.es
# 2022-09-19 20:00:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin valid aym-es 996 examples
# 2022-09-19 20:00:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:es-en src_langtok: 28802; tgt_langtok: 28801
# 2022-09-19 20:00:55 | INFO | fairseq.data.data_utils | loaded 4,643 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/valid.es-en.es
# 2022-09-19 20:00:55 | INFO | fairseq.data.data_utils | loaded 4,643 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/valid.es-en.en
# 2022-09-19 20:00:55 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin valid es-en 4643 examples
# 2022-09-19 20:01:01 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.embed_tokens.weight
# 2022-09-19 20:01:01 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.output_projection.weight
# 2022-09-19 20:01:01 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-19 20:01:01 | INFO | fairseq.utils | rank   0: capabilities =  8.6  ; total memory = 15.740 GB ; name = NVIDIA RTX A4000
# 2022-09-19 20:01:01 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-19 20:01:01 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-09-19 20:01:01 | INFO | fairseq_cli.train | max tokens per device = 4096 and max sentences per device = None
# 2022-09-19 20:01:01 | INFO | fairseq.trainer | Preparing to load checkpoint /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint_last.pt
# 2022-09-19 20:01:01 | INFO | fairseq.trainer | No existing checkpoint found /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint_last.pt
# 2022-09-19 20:01:01 | INFO | fairseq.trainer | loading train data for epoch 1
# 2022-09-19 20:01:01 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for train epoch=1/None
# 2022-09-19 20:01:01 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.multilingual_data_manager | [train] num of shards: {'main:quy-es': 1, 'main:aym-es': 1, 'main:es-en': 1}
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:quy-es src_langtok: 28803; tgt_langtok: 28802
# 2022-09-19 20:01:01 | INFO | fairseq.data.data_utils | loaded 125,008 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/train.quy-es.quy
# 2022-09-19 20:01:01 | INFO | fairseq.data.data_utils | loaded 125,008 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/train.quy-es.es
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin train quy-es 125008 examples
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:aym-es src_langtok: 28800; tgt_langtok: 28802
# 2022-09-19 20:01:01 | INFO | fairseq.data.data_utils | loaded 6,531 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/train.aym-es.aym
# 2022-09-19 20:01:01 | INFO | fairseq.data.data_utils | loaded 6,531 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/train.aym-es.es
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin train aym-es 6531 examples
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:es-en src_langtok: 28802; tgt_langtok: 28801
# 2022-09-19 20:01:01 | INFO | fairseq.data.data_utils | loaded 197,297 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/train.es-en.es
# 2022-09-19 20:01:01 | INFO | fairseq.data.data_utils | loaded 197,297 examples from: /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin/train.es-en.en
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/quy-es++aym-es++es-en/tokenizers/quy-aym-es-en/bin train es-en 197297 examples
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.multilingual_data_manager | estimated total data sizes of all shards used in sampling ratios: [('main:quy-es', 125008), ('main:aym-es', 6531), ('main:es-en', 197297)]. Note that if the data a shard has not been loaded yet, use the max known data size to approximate
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.sampling_method | selected sampler: concat
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Raw sizes: {'main:quy-es': 125008, 'main:aym-es': 6531, 'main:es-en': 197297}; raw total size: 328836
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Resampled sizes: {'main:quy-es': 125008, 'main:aym-es': 6531, 'main:es-en': 197297}; resampled total size: 328836
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] A concat dataset
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] virtual dataset established time: 0:00:00.022389
# 2022-09-19 20:01:01 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 20:01:01 | INFO | fairseq.data.multilingual.sampled_multi_dataset | sizes() calling time: 0:00:00.004644
# 2022-09-19 20:01:01 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.075586
# 2022-09-19 20:01:01 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:01:01 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-19 20:01:01 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.005965
# 2022-09-19 20:01:01 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:01:01 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.011263
# 2022-09-19 20:01:01 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.093643
# 2022-09-19 20:01:01 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:01:01 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1782
# epoch 001:   0%|                                       | 0/1782 [00:00<?, ?it/s]2022-09-19 20:01:01 | INFO | fairseq.trainer | begin training epoch 1
# 2022-09-19 20:01:01 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 001:   0%|1                              | 6/1782 [00:00<03:32,  8.37it/s]2022-09-19 20:01:02 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 001:   1%|3                             | 19/1782 [00:01<03:06,  9.46it/s]2022-09-19 20:01:03 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 001:  31%|3| 545/1782 [00:52<01:53, 10.87it/s, loss=9.538, nll_loss=8.741,2022-09-19 20:01:53 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 16.0
# epoch 001: 100%|9| 1781/1782 [02:52<00:00,  9.88it/s, loss=8.215, nll_loss=7.1872022-09-19 20:03:54 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 20:03:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 20:03:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001528
# 2022-09-19 20:03:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:03:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.050492
# 2022-09-19 20:03:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:03:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.038261
# 2022-09-19 20:03:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.090863
# 2022-09-19 20:03:54 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 001 | valid on 'valid' subset:   0%|               | 0/35 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:   6%|3      | 2/35 [00:00<00:01, 18.54it/s]
# epoch 001 | valid on 'valid' subset:  17%|#2     | 6/35 [00:00<00:01, 21.49it/s]
# epoch 001 | valid on 'valid' subset:  29%|#7    | 10/35 [00:00<00:01, 23.90it/s]
# epoch 001 | valid on 'valid' subset:  40%|##4   | 14/35 [00:00<00:00, 25.90it/s]
# epoch 001 | valid on 'valid' subset:  51%|###   | 18/35 [00:00<00:00, 27.27it/s]
# epoch 001 | valid on 'valid' subset:  60%|###6  | 21/35 [00:00<00:00, 27.61it/s]
# epoch 001 | valid on 'valid' subset:  69%|####1 | 24/35 [00:00<00:00, 27.53it/s]
# epoch 001 | valid on 'valid' subset:  80%|####8 | 28/35 [00:00<00:00, 28.24it/s]
# epoch 001 | valid on 'valid' subset:  91%|#####4| 32/35 [00:01<00:00, 28.90it/s]
#                                                                                 2022-09-19 20:03:55 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 8.345 | nll_loss 7.271 | ppl 154.47 | wps 79864 | wpb 2554 | bsz 189.6 | num_updates 1779
# 2022-09-19 20:03:55 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 1779 updates
# 2022-09-19 20:03:55 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint1.pt
# 2022-09-19 20:03:58 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint1.pt
# 2022-09-19 20:04:02 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint1.pt (epoch 1 @ 1779 updates, score 8.345) (writing took 7.0656988301780075 seconds)
# 2022-09-19 20:04:02 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2022-09-19 20:04:02 | INFO | train | epoch 001 | loss 9.449 | nll_loss 8.614 | ppl 391.92 | wps 26920.1 | ups 9.82 | wpb 2740.7 | bsz 184.2 | num_updates 1779 | lr 0.000222375 | gnorm 2.026 | loss_scale 16 | train_wall 168 | gb_free 12.8 | wall 181
# 2022-09-19 20:04:02 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 20:04:02 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.091333
# 2022-09-19 20:04:02 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:04:02 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-19 20:04:02 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.013662
# 2022-09-19 20:04:02 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:04:02 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.018623
# 2022-09-19 20:04:02 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.124677
# 2022-09-19 20:04:02 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:04:02 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1782
# epoch 002:   0%|                                       | 0/1782 [00:00<?, ?it/s]2022-09-19 20:04:02 | INFO | fairseq.trainer | begin training epoch 2
# 2022-09-19 20:04:02 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 002:   0%|                               | 3/1782 [00:00<04:39,  6.37it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f34448b9ef0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 002:  12%|1| 207/1782 [00:20<02:38,  9.91it/s, loss=7.916, nll_loss=6.847,Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3453404cc0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 002: 100%|9| 1780/1782 [02:53<00:00, 10.11it/s, loss=7.074, nll_loss=5.8882022-09-19 20:06:56 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 20:06:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 20:06:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001629
# 2022-09-19 20:06:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:06:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.050597
# 2022-09-19 20:06:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:06:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.038596
# 2022-09-19 20:06:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.091618
# 2022-09-19 20:06:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 002 | valid on 'valid' subset:   0%|               | 0/35 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:   6%|3      | 2/35 [00:00<00:01, 17.82it/s]
# epoch 002 | valid on 'valid' subset:  17%|#2     | 6/35 [00:00<00:01, 20.75it/s]
# epoch 002 | valid on 'valid' subset:  29%|#7    | 10/35 [00:00<00:01, 23.38it/s]
# epoch 002 | valid on 'valid' subset:  40%|##4   | 14/35 [00:00<00:00, 25.84it/s]
# epoch 002 | valid on 'valid' subset:  51%|###   | 18/35 [00:00<00:00, 28.01it/s]
# epoch 002 | valid on 'valid' subset:  63%|###7  | 22/35 [00:00<00:00, 29.54it/s]
# epoch 002 | valid on 'valid' subset:  74%|####4 | 26/35 [00:00<00:00, 30.75it/s]
# epoch 002 | valid on 'valid' subset:  86%|#####1| 30/35 [00:00<00:00, 31.53it/s]
# epoch 002 | valid on 'valid' subset:  97%|#####8| 34/35 [00:01<00:00, 32.75it/s]
#                                                                                 2022-09-19 20:06:57 | INFO | valid | epoch 002 | valid on 'valid' subset | loss 7.611 | nll_loss 6.421 | ppl 85.71 | wps 87473.1 | wpb 2554 | bsz 189.6 | num_updates 3561 | best_loss 7.611
# 2022-09-19 20:06:57 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 2 @ 3561 updates
# 2022-09-19 20:06:57 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint2.pt
# 2022-09-19 20:07:00 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint2.pt
# 2022-09-19 20:07:03 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint2.pt (epoch 2 @ 3561 updates, score 7.611) (writing took 5.4525104269851 seconds)
# 2022-09-19 20:07:03 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2022-09-19 20:07:03 | INFO | train | epoch 002 | loss 7.506 | nll_loss 6.38 | ppl 83.29 | wps 27088.3 | ups 9.88 | wpb 2742.9 | bsz 184.5 | num_updates 3561 | lr 0.000445125 | gnorm 1.26 | loss_scale 16 | train_wall 169 | gb_free 13.1 | wall 362
# 2022-09-19 20:07:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 20:07:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.101133
# 2022-09-19 20:07:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:07:03 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-19 20:07:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.013294
# 2022-09-19 20:07:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:07:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.026860
# 2022-09-19 20:07:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.142407
# 2022-09-19 20:07:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:07:03 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1782
# epoch 003:   0%|                                       | 0/1782 [00:00<?, ?it/s]2022-09-19 20:07:03 | INFO | fairseq.trainer | begin training epoch 3
# 2022-09-19 20:07:03 | INFO | fairseq_cli.train | Start iterating over samples
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3445744dd8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 003:   6%| | 107/1782 [00:10<02:36, 10.70it/s, loss=7.292, nll_loss=6.137,Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3453404cc0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3445bb5da0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 003: 100%|9| 1780/1782 [02:52<00:00, 10.33it/s, loss=6.578, nll_loss=5.3272022-09-19 20:09:56 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 20:09:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 20:09:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001599
# 2022-09-19 20:09:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:09:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.054727
# 2022-09-19 20:09:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:09:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.040371
# 2022-09-19 20:09:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.097332
# 2022-09-19 20:09:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 003 | valid on 'valid' subset:   0%|               | 0/35 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:   9%|6      | 3/35 [00:00<00:01, 24.92it/s]
# epoch 003 | valid on 'valid' subset:  20%|#4     | 7/35 [00:00<00:01, 27.15it/s]
# epoch 003 | valid on 'valid' subset:  31%|#8    | 11/35 [00:00<00:00, 28.93it/s]
# epoch 003 | valid on 'valid' subset:  43%|##5   | 15/35 [00:00<00:00, 30.39it/s]
# epoch 003 | valid on 'valid' subset:  54%|###2  | 19/35 [00:00<00:00, 31.53it/s]
# epoch 003 | valid on 'valid' subset:  66%|###9  | 23/35 [00:00<00:00, 32.33it/s]
# epoch 003 | valid on 'valid' subset:  77%|####6 | 27/35 [00:00<00:00, 32.62it/s]
# epoch 003 | valid on 'valid' subset:  89%|#####3| 31/35 [00:00<00:00, 31.58it/s]
# epoch 003 | valid on 'valid' subset: 100%|######| 35/35 [00:01<00:00, 33.07it/s]
#                                                                                 2022-09-19 20:09:57 | INFO | valid | epoch 003 | valid on 'valid' subset | loss 7.162 | nll_loss 5.893 | ppl 59.42 | wps 85267.9 | wpb 2554 | bsz 189.6 | num_updates 5343 | best_loss 7.162
# 2022-09-19 20:09:57 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 3 @ 5343 updates
# 2022-09-19 20:09:57 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint3.pt
# 2022-09-19 20:10:00 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint3.pt
# 2022-09-19 20:10:03 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint3.pt (epoch 3 @ 5343 updates, score 7.162) (writing took 5.743011363083497 seconds)
# 2022-09-19 20:10:05 | INFO | fairseq_cli.train | end of epoch 3 (average epoch stats below)
# 2022-09-19 20:10:05 | INFO | train | epoch 003 | loss 6.813 | nll_loss 5.591 | ppl 48.21 | wps 26766.4 | ups 9.76 | wpb 2742.9 | bsz 184.5 | num_updates 5343 | lr 0.000432621 | gnorm 1.096 | loss_scale 16 | train_wall 168 | gb_free 12.8 | wall 544
# 2022-09-19 20:10:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 20:10:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.077461
# 2022-09-19 20:10:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:10:05 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-19 20:10:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.005693
# 2022-09-19 20:10:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:10:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.011018
# 2022-09-19 20:10:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.094984
# 2022-09-19 20:10:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 20:10:05 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1782
# epoch 004:   0%|                                       | 0/1782 [00:00<?, ?it/s]2022-09-19 20:10:05 | INFO | fairseq.trainer | begin training epoch 4
# 2022-09-19 20:10:05 | INFO | fairseq_cli.train | Start iterating over samples
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f34450d5160>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 004:   2%|5                             | 35/1782 [00:03<02:46, 10.50it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3453404cc0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3445bb5da0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f34450d5d30>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
# ...
# 2022-09-19 21:34:48 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 31 @ 55237 updates
# 2022-09-19 21:34:48 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint31.pt
# 2022-09-19 21:34:50 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint31.pt
# 2022-09-19 21:34:52 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint31.pt (epoch 31 @ 55237 updates, score 6.195) (writing took 4.167621457017958 seconds)
# 2022-09-19 21:34:52 | INFO | fairseq_cli.train | end of epoch 31 (average epoch stats below)
# 2022-09-19 21:34:52 | INFO | train | epoch 031 | loss 4.485 | nll_loss 2.915 | ppl 7.54 | wps 27335.6 | ups 9.97 | wpb 2742.9 | bsz 184.5 | num_updates 55237 | lr 0.00013455 | gnorm 1.575 | loss_scale 32 | train_wall 168 | gb_free 12.1 | wall 5631
# 2022-09-19 21:34:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 21:34:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.091509
# 2022-09-19 21:34:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 21:34:52 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-19 21:34:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.008324
# 2022-09-19 21:34:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 21:34:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.013756
# 2022-09-19 21:34:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.114446
# 2022-09-19 21:34:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 21:34:52 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1782
# epoch 032:   0%|                                       | 0/1782 [00:00<?, ?it/s]2022-09-19 21:34:52 | INFO | fairseq.trainer | begin training epoch 32
# 2022-09-19 21:34:52 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 032:   4%| | 65/1782 [00:06<02:48, 10.20it/s, loss=4.432, nll_loss=2.857, 2022-09-19 21:34:59 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 16.0
# epoch 032:  33%|3| 585/1782 [00:56<01:50, 10.84it/s, loss=4.39, nll_loss=2.807, Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f344586f748>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3445b6d4e0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f344587cda0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 032: 100%|9| 1781/1782 [02:52<00:00,  9.14it/s, loss=4.401, nll_loss=2.82,2022-09-19 21:37:45 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 21:37:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 21:37:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.002021
# 2022-09-19 21:37:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 21:37:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.056006
# 2022-09-19 21:37:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 21:37:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.039490
# 2022-09-19 21:37:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.098569
# 2022-09-19 21:37:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 032 | valid on 'valid' subset:   0%|               | 0/35 [00:00<?, ?it/s]
# epoch 032 | valid on 'valid' subset:   6%|3      | 2/35 [00:00<00:01, 19.67it/s]
# epoch 032 | valid on 'valid' subset:  17%|#2     | 6/35 [00:00<00:01, 22.35it/s]
# epoch 032 | valid on 'valid' subset:  29%|#7    | 10/35 [00:00<00:01, 24.73it/s]
# epoch 032 | valid on 'valid' subset:  40%|##4   | 14/35 [00:00<00:00, 27.02it/s]
# epoch 032 | valid on 'valid' subset:  51%|###   | 18/35 [00:00<00:00, 28.82it/s]
# epoch 032 | valid on 'valid' subset:  63%|###7  | 22/35 [00:00<00:00, 30.05it/s]
# epoch 032 | valid on 'valid' subset:  74%|####4 | 26/35 [00:00<00:00, 30.69it/s]
# epoch 032 | valid on 'valid' subset:  86%|#####1| 30/35 [00:00<00:00, 31.41it/s]
# epoch 032 | valid on 'valid' subset:  97%|#####8| 34/35 [00:01<00:00, 32.74it/s]
#                                                                                 2022-09-19 21:37:46 | INFO | valid | epoch 032 | valid on 'valid' subset | loss 6.197 | nll_loss 4.79 | ppl 27.67 | wps 85421.2 | wpb 2554 | bsz 189.6 | num_updates 57018 | best_loss 6.163
# 2022-09-19 21:37:46 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 32 @ 57018 updates
# 2022-09-19 21:37:46 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint32.pt
# 2022-09-19 21:37:49 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint32.pt
# 2022-09-19 21:37:51 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint32.pt (epoch 32 @ 57018 updates, score 6.197) (writing took 4.213055037893355 seconds)
# 2022-09-19 21:37:51 | INFO | fairseq_cli.train | end of epoch 32 (average epoch stats below)
# 2022-09-19 21:37:51 | INFO | train | epoch 032 | loss 4.471 | nll_loss 2.899 | ppl 7.46 | wps 27348.1 | ups 9.97 | wpb 2742.1 | bsz 184.3 | num_updates 57018 | lr 0.000132432 | gnorm 1.591 | loss_scale 16 | train_wall 168 | gb_free 12.4 | wall 5810
# 2022-09-19 21:37:51 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 21:37:51 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.093317
# 2022-09-19 21:37:51 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 21:37:51 | WARNING | fairseq.tasks.fairseq_task | 1 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[34006]
# 2022-09-19 21:37:51 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.006694
# 2022-09-19 21:37:51 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 21:37:51 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.011009
# 2022-09-19 21:37:51 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.111933
# 2022-09-19 21:37:51 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 21:37:51 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1782
# epoch 033:   0%|                                       | 0/1782 [00:00<?, ?it/s]2022-09-19 21:37:51 | INFO | fairseq.trainer | begin training epoch 33
# 2022-09-19 21:37:51 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 033:   0%|                               | 5/1782 [00:00<03:05,  9.60it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3445c26470>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 033:  32%|3| 568/1782 [00:55<01:52, 10.81it/s, loss=4.313, nll_loss=2.719,Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f344586f748>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3445b6d4e0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f344587cda0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3445c47748>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 033: 100%|9| 1780/1782 [02:53<00:00, 10.28it/s, loss=4.411, nll_loss=2.8312022-09-19 21:40:44 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 21:40:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 21:40:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001609
# 2022-09-19 21:40:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 21:40:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.051196
# 2022-09-19 21:40:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 21:40:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.037647
# 2022-09-19 21:40:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.091297
# 2022-09-19 21:40:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 033 | valid on 'valid' subset:   0%|               | 0/35 [00:00<?, ?it/s]
# epoch 033 | valid on 'valid' subset:   9%|6      | 3/35 [00:00<00:01, 24.51it/s]
# epoch 033 | valid on 'valid' subset:  20%|#4     | 7/35 [00:00<00:01, 26.69it/s]
# epoch 033 | valid on 'valid' subset:  31%|#8    | 11/35 [00:00<00:00, 28.41it/s]
# epoch 033 | valid on 'valid' subset:  43%|##5   | 15/35 [00:00<00:00, 29.79it/s]
# epoch 033 | valid on 'valid' subset:  54%|###2  | 19/35 [00:00<00:00, 30.53it/s]
# epoch 033 | valid on 'valid' subset:  66%|###9  | 23/35 [00:00<00:00, 30.69it/s]
# epoch 033 | valid on 'valid' subset:  77%|####6 | 27/35 [00:00<00:00, 30.89it/s]
# epoch 033 | valid on 'valid' subset:  89%|#####3| 31/35 [00:00<00:00, 30.93it/s]
# epoch 033 | valid on 'valid' subset: 100%|######| 35/35 [00:01<00:00, 32.18it/s]
#                                                                                 2022-09-19 21:40:45 | INFO | valid | epoch 033 | valid on 'valid' subset | loss 6.202 | nll_loss 4.795 | ppl 27.76 | wps 82020.7 | wpb 2554 | bsz 189.6 | num_updates 58800 | best_loss 6.163
# 2022-09-19 21:40:45 | INFO | fairseq_cli.train | early stop since valid performance hasn't improved for last 10 runs
# 2022-09-19 21:40:45 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 33 @ 58800 updates
# 2022-09-19 21:40:45 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint33.pt
# 2022-09-19 21:40:48 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint33.pt
# 2022-09-19 21:40:50 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/quy-es++aym-es++es-en/checkpoint33.pt (epoch 33 @ 58800 updates, score 6.202) (writing took 4.199778992915526 seconds)
# 2022-09-19 21:40:50 | INFO | fairseq_cli.train | end of epoch 33 (average epoch stats below)
# 2022-09-19 21:40:50 | INFO | train | epoch 033 | loss 4.451 | nll_loss 2.876 | ppl 7.34 | wps 27321.7 | ups 9.96 | wpb 2742.9 | bsz 184.5 | num_updates 58800 | lr 0.00013041 | gnorm 1.605 | loss_scale 16 | train_wall 169 | gb_free 13.1 | wall 5989
# 2022-09-19 21:40:50 | INFO | fairseq_cli.train | done training in 5988.6 seconds

# %%
! echo $MODEL_DIR
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
cd /storage/master-thesis/models/aym-es+es-en
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
! rm dict.en.txt
! rm dict.es.txt
! rm dict.aym.txt

# %%
! du -shc /notebooks/*
# Out:
# 2.5K	/notebooks/CITATION.cff
# 5.5K	/notebooks/CODE_OF_CONDUCT.md
# 15K	/notebooks/CONTRIBUTING.md
# 19K	/notebooks/ISSUES.md
# 12K	/notebooks/LICENSE
# 512	/notebooks/MANIFEST.in
# 3.5K	/notebooks/Makefile
# 41K	/notebooks/README.md
# 41K	/notebooks/README_zh-hans.md
# 42K	/notebooks/README_zh-hant.md
# 12K	/notebooks/docker
# 4.6M	/notebooks/docs
# 5.0M	/notebooks/examples
# 8.5K	/notebooks/hubconf.py
# 7.8G	/notebooks/master-thesis
# 1.5K	/notebooks/model_cards
# 9.5K	/notebooks/notebooks
# 512	/notebooks/pyproject.toml
# 64K	/notebooks/scripts
# 1.0K	/notebooks/setup.cfg
# 13K	/notebooks/setup.py
# 13M	/notebooks/src
# 731K	/notebooks/templates
# 4.5K	/notebooks/test quy-es -> es-en model.ipynb
# 6.8M	/notebooks/tests
# 147K	/notebooks/train es-en model.ipynb
# 158K	/notebooks/train quy-es + es-en model.ipynb
# 160K	/notebooks/utils
# 3.5K	/notebooks/valohai.yaml
# 7.9G	total

# %%
! du -shc /notebooks/master-thesis/*
# Out:
# 512	/notebooks/master-thesis/Untitled.ipynb
# 362M	/notebooks/master-thesis/corpora
# 7.5G	/notebooks/master-thesis/models
# 7.8G	total

# %%
! du -shc /notebooks/master-thesis/models/*
# Out:
# 1.6G	/notebooks/master-thesis/models/es-en
# 802M	/notebooks/master-thesis/models/quy-es
# 5.2G	/notebooks/master-thesis/models/quy-es+es-en
# 7.5G	total

# %%
! du -shc /*
# Out:
# 19M	/apex
# 5.0M	/bin
# 4.0K	/boot
# 24K	/content
# ^C

# %%
ls
# Out:
#  CITATION.cff         docker/          setup.py
#  CODE_OF_CONDUCT.md   docs/            src/
#  CONTRIBUTING.md      examples/        templates/
#  ISSUES.md            hubconf.py      'test quy-es -> es-en model.ipynb'
#  LICENSE              master-thesis/   tests/
#  MANIFEST.in          model_cards/    'train es-en model.ipynb'
#  Makefile             notebooks/      'train quy-es + es-en model.ipynb'
#  README.md            pyproject.toml   utils/
#  README_zh-hans.md    scripts/         valohai.yaml
#  README_zh-hant.md    setup.cfg

# %%
# Out:
# /storage/master-thesis
