# %% [markdown]
# ## ENVIRONMENT VARIABLES

# %%
EN_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/"

# %%
AYM_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish"

# %%
tokenizer_path = "/storage/master-thesis/models/aym-es_es-en/tokenizers/aym-es-en/"

# %%
# %env TOKENIZER_PATH = /storage/master-thesis/models/aym-es_es-en/tokenizers/aym-es-en
# Out:
# env: TOKENIZER_PATH=/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en

# %%
tokenized_path_es_en = "/storage/master-thesis/models/aym-es_es-en/tokenizers/aym-es-en/es-en/"
tokenized_path_aym_es = "/storage/master-thesis/models/aym-es_es-en/tokenizers/aym-es-en/aym-es/"

# %%
# %env TOKENIZED_PATH_ES_EN = /storage/master-thesis/models/aym-es_es-en/tokenizers/aym-es-en/es-en
# %env TOKENIZED_PATH_AYM_ES = /storage/master-thesis/models/aym-es_es-en/tokenizers/aym-es-en/aym-es
# Out:
# env: TOKENIZED_PATH_ES_EN=/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/es-en
# env: TOKENIZED_PATH_AYM_ES=/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/aym-es

# %%
# %env BIN_DIR = /storage/master-thesis/models/aym-es_es-en/tokenizers/aym-es-en/bin
# Out:
# env: BIN_DIR=/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin

# %%
# %env MODEL_DIR = /storage/master-thesis/models/aym-es_es-en
# Out:
# env: MODEL_DIR=/storage/master-thesis/models/aym-es++es-en

# %%
! mkdir -p $TOKENIZED_PATH_ES_EN
! mkdir -p $TOKENIZED_PATH_AYM_ES
! mkdir -p $BIN_DIR

# %%
! locale
# Out:
# LANG=
# LANGUAGE=
# LC_CTYPE="POSIX"
# LC_NUMERIC="POSIX"
# LC_TIME="POSIX"
# LC_COLLATE="POSIX"
# LC_MONETARY="POSIX"
# LC_MESSAGES="POSIX"
# LC_PAPER="POSIX"
# LC_NAME="POSIX"
# LC_ADDRESS="POSIX"
# LC_TELEPHONE="POSIX"
# LC_MEASUREMENT="POSIX"
# LC_IDENTIFICATION="POSIX"
# LC_ALL=

# %%
! update-locale LANG=en_US.UTF-8 LANGUAGE=en.UTF-8

# %env LANG=en_US.UTF-8
# %env LC_CTYPE=en_US.UTF-8
# %env LC_ALL=en_US.UTF-8
# Out:
# /bin/sh: 1: update-locale: not found
# env: LANG=en_US.UTF-8
# env: LC_CTYPE=en_US.UTF-8
# env: LC_ALL=en_US.UTF-8

# %% [markdown]
# ## Libraries

# %%
pip install tokenizers==0.10.3
# Out:
# Requirement already satisfied: tokenizers==0.10.3 in /usr/local/lib/python3.6/dist-packages (0.10.3)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 1.9.1
# Uninstalling torch-1.9.1:
#   Successfully uninstalled torch-1.9.1
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (1821.5 MB)
#      |#########                       | 528.2 MB 125.7 MB/s eta 0:00:11K     |##                              | 163.1 MB 68.9 MB/s eta 0:00:25
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |################################| 1821.5 MB 6.8 kB/s s eta 0:00:01
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.11.3%2Bcu113-cp36-cp36m-linux_x86_64.whl (24.6 MB)
#      |################################| 24.6 MB 7.9 MB/s eta 0:00:01
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (2.9 MB)
#      |################################| 2.9 MB 7.6 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.18.5)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from torchvision) (8.3.2)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.10.2+cu113 torchaudio-0.10.2+cu113 torchvision-0.11.3+cu113
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall fairseq -y
# Out:
# Found existing installation: fairseq 0.10.2
# Uninstalling fairseq-0.10.2:
#   Successfully uninstalled fairseq-0.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fairseq # --no-deps
# Out:
# Collecting fairseq
#   Downloading fairseq-0.12.2-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.0 MB)
#      |################################| 11.0 MB 5.2 MB/s eta 0:00:01
# Collecting bitarray
#   Downloading bitarray-2.6.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (235 kB)
#      |################################| 235 kB 86.5 MB/s eta 0:00:01
# Collecting hydra-core<1.1,>=1.0.7
#   Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#      |################################| 123 kB 65.3 MB/s eta 0:00:01
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.10.2+cu113)
# Requirement already satisfied: numpy<1.20.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.51.0)
# Collecting omegaconf<2.1
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.24)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2020.11.13)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.3)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.8)
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.10.2+cu113)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (5.2.2)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (4.8)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.4.4)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.8.9)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (2.3.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (3.10.0.2)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.6/dist-packages (from omegaconf<2.1->fairseq) (5.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core<1.1,>=1.0.7->fairseq) (3.4.0)
# Installing collected packages: bitarray, omegaconf, hydra-core, fairseq
#   Attempting uninstall: omegaconf
#     Found existing installation: omegaconf 2.1.1
#     Uninstalling omegaconf-2.1.1:
#       Successfully uninstalled omegaconf-2.1.1
#   Attempting uninstall: hydra-core
#     Found existing installation: hydra-core 1.1.1
#     Uninstalling hydra-core-1.1.1:
#       Successfully uninstalled hydra-core-1.1.1
# Successfully installed bitarray-2.6.0 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip uninstall apex -y
# Out:
# Found existing installation: apex 0.1
# Uninstalling apex-0.1:
#   Successfully uninstalled apex-0.1

# %%
rm -r apex

# %%
#! git clone https://github.com/NVIDIA/apex

! pip install -v --disable-pip-version-check --no-cache-dir apex

# %%
pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |################################| 125 kB 31.6 MB/s eta 0:00:01
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (50.3.2)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5.1
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Converting tatoeba format to standard format

# %%
import csv

with open(EN_ES_CORPUS_DIR + "original/valid.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "dev.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "dev.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
    en.close()
    es.close()
    
with open(EN_ES_CORPUS_DIR + "original/dev.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "train.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "train.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        if "\n" in line[2] or "\n" in line[3]:
            continue
        if len(line) != 4:
            continue
            
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
        
    en.close()
    es.close()

# %% [markdown]
# ### Tokenizing data

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece

en_es_aym_tokenizer = Tokenizer(WordPiece(unk_token="[UNK]"))

# %%
from tokenizers.trainers import WordPieceTrainer

en_es_aym_trainer = WordPieceTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"], show_progress=True)

# %%
from tokenizers.pre_tokenizers import Whitespace

en_es_aym_tokenizer.pre_tokenizer = Whitespace()

en_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/{split}.en" for split in ["dev", "train"]]
es_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/{split}.es" for split in ["dev", "train"]]
aym_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/{split}.aym" for split in ["dev", "train"]]
es2_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/{split}.es" for split in ["dev", "train"]]

files = en_files + es_files + es2_files + aym_files
#print(files)
en_es_aym_tokenizer.train(files= files, trainer=en_es_aym_trainer)

# %%
# ! cat /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.en

# %%
from pathlib import Path



def tokenize_files(tokenizer, files, extension, output_path):
    for file in files:
        print(f"Reading file {file}")
        with open(file, encoding='utf8') as f:
          lines = f.readlines()
          tokenized_lines = tokenizer.encode_batch(lines)
          tokenized_name = Path(file).stem
          tokenized_name = output_path + tokenized_name + "." + extension
          print(tokenized_name)
          with open(tokenized_name, 'w', encoding='utf8') as wf:

            wf.writelines([" ".join(t.tokens) + "\n" for t in tokenized_lines])

# %%
en_es_aym_tokenizer.save(tokenizer_path + "aym-es-en-tokenizer.json")

# %%
print(en_es_aym_tokenizer)
# Out:
# <tokenizers.Tokenizer object at 0x1a44dc0>

# %%
tok = en_es_aym_tokenizer.encode("we hold this truth to be self evident that everyone is created equal?")
print(tok.tokens)
# Out:
# ['we', 'hold', 'this', 'truth', 'to', 'be', 'self', 'evident', 'that', 'everyone', 'is', 'created', 'equal', '?']

# %%
tokenize_files(en_es_aym_tokenizer, en_files, "en", tokenized_path_es_en)
tokenize_files(en_es_aym_tokenizer, es_files, "es", tokenized_path_es_en)

tokenize_files(en_es_aym_tokenizer, aym_files, "aym", tokenized_path_aym_es)
tokenize_files(en_es_aym_tokenizer, es2_files, "es", tokenized_path_aym_es)
# Out:
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.en
# /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/es-en/dev.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/train.en
# /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/es-en/train.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.es
# /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/es-en/dev.es
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/train.es
# /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/es-en/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/dev.aym
# /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/aym-es/dev.aym
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/train.aym
# /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/aym-es/train.aym
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/dev.es
# /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/aym-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/train.es
# /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/aym-es/train.es

# %% [markdown]
# ## Binarizing data

# %%
### Removing previous dict files
! rm $BIN_DIR/dict.aym.txt
! rm $BIN_DIR/dict.es.txt
! rm $BIN_DIR/dict.en.txt
# Out:
# rm: cannot remove '/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/dict.aym.txt': No such file or directory
# rm: cannot remove '/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/dict.es.txt': No such file or directory
# rm: cannot remove '/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/dict.en.txt': No such file or directory

# %%
## Concatenating all training data
! cat $TOKENIZED_PATH_AYM_ES/train.aym $TOKENIZED_PATH_AYM_ES/train.es $TOKENIZED_PATH_ES_EN/train.es $TOKENIZED_PATH_ES_EN/train.en > $BIN_DIR/train.all

# %%
ls
# Out:
#  Untitled.ipynb
#  bar.txt
#  checkpoints/
#  den.pt
#  docker/
#  docs/
#  examples/
#  master-thesis/
#  model_cards/
#  norm.pt
#  notebooks/
#  num.pt
# 'old scripts'/
#  pos.pt
#  s.pt
#  scripts/
#  sj.pt
#  src/
#  templates/
# 'test 10nal-es + es-en model.ipynb'
# 'test capsulenet quy-es + es-en model.ipynb'
# 'test it-nl-ro-en model.ipynb'
# 'test nl-it-en + de-en model.ipynb'
# 'test quy-es + aym-es,en + es-en model.ipynb'
# 'test quy-es + es-en model.ipynb'
# 'test quy-es -> es-en model.ipynb'
# 'test residual drop quy-es + es-en model.ipynb'
#  tests/
# 'train 10nal-es + es-en model.ipynb'
# 'train aym-es,es-en.ipynb'
# 'train capsulenet nl-it-en + de-en model.ipynb'
# 'train capsulenet quy-es + es-en model.ipynb'
# 'train es-en model.ipynb'
# 'train it-nl-ro-en model.ipynb'
# 'train nah-es,es-en.ipynb'
# 'train nl-en,it-en,ro-en,en-de.ipynb'
# 'train quy-es + aym-es,en + es-en model.ipynb'
# 'train quy-es,es-en.ipynb'
# 'train residual drop quy-es + es-en model.ipynb'
#  utils/
#  vj.pt

# %%
! fairseq-preprocess --source-lang all \
    --trainpref $BIN_DIR/train \
    --destdir $BIN_DIR \
    --workers 20 \
    --only-source
# Out:
# 2022-09-19 18:42:16 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=True, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='all', srcdict=None, suppress_crashes=False, target_lang=None, task='translation', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/train', use_plasma_view=False, user_dir=None, validpref=None, wandb_project=None, workers=20)
# 2022-09-19 18:42:19 | INFO | fairseq_cli.preprocess | [all] Dictionary: 28624 types
# 2022-09-19 18:42:25 | INFO | fairseq_cli.preprocess | [all] /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/train.all: 407656 sents, 4155170 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 18:42:25 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin

# %%
! echo $BIN_DIR
# Out:
# /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin

# %%
! fairseq-preprocess --source-lang aym --target-lang es \
    --trainpref $TOKENIZED_PATH_AYM_ES/train --validpref $TOKENIZED_PATH_AYM_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --workers 20
# Out:
# 2022-09-19 18:42:28 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='aym', srcdict='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/aym-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/aym-es/dev', wandb_project=None, workers=20)
# 2022-09-19 18:42:28 | INFO | fairseq_cli.preprocess | [aym] Dictionary: 28624 types
# 2022-09-19 18:42:37 | INFO | fairseq_cli.preprocess | [aym] /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/aym-es/train.aym: 6531 sents, 182939 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 18:42:37 | INFO | fairseq_cli.preprocess | [aym] Dictionary: 28624 types
# 2022-09-19 18:42:37 | INFO | fairseq_cli.preprocess | [aym] /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/aym-es/dev.aym: 996 sents, 16864 tokens, 0.54% replaced (by <unk>)
# 2022-09-19 18:42:37 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28624 types
# 2022-09-19 18:42:38 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/aym-es/train.es: 6531 sents, 178761 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 18:42:38 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28624 types
# 2022-09-19 18:42:38 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/aym-es/dev.es: 996 sents, 14781 tokens, 0.541% replaced (by <unk>)
# 2022-09-19 18:42:38 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin

# %% [markdown]
# ### Reusing es dict from aym-es preprocessing

# %%
! fairseq-preprocess --source-lang es --target-lang en \
    --trainpref $TOKENIZED_PATH_ES_EN/train --validpref $TOKENIZED_PATH_ES_EN/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --workers 20
# Out:
# 2022-09-19 18:42:41 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='es', srcdict='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/dict.all.txt', suppress_crashes=False, target_lang='en', task='translation', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/es-en/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/es-en/dev', wandb_project=None, workers=20)
# 2022-09-19 18:42:41 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28624 types
# 2022-09-19 18:42:44 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/es-en/train.es: 197297 sents, 1853537 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 18:42:44 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28624 types
# 2022-09-19 18:42:45 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/es-en/dev.es: 4643 sents, 50452 tokens, 0.168% replaced (by <unk>)
# 2022-09-19 18:42:45 | INFO | fairseq_cli.preprocess | [en] Dictionary: 28624 types
# 2022-09-19 18:42:48 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/es-en/train.en: 197297 sents, 1939933 tokens, 0.0% replaced (by <unk>)
# 2022-09-19 18:42:48 | INFO | fairseq_cli.preprocess | [en] Dictionary: 28624 types
# 2022-09-19 18:42:48 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/es-en/dev.en: 4643 sents, 52529 tokens, 0.0819% replaced (by <unk>)
# 2022-09-19 18:42:48 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin

# %% [markdown]
# ## Training model

# %%
! fairseq-train $BIN_DIR \
    --arch=transformer --share-all-embeddings \
    --task translation_multi_simple_epoch --lang-pairs aym-es,es-en \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 5e-4 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --dropout 0.3 --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --max-tokens 4096 \
    --restore-file $MODEL_DIR/checkpoint_last.pt \
    --save-dir $MODEL_DIR/ \
    --keep-last-epochs 2 \
    --reset-optimizer \
    --encoder-langtok "src" \
    --decoder-langtok \
    --fp16 \
    --max-epoch 200 \
    --patience 10
# Out:
# 2022-09-19 18:42:57 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 4096, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 4096, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 200, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.0005], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '/storage/master-thesis/models/aym-es++es-en/', 'restore_file': '/storage/master-thesis/models/aym-es++es-en/checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': True, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': 2, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': 10, 'checkpoint_suffix': '', 'checkpoint_shard ...
# 2022-09-19 18:42:57 | WARNING | fairseq.data.multilingual.multilingual_data_manager | External language dictionary is not provided; use lang-pairs to infer the set of supported languages. The language ordering is not stable which might cause misalignment in pretraining and finetuning.
# 2022-09-19 18:42:57 | INFO | fairseq.data.multilingual.multilingual_data_manager | inferred language list: ['aym', 'en', 'es']
# 2022-09-19 18:42:57 | INFO | fairseq.data.multilingual.multilingual_data_manager | [es] dictionary: 28627 types
# 2022-09-19 18:42:57 | INFO | fairseq.data.multilingual.multilingual_data_manager | [es] dictionary: 28627 types
# 2022-09-19 18:42:57 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(28627, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(28627, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=512, out_features=28627, bias=False)
#   )
# )
# 2022-09-19 18:42:57 | INFO | fairseq_cli.train | task: TranslationMultiSimpleEpochTask
# 2022-09-19 18:42:57 | INFO | fairseq_cli.train | model: TransformerModel
# 2022-09-19 18:42:57 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-09-19 18:42:57 | INFO | fairseq_cli.train | num. shared model params: 77,697,536 (num. trained: 77,697,536)
# 2022-09-19 18:42:57 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-09-19 18:42:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for valid epoch=1/None
# 2022-09-19 18:42:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:42:57 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-19 18:42:57 | INFO | fairseq.data.multilingual.multilingual_data_manager | [valid] num of shards: {'main:aym-es': 1, 'main:es-en': 1}
# 2022-09-19 18:42:57 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:aym-es src_langtok: 28624; tgt_langtok: 28626
# 2022-09-19 18:42:57 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/valid.aym-es.aym
# 2022-09-19 18:42:57 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/valid.aym-es.es
# 2022-09-19 18:42:57 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin valid aym-es 996 examples
# 2022-09-19 18:42:57 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:es-en src_langtok: 28626; tgt_langtok: 28625
# 2022-09-19 18:42:57 | INFO | fairseq.data.data_utils | loaded 4,643 examples from: /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/valid.es-en.es
# 2022-09-19 18:42:57 | INFO | fairseq.data.data_utils | loaded 4,643 examples from: /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/valid.es-en.en
# 2022-09-19 18:42:57 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin valid es-en 4643 examples
# 2022-09-19 18:43:03 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.embed_tokens.weight
# 2022-09-19 18:43:03 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.output_projection.weight
# 2022-09-19 18:43:03 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-19 18:43:03 | INFO | fairseq.utils | rank   0: capabilities =  8.6  ; total memory = 15.740 GB ; name = NVIDIA RTX A4000
# 2022-09-19 18:43:03 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-19 18:43:03 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-09-19 18:43:03 | INFO | fairseq_cli.train | max tokens per device = 4096 and max sentences per device = None
# 2022-09-19 18:43:03 | INFO | fairseq.trainer | Preparing to load checkpoint /storage/master-thesis/models/aym-es++es-en/checkpoint_last.pt
# 2022-09-19 18:43:03 | INFO | fairseq.trainer | No existing checkpoint found /storage/master-thesis/models/aym-es++es-en/checkpoint_last.pt
# 2022-09-19 18:43:03 | INFO | fairseq.trainer | loading train data for epoch 1
# 2022-09-19 18:43:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for train epoch=1/None
# 2022-09-19 18:43:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.multilingual_data_manager | [train] num of shards: {'main:aym-es': 1, 'main:es-en': 1}
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:aym-es src_langtok: 28624; tgt_langtok: 28626
# 2022-09-19 18:43:03 | INFO | fairseq.data.data_utils | loaded 6,531 examples from: /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/train.aym-es.aym
# 2022-09-19 18:43:03 | INFO | fairseq.data.data_utils | loaded 6,531 examples from: /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/train.aym-es.es
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin train aym-es 6531 examples
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:es-en src_langtok: 28626; tgt_langtok: 28625
# 2022-09-19 18:43:03 | INFO | fairseq.data.data_utils | loaded 197,297 examples from: /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/train.es-en.es
# 2022-09-19 18:43:03 | INFO | fairseq.data.data_utils | loaded 197,297 examples from: /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin/train.es-en.en
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/aym-es++es-en/tokenizers/aym-es-en/bin train es-en 197297 examples
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.multilingual_data_manager | estimated total data sizes of all shards used in sampling ratios: [('main:aym-es', 6531), ('main:es-en', 197297)]. Note that if the data a shard has not been loaded yet, use the max known data size to approximate
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.sampling_method | selected sampler: concat
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Raw sizes: {'main:aym-es': 6531, 'main:es-en': 197297}; raw total size: 203828
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Resampled sizes: {'main:aym-es': 6531, 'main:es-en': 197297}; resampled total size: 203828
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] A concat dataset
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] virtual dataset established time: 0:00:00.014108
# 2022-09-19 18:43:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 18:43:03 | INFO | fairseq.data.multilingual.sampled_multi_dataset | sizes() calling time: 0:00:00.002372
# 2022-09-19 18:43:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.049147
# 2022-09-19 18:43:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:43:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.003183
# 2022-09-19 18:43:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:43:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.012959
# 2022-09-19 18:43:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.066493
# 2022-09-19 18:43:03 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:43:03 | INFO | fairseq.data.iterators | grouped total_num_itrs = 653
# epoch 001:   0%|                                        | 0/653 [00:00<?, ?it/s]2022-09-19 18:43:03 | INFO | fairseq.trainer | begin training epoch 1
# 2022-09-19 18:43:03 | INFO | fairseq_cli.train | Start iterating over samples
# 2022-09-19 18:43:04 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 001:   4%|#3                             | 29/653 [00:03<01:06,  9.34it/s]2022-09-19 18:43:07 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 001: 100%|9| 652/653 [01:10<00:00,  8.88it/s, loss=8.226, nll_loss=7.218, 2022-09-19 18:44:14 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 18:44:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 18:44:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001761
# 2022-09-19 18:44:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:44:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.048420
# 2022-09-19 18:44:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:44:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.038431
# 2022-09-19 18:44:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.089701
# 2022-09-19 18:44:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 001 | valid on 'valid' subset:   0%|               | 0/27 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:  11%|7      | 3/27 [00:00<00:00, 24.52it/s]
# epoch 001 | valid on 'valid' subset:  26%|#8     | 7/27 [00:00<00:00, 26.29it/s]
# epoch 001 | valid on 'valid' subset:  41%|##4   | 11/27 [00:00<00:00, 27.85it/s]
# epoch 001 | valid on 'valid' subset:  56%|###3  | 15/27 [00:00<00:00, 29.18it/s]
# epoch 001 | valid on 'valid' subset:  70%|####2 | 19/27 [00:00<00:00, 30.13it/s]
# epoch 001 | valid on 'valid' subset:  85%|#####1| 23/27 [00:00<00:00, 30.84it/s]
#                                                                                 2022-09-19 18:44:15 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 8.512 | nll_loss 7.499 | ppl 180.93 | wps 88778.5 | wpb 2701.8 | bsz 208.9 | num_updates 651
# 2022-09-19 18:44:15 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 651 updates
# 2022-09-19 18:44:15 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint1.pt
# 2022-09-19 18:44:18 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint1.pt
# 2022-09-19 18:44:22 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/aym-es++es-en/checkpoint1.pt (epoch 1 @ 651 updates, score 8.512) (writing took 6.564875626005232 seconds)
# 2022-09-19 18:44:22 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2022-09-19 18:44:22 | INFO | train | epoch 001 | loss 9.694 | nll_loss 8.935 | ppl 489.4 | wps 29471.9 | ups 8.28 | wpb 3555.6 | bsz 311.4 | num_updates 651 | lr 8.1375e-05 | gnorm 2.856 | loss_scale 32 | train_wall 69 | gb_free 12.1 | wall 79
# 2022-09-19 18:44:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 18:44:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.048863
# 2022-09-19 18:44:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:44:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.003116
# 2022-09-19 18:44:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:44:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.010262
# 2022-09-19 18:44:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.063496
# 2022-09-19 18:44:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:44:22 | INFO | fairseq.data.iterators | grouped total_num_itrs = 653
# epoch 002:   0%|                                        | 0/653 [00:00<?, ?it/s]2022-09-19 18:44:22 | INFO | fairseq.trainer | begin training epoch 2
# 2022-09-19 18:44:22 | INFO | fairseq_cli.train | Start iterating over samples
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff43b10b8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 002:  14%|1| 94/653 [00:10<01:01,  9.15it/s, loss=7.952, nll_loss=6.903, pException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ffdc1cc88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 002: 100%|9| 652/653 [01:11<00:00,  9.03it/s, loss=6.844, nll_loss=5.634, 2022-09-19 18:45:34 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 18:45:34 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 18:45:34 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001856
# 2022-09-19 18:45:34 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:45:34 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.043250
# 2022-09-19 18:45:34 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:45:34 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.032696
# 2022-09-19 18:45:34 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.078776
# 2022-09-19 18:45:34 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 002 | valid on 'valid' subset:   0%|               | 0/27 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:   7%|5      | 2/27 [00:00<00:01, 18.31it/s]
# epoch 002 | valid on 'valid' subset:  22%|#5     | 6/27 [00:00<00:01, 20.94it/s]
# epoch 002 | valid on 'valid' subset:  37%|##2   | 10/27 [00:00<00:00, 23.23it/s]
# epoch 002 | valid on 'valid' subset:  52%|###1  | 14/27 [00:00<00:00, 25.50it/s]
# epoch 002 | valid on 'valid' subset:  67%|####  | 18/27 [00:00<00:00, 27.36it/s]
# epoch 002 | valid on 'valid' subset:  81%|####8 | 22/27 [00:00<00:00, 28.66it/s]
# epoch 002 | valid on 'valid' subset:  96%|#####7| 26/27 [00:00<00:00, 30.64it/s]
#                                                                                 2022-09-19 18:45:35 | INFO | valid | epoch 002 | valid on 'valid' subset | loss 7.551 | nll_loss 6.387 | ppl 83.66 | wps 89035.7 | wpb 2701.8 | bsz 208.9 | num_updates 1304 | best_loss 7.551
# 2022-09-19 18:45:35 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 2 @ 1304 updates
# 2022-09-19 18:45:35 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint2.pt
# 2022-09-19 18:45:38 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint2.pt
# 2022-09-19 18:45:41 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/aym-es++es-en/checkpoint2.pt (epoch 2 @ 1304 updates, score 7.551) (writing took 5.428136229980737 seconds)
# 2022-09-19 18:45:41 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2022-09-19 18:45:41 | INFO | train | epoch 002 | loss 7.143 | nll_loss 5.976 | ppl 62.95 | wps 29643.6 | ups 8.33 | wpb 3556.7 | bsz 312.1 | num_updates 1304 | lr 0.000163 | gnorm 1.765 | loss_scale 32 | train_wall 70 | gb_free 12.1 | wall 157
# 2022-09-19 18:45:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 18:45:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.050751
# 2022-09-19 18:45:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:45:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.002999
# 2022-09-19 18:45:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:45:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.010812
# 2022-09-19 18:45:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.065851
# 2022-09-19 18:45:41 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:45:46 | INFO | fairseq.data.iterators | grouped total_num_itrs = 653
# epoch 003:   0%|                                        | 0/653 [00:00<?, ?it/s]2022-09-19 18:45:46 | INFO | fairseq.trainer | begin training epoch 3
# 2022-09-19 18:45:46 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 003:  13%|###8                           | 82/653 [00:08<01:06,  8.59it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ffdc1cc88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff3f9cba8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 003: 100%|9| 652/653 [01:11<00:00,  8.86it/s, loss=6.153, nll_loss=4.842, 2022-09-19 18:46:57 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 18:46:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 18:46:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.003419
# 2022-09-19 18:46:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:46:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.044346
# 2022-09-19 18:46:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:46:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.032120
# 2022-09-19 18:46:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.080742
# 2022-09-19 18:46:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 003 | valid on 'valid' subset:   0%|               | 0/27 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:   7%|5      | 2/27 [00:00<00:01, 17.40it/s]
# epoch 003 | valid on 'valid' subset:  22%|#5     | 6/27 [00:00<00:01, 20.09it/s]
# epoch 003 | valid on 'valid' subset:  37%|##2   | 10/27 [00:00<00:00, 22.48it/s]
# epoch 003 | valid on 'valid' subset:  52%|###1  | 14/27 [00:00<00:00, 24.84it/s]
# epoch 003 | valid on 'valid' subset:  67%|####  | 18/27 [00:00<00:00, 26.74it/s]
# epoch 003 | valid on 'valid' subset:  81%|####8 | 22/27 [00:00<00:00, 27.85it/s]
# epoch 003 | valid on 'valid' subset:  93%|#####5| 25/27 [00:00<00:00, 27.98it/s]
#                                                                                 2022-09-19 18:46:58 | INFO | valid | epoch 003 | valid on 'valid' subset | loss 7.001 | nll_loss 5.719 | ppl 52.67 | wps 85099.8 | wpb 2701.8 | bsz 208.9 | num_updates 1957 | best_loss 7.001
# 2022-09-19 18:46:58 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 3 @ 1957 updates
# 2022-09-19 18:46:58 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint3.pt
# 2022-09-19 18:47:06 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint3.pt
# 2022-09-19 18:47:09 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/aym-es++es-en/checkpoint3.pt (epoch 3 @ 1957 updates, score 7.001) (writing took 10.80489595909603 seconds)
# 2022-09-19 18:47:09 | INFO | fairseq_cli.train | end of epoch 3 (average epoch stats below)
# 2022-09-19 18:47:09 | INFO | train | epoch 003 | loss 6.286 | nll_loss 4.997 | ppl 31.94 | wps 26135.4 | ups 7.35 | wpb 3556.7 | bsz 312.1 | num_updates 1957 | lr 0.000244625 | gnorm 1.404 | loss_scale 32 | train_wall 70 | gb_free 12.2 | wall 246
# 2022-09-19 18:47:09 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 18:47:09 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.057625
# 2022-09-19 18:47:09 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:47:09 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.003309
# 2022-09-19 18:47:09 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:47:09 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.011433
# 2022-09-19 18:47:09 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.073698
# 2022-09-19 18:47:09 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:47:10 | INFO | fairseq.data.iterators | grouped total_num_itrs = 653
# epoch 004:   0%|                                        | 0/653 [00:00<?, ?it/s]2022-09-19 18:47:10 | INFO | fairseq.trainer | begin training epoch 4
# 2022-09-19 18:47:10 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 004:  11%|1| 72/653 [00:08<01:00,  9.64it/s, loss=6.015, nll_loss=4.684, pException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ffdc1cc88>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff3f9cba8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f40caf08a58>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 004: 100%|9| 652/653 [01:11<00:00,  9.27it/s, loss=5.089, nll_loss=3.624, 2022-09-19 18:48:21 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 18:48:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 18:48:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.003648
# 2022-09-19 18:48:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:48:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.043645
# 2022-09-19 18:48:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:48:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.032486
# 2022-09-19 18:48:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.080807
# 2022-09-19 18:48:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 004 | valid on 'valid' subset:   0%|               | 0/27 [00:00<?, ?it/s]
# epoch 004 | valid on 'valid' subset:   4%|2      | 1/27 [00:00<00:03,  8.02it/s]
# epoch 004 | valid on 'valid' subset:  15%|#      | 4/27 [00:00<00:02, 10.20it/s]
# epoch 004 | valid on 'valid' subset:  26%|#8     | 7/27 [00:00<00:01, 12.64it/s]
# epoch 004 | valid on 'valid' subset:  41%|##4   | 11/27 [00:00<00:01, 15.30it/s]
# epoch 004 | valid on 'valid' subset:  56%|###3  | 15/27 [00:00<00:00, 17.96it/s]
# epoch 004 | valid on 'valid' subset:  67%|####  | 18/27 [00:00<00:00, 19.89it/s]
# epoch 004 | valid on 'valid' subset:  78%|####6 | 21/27 [00:00<00:00, 21.82it/s]
# epoch 004 | valid on 'valid' subset:  93%|#####5| 25/27 [00:00<00:00, 24.16it/s]
#                                                                                 2022-09-19 18:48:22 | INFO | valid | epoch 004 | valid on 'valid' subset | loss 6.469 | nll_loss 5.086 | ppl 33.97 | wps 81255.3 | wpb 2701.8 | bsz 208.9 | num_updates 2610 | best_loss 6.469
# 2022-09-19 18:48:22 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 4 @ 2610 updates
# 2022-09-19 18:48:22 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint4.pt
# 2022-09-19 18:48:25 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint4.pt
# 2022-09-19 18:48:27 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/aym-es++es-en/checkpoint4.pt (epoch 4 @ 2610 updates, score 6.469) (writing took 5.115831756033003 seconds)
# 2022-09-19 18:48:27 | INFO | fairseq_cli.train | end of epoch 4 (average epoch stats below)
# 2022-09-19 18:48:27 | INFO | train | epoch 004 | loss 5.532 | nll_loss 4.132 | ppl 17.53 | wps 29734.2 | ups 8.36 | wpb 3556.7 | bsz 312.1 | num_updates 2610 | lr 0.00032625 | gnorm 1.247 | loss_scale 32 | train_wall 70 | gb_free 12.2 | wall 324
# 2022-09-19 18:48:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 18:48:28 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.045430
# 2022-09-19 18:48:28 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:48:28 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.001955
# 2022-09-19 18:48:28 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:48:28 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.005503
# 2022-09-19 18:48:28 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.053913
# 2022-09-19 18:48:28 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 18:48:28 | INFO | fairseq.data.iterators | grouped total_num_itrs = 653
# epoch 005:   0%|                                        | 0/653 [00:00<?, ?it/s]2022-09-19 18:48:28 | INFO | fairseq.trainer | begin training epoch 5
# 2022-09-19 18:48:28 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 005:   0%|                                | 2/653 [00:00<01:10,  9.20it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff39534e0>>
# Traceback (most recent call last):
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff40fc7f0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 030: 100%|9| 652/653 [01:11<00:00,  9.37it/s, loss=2.673, nll_loss=0.866, 2022-09-19 19:23:17 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 19:23:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 19:23:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.004072
# 2022-09-19 19:23:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 19:23:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.062321
# 2022-09-19 19:23:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 19:23:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.048056
# 2022-09-19 19:23:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.115867
# 2022-09-19 19:23:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 030 | valid on 'valid' subset:   0%|               | 0/27 [00:00<?, ?it/s]
# epoch 030 | valid on 'valid' subset:   7%|5      | 2/27 [00:00<00:01, 16.03it/s]
# epoch 030 | valid on 'valid' subset:  19%|#2     | 5/27 [00:00<00:01, 18.46it/s]
# epoch 030 | valid on 'valid' subset:  33%|##3    | 9/27 [00:00<00:00, 21.08it/s]
# epoch 030 | valid on 'valid' subset:  48%|##8   | 13/27 [00:00<00:00, 23.72it/s]
# epoch 030 | valid on 'valid' subset:  63%|###7  | 17/27 [00:00<00:00, 25.89it/s]
# epoch 030 | valid on 'valid' subset:  78%|####6 | 21/27 [00:00<00:00, 27.60it/s]
# epoch 030 | valid on 'valid' subset:  93%|#####5| 25/27 [00:00<00:00, 29.00it/s]
#                                                                                 2022-09-19 19:23:18 | INFO | valid | epoch 030 | valid on 'valid' subset | loss 4.854 | nll_loss 3.215 | ppl 9.29 | wps 87922 | wpb 2701.8 | bsz 208.9 | num_updates 19588 | best_loss 4.769
# 2022-09-19 19:23:18 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 30 @ 19588 updates
# 2022-09-19 19:23:18 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint30.pt
# 2022-09-19 19:23:20 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint30.pt
# 2022-09-19 19:23:22 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/aym-es++es-en/checkpoint30.pt (epoch 30 @ 19588 updates, score 4.854) (writing took 4.027992377988994 seconds)
# 2022-09-19 19:23:25 | INFO | fairseq_cli.train | end of epoch 30 (average epoch stats below)
# 2022-09-19 19:23:25 | INFO | train | epoch 030 | loss 2.681 | nll_loss 0.874 | ppl 1.83 | wps 29133.3 | ups 8.19 | wpb 3556.7 | bsz 312.1 | num_updates 19588 | lr 0.000225946 | gnorm 0.864 | loss_scale 64 | train_wall 70 | gb_free 12.5 | wall 2422
# 2022-09-19 19:23:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 19:23:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.041731
# 2022-09-19 19:23:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 19:23:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.001436
# 2022-09-19 19:23:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 19:23:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.004872
# 2022-09-19 19:23:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.048743
# 2022-09-19 19:23:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 19:23:25 | INFO | fairseq.data.iterators | grouped total_num_itrs = 653
# epoch 031:   0%|                                        | 0/653 [00:00<?, ?it/s]2022-09-19 19:23:25 | INFO | fairseq.trainer | begin training epoch 31
# 2022-09-19 19:23:25 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 031:   0%|                                | 1/653 [00:00<01:35,  6.81it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff431def0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 031:  17%|1| 113/653 [00:12<01:01,  8.84it/s, loss=2.725, nll_loss=0.918, Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff452f828>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff43fb2e8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff4547f60>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff4531cc0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
# epoch 031:  17%|1| 114/653 [00:12<01:01,  8.73it/s, loss=2.725, nll_loss=0.918,     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff44c16d8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff42cc048>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff43bd6d8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff452f518>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff40fc7f0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3ff4024438>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 031: 100%|9| 652/653 [01:11<00:00,  8.84it/s, loss=2.592, nll_loss=0.776, 2022-09-19 19:24:37 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-19 19:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-19 19:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001480
# 2022-09-19 19:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 19:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.041632
# 2022-09-19 19:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-19 19:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.031929
# 2022-09-19 19:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.075694
# 2022-09-19 19:24:37 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 031 | valid on 'valid' subset:   0%|               | 0/27 [00:00<?, ?it/s]
# epoch 031 | valid on 'valid' subset:  11%|7      | 3/27 [00:00<00:01, 23.97it/s]
# epoch 031 | valid on 'valid' subset:  26%|#8     | 7/27 [00:00<00:00, 25.84it/s]
# epoch 031 | valid on 'valid' subset:  41%|##4   | 11/27 [00:00<00:00, 27.50it/s]
# epoch 031 | valid on 'valid' subset:  56%|###3  | 15/27 [00:00<00:00, 29.09it/s]
# epoch 031 | valid on 'valid' subset:  70%|####2 | 19/27 [00:00<00:00, 30.12it/s]
# epoch 031 | valid on 'valid' subset:  85%|#####1| 23/27 [00:00<00:00, 30.80it/s]
#                                                                                 2022-09-19 19:24:38 | INFO | valid | epoch 031 | valid on 'valid' subset | loss 4.892 | nll_loss 3.263 | ppl 9.6 | wps 89395.4 | wpb 2701.8 | bsz 208.9 | num_updates 20241 | best_loss 4.769
# 2022-09-19 19:24:38 | INFO | fairseq_cli.train | early stop since valid performance hasn't improved for last 10 runs
# 2022-09-19 19:24:38 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 31 @ 20241 updates
# 2022-09-19 19:24:38 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint31.pt
# 2022-09-19 19:24:40 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/aym-es++es-en/checkpoint31.pt
# 2022-09-19 19:24:42 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/aym-es++es-en/checkpoint31.pt (epoch 31 @ 20241 updates, score 4.892) (writing took 3.929054894950241 seconds)
# 2022-09-19 19:24:48 | INFO | fairseq_cli.train | end of epoch 31 (average epoch stats below)
# 2022-09-19 19:24:48 | INFO | train | epoch 031 | loss 2.657 | nll_loss 0.846 | ppl 1.8 | wps 28147.5 | ups 7.91 | wpb 3556.7 | bsz 312.1 | num_updates 20241 | lr 0.000222272 | gnorm 0.858 | loss_scale 64 | train_wall 70 | gb_free 12.5 | wall 2505
# 2022-09-19 19:24:48 | INFO | fairseq_cli.train | done training in 2504.4 seconds

# %%
! echo $MODEL_DIR
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
cd /storage/master-thesis/models/aym-es+es-en
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
! rm dict.en.txt
! rm dict.es.txt
! rm dict.aym.txt

# %%
! du -shc /notebooks/*
# Out:
# 2.5K	/notebooks/CITATION.cff
# 5.5K	/notebooks/CODE_OF_CONDUCT.md
# 15K	/notebooks/CONTRIBUTING.md
# 19K	/notebooks/ISSUES.md
# 12K	/notebooks/LICENSE
# 512	/notebooks/MANIFEST.in
# 3.5K	/notebooks/Makefile
# 41K	/notebooks/README.md
# 41K	/notebooks/README_zh-hans.md
# 42K	/notebooks/README_zh-hant.md
# 12K	/notebooks/docker
# 4.6M	/notebooks/docs
# 5.0M	/notebooks/examples
# 8.5K	/notebooks/hubconf.py
# 7.8G	/notebooks/master-thesis
# 1.5K	/notebooks/model_cards
# 9.5K	/notebooks/notebooks
# 512	/notebooks/pyproject.toml
# 64K	/notebooks/scripts
# 1.0K	/notebooks/setup.cfg
# 13K	/notebooks/setup.py
# 13M	/notebooks/src
# 731K	/notebooks/templates
# 4.5K	/notebooks/test quy-es -> es-en model.ipynb
# 6.8M	/notebooks/tests
# 147K	/notebooks/train es-en model.ipynb
# 158K	/notebooks/train quy-es + es-en model.ipynb
# 160K	/notebooks/utils
# 3.5K	/notebooks/valohai.yaml
# 7.9G	total

# %%
! du -shc /notebooks/master-thesis/*
# Out:
# 512	/notebooks/master-thesis/Untitled.ipynb
# 362M	/notebooks/master-thesis/corpora
# 7.5G	/notebooks/master-thesis/models
# 7.8G	total

# %%
! du -shc /notebooks/master-thesis/models/*
# Out:
# 1.6G	/notebooks/master-thesis/models/es-en
# 802M	/notebooks/master-thesis/models/quy-es
# 5.2G	/notebooks/master-thesis/models/quy-es+es-en
# 7.5G	total

# %%
! du -shc /*
# Out:
# 19M	/apex
# 5.0M	/bin
# 4.0K	/boot
# 24K	/content
# ^C

# %%
ls
# Out:
#  CITATION.cff         docker/          setup.py
#  CODE_OF_CONDUCT.md   docs/            src/
#  CONTRIBUTING.md      examples/        templates/
#  ISSUES.md            hubconf.py      'test quy-es -> es-en model.ipynb'
#  LICENSE              master-thesis/   tests/
#  MANIFEST.in          model_cards/    'train es-en model.ipynb'
#  Makefile             notebooks/      'train quy-es + es-en model.ipynb'
#  README.md            pyproject.toml   utils/
#  README_zh-hans.md    scripts/         valohai.yaml
#  README_zh-hant.md    setup.cfg

# %%
# Out:
# /storage/master-thesis
