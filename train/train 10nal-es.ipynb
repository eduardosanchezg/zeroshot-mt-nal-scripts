# %% [markdown]
# ## ENVIRONMENT VARIABLES

# %%
QUY_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish"

# %%
CNI_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/ashaninka-spanish"

# %%
AYM_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish"

# %%
BZD_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/bribri-spanish"

# %%
GN_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/guarani-spanish"

# %%
OTO_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/hnahnu-spanish"

# %%
NAH_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish"

# %%
TAR_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/raramuri-spanish"

# %%
SHP_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/shipibo_konibo-spanish"

# %%
HCH_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/americasnlp2021/data/wixarika-spanish"

# %%
tokenizer_path = "/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/"

# %%
# %env TOKENIZER_PATH = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es
# Out:
# env: TOKENIZER_PATH=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es

# %%
tokenized_path_quy_es = "/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/"
tokenized_path_cni_es = "/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es/"
tokenized_path_aym_es = "/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es/"
tokenized_path_bzd_es = "/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es/"
tokenized_path_gn_es = "/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es/"
tokenized_path_oto_es = "/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es/"
tokenized_path_nah_es = "/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es/"
tokenized_path_tar_es = "/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es/"
tokenized_path_shp_es = "/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es/"
tokenized_path_hch_es = "/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es/"

# %%
# %env TOKENIZED_PATH_QUY_ES = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es
# %env TOKENIZED_PATH_CNI_ES = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es
# %env TOKENIZED_PATH_AYM_ES = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es
# %env TOKENIZED_PATH_BZD_ES = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es
# %env TOKENIZED_PATH_GN_ES = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es
# %env TOKENIZED_PATH_OTO_ES = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es
# %env TOKENIZED_PATH_NAH_ES = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es
# %env TOKENIZED_PATH_TAR_ES = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es
# %env TOKENIZED_PATH_SHP_ES = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es
# %env TOKENIZED_PATH_HCH_ES = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es
# Out:
# env: TOKENIZED_PATH_QUY_ES=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es
# env: TOKENIZED_PATH_CNI_ES=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es
# env: TOKENIZED_PATH_AYM_ES=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es
# env: TOKENIZED_PATH_BZD_ES=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es
# env: TOKENIZED_PATH_GN_ES=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es
# env: TOKENIZED_PATH_OTO_ES=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es
# env: TOKENIZED_PATH_NAH_ES=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es
# env: TOKENIZED_PATH_TAR_ES=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es
# env: TOKENIZED_PATH_SHP_ES=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es
# env: TOKENIZED_PATH_HCH_ES=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es

# %%
# %env BIN_DIR = /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin
# Out:
# env: BIN_DIR=/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %%
# %env MODEL_DIR = /storage/master-thesis/models/10nal-es
# Out:
# env: MODEL_DIR=/storage/master-thesis/models/10nal-es

# %%
! mkdir -p $TOKENIZED_PATH_QUY_ES
! mkdir -p $TOKENIZED_PATH_CNI_ES
! mkdir -p $TOKENIZED_PATH_AYM_ES
! mkdir -p $TOKENIZED_PATH_BZD_ES
! mkdir -p $TOKENIZED_PATH_GN_ES
! mkdir -p $TOKENIZED_PATH_OTO_ES
! mkdir -p $TOKENIZED_PATH_NAH_ES
! mkdir -p $TOKENIZED_PATH_TAR_ES
! mkdir -p $TOKENIZED_PATH_SHP_ES
! mkdir -p $TOKENIZED_PATH_HCH_ES
! mkdir -p $BIN_DIR

# %% [markdown]
# ## Libraries

# %%
pip install tokenizers==0.10.3
# Out:
# Requirement already satisfied: tokenizers==0.10.3 in /usr/local/lib/python3.6/dist-packages (0.10.3)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 1.9.1
# Uninstalling torch-1.9.1:
#   Successfully uninstalled torch-1.9.1
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (1821.5 MB)
#      |################################| 1821.5 MB 8.0 kB/s eta 0:00:0101K     |#####                           | 304.1 MB 85.2 MB/s eta 0:00:18             | 981.7 MB 987 kB/s eta 0:14:11     |#######################         | 1359.5 MB 1.2 MB/s eta 0:06:33
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.11.3%2Bcu113-cp36-cp36m-linux_x86_64.whl (24.6 MB)
#      |################################| 24.6 MB 7.3 MB/s eta 0:00:01
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (2.9 MB)
#      |################################| 2.9 MB 7.7 MB/s eta 0:00:01
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.18.5)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from torchvision) (8.3.2)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.10.2+cu113 torchaudio-0.10.2+cu113 torchvision-0.11.3+cu113
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall fairseq -y
# Out:
# Found existing installation: fairseq 0.10.2
# Uninstalling fairseq-0.10.2:
#   Successfully uninstalled fairseq-0.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fairseq
# Out:
# Collecting fairseq
#   Downloading fairseq-0.12.2-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.0 MB)
#      |################################| 11.0 MB 8.2 MB/s eta 0:00:01
# Collecting omegaconf<2.1
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.8)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2020.11.13)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.24)
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.3)
# Collecting hydra-core<1.1,>=1.0.7
#   Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#      |################################| 123 kB 119.4 MB/s eta 0:00:01
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.10.2+cu113)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.51.0)
# Collecting bitarray
#   Downloading bitarray-2.6.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (235 kB)
#      |################################| 235 kB 80.3 MB/s eta 0:00:01
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.10.2+cu113)
# Requirement already satisfied: numpy<1.20.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.6/dist-packages (from omegaconf<2.1->fairseq) (5.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from omegaconf<2.1->fairseq) (3.10.0.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.4.4)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (2.3.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.8.9)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (5.2.2)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (4.8)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core<1.1,>=1.0.7->fairseq) (3.4.0)
# Installing collected packages: omegaconf, hydra-core, bitarray, fairseq
#   Attempting uninstall: omegaconf
#     Found existing installation: omegaconf 2.1.1
#     Uninstalling omegaconf-2.1.1:
#       Successfully uninstalled omegaconf-2.1.1
#   Attempting uninstall: hydra-core
#     Found existing installation: hydra-core 1.1.1
#     Uninstalling hydra-core-1.1.1:
#       Successfully uninstalled hydra-core-1.1.1
# Successfully installed bitarray-2.6.0 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip uninstall apex -y
# Out:
# Found existing installation: apex 0.1
# Uninstalling apex-0.1:
#   Successfully uninstalled apex-0.1

# %%
! pip install -v --disable-pip-version-check --no-cache-dir apex

# %% [markdown]
# ### Tokenizing data

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece

nal_es_tokenizer = Tokenizer(WordPiece(unk_token="[UNK]"))

# %%
from tokenizers.trainers import WordPieceTrainer

nal_es_trainer = WordPieceTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"], vocab_size=30000, show_progress=True)

# %%
from tokenizers.pre_tokenizers import Whitespace

nal_es_tokenizer.pre_tokenizer = Whitespace()

quy_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/{split}.quy" for split in ["dev", "dict", "train"]]
es_quy_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/{split}.es" for split in ["dev", "dict", "train"]]

cni_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/ashaninka-spanish/{split}.cni" for split in ["dev", "train"]]
es_cni_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/ashaninka-spanish/{split}.es" for split in ["dev", "train"]]

aym_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/{split}.aym" for split in ["dev", "train"]]
es_aym_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/{split}.es" for split in ["dev", "train"]]

bzd_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/bribri-spanish/{split}.bzd" for split in ["dev", "train"]]
es_bzd_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/bribri-spanish/{split}.es" for split in ["dev", "train"]]

gn_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/guarani-spanish/{split}.gn" for split in ["dev", "train"]]
es_gn_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/guarani-spanish/{split}.es" for split in ["dev", "train"]]

oto_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/hnahnu-spanish/{split}.oto" for split in ["dev", "train"]]
es_oto_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/hnahnu-spanish/{split}.es" for split in ["dev", "train"]]

nah_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/{split}.nah" for split in ["dev", "train"]]
es_nah_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/{split}.es" for split in ["dev", "train"]]

tar_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/raramuri-spanish/{split}.tar" for split in ["dev", "train"]]
es_tar_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/raramuri-spanish/{split}.es" for split in ["dev", "train"]]

shp_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/shipibo_konibo-spanish/{split}.shp" for split in ["dev", "train"]]
es_shp_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/shipibo_konibo-spanish/{split}.es" for split in ["dev", "train"]]

hch_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/wixarika-spanish/{split}.hch" for split in ["dev", "train"]]
es_hch_files = [f"/notebooks/master-thesis/corpora/americasnlp2021/data/wixarika-spanish/{split}.es" for split in ["dev", "train"]]


files = quy_files + es_quy_files + cni_files + es_cni_files + aym_files + es_aym_files + bzd_files + es_bzd_files + gn_files + es_gn_files + oto_files + es_oto_files + nah_files + es_nah_files + tar_files + es_tar_files + shp_files + es_shp_files + hch_files + es_hch_files
nal_es_tokenizer.train(files= files, trainer=nal_es_trainer)

# %%
from pathlib import Path



def tokenize_files(tokenizer, files, extension, output_path):
    for file in files:
        print(f"Reading file {file}")
        with open(file, encoding='utf8') as f:
          lines = f.readlines()
          tokenized_lines = tokenizer.encode_batch(lines)
          tokenized_name = Path(file).stem
          tokenized_name = output_path + tokenized_name + "." + extension
          print(tokenized_name)
          with open(tokenized_name, 'w', encoding='utf8') as wf:

            wf.writelines([" ".join(t.tokens) + "\n" for t in tokenized_lines])

# %%
nal_es_tokenizer.save(tokenizer_path + "nal_es_tokenizer.json")

# %%
print(nal_es_tokenizer)
# Out:
# <tokenizers.Tokenizer object at 0x7fdaf8023ca0>

# %%
tok = nal_es_tokenizer.encode("we hold this truth to be self evident that everyone is created equal?")
print(tok.tokens)
# Out:
# ['we', 'ho', '##ld', 'thi', '##s', 'tru', '##th', 'to', 'be', 'sel', '##f', 'evid', '##en', '##t', 'th', '##at', 'eve', '##ry', '##one', 'is', 'crea', '##te', '##d', 'e', '##qual', '?']

# %%
tokenize_files(nal_es_tokenizer, quy_files, "quy", tokenized_path_quy_es)
tokenize_files(nal_es_tokenizer, es_quy_files, "es", tokenized_path_quy_es)

tokenize_files(nal_es_tokenizer, cni_files, "cni", tokenized_path_cni_es)
tokenize_files(nal_es_tokenizer, es_cni_files, "es", tokenized_path_cni_es)

tokenize_files(nal_es_tokenizer, aym_files, "aym", tokenized_path_aym_es)
tokenize_files(nal_es_tokenizer, es_aym_files, "es", tokenized_path_aym_es)

tokenize_files(nal_es_tokenizer, bzd_files, "bzd", tokenized_path_bzd_es)
tokenize_files(nal_es_tokenizer, es_bzd_files, "es", tokenized_path_bzd_es)

tokenize_files(nal_es_tokenizer, gn_files, "gn", tokenized_path_gn_es)
tokenize_files(nal_es_tokenizer, es_gn_files, "es", tokenized_path_gn_es)

tokenize_files(nal_es_tokenizer, oto_files, "oto", tokenized_path_oto_es)
tokenize_files(nal_es_tokenizer, es_oto_files, "es", tokenized_path_oto_es)

tokenize_files(nal_es_tokenizer, nah_files, "nah", tokenized_path_nah_es)
tokenize_files(nal_es_tokenizer, es_nah_files, "es", tokenized_path_nah_es)

tokenize_files(nal_es_tokenizer, tar_files, "tar", tokenized_path_tar_es)
tokenize_files(nal_es_tokenizer, es_tar_files, "es", tokenized_path_tar_es)

tokenize_files(nal_es_tokenizer, shp_files, "shp", tokenized_path_shp_es)
tokenize_files(nal_es_tokenizer, es_shp_files, "es", tokenized_path_shp_es)

tokenize_files(nal_es_tokenizer, hch_files, "hch", tokenized_path_hch_es)
tokenize_files(nal_es_tokenizer, es_hch_files, "es", tokenized_path_hch_es)
# Out:
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/dev.quy
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/dev.quy
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/dict.quy
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/dict.quy
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/train.quy
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/train.quy
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/dev.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/dict.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/dict.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/quechua-spanish/train.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/ashaninka-spanish/dev.cni
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es/dev.cni
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/ashaninka-spanish/train.cni
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es/train.cni
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/ashaninka-spanish/dev.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/ashaninka-spanish/train.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/dev.aym
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es/dev.aym
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/train.aym
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es/train.aym
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/dev.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/aymara-spanish/train.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/bribri-spanish/dev.bzd
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es/dev.bzd
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/bribri-spanish/train.bzd
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es/train.bzd
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/bribri-spanish/dev.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/bribri-spanish/train.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/guarani-spanish/dev.gn
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es/dev.gn
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/guarani-spanish/train.gn
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es/train.gn
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/guarani-spanish/dev.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/guarani-spanish/train.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/hnahnu-spanish/dev.oto
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es/dev.oto
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/hnahnu-spanish/train.oto
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es/train.oto
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/hnahnu-spanish/dev.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/hnahnu-spanish/train.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/dev.nah
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es/dev.nah
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/train.nah
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es/train.nah
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/dev.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/nahuatl-spanish/train.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/raramuri-spanish/dev.tar
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es/dev.tar
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/raramuri-spanish/train.tar
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es/train.tar
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/raramuri-spanish/dev.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/raramuri-spanish/train.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/shipibo_konibo-spanish/dev.shp
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es/dev.shp
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/shipibo_konibo-spanish/train.shp
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es/train.shp
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/shipibo_konibo-spanish/dev.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/shipibo_konibo-spanish/train.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es/train.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/wixarika-spanish/dev.hch
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es/dev.hch
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/wixarika-spanish/train.hch
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es/train.hch
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/wixarika-spanish/dev.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es/dev.es
# Reading file /notebooks/master-thesis/corpora/americasnlp2021/data/wixarika-spanish/train.es
# /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es/train.es

# %% [markdown]
# ## Binarizing data

# %%
## Concatenating all training data
! cat $TOKENIZED_PATH_QUY_ES/train.quy $TOKENIZED_PATH_QUY_ES/train.es \
    $TOKENIZED_PATH_CNI_ES/train.cni $TOKENIZED_PATH_CNI_ES/train.es \
    $TOKENIZED_PATH_AYM_ES/train.aym $TOKENIZED_PATH_AYM_ES/train.es \
    $TOKENIZED_PATH_BZD_ES/train.bzd $TOKENIZED_PATH_BZD_ES/train.es \
    $TOKENIZED_PATH_GN_ES/train.gn $TOKENIZED_PATH_GN_ES/train.es \
    $TOKENIZED_PATH_OTO_ES/train.oto $TOKENIZED_PATH_OTO_ES/train.es \
    $TOKENIZED_PATH_NAH_ES/train.nah $TOKENIZED_PATH_NAH_ES/train.es \
    $TOKENIZED_PATH_TAR_ES/train.tar $TOKENIZED_PATH_TAR_ES/train.es \
    $TOKENIZED_PATH_SHP_ES/train.shp $TOKENIZED_PATH_SHP_ES/train.es \
    $TOKENIZED_PATH_HCH_ES/train.hch $TOKENIZED_PATH_HCH_ES/train.es \
    > $BIN_DIR/train.all

# %%
! fairseq-preprocess --source-lang all \
    --trainpref $BIN_DIR/train \
    --destdir $BIN_DIR \
    --workers 20 \
    --task translation_multi_simple_epoch \
    --only-source
# Out:
# 2022-09-21 11:15:30 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=True, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='all', srcdict=None, suppress_crashes=False, target_lang=None, task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train', use_plasma_view=False, user_dir=None, validpref=None, wandb_project=None, workers=20)
# 2022-09-21 11:15:35 | INFO | fairseq_cli.preprocess | [all] Dictionary: 29256 types
# 2022-09-21 11:15:46 | INFO | fairseq_cli.preprocess | [all] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.all: 456548 sents, 9035883 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:15:46 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %%
! fairseq-preprocess --source-lang quy --target-lang es \
    --trainpref $TOKENIZED_PATH_QUY_ES/train --validpref $TOKENIZED_PATH_QUY_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-21 11:15:49 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='quy', srcdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/dev', wandb_project=None, workers=20)
# 2022-09-21 11:15:49 | INFO | fairseq_cli.preprocess | [quy] Dictionary: 29256 types
# 2022-09-21 11:15:52 | INFO | fairseq_cli.preprocess | [quy] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/train.quy: 125008 sents, 2000657 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:15:52 | INFO | fairseq_cli.preprocess | [quy] Dictionary: 29256 types
# 2022-09-21 11:15:53 | INFO | fairseq_cli.preprocess | [quy] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/dev.quy: 996 sents, 14550 tokens, 0.77% replaced (by <unk>)
# 2022-09-21 11:15:53 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:04 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/train.es: 125008 sents, 2486583 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:04 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:05 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/quy-es/dev.es: 996 sents, 14860 tokens, 0.794% replaced (by <unk>)
# 2022-09-21 11:16:05 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %% [markdown]
# ### Reusing es dict from quy-es preprocessing

# %%
! fairseq-preprocess --source-lang cni --target-lang es \
    --trainpref $TOKENIZED_PATH_CNI_ES/train --validpref $TOKENIZED_PATH_CNI_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-21 11:16:07 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='cni', srcdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es/dev', wandb_project=None, workers=20)
# 2022-09-21 11:16:07 | INFO | fairseq_cli.preprocess | [cni] Dictionary: 29256 types
# 2022-09-21 11:16:08 | INFO | fairseq_cli.preprocess | [cni] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es/train.cni: 3883 sents, 80554 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:08 | INFO | fairseq_cli.preprocess | [cni] Dictionary: 29256 types
# 2022-09-21 11:16:08 | INFO | fairseq_cli.preprocess | [cni] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es/dev.cni: 883 sents, 17843 tokens, 0.437% replaced (by <unk>)
# 2022-09-21 11:16:08 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:09 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es/train.es: 3883 sents, 72550 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:09 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:09 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/cni-es/dev.es: 883 sents, 12904 tokens, 0.705% replaced (by <unk>)
# 2022-09-21 11:16:09 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %%
! fairseq-preprocess --source-lang aym --target-lang es \
    --trainpref $TOKENIZED_PATH_AYM_ES/train --validpref $TOKENIZED_PATH_AYM_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-21 11:16:12 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='aym', srcdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es/dev', wandb_project=None, workers=20)
# 2022-09-21 11:16:12 | INFO | fairseq_cli.preprocess | [aym] Dictionary: 29256 types
# 2022-09-21 11:16:13 | INFO | fairseq_cli.preprocess | [aym] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es/train.aym: 6531 sents, 210061 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:13 | INFO | fairseq_cli.preprocess | [aym] Dictionary: 29256 types
# 2022-09-21 11:16:13 | INFO | fairseq_cli.preprocess | [aym] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es/dev.aym: 996 sents, 18942 tokens, 0.591% replaced (by <unk>)
# 2022-09-21 11:16:13 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:14 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es/train.es: 6531 sents, 187902 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:14 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:15 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/aym-es/dev.es: 996 sents, 14860 tokens, 0.794% replaced (by <unk>)
# 2022-09-21 11:16:15 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %%
! fairseq-preprocess --source-lang bzd --target-lang es \
    --trainpref $TOKENIZED_PATH_BZD_ES/train --validpref $TOKENIZED_PATH_BZD_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-21 11:16:17 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='bzd', srcdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es/dev', wandb_project=None, workers=20)
# 2022-09-21 11:16:17 | INFO | fairseq_cli.preprocess | [bzd] Dictionary: 29256 types
# 2022-09-21 11:16:26 | INFO | fairseq_cli.preprocess | [bzd] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es/train.bzd: 7508 sents, 93196 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:26 | INFO | fairseq_cli.preprocess | [bzd] Dictionary: 29256 types
# 2022-09-21 11:16:26 | INFO | fairseq_cli.preprocess | [bzd] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es/dev.bzd: 996 sents, 24468 tokens, 0.617% replaced (by <unk>)
# 2022-09-21 11:16:26 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:27 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es/train.es: 7508 sents, 68905 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:27 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:27 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bzd-es/dev.es: 996 sents, 14860 tokens, 0.794% replaced (by <unk>)
# 2022-09-21 11:16:27 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %%
! fairseq-preprocess --source-lang gn --target-lang es \
    --trainpref $TOKENIZED_PATH_GN_ES/train --validpref $TOKENIZED_PATH_GN_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-21 11:16:29 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='gn', srcdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es/dev', wandb_project=None, workers=20)
# 2022-09-21 11:16:30 | INFO | fairseq_cli.preprocess | [gn] Dictionary: 29256 types
# 2022-09-21 11:16:31 | INFO | fairseq_cli.preprocess | [gn] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es/train.gn: 26032 sents, 753112 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:31 | INFO | fairseq_cli.preprocess | [gn] Dictionary: 29256 types
# 2022-09-21 11:16:31 | INFO | fairseq_cli.preprocess | [gn] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es/dev.gn: 995 sents, 18282 tokens, 0.552% replaced (by <unk>)
# 2022-09-21 11:16:31 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:32 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es/train.es: 26032 sents, 820902 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:32 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:33 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/gn-es/dev.es: 995 sents, 14859 tokens, 0.794% replaced (by <unk>)
# 2022-09-21 11:16:33 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %%
! fairseq-preprocess --source-lang oto --target-lang es \
    --trainpref $TOKENIZED_PATH_OTO_ES/train --validpref $TOKENIZED_PATH_OTO_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-21 11:16:35 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='oto', srcdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es/dev', wandb_project=None, workers=20)
# 2022-09-21 11:16:35 | INFO | fairseq_cli.preprocess | [oto] Dictionary: 29256 types
# 2022-09-21 11:16:36 | INFO | fairseq_cli.preprocess | [oto] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es/train.oto: 4889 sents, 131070 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:36 | INFO | fairseq_cli.preprocess | [oto] Dictionary: 29256 types
# 2022-09-21 11:16:36 | INFO | fairseq_cli.preprocess | [oto] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es/dev.oto: 599 sents, 11772 tokens, 10.5% replaced (by <unk>)
# 2022-09-21 11:16:36 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:37 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es/train.es: 4889 sents, 85723 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:37 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:37 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/oto-es/dev.es: 599 sents, 6971 tokens, 0.689% replaced (by <unk>)
# 2022-09-21 11:16:37 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %%
! fairseq-preprocess --source-lang nah --target-lang es \
    --trainpref $TOKENIZED_PATH_NAH_ES/train --validpref $TOKENIZED_PATH_NAH_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-21 11:16:39 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='nah', srcdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es/dev', wandb_project=None, workers=20)
# 2022-09-21 11:16:39 | INFO | fairseq_cli.preprocess | [nah] Dictionary: 29256 types
# 2022-09-21 11:16:51 | INFO | fairseq_cli.preprocess | [nah] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es/train.nah: 16145 sents, 581747 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:51 | INFO | fairseq_cli.preprocess | [nah] Dictionary: 29256 types
# 2022-09-21 11:16:52 | INFO | fairseq_cli.preprocess | [nah] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es/dev.nah: 671 sents, 9822 tokens, 0.428% replaced (by <unk>)
# 2022-09-21 11:16:52 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:53 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es/train.es: 16145 sents, 562092 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:53 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:53 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/nah-es/dev.es: 671 sents, 8584 tokens, 0.687% replaced (by <unk>)
# 2022-09-21 11:16:53 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %%
! fairseq-preprocess --source-lang tar --target-lang es \
    --trainpref $TOKENIZED_PATH_TAR_ES/train --validpref $TOKENIZED_PATH_TAR_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-21 11:16:55 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='tar', srcdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es/dev', wandb_project=None, workers=20)
# 2022-09-21 11:16:56 | INFO | fairseq_cli.preprocess | [tar] Dictionary: 29256 types
# 2022-09-21 11:16:56 | INFO | fairseq_cli.preprocess | [tar] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es/train.tar: 14720 sents, 181222 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:56 | INFO | fairseq_cli.preprocess | [tar] Dictionary: 29256 types
# 2022-09-21 11:16:57 | INFO | fairseq_cli.preprocess | [tar] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es/dev.tar: 995 sents, 22622 tokens, 4.65% replaced (by <unk>)
# 2022-09-21 11:16:57 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:57 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es/train.es: 14720 sents, 182523 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:16:57 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:16:57 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/tar-es/dev.es: 995 sents, 14859 tokens, 0.794% replaced (by <unk>)
# 2022-09-21 11:16:57 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %%
! fairseq-preprocess --source-lang shp --target-lang es \
    --trainpref $TOKENIZED_PATH_SHP_ES/train --validpref $TOKENIZED_PATH_SHP_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-21 11:16:59 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='shp', srcdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es/dev', wandb_project=None, workers=20)
# 2022-09-21 11:17:00 | INFO | fairseq_cli.preprocess | [shp] Dictionary: 29256 types
# 2022-09-21 11:17:09 | INFO | fairseq_cli.preprocess | [shp] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es/train.shp: 14592 sents, 153014 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:17:09 | INFO | fairseq_cli.preprocess | [shp] Dictionary: 29256 types
# 2022-09-21 11:17:10 | INFO | fairseq_cli.preprocess | [shp] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es/dev.shp: 996 sents, 17709 tokens, 0.672% replaced (by <unk>)
# 2022-09-21 11:17:10 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:17:10 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es/train.es: 14592 sents, 142279 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:17:10 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:17:11 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/shp-es/dev.es: 996 sents, 14860 tokens, 0.794% replaced (by <unk>)
# 2022-09-21 11:17:11 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %%
! fairseq-preprocess --source-lang hch --target-lang es \
    --trainpref $TOKENIZED_PATH_HCH_ES/train --validpref $TOKENIZED_PATH_HCH_ES/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --task translation_multi_simple_epoch \
    --workers 20
# Out:
# 2022-09-21 11:17:13 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='hch', srcdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', suppress_crashes=False, target_lang='es', task='translation_multi_simple_epoch', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es/dev', wandb_project=None, workers=20)
# 2022-09-21 11:17:13 | INFO | fairseq_cli.preprocess | [hch] Dictionary: 29256 types
# 2022-09-21 11:17:14 | INFO | fairseq_cli.preprocess | [hch] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es/train.hch: 8966 sents, 142183 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:17:14 | INFO | fairseq_cli.preprocess | [hch] Dictionary: 29256 types
# 2022-09-21 11:17:14 | INFO | fairseq_cli.preprocess | [hch] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es/dev.hch: 994 sents, 24238 tokens, 0.413% replaced (by <unk>)
# 2022-09-21 11:17:14 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:17:15 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es/train.es: 8966 sents, 99608 tokens, 0.0% replaced (by <unk>)
# 2022-09-21 11:17:15 | INFO | fairseq_cli.preprocess | [es] Dictionary: 29256 types
# 2022-09-21 11:17:15 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/hch-es/dev.es: 994 sents, 14858 tokens, 0.794% replaced (by <unk>)
# 2022-09-21 11:17:15 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin

# %% [markdown]
# ## Training model

# %%
! fairseq-train $BIN_DIR \
    --arch=transformer --share-all-embeddings \
    --task translation_multi_simple_epoch --lang-pairs quy-es,cni-es,aym-es,bzd-es,gn-es,oto-es,nah-es,tar-es,shp-es,hch-es \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 5e-4 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --dropout 0.3 --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --max-tokens 4096 \
    --restore-file $MODEL_DIR/checkpoint_last.pt \
    --save-dir $MODEL_DIR/ \
    --keep-last-epochs 2 \
    --reset-optimizer \
    --encoder-langtok "src" \
    --decoder-langtok \
    --fp16 \
    --max-epoch 200 \
    --patience 10
# Out:
# 2022-09-28 12:24:24 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2022-09-28 12:24:26 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 4096, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 4096, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 200, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.0005], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '/storage/master-thesis/models/10nal-es/', 'restore_file': '/storage/master-thesis/models/10nal-es/checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': True, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': 2, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': 10, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1 ...
# 2022-09-28 12:24:26 | WARNING | fairseq.data.multilingual.multilingual_data_manager | External language dictionary is not provided; use lang-pairs to infer the set of supported languages. The language ordering is not stable which might cause misalignment in pretraining and finetuning.
# 2022-09-28 12:24:26 | INFO | fairseq.data.multilingual.multilingual_data_manager | inferred language list: ['aym', 'bzd', 'cni', 'es', 'gn', 'hch', 'nah', 'oto', 'quy', 'shp', 'tar']
# 2022-09-28 12:24:26 | INFO | fairseq.data.multilingual.multilingual_data_manager | [tar] dictionary: 29267 types
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | [es] dictionary: 29267 types
# 2022-09-28 12:24:27 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(29267, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(29267, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=512, out_features=29267, bias=False)
#   )
# )
# 2022-09-28 12:24:27 | INFO | fairseq_cli.train | task: TranslationMultiSimpleEpochTask
# 2022-09-28 12:24:27 | INFO | fairseq_cli.train | model: TransformerModel
# 2022-09-28 12:24:27 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-09-28 12:24:27 | INFO | fairseq_cli.train | num. shared model params: 78,025,216 (num. trained: 78,025,216)
# 2022-09-28 12:24:27 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-09-28 12:24:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for valid epoch=1/None
# 2022-09-28 12:24:27 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | [valid] num of shards: {'main:quy-es': 1, 'main:cni-es': 1, 'main:aym-es': 1, 'main:bzd-es': 1, 'main:gn-es': 1, 'main:oto-es': 1, 'main:nah-es': 1, 'main:tar-es': 1, 'main:shp-es': 1, 'main:hch-es': 1}
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:quy-es src_langtok: 29264; tgt_langtok: 29259
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.quy-es.quy
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.quy-es.es
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin valid quy-es 996 examples
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:cni-es src_langtok: 29258; tgt_langtok: 29259
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 883 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.cni-es.cni
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 883 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.cni-es.es
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin valid cni-es 883 examples
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:aym-es src_langtok: 29256; tgt_langtok: 29259
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.aym-es.aym
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.aym-es.es
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin valid aym-es 996 examples
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:bzd-es src_langtok: 29257; tgt_langtok: 29259
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.bzd-es.bzd
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.bzd-es.es
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin valid bzd-es 996 examples
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:gn-es src_langtok: 29260; tgt_langtok: 29259
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 995 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.gn-es.gn
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 995 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.gn-es.es
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin valid gn-es 995 examples
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:oto-es src_langtok: 29263; tgt_langtok: 29259
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 599 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.oto-es.oto
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 599 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.oto-es.es
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin valid oto-es 599 examples
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:nah-es src_langtok: 29262; tgt_langtok: 29259
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 671 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.nah-es.nah
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 671 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.nah-es.es
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin valid nah-es 671 examples
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:tar-es src_langtok: 29266; tgt_langtok: 29259
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 995 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.tar-es.tar
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 995 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.tar-es.es
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin valid tar-es 995 examples
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:shp-es src_langtok: 29265; tgt_langtok: 29259
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.shp-es.shp
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 996 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.shp-es.es
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin valid shp-es 996 examples
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:hch-es src_langtok: 29261; tgt_langtok: 29259
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 994 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.hch-es.hch
# 2022-09-28 12:24:27 | INFO | fairseq.data.data_utils | loaded 994 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/valid.hch-es.es
# 2022-09-28 12:24:27 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin valid hch-es 994 examples
# 2022-09-28 12:24:32 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.embed_tokens.weight
# 2022-09-28 12:24:32 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.output_projection.weight
# 2022-09-28 12:24:32 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-28 12:24:32 | INFO | fairseq.utils | rank   0: capabilities =  8.6  ; total memory = 15.740 GB ; name = NVIDIA RTX A4000
# 2022-09-28 12:24:32 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-09-28 12:24:32 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-09-28 12:24:32 | INFO | fairseq_cli.train | max tokens per device = 4096 and max sentences per device = None
# 2022-09-28 12:24:32 | INFO | fairseq.trainer | Preparing to load checkpoint /storage/master-thesis/models/10nal-es/checkpoint_last.pt
# 2022-09-28 12:24:37 | INFO | fairseq.trainer | Loaded checkpoint /storage/master-thesis/models/10nal-es/checkpoint_last.pt (epoch 35 @ 0 updates)
# 2022-09-28 12:24:38 | INFO | fairseq.trainer | loading train data for epoch 35
# 2022-09-28 12:24:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for train epoch=35/None
# 2022-09-28 12:24:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | [train] num of shards: {'main:quy-es': 1, 'main:cni-es': 1, 'main:aym-es': 1, 'main:bzd-es': 1, 'main:gn-es': 1, 'main:oto-es': 1, 'main:nah-es': 1, 'main:tar-es': 1, 'main:shp-es': 1, 'main:hch-es': 1}
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:quy-es src_langtok: 29264; tgt_langtok: 29259
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 125,008 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.quy-es.quy
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 125,008 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.quy-es.es
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin train quy-es 125008 examples
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:cni-es src_langtok: 29258; tgt_langtok: 29259
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 3,883 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.cni-es.cni
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 3,883 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.cni-es.es
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin train cni-es 3883 examples
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:aym-es src_langtok: 29256; tgt_langtok: 29259
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 6,531 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.aym-es.aym
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 6,531 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.aym-es.es
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin train aym-es 6531 examples
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:bzd-es src_langtok: 29257; tgt_langtok: 29259
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 7,508 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.bzd-es.bzd
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 7,508 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.bzd-es.es
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin train bzd-es 7508 examples
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:gn-es src_langtok: 29260; tgt_langtok: 29259
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 26,032 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.gn-es.gn
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 26,032 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.gn-es.es
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin train gn-es 26032 examples
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:oto-es src_langtok: 29263; tgt_langtok: 29259
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 4,889 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.oto-es.oto
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 4,889 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.oto-es.es
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin train oto-es 4889 examples
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:nah-es src_langtok: 29262; tgt_langtok: 29259
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 16,145 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.nah-es.nah
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 16,145 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.nah-es.es
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin train nah-es 16145 examples
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:tar-es src_langtok: 29266; tgt_langtok: 29259
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 14,720 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.tar-es.tar
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 14,720 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.tar-es.es
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin train tar-es 14720 examples
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:shp-es src_langtok: 29265; tgt_langtok: 29259
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 14,592 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.shp-es.shp
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 14,592 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.shp-es.es
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin train shp-es 14592 examples
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:hch-es src_langtok: 29261; tgt_langtok: 29259
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 8,966 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.hch-es.hch
# 2022-09-28 12:24:38 | INFO | fairseq.data.data_utils | loaded 8,966 examples from: /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin/train.hch-es.es
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/10nal-es/tokenizers/10nal-es/bin train hch-es 8966 examples
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.multilingual_data_manager | estimated total data sizes of all shards used in sampling ratios: [('main:quy-es', 125008), ('main:cni-es', 3883), ('main:aym-es', 6531), ('main:bzd-es', 7508), ('main:gn-es', 26032), ('main:oto-es', 4889), ('main:nah-es', 16145), ('main:tar-es', 14720), ('main:shp-es', 14592), ('main:hch-es', 8966)]. Note that if the data a shard has not been loaded yet, use the max known data size to approximate
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.sampling_method | selected sampler: concat
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Raw sizes: {'main:quy-es': 125008, 'main:cni-es': 3883, 'main:aym-es': 6531, 'main:bzd-es': 7508, 'main:gn-es': 26032, 'main:oto-es': 4889, 'main:nah-es': 16145, 'main:tar-es': 14720, 'main:shp-es': 14592, 'main:hch-es': 8966}; raw total size: 228274
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Resampled sizes: {'main:quy-es': 125008, 'main:cni-es': 3883, 'main:aym-es': 6531, 'main:bzd-es': 7508, 'main:gn-es': 26032, 'main:oto-es': 4889, 'main:nah-es': 16145, 'main:tar-es': 14720, 'main:shp-es': 14592, 'main:hch-es': 8966}; resampled total size: 228274
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] A concat dataset
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] virtual dataset established time: 0:00:00.015342
# 2022-09-28 12:24:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-28 12:24:38 | INFO | fairseq.data.multilingual.sampled_multi_dataset | sizes() calling time: 0:00:00.002340
# 2022-09-28 12:24:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.048695
# 2022-09-28 12:24:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:24:38 | WARNING | fairseq.tasks.fairseq_task | 17 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[176601, 177307, 174630, 177625, 183072, 174730, 179382, 178292, 182127, 180802]
# 2022-09-28 12:24:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.003059
# 2022-09-28 12:24:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:24:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.006711
# 2022-09-28 12:24:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.059140
# 2022-09-28 12:24:38 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:24:38 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1443
# epoch 035:   0%|                                       | 0/1443 [00:00<?, ?it/s]2022-09-28 12:24:38 | INFO | fairseq.trainer | begin training epoch 35
# 2022-09-28 12:24:38 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 035:   0%|                               | 1/1443 [00:00<04:36,  5.21it/s]2022-09-28 12:24:38 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 035:   1%|1                              | 9/1443 [00:00<02:47,  8.56it/s]2022-09-28 12:24:39 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 035:  17%|1| 239/1443 [00:23<01:58, 10.13it/s, loss=5.035, nll_loss=3.498,2022-09-28 12:25:02 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 16.0
# epoch 035: 100%|9| 1442/1443 [02:26<00:00, 10.06it/s, loss=5.182, nll_loss=3.6622022-09-28 12:27:04 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-28 12:27:04 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-28 12:27:04 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.002077
# 2022-09-28 12:27:04 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:27:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.083669
# 2022-09-28 12:27:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:27:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.058822
# 2022-09-28 12:27:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.145302
# 2022-09-28 12:27:05 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 035 | valid on 'valid' subset:   0%|               | 0/62 [00:00<?, ?it/s]
# epoch 035 | valid on 'valid' subset:   5%|3      | 3/62 [00:00<00:01, 29.98it/s]
# epoch 035 | valid on 'valid' subset:  11%|7      | 7/62 [00:00<00:01, 30.98it/s]
# epoch 035 | valid on 'valid' subset:  18%|#     | 11/62 [00:00<00:01, 31.78it/s]
# epoch 035 | valid on 'valid' subset:  24%|#4    | 15/62 [00:00<00:01, 32.10it/s]
# epoch 035 | valid on 'valid' subset:  31%|#8    | 19/62 [00:00<00:01, 32.13it/s]
# epoch 035 | valid on 'valid' subset:  37%|##2   | 23/62 [00:00<00:01, 32.24it/s]
# epoch 035 | valid on 'valid' subset:  44%|##6   | 27/62 [00:00<00:01, 32.27it/s]
# epoch 035 | valid on 'valid' subset:  50%|###   | 31/62 [00:00<00:00, 32.40it/s]
# epoch 035 | valid on 'valid' subset:  56%|###3  | 35/62 [00:01<00:00, 32.52it/s]
# epoch 035 | valid on 'valid' subset:  63%|###7  | 39/62 [00:01<00:00, 32.14it/s]
# epoch 035 | valid on 'valid' subset:  69%|####1 | 43/62 [00:01<00:00, 32.37it/s]
# epoch 035 | valid on 'valid' subset:  76%|####5 | 47/62 [00:01<00:00, 32.23it/s]
# epoch 035 | valid on 'valid' subset:  82%|####9 | 51/62 [00:01<00:00, 32.46it/s]
# epoch 035 | valid on 'valid' subset:  89%|#####3| 55/62 [00:01<00:00, 32.13it/s]
# epoch 035 | valid on 'valid' subset:  95%|#####7| 59/62 [00:01<00:00, 32.26it/s]
#                                                                                 2022-09-28 12:27:07 | INFO | valid | epoch 035 | valid on 'valid' subset | loss 8.114 | nll_loss 6.873 | ppl 117.21 | wps 76089.7 | wpb 2283.8 | bsz 147.1 | num_updates 1440
# 2022-09-28 12:27:07 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 35 @ 1440 updates
# 2022-09-28 12:27:07 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/10nal-es/checkpoint35.pt
# 2022-09-28 12:27:14 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/10nal-es/checkpoint35.pt
# 2022-09-28 12:27:17 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/10nal-es/checkpoint35.pt (epoch 35 @ 1440 updates, score 8.114) (writing took 10.325124805793166 seconds)
# 2022-09-28 12:27:17 | INFO | fairseq_cli.train | end of epoch 35 (average epoch stats below)
# 2022-09-28 12:27:17 | INFO | train | epoch 035 | loss 5.065 | nll_loss 3.531 | ppl 11.56 | wps 30788.1 | ups 9.07 | wpb 3394.9 | bsz 158.1 | num_updates 1440 | lr 0.00018 | gnorm 1.383 | loss_scale 16 | train_wall 143 | gb_free 12.1 | wall 165
# 2022-09-28 12:27:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-28 12:27:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.054641
# 2022-09-28 12:27:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:27:17 | WARNING | fairseq.tasks.fairseq_task | 17 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[176601, 177307, 174630, 177625, 183072, 174730, 179382, 178292, 182127, 180802]
# 2022-09-28 12:27:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.003543
# 2022-09-28 12:27:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:27:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.007281
# 2022-09-28 12:27:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.066292
# 2022-09-28 12:27:17 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:27:17 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1443
# epoch 036:   0%|                                       | 0/1443 [00:00<?, ?it/s]2022-09-28 12:27:17 | INFO | fairseq.trainer | begin training epoch 36
# 2022-09-28 12:27:17 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 036:  29%|2| 418/1443 [00:42<01:47,  9.53it/s, loss=5.202, nll_loss=3.681,Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa6615d1940>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 036:  43%|4| 623/1443 [01:03<01:25,  9.54it/s, loss=5.145, nll_loss=3.618,2022-09-28 12:28:21 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 8.0
# epoch 036: 100%|9| 1442/1443 [02:27<00:00,  9.59it/s, loss=5.358, nll_loss=3.8622022-09-28 12:29:44 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-28 12:29:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-28 12:29:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.002070
# 2022-09-28 12:29:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:29:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.074815
# 2022-09-28 12:29:44 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:29:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.060174
# 2022-09-28 12:29:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.137718
# 2022-09-28 12:29:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 036 | valid on 'valid' subset:   0%|               | 0/62 [00:00<?, ?it/s]
# epoch 036 | valid on 'valid' subset:   5%|3      | 3/62 [00:00<00:02, 25.82it/s]
# epoch 036 | valid on 'valid' subset:  11%|7      | 7/62 [00:00<00:01, 27.68it/s]
# epoch 036 | valid on 'valid' subset:  18%|#     | 11/62 [00:00<00:01, 29.24it/s]
# epoch 036 | valid on 'valid' subset:  24%|#4    | 15/62 [00:00<00:01, 30.34it/s]
# epoch 036 | valid on 'valid' subset:  31%|#8    | 19/62 [00:00<00:01, 31.33it/s]
# epoch 036 | valid on 'valid' subset:  37%|##2   | 23/62 [00:00<00:01, 31.87it/s]
# epoch 036 | valid on 'valid' subset:  44%|##6   | 27/62 [00:00<00:01, 32.17it/s]
# epoch 036 | valid on 'valid' subset:  50%|###   | 31/62 [00:00<00:00, 32.08it/s]
# epoch 036 | valid on 'valid' subset:  56%|###3  | 35/62 [00:01<00:00, 32.29it/s]
# epoch 036 | valid on 'valid' subset:  63%|###7  | 39/62 [00:01<00:00, 32.06it/s]
# epoch 036 | valid on 'valid' subset:  69%|####1 | 43/62 [00:01<00:00, 32.29it/s]
# epoch 036 | valid on 'valid' subset:  76%|####5 | 47/62 [00:01<00:00, 32.13it/s]
# epoch 036 | valid on 'valid' subset:  82%|####9 | 51/62 [00:01<00:00, 32.23it/s]
# epoch 036 | valid on 'valid' subset:  89%|#####3| 55/62 [00:01<00:00, 31.95it/s]
# epoch 036 | valid on 'valid' subset:  95%|#####7| 59/62 [00:01<00:00, 32.07it/s]
#                                                                                 2022-09-28 12:29:46 | INFO | valid | epoch 036 | valid on 'valid' subset | loss 8.059 | nll_loss 6.819 | ppl 112.93 | wps 76231 | wpb 2283.8 | bsz 147.1 | num_updates 2882 | best_loss 8.059
# 2022-09-28 12:29:46 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 36 @ 2882 updates
# 2022-09-28 12:29:46 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/10nal-es/checkpoint36.pt
# 2022-09-28 12:29:49 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/10nal-es/checkpoint36.pt
# 2022-09-28 12:29:51 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/10nal-es/checkpoint36.pt (epoch 36 @ 2882 updates, score 8.059) (writing took 4.963149845134467 seconds)
# 2022-09-28 12:29:52 | INFO | fairseq_cli.train | end of epoch 36 (average epoch stats below)
# 2022-09-28 12:29:52 | INFO | train | epoch 036 | loss 5.231 | nll_loss 3.715 | ppl 13.14 | wps 31585.3 | ups 9.31 | wpb 3393.7 | bsz 157.8 | num_updates 2882 | lr 0.00036025 | gnorm 1.535 | loss_scale 8 | train_wall 144 | gb_free 12.2 | wall 320
# 2022-09-28 12:29:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-28 12:29:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.053462
# 2022-09-28 12:29:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 12:29:52 | WARNING | fairseq.tasks.fairseq_task | 17 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[176601, 177307, 174630, 177625, 183072, 174730, 179382, 178292, 182127, 180802]
# 2022-09-28 12:29:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.003581
# ...
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 048: 100%|9| 1441/1443 [02:27<00:00,  9.55it/s, loss=5.108, nll_loss=3.5722022-09-28 13:00:46 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-28 13:00:46 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-28 13:00:46 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.002145
# 2022-09-28 13:00:46 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 13:00:46 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.075231
# 2022-09-28 13:00:46 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 13:00:46 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.058800
# 2022-09-28 13:00:46 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.136780
# 2022-09-28 13:00:46 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 048 | valid on 'valid' subset:   0%|               | 0/62 [00:00<?, ?it/s]
# epoch 048 | valid on 'valid' subset:   5%|3      | 3/62 [00:00<00:02, 28.52it/s]
# epoch 048 | valid on 'valid' subset:  11%|7      | 7/62 [00:00<00:01, 29.89it/s]
# epoch 048 | valid on 'valid' subset:  18%|#     | 11/62 [00:00<00:01, 30.92it/s]
# epoch 048 | valid on 'valid' subset:  24%|#4    | 15/62 [00:00<00:01, 31.52it/s]
# epoch 048 | valid on 'valid' subset:  31%|#8    | 19/62 [00:00<00:01, 32.10it/s]
# epoch 048 | valid on 'valid' subset:  37%|##2   | 23/62 [00:00<00:01, 32.43it/s]
# epoch 048 | valid on 'valid' subset:  44%|##6   | 27/62 [00:00<00:01, 32.49it/s]
# epoch 048 | valid on 'valid' subset:  50%|###   | 31/62 [00:00<00:00, 32.44it/s]
# epoch 048 | valid on 'valid' subset:  56%|###3  | 35/62 [00:01<00:00, 32.47it/s]
# epoch 048 | valid on 'valid' subset:  63%|###7  | 39/62 [00:01<00:00, 32.20it/s]
# epoch 048 | valid on 'valid' subset:  69%|####1 | 43/62 [00:01<00:00, 32.30it/s]
# epoch 048 | valid on 'valid' subset:  76%|####5 | 47/62 [00:01<00:00, 32.08it/s]
# epoch 048 | valid on 'valid' subset:  82%|####9 | 51/62 [00:01<00:00, 32.17it/s]
# epoch 048 | valid on 'valid' subset:  89%|#####3| 55/62 [00:01<00:00, 31.89it/s]
# epoch 048 | valid on 'valid' subset:  95%|#####7| 59/62 [00:01<00:00, 32.20it/s]
#                                                                                 2022-09-28 13:00:48 | INFO | valid | epoch 048 | valid on 'valid' subset | loss 8.122 | nll_loss 6.891 | ppl 118.71 | wps 76108.9 | wpb 2283.8 | bsz 147.1 | num_updates 20197 | best_loss 8.042
# 2022-09-28 13:00:48 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 48 @ 20197 updates
# 2022-09-28 13:00:48 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/10nal-es/checkpoint48.pt
# 2022-09-28 13:00:51 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/10nal-es/checkpoint48.pt
# 2022-09-28 13:00:52 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/10nal-es/checkpoint48.pt (epoch 48 @ 20197 updates, score 8.122) (writing took 3.773992231115699 seconds)
# 2022-09-28 13:00:52 | INFO | fairseq_cli.train | end of epoch 48 (average epoch stats below)
# 2022-09-28 13:00:52 | INFO | train | epoch 048 | loss 5.041 | nll_loss 3.496 | ppl 11.28 | wps 31867.9 | ups 9.39 | wpb 3394.2 | bsz 158.2 | num_updates 20197 | lr 0.000222514 | gnorm 1.59 | loss_scale 4 | train_wall 144 | gb_free 12.3 | wall 2180
# 2022-09-28 13:00:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-28 13:00:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.053122
# 2022-09-28 13:00:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 13:00:52 | WARNING | fairseq.tasks.fairseq_task | 17 samples have invalid sizes and will be skipped, max_positions=(1024, 1024), first few sample ids=[176601, 177307, 174630, 177625, 183072, 174730, 179382, 178292, 182127, 180802]
# 2022-09-28 13:00:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.003872
# 2022-09-28 13:00:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 13:00:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.007518
# 2022-09-28 13:00:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.065338
# 2022-09-28 13:00:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 13:00:57 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1443
# epoch 049:   0%|                                       | 0/1443 [00:00<?, ?it/s]2022-09-28 13:00:57 | INFO | fairseq.trainer | begin training epoch 49
# 2022-09-28 13:00:57 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 049:  15%|1| 223/1443 [00:22<02:04,  9.82it/s, loss=4.968, nll_loss=3.412,Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa63d6b9518>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa743f78b00>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa653ad7f60>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa653f975c0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa6520659b0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa6539bb400>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa653b379b0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa653dffcc0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa653b02e80>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa653cdcf98>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 049: 100%|9| 1442/1443 [02:27<00:00,  9.06it/s, loss=5.031, nll_loss=3.4842022-09-28 13:03:24 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-09-28 13:03:24 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-09-28 13:03:24 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.002063
# 2022-09-28 13:03:24 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 13:03:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.075287
# 2022-09-28 13:03:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-09-28 13:03:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.061905
# 2022-09-28 13:03:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.140050
# 2022-09-28 13:03:25 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 049 | valid on 'valid' subset:   0%|               | 0/62 [00:00<?, ?it/s]
# epoch 049 | valid on 'valid' subset:   5%|3      | 3/62 [00:00<00:02, 28.76it/s]
# epoch 049 | valid on 'valid' subset:  11%|7      | 7/62 [00:00<00:01, 30.02it/s]
# epoch 049 | valid on 'valid' subset:  18%|#     | 11/62 [00:00<00:01, 31.22it/s]
# epoch 049 | valid on 'valid' subset:  24%|#4    | 15/62 [00:00<00:01, 31.67it/s]
# epoch 049 | valid on 'valid' subset:  31%|#8    | 19/62 [00:00<00:01, 32.24it/s]
# epoch 049 | valid on 'valid' subset:  37%|##2   | 23/62 [00:00<00:01, 32.45it/s]
# epoch 049 | valid on 'valid' subset:  44%|##6   | 27/62 [00:00<00:01, 32.58it/s]
# epoch 049 | valid on 'valid' subset:  50%|###   | 31/62 [00:00<00:00, 32.44it/s]
# epoch 049 | valid on 'valid' subset:  56%|###3  | 35/62 [00:01<00:00, 32.58it/s]
# epoch 049 | valid on 'valid' subset:  63%|###7  | 39/62 [00:01<00:00, 32.08it/s]
# epoch 049 | valid on 'valid' subset:  69%|####1 | 43/62 [00:01<00:00, 32.33it/s]
# epoch 049 | valid on 'valid' subset:  76%|####5 | 47/62 [00:01<00:00, 32.22it/s]
# epoch 049 | valid on 'valid' subset:  82%|####9 | 51/62 [00:01<00:00, 32.43it/s]
# epoch 049 | valid on 'valid' subset:  89%|#####3| 55/62 [00:01<00:00, 32.26it/s]
# epoch 049 | valid on 'valid' subset:  95%|#####7| 59/62 [00:01<00:00, 32.41it/s]
#                                                                                 2022-09-28 13:03:27 | INFO | valid | epoch 049 | valid on 'valid' subset | loss 8.103 | nll_loss 6.865 | ppl 116.57 | wps 76473.5 | wpb 2283.8 | bsz 147.1 | num_updates 21640 | best_loss 8.042
# 2022-09-28 13:03:27 | INFO | fairseq_cli.train | early stop since valid performance hasn't improved for last 10 runs
# 2022-09-28 13:03:27 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 49 @ 21640 updates
# 2022-09-28 13:03:27 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/10nal-es/checkpoint49.pt
# 2022-09-28 13:03:29 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/10nal-es/checkpoint49.pt
# 2022-09-28 13:03:30 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/10nal-es/checkpoint49.pt (epoch 49 @ 21640 updates, score 8.103) (writing took 3.696453089825809 seconds)
# 2022-09-28 13:03:30 | INFO | fairseq_cli.train | end of epoch 49 (average epoch stats below)
# 2022-09-28 13:03:30 | INFO | train | epoch 049 | loss 5.016 | nll_loss 3.466 | ppl 11.05 | wps 30912.7 | ups 9.11 | wpb 3394.2 | bsz 158.2 | num_updates 21640 | lr 0.000214967 | gnorm 1.623 | loss_scale 8 | train_wall 144 | gb_free 12.4 | wall 2338
# 2022-09-28 13:03:30 | INFO | fairseq_cli.train | done training in 2332.2 seconds

# %%
! echo $MODEL_DIR
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
cd /storage/master-thesis/models/quy-es+es-en
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
! rm checkpoint108.pt
! rm checkpoint109.pt
! rm checkpoint_best.pt
! rm checkpoint_last.pt

# %%
! rm dict.en.txt
! rm dict.es.txt
! rm dict.quy.txt

# %%
! du -shc /notebooks/*
# Out:
# 2.5K	/notebooks/CITATION.cff
# 5.5K	/notebooks/CODE_OF_CONDUCT.md
# 15K	/notebooks/CONTRIBUTING.md
# 19K	/notebooks/ISSUES.md
# 12K	/notebooks/LICENSE
# 512	/notebooks/MANIFEST.in
# 3.5K	/notebooks/Makefile
# 41K	/notebooks/README.md
# 41K	/notebooks/README_zh-hans.md
# 42K	/notebooks/README_zh-hant.md
# 12K	/notebooks/docker
# 4.6M	/notebooks/docs
# 5.0M	/notebooks/examples
# 8.5K	/notebooks/hubconf.py
# 7.8G	/notebooks/master-thesis
# 1.5K	/notebooks/model_cards
# 9.5K	/notebooks/notebooks
# 512	/notebooks/pyproject.toml
# 64K	/notebooks/scripts
# 1.0K	/notebooks/setup.cfg
# 13K	/notebooks/setup.py
# 13M	/notebooks/src
# 731K	/notebooks/templates
# 4.5K	/notebooks/test quy-es -> es-en model.ipynb
# 6.8M	/notebooks/tests
# 147K	/notebooks/train es-en model.ipynb
# 158K	/notebooks/train quy-es + es-en model.ipynb
# 160K	/notebooks/utils
# 3.5K	/notebooks/valohai.yaml
# 7.9G	total

# %%
! du -shc /notebooks/master-thesis/*
# Out:
# 512	/notebooks/master-thesis/Untitled.ipynb
# 362M	/notebooks/master-thesis/corpora
# 7.5G	/notebooks/master-thesis/models
# 7.8G	total

# %%
! du -shc /notebooks/master-thesis/models/*
# Out:
# 1.6G	/notebooks/master-thesis/models/es-en
# 802M	/notebooks/master-thesis/models/quy-es
# 5.2G	/notebooks/master-thesis/models/quy-es+es-en
# 7.5G	total

# %%
! du -shc /*
# Out:
# 19M	/apex
# 5.0M	/bin
# 4.0K	/boot
# 24K	/content
# ^C

# %%
ls
# Out:
#  CITATION.cff         docker/          setup.py
#  CODE_OF_CONDUCT.md   docs/            src/
#  CONTRIBUTING.md      examples/        templates/
#  ISSUES.md            hubconf.py      'test quy-es -> es-en model.ipynb'
#  LICENSE              master-thesis/   tests/
#  MANIFEST.in          model_cards/    'train es-en model.ipynb'
#  Makefile             notebooks/      'train quy-es + es-en model.ipynb'
#  README.md            pyproject.toml   utils/
#  README_zh-hans.md    scripts/         valohai.yaml
#  README_zh-hant.md    setup.cfg

# %%
# Out:
# /storage/master-thesis
