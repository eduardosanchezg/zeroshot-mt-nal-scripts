# %% [markdown]
# ## ENVIRONMENT VARIABLES

# %%
EN_ES_CORPUS_DIR = "/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/"

# %%
EN_NGU_CORPUS_DIR = "/notebooks/master-thesis/corpora/tatoeba-challenge/en-ngu/"

# %%
tokenizer_path = "/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/"

# %%
# %env TOKENIZER_PATH = /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu
# Out:
# env: TOKENIZER_PATH=/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu

# %%
tokenized_path_es_en = "/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en/"
tokenized_path_ngu_en = "/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en/"

# %%
# %env TOKENIZED_PATH_ES_EN = /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en
# %env TOKENIZED_PATH_NGU_EN = /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en
# Out:
# env: TOKENIZED_PATH_ES_EN=/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en
# env: TOKENIZED_PATH_NGU_EN=/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en

# %%
# %env BIN_DIR = /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin
# Out:
# env: BIN_DIR=/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin

# %%
! mkdir -p $TOKENIZED_PATH_ES_EN
! mkdir -p $TOKENIZED_PATH_NGU_EN
! mkdir -p $BIN_DIR

# %%
# %env MODEL_DIR = /storage/master-thesis/models/es-en_ngu-en
# Out:
# env: MODEL_DIR=/storage/master-thesis/models/es-en_ngu-en

# %%
! locale
# Out:
# LANG=
# LANGUAGE=
# LC_CTYPE="POSIX"
# LC_NUMERIC="POSIX"
# LC_TIME="POSIX"
# LC_COLLATE="POSIX"
# LC_MONETARY="POSIX"
# LC_MESSAGES="POSIX"
# LC_PAPER="POSIX"
# LC_NAME="POSIX"
# LC_ADDRESS="POSIX"
# LC_TELEPHONE="POSIX"
# LC_MEASUREMENT="POSIX"
# LC_IDENTIFICATION="POSIX"
# LC_ALL=

# %%
! update-locale LANG=en_US.UTF-8 LANGUAGE=en.UTF-8

# %env LANG=en_US.UTF-8
# %env LC_CTYPE=en_US.UTF-8
# %env LC_ALL=en_US.UTF-8
# Out:
# /bin/sh: 1: update-locale: not found
# env: LANG=en_US.UTF-8
# env: LC_CTYPE=en_US.UTF-8
# env: LC_ALL=en_US.UTF-8

# %% [markdown]
# ## Libraries

# %%
pip install tokenizers==0.10.3
# Out:
# Requirement already satisfied: tokenizers==0.10.3 in /usr/local/lib/python3.6/dist-packages (0.10.3)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 1.10.0+cu113
# Uninstalling torch-1.10.0+cu113:
#   Successfully uninstalled torch-1.10.0+cu113
# WARNING: Skipping torchvision as it is not installed.
# Found existing installation: torchaudio 0.10.0+cu113
# Uninstalling torchaudio-0.10.0+cu113:
#   Successfully uninstalled torchaudio-0.10.0+cu113
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cu113/torch-1.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (1821.5 MB)
# Collecting torchvision
#   Using cached https://download.pytorch.org/whl/cu113/torchvision-0.11.3%2Bcu113-cp36-cp36m-linux_x86_64.whl (24.6 MB)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/cu113/torchaudio-0.10.2%2Bcu113-cp36-cp36m-linux_x86_64.whl (2.9 MB)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from torchvision) (8.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.18.5)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.10.2+cu113 torchaudio-0.10.2+cu113 torchvision-0.11.3+cu113
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall fairseq -y
# Out:
# WARNING: Skipping fairseq as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fairseq # --no-deps
# Out:
# Collecting fairseq
#   Using cached fairseq-0.12.2-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.0 MB)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.24)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.8)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.10.2)
# Requirement already satisfied: hydra-core<1.1,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.0.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.51.0)
# Requirement already satisfied: bitarray in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.6.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.3)
# Requirement already satisfied: numpy<1.20.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.10.1)
# Requirement already satisfied: omegaconf<2.1 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.6)
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.6/dist-packages (from fairseq) (2.0.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2020.11.13)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (3.10.0.2)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (5.2.2)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.6/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (4.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.6/dist-packages (from omegaconf<2.1->fairseq) (5.4.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.4.4)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (2.3.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.8.9)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core<1.1,>=1.0.7->fairseq) (3.4.0)
# Installing collected packages: fairseq
# Successfully installed fairseq-0.12.2
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip uninstall apex -y
# Out:
# Found existing installation: apex 0.1
# Uninstalling apex-0.1:
#   Successfully uninstalled apex-0.1

# %%
rm -r apex

# %%
#! git clone https://github.com/NVIDIA/apex

! pip install -v --disable-pip-version-check --no-cache-dir apex

# %%
cd ..
# Out:
# /

# %%
pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |################################| 125 kB 34.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.5)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.13.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (50.3.2)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5.1
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Converting tatoeba format to standard format

# %%
import csv

with open(EN_ES_CORPUS_DIR + "original/valid.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "dev.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "dev.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
    en.close()
    es.close()
    
with open(EN_ES_CORPUS_DIR + "original/dev.txt", encoding='utf8') as f:
    es = open(EN_ES_CORPUS_DIR + "train.es", 'w', encoding='utf8')
    en = open(EN_ES_CORPUS_DIR + "train.en", 'w', encoding='utf8')
    for line in csv.reader(f, delimiter="\t"):
        if "\n" in line[2] or "\n" in line[3]:
            continue
        if len(line) != 4:
            continue
            
        es.write(line[3] + "\n")
        en.write(line[2] + "\n")
        
    en.close()
    es.close()

# %% [markdown]
# ### Tokenizing data

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece

en_es_ngu_tokenizer = Tokenizer(WordPiece(unk_token="[UNK]"))

# %%
from tokenizers.trainers import WordPieceTrainer

en_es_ngu_trainer = WordPieceTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"], show_progress=True)

# %%
from tokenizers.pre_tokenizers import Whitespace

en_es_ngu_tokenizer.pre_tokenizer = Whitespace()

en_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/{split}.en" for split in ["dev", "train"]]
es_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-es/{split}.es" for split in ["dev", "train"]]
en2_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-ngu/{split}.en" for split in ["dev", "train"]]
ngu_files = [f"/notebooks/master-thesis/corpora/tatoeba-challenge/en-ngu/{split}.ngu" for split in ["dev", "train"]]

files = en_files + es_files + en2_files + ngu_files
#print(files)
en_es_ngu_tokenizer.train(files= files, trainer=en_es_ngu_trainer)

# %%
# ! cat /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.en

# %%
from pathlib import Path



def tokenize_files(tokenizer, files, extension, output_path):
    for file in files:
        print(f"Reading file {file}")
        with open(file, encoding='utf8') as f:
          lines = f.readlines()
          tokenized_lines = tokenizer.encode_batch(lines)
          tokenized_name = Path(file).stem
          tokenized_name = output_path + tokenized_name + "." + extension
          print(tokenized_name)
          with open(tokenized_name, 'w', encoding='utf8') as wf:

            wf.writelines([" ".join(t.tokens) + "\n" for t in tokenized_lines])

# %%
en_es_ngu_tokenizer.save(tokenizer_path + "es-en-ngu-tokenizer.json")

# %%
print(en_es_ngu_tokenizer)
# Out:
# <tokenizers.Tokenizer object at 0x1fad0f0>

# %%
tok = en_es_ngu_tokenizer.encode("we hold this truth to be self evidentblabla that everyone is created equal?")
print(tok.tokens)
# Out:
# ['we', 'hold', 'this', 'truth', 'to', 'be', 'self', 'evident', '##bla', '##bla', 'that', 'everyone', 'is', 'created', 'equal', '?']

# %%
tokenize_files(en_es_ngu_tokenizer, en_files, "en", tokenized_path_es_en)
tokenize_files(en_es_ngu_tokenizer, es_files, "es", tokenized_path_es_en)

tokenize_files(en_es_ngu_tokenizer, en2_files, "en", tokenized_path_ngu_en)
tokenize_files(en_es_ngu_tokenizer, ngu_files, "ngu", tokenized_path_ngu_en)
# Out:
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.en
# /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en/dev.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/train.en
# /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en/train.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/dev.es
# /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en/dev.es
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-es/train.es
# /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en/train.es
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-ngu/dev.en
# /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en/dev.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-ngu/train.en
# /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en/train.en
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-ngu/dev.ngu
# /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en/dev.ngu
# Reading file /notebooks/master-thesis/corpora/tatoeba-challenge/en-ngu/train.ngu
# /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en/train.ngu

# %% [markdown]
# ## Binarizing data

# %%
### Removing previous dict files
! rm $BIN_DIR/dict.es.txt
! rm $BIN_DIR/dict.en.txt
! rm $BIN_DIR/dict.ngu.txt
# Out:
# rm: cannot remove '/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/dict.es.txt': No such file or directory
# rm: cannot remove '/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/dict.en.txt': No such file or directory
# rm: cannot remove '/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/dict.ngu.txt': No such file or directory

# %%
## Concatenating all training data
! cat $TOKENIZED_PATH_ES_EN/train.es $TOKENIZED_PATH_ES_EN/train.en $TOKENIZED_PATH_NGU_EN/train.ngu $TOKENIZED_PATH_NGU_EN/train.en > $BIN_DIR/train.all

# %%
! fairseq-preprocess --source-lang all \
    --trainpref $BIN_DIR/train \
    --destdir $BIN_DIR \
    --workers 20 \
    --only-source
# Out:
# 2022-10-30 17:59:19 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=True, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='all', srcdict=None, suppress_crashes=False, target_lang=None, task='translation', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/train', use_plasma_view=False, user_dir=None, validpref=None, wandb_project=None, workers=20)
# 2022-10-30 17:59:22 | INFO | fairseq_cli.preprocess | [all] Dictionary: 28488 types
# 2022-10-30 17:59:28 | INFO | fairseq_cli.preprocess | [all] /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/train.all: 452050 sents, 4956470 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 17:59:28 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin

# %%
! echo $BIN_DIR
# Out:
# /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin

# %% [markdown]
# ### Reusing es dict from nah-es preprocessing

# %%
! fairseq-preprocess --source-lang es --target-lang en \
    --trainpref $TOKENIZED_PATH_ES_EN/train --validpref $TOKENIZED_PATH_ES_EN/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --workers 20
# Out:
# 2022-10-30 17:59:30 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='es', srcdict='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/dict.all.txt', suppress_crashes=False, target_lang='en', task='translation', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en/dev', wandb_project=None, workers=20)
# 2022-10-30 17:59:31 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28488 types
# 2022-10-30 17:59:33 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en/train.es: 197297 sents, 1876958 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 17:59:33 | INFO | fairseq_cli.preprocess | [es] Dictionary: 28488 types
# 2022-10-30 17:59:34 | INFO | fairseq_cli.preprocess | [es] /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en/dev.es: 4643 sents, 51353 tokens, 0.101% replaced (by <unk>)
# 2022-10-30 17:59:34 | INFO | fairseq_cli.preprocess | [en] Dictionary: 28488 types
# 2022-10-30 17:59:36 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en/train.en: 197297 sents, 1942686 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 17:59:36 | INFO | fairseq_cli.preprocess | [en] Dictionary: 28488 types
# 2022-10-30 17:59:37 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/es-en/dev.en: 4643 sents, 52715 tokens, 0.074% replaced (by <unk>)
# 2022-10-30 17:59:37 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin

# %%
! fairseq-preprocess --source-lang ngu --target-lang en \
    --trainpref $TOKENIZED_PATH_NGU_EN/train --validpref $TOKENIZED_PATH_NGU_EN/dev \
    --destdir $BIN_DIR \
    --srcdict $BIN_DIR/dict.all.txt \
    --tgtdict $BIN_DIR/dict.all.txt \
    --workers 20
# Out:
# 2022-10-30 17:59:39 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='ngu', srcdict='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/dict.all.txt', suppress_crashes=False, target_lang='en', task='translation', tensorboard_logdir=None, testpref=None, tgtdict='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/dict.all.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en/train', use_plasma_view=False, user_dir=None, validpref='/storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en/dev', wandb_project=None, workers=20)
# 2022-10-30 17:59:39 | INFO | fairseq_cli.preprocess | [ngu] Dictionary: 28488 types
# 2022-10-30 17:59:39 | INFO | fairseq_cli.preprocess | [ngu] /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en/train.ngu: 28728 sents, 539318 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 17:59:39 | INFO | fairseq_cli.preprocess | [ngu] Dictionary: 28488 types
# 2022-10-30 17:59:40 | INFO | fairseq_cli.preprocess | [ngu] /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en/dev.ngu: 38 sents, 459 tokens, 1.31% replaced (by <unk>)
# 2022-10-30 17:59:40 | INFO | fairseq_cli.preprocess | [en] Dictionary: 28488 types
# 2022-10-30 17:59:41 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en/train.en: 28728 sents, 597508 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 17:59:41 | INFO | fairseq_cli.preprocess | [en] Dictionary: 28488 types
# 2022-10-30 17:59:41 | INFO | fairseq_cli.preprocess | [en] /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/ngu-en/dev.en: 38 sents, 320 tokens, 0.0% replaced (by <unk>)
# 2022-10-30 17:59:41 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin

# %% [markdown]
# ## Training model

# %%
! fairseq-train $BIN_DIR \
    --arch=transformer --share-all-embeddings \
    --task translation_multi_simple_epoch --lang-pairs es-en,ngu-en \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 5e-4 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --dropout 0.3 --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --max-tokens 4096 \
    --restore-file $MODEL_DIR/checkpoint_last.pt \
    --save-dir $MODEL_DIR/ \
    --keep-last-epochs 2 \
    --reset-optimizer \
    --encoder-langtok "src" \
    --decoder-langtok \
    --fp16 \
    --max-epoch 200 \
    --patience 10
# Out:
# 2022-10-30 17:59:44 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 4096, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 4096, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 200, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.0005], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '/storage/master-thesis/models/es-en_ngu-en/', 'restore_file': '/storage/master-thesis/models/es-en_ngu-en/checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': True, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': 2, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': 10, 'checkpoint_suffix': '', 'checkpoint_shard_c ...
# 2022-10-30 17:59:44 | WARNING | fairseq.data.multilingual.multilingual_data_manager | External language dictionary is not provided; use lang-pairs to infer the set of supported languages. The language ordering is not stable which might cause misalignment in pretraining and finetuning.
# 2022-10-30 17:59:44 | INFO | fairseq.data.multilingual.multilingual_data_manager | inferred language list: ['en', 'es', 'ngu']
# 2022-10-30 17:59:44 | INFO | fairseq.data.multilingual.multilingual_data_manager | [ngu] dictionary: 28491 types
# 2022-10-30 17:59:44 | INFO | fairseq.data.multilingual.multilingual_data_manager | [en] dictionary: 28491 types
# 2022-10-30 17:59:45 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(28491, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(28491, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=512, out_features=28491, bias=False)
#   )
# )
# 2022-10-30 17:59:45 | INFO | fairseq_cli.train | task: TranslationMultiSimpleEpochTask
# 2022-10-30 17:59:45 | INFO | fairseq_cli.train | model: TransformerModel
# 2022-10-30 17:59:45 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-10-30 17:59:45 | INFO | fairseq_cli.train | num. shared model params: 77,627,904 (num. trained: 77,627,904)
# 2022-10-30 17:59:45 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-10-30 17:59:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for valid epoch=1/None
# 2022-10-30 17:59:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 17:59:45 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-10-30 17:59:45 | INFO | fairseq.data.multilingual.multilingual_data_manager | [valid] num of shards: {'main:es-en': 1, 'main:ngu-en': 1}
# 2022-10-30 17:59:45 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:es-en src_langtok: 28489; tgt_langtok: 28488
# 2022-10-30 17:59:45 | INFO | fairseq.data.data_utils | loaded 4,643 examples from: /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/valid.es-en.es
# 2022-10-30 17:59:45 | INFO | fairseq.data.data_utils | loaded 4,643 examples from: /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/valid.es-en.en
# 2022-10-30 17:59:45 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin valid es-en 4643 examples
# 2022-10-30 17:59:45 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:ngu-en src_langtok: 28490; tgt_langtok: 28488
# 2022-10-30 17:59:45 | INFO | fairseq.data.data_utils | loaded 38 examples from: /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/valid.ngu-en.ngu
# 2022-10-30 17:59:45 | INFO | fairseq.data.data_utils | loaded 38 examples from: /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/valid.ngu-en.en
# 2022-10-30 17:59:45 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin valid ngu-en 38 examples
# 2022-10-30 17:59:50 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.embed_tokens.weight
# 2022-10-30 17:59:50 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.output_projection.weight
# 2022-10-30 17:59:50 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-10-30 17:59:50 | INFO | fairseq.utils | rank   0: capabilities =  8.6  ; total memory = 15.740 GB ; name = NVIDIA RTX A4000
# 2022-10-30 17:59:50 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-10-30 17:59:50 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-10-30 17:59:50 | INFO | fairseq_cli.train | max tokens per device = 4096 and max sentences per device = None
# 2022-10-30 17:59:50 | INFO | fairseq.trainer | Preparing to load checkpoint /storage/master-thesis/models/es-en_ngu-en/checkpoint_last.pt
# 2022-10-30 17:59:50 | INFO | fairseq.trainer | No existing checkpoint found /storage/master-thesis/models/es-en_ngu-en/checkpoint_last.pt
# 2022-10-30 17:59:50 | INFO | fairseq.trainer | loading train data for epoch 1
# 2022-10-30 17:59:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | loading data for train epoch=1/None
# 2022-10-30 17:59:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.multilingual_data_manager | langtoks settings: {'main': ('src', 'tgt')}
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.multilingual_data_manager | [train] num of shards: {'main:es-en': 1, 'main:ngu-en': 1}
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:es-en src_langtok: 28489; tgt_langtok: 28488
# 2022-10-30 17:59:50 | INFO | fairseq.data.data_utils | loaded 197,297 examples from: /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/train.es-en.es
# 2022-10-30 17:59:50 | INFO | fairseq.data.data_utils | loaded 197,297 examples from: /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/train.es-en.en
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin train es-en 197297 examples
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.multilingual_data_manager | main:ngu-en src_langtok: 28490; tgt_langtok: 28488
# 2022-10-30 17:59:50 | INFO | fairseq.data.data_utils | loaded 28,728 examples from: /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/train.ngu-en.ngu
# 2022-10-30 17:59:50 | INFO | fairseq.data.data_utils | loaded 28,728 examples from: /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin/train.ngu-en.en
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.multilingual_data_manager | /storage/master-thesis/models/es-en_ngu-en/tokenizers/es-en-ngu/bin train ngu-en 28728 examples
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.multilingual_data_manager | estimated total data sizes of all shards used in sampling ratios: [('main:es-en', 197297), ('main:ngu-en', 28728)]. Note that if the data a shard has not been loaded yet, use the max known data size to approximate
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.sampling_method | selected sampler: concat
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Raw sizes: {'main:es-en': 197297, 'main:ngu-en': 28728}; raw total size: 226025
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] Resampled sizes: {'main:es-en': 197297, 'main:ngu-en': 28728}; resampled total size: 226025
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] A concat dataset
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.sampled_multi_dataset | [train] virtual dataset established time: 0:00:00.015395
# 2022-10-30 17:59:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 17:59:50 | INFO | fairseq.data.multilingual.sampled_multi_dataset | sizes() calling time: 0:00:00.002315
# 2022-10-30 17:59:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.045177
# 2022-10-30 17:59:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 17:59:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.001357
# 2022-10-30 17:59:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 17:59:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.005338
# 2022-10-30 17:59:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.052537
# 2022-10-30 17:59:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 17:59:50 | INFO | fairseq.data.iterators | grouped total_num_itrs = 771
# epoch 001:   0%|                                        | 0/771 [00:00<?, ?it/s]2022-10-30 17:59:50 | INFO | fairseq.trainer | begin training epoch 1
# 2022-10-30 17:59:50 | INFO | fairseq_cli.train | Start iterating over samples
# 2022-10-30 17:59:50 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 001:   4%|#1                             | 29/771 [00:03<01:15,  9.77it/s]2022-10-30 17:59:53 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 001: 100%|9| 770/771 [01:20<00:00,  9.35it/s, loss=8.204, nll_loss=7.178, 2022-10-30 18:01:11 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 18:01:11 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:01:11 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001223
# 2022-10-30 18:01:11 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:01:11 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.033596
# 2022-10-30 18:01:11 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:01:11 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.028158
# 2022-10-30 18:01:11 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.063556
# 2022-10-30 18:01:11 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 001 | valid on 'valid' subset:   0%|               | 0/22 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:  14%|9      | 3/22 [00:00<00:00, 24.80it/s]
# epoch 001 | valid on 'valid' subset:  32%|##2    | 7/22 [00:00<00:00, 26.77it/s]
# epoch 001 | valid on 'valid' subset:  50%|###   | 11/22 [00:00<00:00, 28.30it/s]
# epoch 001 | valid on 'valid' subset:  68%|####  | 15/22 [00:00<00:00, 29.57it/s]
# epoch 001 | valid on 'valid' subset:  86%|#####1| 19/22 [00:00<00:00, 30.54it/s]
#                                                                                 2022-10-30 18:01:12 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 7.747 | nll_loss 6.614 | ppl 97.93 | wps 88398.4 | wpb 2623.5 | bsz 212.8 | num_updates 769
# 2022-10-30 18:01:12 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 769 updates
# 2022-10-30 18:01:12 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint1.pt
# 2022-10-30 18:01:19 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint1.pt
# 2022-10-30 18:01:21 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en_ngu-en/checkpoint1.pt (epoch 1 @ 769 updates, score 7.747) (writing took 8.71069734543562 seconds)
# 2022-10-30 18:01:21 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2022-10-30 18:01:21 | INFO | train | epoch 001 | loss 9.481 | nll_loss 8.676 | ppl 409.11 | wps 30551.7 | ups 8.52 | wpb 3587.6 | bsz 292.6 | num_updates 769 | lr 9.6125e-05 | gnorm 2.589 | loss_scale 32 | train_wall 79 | gb_free 12.1 | wall 91
# 2022-10-30 18:01:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:01:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.046760
# 2022-10-30 18:01:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:01:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.001963
# 2022-10-30 18:01:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:01:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.005096
# 2022-10-30 18:01:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.054592
# 2022-10-30 18:01:21 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:01:21 | INFO | fairseq.data.iterators | grouped total_num_itrs = 771
# epoch 002:   0%|                                        | 0/771 [00:00<?, ?it/s]2022-10-30 18:01:21 | INFO | fairseq.trainer | begin training epoch 2
# 2022-10-30 18:01:21 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 002:  11%|1| 88/771 [00:09<01:14,  9.18it/s, loss=7.776, nll_loss=6.692, pException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f074e799898>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 002: 100%|9| 770/771 [01:21<00:00,  9.26it/s, loss=6.833, nll_loss=5.615, 2022-10-30 18:02:42 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 18:02:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:02:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001345
# 2022-10-30 18:02:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:02:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.032709
# 2022-10-30 18:02:42 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:02:43 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.025698
# 2022-10-30 18:02:43 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.060295
# 2022-10-30 18:02:43 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 002 | valid on 'valid' subset:   0%|               | 0/22 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:   9%|6      | 2/22 [00:00<00:01, 18.52it/s]
# epoch 002 | valid on 'valid' subset:  27%|#9     | 6/22 [00:00<00:00, 21.28it/s]
# epoch 002 | valid on 'valid' subset:  45%|##7   | 10/22 [00:00<00:00, 23.78it/s]
# epoch 002 | valid on 'valid' subset:  64%|###8  | 14/22 [00:00<00:00, 26.03it/s]
# epoch 002 | valid on 'valid' subset:  82%|####9 | 18/22 [00:00<00:00, 27.82it/s]
#                                                                                 2022-10-30 18:02:43 | INFO | valid | epoch 002 | valid on 'valid' subset | loss 6.659 | nll_loss 5.335 | ppl 40.37 | wps 88694 | wpb 2623.5 | bsz 212.8 | num_updates 1540 | best_loss 6.659
# 2022-10-30 18:02:43 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 2 @ 1540 updates
# 2022-10-30 18:02:43 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint2.pt
# 2022-10-30 18:02:50 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint2.pt
# 2022-10-30 18:02:52 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en_ngu-en/checkpoint2.pt (epoch 2 @ 1540 updates, score 6.659) (writing took 8.950202050618827 seconds)
# 2022-10-30 18:02:52 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2022-10-30 18:02:52 | INFO | train | epoch 002 | loss 7.133 | nll_loss 5.958 | ppl 62.15 | wps 30261.5 | ups 8.43 | wpb 3587.8 | bsz 293.2 | num_updates 1540 | lr 0.0001925 | gnorm 1.676 | loss_scale 32 | train_wall 80 | gb_free 12.3 | wall 182
# 2022-10-30 18:02:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:02:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.047179
# 2022-10-30 18:02:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:02:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.002562
# 2022-10-30 18:02:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:02:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.005549
# 2022-10-30 18:02:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.056368
# 2022-10-30 18:02:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:02:52 | INFO | fairseq.data.iterators | grouped total_num_itrs = 771
# epoch 003:   0%|                                        | 0/771 [00:00<?, ?it/s]2022-10-30 18:02:52 | INFO | fairseq.trainer | begin training epoch 3
# 2022-10-30 18:02:52 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 003:  12%|1| 90/771 [00:09<01:13,  9.24it/s, loss=6.6, nll_loss=5.349, pplException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f074e799898>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0740e20da0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 003: 100%|9| 770/771 [01:21<00:00,  9.13it/s, loss=6.027, nll_loss=4.693, 2022-10-30 18:04:14 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 18:04:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:04:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.002420
# 2022-10-30 18:04:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:04:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.034590
# 2022-10-30 18:04:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:04:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.025978
# 2022-10-30 18:04:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.063539
# 2022-10-30 18:04:14 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 003 | valid on 'valid' subset:   0%|               | 0/22 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:  14%|9      | 3/22 [00:00<00:00, 23.10it/s]
# epoch 003 | valid on 'valid' subset:  27%|#9     | 6/22 [00:00<00:00, 24.52it/s]
# epoch 003 | valid on 'valid' subset:  45%|##7   | 10/22 [00:00<00:00, 26.56it/s]
# epoch 003 | valid on 'valid' subset:  64%|###8  | 14/22 [00:00<00:00, 28.32it/s]
# epoch 003 | valid on 'valid' subset:  82%|####9 | 18/22 [00:00<00:00, 29.66it/s]
#                                                                                 2022-10-30 18:04:15 | INFO | valid | epoch 003 | valid on 'valid' subset | loss 6.008 | nll_loss 4.571 | ppl 23.77 | wps 86911.3 | wpb 2623.5 | bsz 212.8 | num_updates 2311 | best_loss 6.008
# 2022-10-30 18:04:15 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 3 @ 2311 updates
# 2022-10-30 18:04:15 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint3.pt
# 2022-10-30 18:04:17 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint3.pt
# 2022-10-30 18:04:19 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en_ngu-en/checkpoint3.pt (epoch 3 @ 2311 updates, score 6.008) (writing took 3.9130673427134752 seconds)
# 2022-10-30 18:04:19 | INFO | fairseq_cli.train | end of epoch 3 (average epoch stats below)
# 2022-10-30 18:04:19 | INFO | train | epoch 003 | loss 6.234 | nll_loss 4.93 | ppl 30.47 | wps 31983.8 | ups 8.91 | wpb 3587.8 | bsz 293.2 | num_updates 2311 | lr 0.000288875 | gnorm 1.358 | loss_scale 32 | train_wall 80 | gb_free 12.2 | wall 269
# 2022-10-30 18:04:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:04:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.052822
# 2022-10-30 18:04:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:04:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.002127
# 2022-10-30 18:04:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:04:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.005499
# 2022-10-30 18:04:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.061278
# 2022-10-30 18:04:19 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:04:24 | INFO | fairseq.data.iterators | grouped total_num_itrs = 771
# epoch 004:   0%|                                        | 0/771 [00:00<?, ?it/s]2022-10-30 18:04:24 | INFO | fairseq.trainer | begin training epoch 4
# 2022-10-30 18:04:24 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 004:   8%|##4                            | 61/771 [00:06<01:16,  9.31it/s]Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f074e799898>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0740e20da0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0740a37dd8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 004: 100%|9| 769/771 [01:21<00:00,  9.57it/s, loss=5.216, nll_loss=3.761, 2022-10-30 18:05:45 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 18:05:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:05:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001334
# 2022-10-30 18:05:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:05:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.032451
# 2022-10-30 18:05:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:05:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.025234
# 2022-10-30 18:05:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.059482
# 2022-10-30 18:05:45 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 004 | valid on 'valid' subset:   0%|               | 0/22 [00:00<?, ?it/s]
# epoch 004 | valid on 'valid' subset:   9%|6      | 2/22 [00:00<00:01, 17.18it/s]
# epoch 004 | valid on 'valid' subset:  27%|#9     | 6/22 [00:00<00:00, 20.01it/s]
# epoch 004 | valid on 'valid' subset:  45%|##7   | 10/22 [00:00<00:00, 22.70it/s]
# epoch 004 | valid on 'valid' subset:  64%|###8  | 14/22 [00:00<00:00, 25.13it/s]
# epoch 004 | valid on 'valid' subset:  82%|####9 | 18/22 [00:00<00:00, 27.10it/s]
#                                                                                 2022-10-30 18:05:46 | INFO | valid | epoch 004 | valid on 'valid' subset | loss 5.32 | nll_loss 3.722 | ppl 13.2 | wps 88955.8 | wpb 2623.5 | bsz 212.8 | num_updates 3082 | best_loss 5.32
# 2022-10-30 18:05:46 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 4 @ 3082 updates
# 2022-10-30 18:05:46 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint4.pt
# 2022-10-30 18:05:48 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint4.pt
# 2022-10-30 18:05:50 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en_ngu-en/checkpoint4.pt (epoch 4 @ 3082 updates, score 5.32) (writing took 3.853461192920804 seconds)
# 2022-10-30 18:05:50 | INFO | fairseq_cli.train | end of epoch 4 (average epoch stats below)
# 2022-10-30 18:05:50 | INFO | train | epoch 004 | loss 5.519 | nll_loss 4.109 | ppl 17.25 | wps 30279.5 | ups 8.44 | wpb 3587.8 | bsz 293.2 | num_updates 3082 | lr 0.00038525 | gnorm 1.2 | loss_scale 32 | train_wall 80 | gb_free 12.2 | wall 360
# 2022-10-30 18:05:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:05:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.049754
# 2022-10-30 18:05:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:05:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.001792
# 2022-10-30 18:05:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:05:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.005611
# 2022-10-30 18:05:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.057956
# 2022-10-30 18:05:50 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:05:50 | INFO | fairseq.data.iterators | grouped total_num_itrs = 771
# epoch 005:   0%|                                        | 0/771 [00:00<?, ?it/s]2022-10-30 18:05:50 | INFO | fairseq.trainer | begin training epoch 5
# 2022-10-30 18:05:50 | INFO | fairseq_cli.train | Start iterating over samples
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0740a1e8d0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 005:   6%| | 49/771 [00:05<01:16,  9.45it/s, loss=5.045, nll_loss=3.567, pException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f074e799898>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0740e20da0>>
# Traceback (most recent call last):
# ...
# 2022-10-30 18:47:01 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 033:  31%|3| 238/771 [00:25<00:56,  9.45it/s, loss=2.78, nll_loss=0.981, pException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f074101ab00>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 033: 100%|9| 770/771 [01:21<00:00,  9.67it/s, loss=2.745, nll_loss=0.948, 2022-10-30 18:48:22 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 18:48:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:48:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.001396
# 2022-10-30 18:48:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:48:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.033845
# 2022-10-30 18:48:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:48:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.030904
# 2022-10-30 18:48:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.066778
# 2022-10-30 18:48:22 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 033 | valid on 'valid' subset:   0%|               | 0/22 [00:00<?, ?it/s]
# epoch 033 | valid on 'valid' subset:  14%|9      | 3/22 [00:00<00:00, 25.51it/s]
# epoch 033 | valid on 'valid' subset:  32%|##2    | 7/22 [00:00<00:00, 27.25it/s]
# epoch 033 | valid on 'valid' subset:  50%|###   | 11/22 [00:00<00:00, 28.87it/s]
# epoch 033 | valid on 'valid' subset:  68%|####  | 15/22 [00:00<00:00, 30.01it/s]
# epoch 033 | valid on 'valid' subset:  86%|#####1| 19/22 [00:00<00:00, 30.95it/s]
#                                                                                 2022-10-30 18:48:23 | INFO | valid | epoch 033 | valid on 'valid' subset | loss 3.747 | nll_loss 1.987 | ppl 3.97 | wps 88624.9 | wpb 2623.5 | bsz 212.8 | num_updates 25441 | best_loss 3.71
# 2022-10-30 18:48:23 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 33 @ 25441 updates
# 2022-10-30 18:48:23 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint33.pt
# 2022-10-30 18:48:25 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint33.pt
# 2022-10-30 18:48:26 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en_ngu-en/checkpoint33.pt (epoch 33 @ 25441 updates, score 3.747) (writing took 2.9660885706543922 seconds)
# 2022-10-30 18:48:26 | INFO | fairseq_cli.train | end of epoch 33 (average epoch stats below)
# 2022-10-30 18:48:26 | INFO | train | epoch 033 | loss 2.752 | nll_loss 0.951 | ppl 1.93 | wps 32415.8 | ups 9.03 | wpb 3587.8 | bsz 293.2 | num_updates 25441 | lr 0.000198259 | gnorm 0.902 | loss_scale 64 | train_wall 80 | gb_free 12.4 | wall 2916
# 2022-10-30 18:48:26 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:48:26 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.050489
# 2022-10-30 18:48:26 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:48:26 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.002041
# 2022-10-30 18:48:26 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:48:26 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.005914
# 2022-10-30 18:48:26 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.059269
# 2022-10-30 18:48:26 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:48:31 | INFO | fairseq.data.iterators | grouped total_num_itrs = 771
# epoch 034:   0%|                                        | 0/771 [00:00<?, ?it/s]2022-10-30 18:48:31 | INFO | fairseq.trainer | begin training epoch 34
# 2022-10-30 18:48:31 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 034:  31%|3| 242/771 [00:25<00:57,  9.28it/s, loss=2.693, nll_loss=0.88, pException ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f074101ab00>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0740ed30b8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 034: 100%|9| 770/771 [01:21<00:00,  9.47it/s, loss=2.824, nll_loss=1.033, 2022-10-30 18:49:52 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 18:49:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:49:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.004132
# 2022-10-30 18:49:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:49:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.034282
# 2022-10-30 18:49:52 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:49:53 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.026550
# 2022-10-30 18:49:53 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.065754
# 2022-10-30 18:49:53 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 034 | valid on 'valid' subset:   0%|               | 0/22 [00:00<?, ?it/s]
# epoch 034 | valid on 'valid' subset:  14%|9      | 3/22 [00:00<00:00, 24.36it/s]
# epoch 034 | valid on 'valid' subset:  32%|##2    | 7/22 [00:00<00:00, 26.32it/s]
# epoch 034 | valid on 'valid' subset:  50%|###   | 11/22 [00:00<00:00, 28.14it/s]
# epoch 034 | valid on 'valid' subset:  68%|####  | 15/22 [00:00<00:00, 29.54it/s]
# epoch 034 | valid on 'valid' subset:  86%|#####1| 19/22 [00:00<00:00, 30.53it/s]
#                                                                                 2022-10-30 18:49:53 | INFO | valid | epoch 034 | valid on 'valid' subset | loss 3.728 | nll_loss 1.97 | ppl 3.92 | wps 88919.1 | wpb 2623.5 | bsz 212.8 | num_updates 26212 | best_loss 3.71
# 2022-10-30 18:49:53 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 34 @ 26212 updates
# 2022-10-30 18:49:53 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint34.pt
# 2022-10-30 18:49:55 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint34.pt
# 2022-10-30 18:49:56 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en_ngu-en/checkpoint34.pt (epoch 34 @ 26212 updates, score 3.728) (writing took 3.186374762095511 seconds)
# 2022-10-30 18:49:56 | INFO | fairseq_cli.train | end of epoch 34 (average epoch stats below)
# 2022-10-30 18:49:56 | INFO | train | epoch 034 | loss 2.733 | nll_loss 0.93 | ppl 1.9 | wps 30591.4 | ups 8.53 | wpb 3587.8 | bsz 293.2 | num_updates 26212 | lr 0.000195321 | gnorm 0.893 | loss_scale 64 | train_wall 79 | gb_free 12.2 | wall 3006
# 2022-10-30 18:49:56 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:49:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler order indices time: 0:00:00.050367
# 2022-10-30 18:49:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:49:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler filter_by_size time: 0:00:00.002347
# 2022-10-30 18:49:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:49:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] @batch_sampler batch_by_size time: 0:00:00.006282
# 2022-10-30 18:49:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | [train] per epoch batch_sampler set-up time: 0:00:00.059912
# 2022-10-30 18:49:57 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:49:57 | INFO | fairseq.data.iterators | grouped total_num_itrs = 771
# epoch 035:   0%|                                        | 0/771 [00:00<?, ?it/s]2022-10-30 18:49:57 | INFO | fairseq.trainer | begin training epoch 35
# 2022-10-30 18:49:57 | INFO | fairseq_cli.train | Start iterating over samples
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0740f0b588>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 035:  32%|3| 243/771 [00:25<00:54,  9.74it/s, loss=2.667, nll_loss=0.854, Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f074101ab00>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0740ed30b8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f0740f42e48>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 134, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch 035: 100%|9| 770/771 [01:21<00:00,  9.29it/s, loss=2.766, nll_loss=0.967, 2022-10-30 18:51:18 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2022-10-30 18:51:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | start batch sampler: mem usage: N/A
# 2022-10-30 18:51:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler order indices time: 0:00:00.003335
# 2022-10-30 18:51:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:51:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler filter_by_size time: 0:00:00.033572
# 2022-10-30 18:51:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
# 2022-10-30 18:51:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] @batch_sampler batch_by_size time: 0:00:00.025892
# 2022-10-30 18:51:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | [valid] per epoch batch_sampler set-up time: 0:00:00.063523
# 2022-10-30 18:51:18 | INFO | fairseq.tasks.translation_multi_simple_epoch | mem usage: N/A
#
# epoch 035 | valid on 'valid' subset:   0%|               | 0/22 [00:00<?, ?it/s]
# epoch 035 | valid on 'valid' subset:  14%|9      | 3/22 [00:00<00:00, 24.03it/s]
# epoch 035 | valid on 'valid' subset:  32%|##2    | 7/22 [00:00<00:00, 26.12it/s]
# epoch 035 | valid on 'valid' subset:  50%|###   | 11/22 [00:00<00:00, 28.00it/s]
# epoch 035 | valid on 'valid' subset:  68%|####  | 15/22 [00:00<00:00, 29.26it/s]
# epoch 035 | valid on 'valid' subset:  86%|#####1| 19/22 [00:00<00:00, 30.18it/s]
#                                                                                 2022-10-30 18:51:19 | INFO | valid | epoch 035 | valid on 'valid' subset | loss 3.736 | nll_loss 1.979 | ppl 3.94 | wps 87961.1 | wpb 2623.5 | bsz 212.8 | num_updates 26983 | best_loss 3.71
# 2022-10-30 18:51:19 | INFO | fairseq_cli.train | early stop since valid performance hasn't improved for last 10 runs
# 2022-10-30 18:51:19 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 35 @ 26983 updates
# 2022-10-30 18:51:19 | INFO | fairseq.trainer | Saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint35.pt
# 2022-10-30 18:51:21 | INFO | fairseq.trainer | Finished saving checkpoint to /storage/master-thesis/models/es-en_ngu-en/checkpoint35.pt
# 2022-10-30 18:51:22 | INFO | fairseq.checkpoint_utils | Saved checkpoint /storage/master-thesis/models/es-en_ngu-en/checkpoint35.pt (epoch 35 @ 26983 updates, score 3.736) (writing took 3.2202824410051107 seconds)
# 2022-10-30 18:51:22 | INFO | fairseq_cli.train | end of epoch 35 (average epoch stats below)
# 2022-10-30 18:51:22 | INFO | train | epoch 035 | loss 2.716 | nll_loss 0.911 | ppl 1.88 | wps 32291.8 | ups 9 | wpb 3587.8 | bsz 293.2 | num_updates 26983 | lr 0.000192511 | gnorm 0.904 | loss_scale 64 | train_wall 80 | gb_free 12.1 | wall 3092
# 2022-10-30 18:51:22 | INFO | fairseq_cli.train | done training in 3091.9 seconds

# %%
! echo $MODEL_DIR
# Out:
# /storage/master-thesis/models/quy-es+es-en

# %%
! rm dict.en.txt
! rm dict.es.txt
! rm dict.ngu.txt

# %%
! du -shc /notebooks/*
# Out:
# 2.5K	/notebooks/CITATION.cff
# 5.5K	/notebooks/CODE_OF_CONDUCT.md
# 15K	/notebooks/CONTRIBUTING.md
# 19K	/notebooks/ISSUES.md
# 12K	/notebooks/LICENSE
# 512	/notebooks/MANIFEST.in
# 3.5K	/notebooks/Makefile
# 41K	/notebooks/README.md
# 41K	/notebooks/README_zh-hans.md
# 42K	/notebooks/README_zh-hant.md
# 12K	/notebooks/docker
# 4.6M	/notebooks/docs
# 5.0M	/notebooks/examples
# 8.5K	/notebooks/hubconf.py
# 7.8G	/notebooks/master-thesis
# 1.5K	/notebooks/model_cards
# 9.5K	/notebooks/notebooks
# 512	/notebooks/pyproject.toml
# 64K	/notebooks/scripts
# 1.0K	/notebooks/setup.cfg
# 13K	/notebooks/setup.py
# 13M	/notebooks/src
# 731K	/notebooks/templates
# 4.5K	/notebooks/test quy-es -> es-en model.ipynb
# 6.8M	/notebooks/tests
# 147K	/notebooks/train es-en model.ipynb
# 158K	/notebooks/train quy-es + es-en model.ipynb
# 160K	/notebooks/utils
# 3.5K	/notebooks/valohai.yaml
# 7.9G	total

# %%
! du -shc /notebooks/master-thesis/*
# Out:
# 512	/notebooks/master-thesis/Untitled.ipynb
# 362M	/notebooks/master-thesis/corpora
# 7.5G	/notebooks/master-thesis/models
# 7.8G	total

# %%
! du -shc /notebooks/master-thesis/models/*
# Out:
# 1.6G	/notebooks/master-thesis/models/es-en
# 802M	/notebooks/master-thesis/models/quy-es
# 5.2G	/notebooks/master-thesis/models/quy-es+es-en
# 7.5G	total

# %%
! du -shc /*
# Out:
# 19M	/apex
# 5.0M	/bin
# 4.0K	/boot
# 24K	/content
# ^C

# %%
ls
# Out:
#  CITATION.cff         docker/          setup.py
#  CODE_OF_CONDUCT.md   docs/            src/
#  CONTRIBUTING.md      examples/        templates/
#  ISSUES.md            hubconf.py      'test quy-es -> es-en model.ipynb'
#  LICENSE              master-thesis/   tests/
#  MANIFEST.in          model_cards/    'train es-en model.ipynb'
#  Makefile             notebooks/      'train quy-es + es-en model.ipynb'
#  README.md            pyproject.toml   utils/
#  README_zh-hans.md    scripts/         valohai.yaml
#  README_zh-hant.md    setup.cfg

# %%
# Out:
# /storage/master-thesis
